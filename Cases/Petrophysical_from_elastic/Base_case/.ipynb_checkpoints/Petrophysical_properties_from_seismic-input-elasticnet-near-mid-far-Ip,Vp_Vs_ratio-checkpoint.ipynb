# %% [markdown]
# ## Petrophysical properties inversion from seismic data

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import numpy as np
from random import randint
from wiggle.wiggle import wiggle
from matplotlib.pyplot import figure
import math
import tensorflow as tf

# %%
# Checking the devices available for use in AWS
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2431723457705589125
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 969948155275306973
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9363687103343266882
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11326753997
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 935018806922277779
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7"
# ]

# %%
# Loading the Vp, Vs and Density data

dataframe = sio.loadmat('../../../Data_generation_base_case/Train_DataSyn1_time_clip.mat')
Vp = dataframe['VpMat']
Vp = np.reshape(Vp, (Vp.shape[0]*Vp.shape[1], Vp.shape[2]))
Vs = dataframe['VsMat']
Vs = np.reshape(Vs, (Vs.shape[0]*Vs.shape[1], Vs.shape[2]))
RHOB = dataframe['RHOBMat']
RHOB = np.reshape(RHOB, (RHOB.shape[0]*RHOB.shape[1], RHOB.shape[2]))

depth = dataframe['depthVec']

# Loading facies, porosity, vclay and water saturation data 
dataframe_facies = sio.loadmat('../../../Data_generation_base_case/Train_FaciesMat.mat')
facies = dataframe_facies['zFaciesMat']
facies = np.reshape(facies, (facies.shape[0]*facies.shape[1], facies.shape[2]))

dataframe_porosity = sio.loadmat('../../../Data_generation_base_case/Train_PhiMat.mat')
porosity = dataframe_porosity['zPhiMat']
porosity = np.reshape(porosity, (porosity.shape[0]*porosity.shape[1], porosity.shape[2]))

dataframe_vclay = sio.loadmat('../../../Data_generation_base_case/Train_ClayMat.mat')
vclay = dataframe_vclay['zClayMat']
vclay = np.reshape(vclay, (vclay.shape[0]*vclay.shape[1], vclay.shape[2]))

dataframe_Sw = sio.loadmat('../../../Data_generation_base_case/Train_SwMat.mat')
Sw = dataframe_Sw['zSwMat']
Sw = np.reshape(Sw, (Sw.shape[0]*Sw.shape[1], Sw.shape[2]))

# %%
# Plot of loaded data

sample_number = 12
f, axarr = plt.subplots(1, 8, sharey = True, figsize=(10,6))

axarr[0].plot(facies[sample_number, :], depth)
axarr[0].set_xlabel("Facies")
axarr[0].set_ylabel("Depth")

axarr[1].plot(porosity[sample_number, :], depth)
axarr[1].set_xlabel("Porosity")
axarr[1].set_xlim(0,0.4)

axarr[2].plot(vclay[sample_number, :], depth)
axarr[2].set_xlabel("Vclay")
axarr[2].set_xlim(0,1)

axarr[3].plot(Sw[sample_number, :], depth)
axarr[3].set_xlabel("Sw")
axarr[3].set_xlim(0,1)

axarr[4].plot(Vp[sample_number, :], depth)
axarr[4].set_xlabel("Vp")
# plt.xlim(0,1)

axarr[5].plot(Vs[sample_number, :], depth)
axarr[5].set_xlabel("Vs")
# plt.xlim(0,1)

axarr[6].plot(RHOB[sample_number, :], depth)
axarr[6].set_xlabel("RHOB")
# plt.xlim(0,1)

axarr[7].plot(Vp[sample_number, :]*RHOB[sample_number, :], depth)
axarr[7].set_xlabel("Ip")
# Out:
# Text(0.5,0,'Ip')

# %%
sample_number = 12
f, axarr = plt.subplots(1, 6, sharey = True, figsize=(10,6))

axarr[0].plot(facies[sample_number, :], depth)
axarr[0].set_xlabel("Facies")
axarr[0].set_ylabel("Depth")

axarr[1].plot(porosity[sample_number, :], depth)
axarr[1].set_xlabel("Porosity")
axarr[1].set_xlim(0,0.4)

axarr[2].plot(vclay[sample_number, :], depth)
axarr[2].set_xlabel("Vclay")
axarr[2].set_xlim(0,1)

axarr[3].plot(Sw[sample_number, :], depth)
axarr[3].set_xlabel("Sw")
axarr[3].set_xlim(0,1)

axarr[4].plot(Vp[sample_number, :]*RHOB[sample_number, :], depth)
axarr[4].set_xlabel("Ip")

axarr[5].plot(Vp[sample_number, :]/Vs[sample_number, :], depth)
axarr[5].set_xlabel("Vp/Vs")
# Out:
# Text(0.5,0,'Vp/Vs')

# %%
# AVO and source parameters 
src_len=np.int(60)
freq=40
dt=7e-4
# ntheta=46
thetaStart=0
thetaEnd=30
thetaInc=5
theta=np.arange(thetaStart,thetaEnd+thetaInc,thetaInc)
ntheta=theta.size
# nt=201
# ncdp=1111
angle=np.reshape(theta,[1,ntheta])
# theta=np.arange(0,ntheta,1)
print('angle:', angle.shape)
print('angle:', angle)
# Out:
# angle: (1, 7)
# angle: [[ 0  5 10 15 20 25 30]]

# %%
# Generate the seismic wavelet
def ricker(f,n,dt,t0):

    T = dt*(np.floor(n/2));
    t = np.linspace(-T,T,n)
    tau = t-t0;
    pi=np.pi
    s = (1-tau*tau*f**2*pi**2)*np.exp(-tau**2*pi**2*f**2);
    rw = s;

    return rw,t
src,tsrc=ricker(freq,src_len,dt,0)
plt.plot(tsrc,src, '-ok')
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Source Wavelet")
plt.show()

# %%
# Full Zoeppritz using tensorflow

def gather(input1,tftheta,tfsrc):
    print('input1:',input1)
    vp = tf.expand_dims(input1[:,:,0],2)
    vs = tf.expand_dims(input1[:,:,1],2)
    rho = tf.expand_dims(input1[:,:,2],2)
    vp=tf.check_numerics(vp,"Nan at vp start")
    vs=tf.check_numerics(vs,"Nan at vp start")
    rho=tf.check_numerics(rho,"Nan at vp start")
    

    nref= tf.shape(input1)[1]#vp.get_shape()[1]#.as_list()[1]
    bs=tf.shape(input1)[0]
    ntheta=tf.shape(tftheta)[1]
    #nt=tf.shape(input1)[1]
    
    tfzero=tf.zeros([bs,1,ntheta], dtype=tf.float32)
    
    tfangle = tf.expand_dims(tf.convert_to_tensor(tftheta, 
                                                  dtype=tf.float32),0)
    tfangle=tf.tile(tfangle,[bs,nref-1,1])

  
    vp1=tf.tile(vp[:,0:nref-1],[1, 1, ntheta])
    vs1=tf.tile(vs[:,0:nref-1],[1, 1, ntheta])
    d1=tf.tile(rho[:,0:nref-1],[1, 1, ntheta])

    vp2=tf.tile(vp[:,1:nref],[1, 1, ntheta])
    vs2=tf.tile(vs[:,1:nref],[1, 1, ntheta])
    d2=tf.tile(rho[:,1:nref],[1, 1, ntheta])
    
    
    vpj1=tf.complex(vp1,tf.zeros_like(vp1))
    vsj1=tf.complex(vs1,tf.zeros_like(vs1))
    dj1=tf.complex(d1,tf.zeros_like(d1))

    vpj2=tf.complex(vp2,tf.zeros_like(vp2))
    vsj2=tf.complex(vs2,tf.zeros_like(vs2))
    dj2=tf.complex(d2,tf.zeros_like(d2))
    
    
    t=tf.scalar_mul(np.pi/180,tfangle)    
    p=tf.divide(tf.sin(t),vp1)
    ct=tf.cos(t)
    
    sint=tf.complex(tf.sin(t),tf.zeros_like(t))
    
    # FULL ZOEPPRITZ
    ct2=tf.real(tf.sqrt(np.subtract(1+0j,tf.multiply(tf.square(sint)
                , tf.divide(tf.square(vpj2),tf.square(vpj1))))))
    
    cj1=tf.real(tf.sqrt(np.subtract(1+0j,tf.multiply(tf.square(sint)
                , tf.divide(tf.square(vsj1),tf.square(vpj1))))))
    
    cj2=tf.real(tf.sqrt(np.subtract(1+0j,tf.multiply(tf.square(sint)
                , tf.divide(tf.square(vsj2),tf.square(vpj1))))))
    
    a=tf.subtract(
            tf.multiply(d2, tf.subtract(1.0, tf.scalar_mul(2.0,tf.multiply(tf.square(vs2), tf.square(p))))),
            tf.multiply(d1, tf.subtract(1.0, tf.scalar_mul(2.0,tf.multiply(tf.square(vs1), tf.square(p)))))
            )
    
    b=tf.add(
            tf.multiply(d2, tf.subtract(1.0, tf.scalar_mul(2.0,tf.multiply(tf.square(vs2), tf.square(p))))),
            tf.multiply(d1,tf.scalar_mul(2.0,tf.multiply(tf.square(vs1), tf.square(p))))
            )
    c=tf.add(
            tf.multiply(d1, tf.subtract(1.0, tf.scalar_mul(2.0,tf.multiply(tf.square(vs1), tf.square(p))))),
            tf.multiply(d2,tf.scalar_mul(2.0,tf.multiply(tf.square(vs2), tf.square(p))))
            )
    
    d=tf.scalar_mul(2.0, 
            tf.subtract(
                    tf.multiply(d2,tf.square(vs2)),
                    tf.multiply(d1,tf.square(vs1)))
            )
            
    E=tf.add(
            tf.multiply(b,tf.divide(ct,vp1)),
            tf.multiply(c,tf.divide(ct2,vp2))
            )
    F=tf.add(
            tf.multiply(b,tf.divide(cj1,vs1)),
            tf.multiply(c,tf.divide(cj2,vs2))
            )
    G=tf.subtract(a,
                  tf.divide(
                          tf.multiply(d,tf.multiply(ct,cj2)),
                          tf.multiply(vp1,vs2))
                  )
    H=tf.subtract(a,
                  tf.divide(
                          tf.multiply(d,tf.multiply(ct2,cj1)),
                          tf.multiply(vp2,vs1))
                  )
    D=tf.add(
            tf.multiply(E,F),
            tf.multiply(G,tf.multiply(H,tf.square(p)))
            )
    
    Rpp=tf.real(tf.divide(tf.subtract(
            tf.multiply(tf.subtract( tf.multiply(b,tf.divide(ct,vp1)), tf.multiply(c,tf.divide(ct2,vp2))),F),
            tf.multiply( tf.add(a, tf.multiply(d,tf.multiply(ct,tf.divide(cj2,tf.multiply(vp1,vs2))))) ,tf.multiply(H,tf.square(p)))            
            ),D))
    #print('Rpp1:',Rpp)
    Rpp=tf.concat([Rpp,tfzero],1)
    #print('Rpp2:',Rpp)
    # Rpp1=tf.zeros()
    Rpp1=tf.expand_dims(Rpp,axis=3)
    #Rpp1=tf.where(tf.is_nan(Rpp1), tf.zeros_like(Rpp1), Rpp1)
    #print('Rpp11:',Rpp1)
    #print('tfsrc:',tfsrc)
    seis=tf.transpose(tf.nn.conv2d(Rpp1,tfsrc,strides=[1,1,1,1],padding='SAME'),perm=[0,2,1,3])
    #print("seis:",seis)
    seis=tf.reshape(seis,[-1,nt*ntheta])
    #seis=tf.Print(seis,[tf.shape(seis)])

    #print('seis:',seis)
    
    return seis,Rpp

# %%
# Convert Vp, Vs and Density logs from depth to time 
time = np.zeros((Vp.shape[0], Vp.shape[1]+1))

for i in range(time.shape[0]):
    depth_diff = np.mean(np.diff(depth.T))
    time[i,0] = 0
    time[i,1:] = 2*np.cumsum(depth_diff/(Vp[i,:]*1e3))

time = time[:,0:-1]
# Interpolate the time values such that all logs have the same dt_log
end_time = (np.max(time))
time_upscaled = np.arange(0, end_time, dt)

Vp_time = np.zeros((Vp.shape[0], time_upscaled.shape[0]))
Vs_time = np.zeros((Vs.shape[0], time_upscaled.shape[0]))
RHOB_time = np.zeros((RHOB.shape[0], time_upscaled.shape[0]))
for i in range(time.shape[0]):
    Vp_time[i,:] = np.interp(time_upscaled, time[i,:], Vp[i,:])
    Vs_time[i,:] = np.interp(time_upscaled, time[i,:], Vs[i,:])
    RHOB_time[i,:] = np.interp(time_upscaled, time[i,:], RHOB[i,:])
    
nt = time_upscaled.shape[0]

# %%
sample_number = 10
plt.subplot(1,2,1)
plt.plot(Vp_time[sample_number,:], time_upscaled)
plt.subplot(1,2,2)
plt.plot(Vp[sample_number,:], depth)

# %%
# Forward modeling results (Seismic gathers) (DONOT RUN IF NEW DATA IS NOT GENERATED)

# Test the forward modeling
bs=Vp_time.shape[0]
input11=np.zeros([bs,nt,3],dtype=np.float32)

input11[0:bs,:,0]=Vp_time[0:bs,:]
input11[0:bs,:,1]=Vs_time[0:bs,:]
input11[0:bs,:,2]=RHOB_time[0:bs,:]
# plt.plot(np.squeeze(input11))
# plt.show()

input111=tf.convert_to_tensor(input11,dtype=tf.float32)
# print("src:",src.shape)


tfsrc=tf.reshape(tf.constant(src,dtype=tf.float32),[src_len,1,1,1])


# print('tfsrc:',tfsrc)
# print('angle:',angle.shape)
tftheta=tf.convert_to_tensor(angle,dtype=tf.float32)
# print('tftheta:',tftheta)
seisgen=gather(input111,tftheta,tfsrc)


sess=tf.Session()
seis11,Rpp11=sess.run(seisgen)

sess.close()

seis=np.transpose(np.reshape(seis11,[-1,ntheta,nt]),[0,2,1])
Rpp=Rpp11#np.reshape(Rpp11,[bs,nt,ntheta])

sample_number = 20
wiggle(np.squeeze(seis[sample_number,:,:]),time_upscaled,theta)
plt.title("Seismogram")
plt.xlabel("$\\theta$")
plt.ylabel("Time (s)")
plt.show()

impedance_time = Vp_time * RHOB_time
impedance_time_sample = impedance_time[sample_number,:]
plt.subplot(1,3,1)
plt.plot((impedance_time_sample - np.min(impedance_time_sample))/(np.max(impedance_time_sample)-np.min(impedance_time_sample)), time_upscaled)
plt.gca().invert_yaxis()
plt.subplot(1,3,2)
seis_sample = np.squeeze(seis[sample_number,:,0])
plt.plot((seis_sample - np.min(seis_sample))/(np.max(seis_sample) - np.min(seis_sample)), time_upscaled)
plt.gca().invert_yaxis()
plt.subplot(1,3,3)
plt.plot(np.squeeze(Rpp[sample_number,:,0]), time_upscaled)
plt.gca().invert_yaxis()
# Out:
# input1: Tensor("Const:0", shape=(2500, 246, 3), dtype=float32)

# %%
# Exporting generated seismic data
np.save('../../../Data_generation_base_case/seismic_forward_modeled.npy', seis)
np.save('../../../Data_generation_base_case/Rpp_forward_modeled.npy', Rpp)

# %%
# Load forward modeled seismic data and Rpp
seis = np.load('../../../Data_generation_base_case/seismic_forward_modeled.npy')
Rpp = np.load('../../../Data_generation_base_case/Rpp_forward_modeled.npy')

sample_number = 12
wiggle(np.squeeze(seis[sample_number,:,:]),time_upscaled,theta)
plt.title("Seismogram")
plt.xlabel("$\\theta$")
plt.ylabel("Time (s)")
plt.show()

impedance_time = Vp_time * RHOB_time
impedance_time_sample = impedance_time[sample_number,:]
plt.subplot(1,3,1)
plt.plot((impedance_time_sample - np.min(impedance_time_sample))/(np.max(impedance_time_sample)-np.min(impedance_time_sample)), time_upscaled)
plt.gca().invert_yaxis()
plt.subplot(1,3,2)
seis_sample = np.squeeze(seis[sample_number,:,0])
plt.plot((seis_sample - np.min(seis_sample))/(np.max(seis_sample) - np.min(seis_sample)), time_upscaled)
plt.gca().invert_yaxis()
plt.subplot(1,3,3)
plt.plot(np.squeeze(Rpp[sample_number,:,0]), time_upscaled)
plt.gca().invert_yaxis()

# %%
# Import keras modules for CNN

from keras import layers, initializers, optimizers
from keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling1D, MaxPooling2D, Dropout, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers import LeakyReLU, Reshape
from keras.models import Model, model_from_json, load_model
from keras.preprocessing import image
from keras.utils import layer_utils, normalize
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.utils import np_utils
from keras.callbacks import EarlyStopping, ModelCheckpoint
# from kt_utils import *

import keras.backend as K
K.set_image_data_format('channels_last')

import sklearn.model_selection
import pydot
# Out:
# Using TensorFlow backend.

# %%
# Getting the input data (normalized) and output data 

# Reshape seismic gathers into (number of examples, angle, time) and normalize such that seismic traces have positive values
seis_reshaped = np.swapaxes(seis,1,2)
seis_reshaped_normalized = (seis_reshaped - np.min(seis_reshaped))/(np.max(seis_reshaped)-np.min(seis_reshaped))

# Selecting near(0 degree), mid (15 degree) and far (30 degree) angle traces from the full seismic gathers
row_idx = np.array([0, 3, 6])
angle_seis_reshaped_normalized = seis_reshaped_normalized[:,row_idx,:]

# Output as Ip, Vp_Vs ratio
num_examples = Vp_time.shape[0]

# # Normalize Vp, Vs and Density
# Vp_time_norm = (Vp_time - np.min(Vp_time))/(np.max(Vp_time) - np.min(Vp_time))
# Vs_time_norm = (Vs_time - np.min(Vs_time))/(np.max(Vs_time) - np.min(Vs_time))
# RHOB_time_norm = (RHOB_time - np.min(RHOB_time))/(np.max(RHOB_time) - np.min(RHOB_time))

emodel = np.concatenate((Vp_time*RHOB_time,Vp_time/Vs_time), axis=1)
# emodel = np.concatenate((Vp_time_norm,Vs_time_norm,RHOB_time_norm), axis=1)
emodel = emodel.reshape((num_examples, 2, nt))


# Split data into train and test set - elastic model
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(angle_seis_reshaped_normalized, 
                                                                            emodel, test_size=0.2, random_state=1)
# X_train, X_test, Y_train_norm, Y_test_norm = sklearn.model_selection.train_test_split(angle_seis_reshaped_normalized, 
#                                                                             emodel, test_size=0.2, random_state=1)


# Add 4th dimension of number of channels=1 to the input data
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)


print ("number of training examples = " + str(X_train.shape[0]))
# print ("number of validation examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
# print ("Y_train shape: " + str(Y_train_norm.shape))
# print ("X_val shape: " + str(X_val.shape))
# print ("Y_val shape: " + str(Y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# print ("Y_test shape: " + str(Y_test_norm.shape))
# Out:
# number of training examples = 2000
# number of test examples = 500
# X_train shape: (2000, 3, 246, 1)
# Y_train shape: (2000, 2, 246)
# X_test shape: (500, 3, 246, 1)
# Y_test shape: (500, 2, 246)

# %%
sample_number = 10

plt.subplot(1,2,1)
plt.plot(Y_train[sample_number, 0, :], time_upscaled)

plt.subplot(1,2,2)
plt.plot(Y_train[sample_number, 0, :], time_upscaled)

# %%
seis_reshaped_normalized = (seis_reshaped - np.min(seis_reshaped))/(np.max(seis_reshaped)-np.min(seis_reshaped))

plt.subplot(1,2,1)
plt.plot(np.squeeze(seis_reshaped[2,1,:]),time_upscaled)
plt.subplot(1,2,2)
plt.plot(np.squeeze(seis_reshaped_normalized[2,1,:]),time_upscaled)

# %%
# Building neural network for elastic properties prediction in Keras 
given_seed = 3 # For repeatibility

def elasticnet(input_shape):
    """
    Implementation of the AVONet.
    
    Arguments:
    input_shape -- shape of the images of the dataset

    Returns:
    model -- a Model() instance in Keras
    """
    

    # Define the input placeholder as a tensor with shape input_shape. Input = input angle gather 
    X_input = Input(input_shape)

    X = X_input

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(60, (1, 60), strides=(1, 1), name='conv0', padding='same',
               kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn0')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv0')(X)
    # MAXPOOL
#     X = MaxPooling2D((2, 2), strides=(1,1),name='max_pool0')(X)
    
    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(1, (1, 60), strides=(1, 1), name='conv1', padding='same',
               kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn1')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv1')(X)
    # MAXPOOL
#     X = MaxPooling2D((2, 2), strides=(1,1),name='max_pool1')(X)
      

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
#     X = Dense(200, name='fc0',
#              kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
#     X = Activation('relu')(X)
    X = Dense(246*2, name='fc1',
             kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = Activation('relu')(X)
    X = Reshape((2, 246))(X)
    
    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs=X_input, outputs=X, name='ElasticModel')

    return model
    ### END CODE HERE ###

# %%
# Create the model
ElasticModel = elasticnet(X_train.shape[1:])
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# Summary and plot of the model

ElasticModel.summary()


# plot_model(AVOModel)
# SVG(model_to_dot(ElasticModel).create(prog='dot', format='svg'))
# plot_model(ElasticModel, to_file='./Figures/model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3, 246, 1)         0
# _________________________________________________________________
# conv0 (Conv2D)               (None, 3, 246, 60)        3660
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 3, 246, 60)        240
# _________________________________________________________________
# activation_1 (Activation)    (None, 3, 246, 60)        0
# _________________________________________________________________
# drop_conv0 (Dropout)         (None, 3, 246, 60)        0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 3, 246, 1)         3601
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 3, 246, 1)         4
# _________________________________________________________________
# activation_2 (Activation)    (None, 3, 246, 1)         0
# _________________________________________________________________
# drop_conv1 (Dropout)         (None, 3, 246, 1)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 738)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 492)               363588
# _________________________________________________________________
# activation_3 (Activation)    (None, 492)               0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 2, 246)            0
# =================================================================
# Total params: 371,093
# Trainable params: 370,971
# Non-trainable params: 122
# _________________________________________________________________

# %%
# Learning rate scheduler
from keras.callbacks import LearningRateScheduler
# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.01
    drop = 0.5
    epochs_drop = 500.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

# %%
# Compile the model with optimization algorithm, loss function
adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

ElasticModel.compile(loss='mean_squared_error', optimizer = adam)

# %%
# Removing previous best_model.h5 file
import os
os.remove("best_model_elastic.h5")

# %%
# Using early stopping and Model Checkpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=250)
mc = ModelCheckpoint('best_model_elastic.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
# Start the training
# Using learning rate scheduler
# lrate = LearningRateScheduler(step_decay)
# callbacks_list = [es, mc, lrate]
# history = ElasticModel.fit(X_train, Y_train, validation_split=0.2, 
#                            epochs=1500, batch_size=32, callbacks=callbacks_list, verbose=0)

history = ElasticModel.fit(X_train, Y_train, validation_split=0.2, 
                           epochs=1500, batch_size=32, callbacks=[es, mc],
                          verbose = 0)
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# Epoch 00001: val_loss improved from inf to 0.52481, saving model to best_model_elastic.h5
#
# Epoch 00002: val_loss did not improve from 0.52481
#
# Epoch 00003: val_loss improved from 0.52481 to 0.46205, saving model to best_model_elastic.h5
#
# Epoch 00004: val_loss did not improve from 0.46205
#
# Epoch 00005: val_loss improved from 0.46205 to 0.34944, saving model to best_model_elastic.h5
#
# Epoch 00006: val_loss did not improve from 0.34944
#
# Epoch 00007: val_loss did not improve from 0.34944
#
# Epoch 00008: val_loss did not improve from 0.34944
#
# Epoch 00009: val_loss did not improve from 0.34944
#
# Epoch 00010: val_loss did not improve from 0.34944
#
# Epoch 00011: val_loss did not improve from 0.34944
#
# Epoch 00012: val_loss did not improve from 0.34944
#
# Epoch 00013: val_loss did not improve from 0.34944
#
# Epoch 00014: val_loss did not improve from 0.34944
#
# Epoch 00015: val_loss improved from 0.34944 to 0.33470, saving model to best_model_elastic.h5
#
# Epoch 00016: val_loss did not improve from 0.33470
#
# Epoch 00017: val_loss improved from 0.33470 to 0.29617, saving model to best_model_elastic.h5
#
# Epoch 00018: val_loss improved from 0.29617 to 0.27622, saving model to best_model_elastic.h5
#
# Epoch 00019: val_loss did not improve from 0.27622
#
# Epoch 00020: val_loss did not improve from 0.27622
#
# Epoch 00021: val_loss improved from 0.27622 to 0.26234, saving model to best_model_elastic.h5
#
# Epoch 00022: val_loss improved from 0.26234 to 0.24662, saving model to best_model_elastic.h5
#
# Epoch 00023: val_loss did not improve from 0.24662
#
# Epoch 00024: val_loss did not improve from 0.24662
#
# Epoch 00025: val_loss did not improve from 0.24662
#
# Epoch 00026: val_loss did not improve from 0.24662
#
# Epoch 00027: val_loss improved from 0.24662 to 0.23553, saving model to best_model_elastic.h5
#
# Epoch 00028: val_loss did not improve from 0.23553
#
# Epoch 00029: val_loss did not improve from 0.23553
#
# Epoch 00030: val_loss did not improve from 0.23553
#
# Epoch 00031: val_loss did not improve from 0.23553
#
# Epoch 00032: val_loss did not improve from 0.23553
#
# Epoch 00033: val_loss did not improve from 0.23553
#
# Epoch 00034: val_loss did not improve from 0.23553
#
# Epoch 00035: val_loss did not improve from 0.23553
#
# Epoch 00036: val_loss improved from 0.23553 to 0.22400, saving model to best_model_elastic.h5
#
# Epoch 00037: val_loss did not improve from 0.22400
#
# Epoch 00038: val_loss did not improve from 0.22400
#
# Epoch 00039: val_loss did not improve from 0.22400
#
# Epoch 00040: val_loss did not improve from 0.22400
#
# Epoch 00041: val_loss did not improve from 0.22400
#
# Epoch 00042: val_loss did not improve from 0.22400
#
# Epoch 00043: val_loss did not improve from 0.22400
#
# Epoch 00044: val_loss did not improve from 0.22400
#
# Epoch 00045: val_loss did not improve from 0.22400
#
# Epoch 00046: val_loss did not improve from 0.22400
#
# Epoch 00047: val_loss did not improve from 0.22400
#
# Epoch 00048: val_loss did not improve from 0.22400
#
# Epoch 00049: val_loss improved from 0.22400 to 0.21930, saving model to best_model_elastic.h5
#
# Epoch 00050: val_loss did not improve from 0.21930
#
# Epoch 00051: val_loss did not improve from 0.21930
#
# Epoch 00052: val_loss did not improve from 0.21930
#
# Epoch 00053: val_loss did not improve from 0.21930
#
# Epoch 00054: val_loss did not improve from 0.21930
#
# Epoch 00055: val_loss did not improve from 0.21930
#
# Epoch 00056: val_loss did not improve from 0.21930
#
# Epoch 00057: val_loss did not improve from 0.21930
#
# Epoch 00058: val_loss did not improve from 0.21930
#
# Epoch 00059: val_loss did not improve from 0.21930
#
# Epoch 00060: val_loss improved from 0.21930 to 0.21582, saving model to best_model_elastic.h5
#
# Epoch 00061: val_loss did not improve from 0.21582
#
# Epoch 00062: val_loss did not improve from 0.21582
#
# Epoch 00063: val_loss did not improve from 0.21582
#
# Epoch 00064: val_loss did not improve from 0.21582
#
# Epoch 00065: val_loss did not improve from 0.21582
#
# Epoch 00066: val_loss did not improve from 0.21582
#
# Epoch 00067: val_loss did not improve from 0.21582
#
# Epoch 00068: val_loss did not improve from 0.21582
#
# Epoch 00069: val_loss did not improve from 0.21582
#
# Epoch 00070: val_loss did not improve from 0.21582
#
# Epoch 00071: val_loss improved from 0.21582 to 0.21137, saving model to best_model_elastic.h5
#
# Epoch 00072: val_loss did not improve from 0.21137
#
# Epoch 00073: val_loss did not improve from 0.21137
#
# Epoch 00074: val_loss improved from 0.21137 to 0.20971, saving model to best_model_elastic.h5
#
# Epoch 00075: val_loss did not improve from 0.20971
#
# Epoch 00076: val_loss did not improve from 0.20971
#
# Epoch 00077: val_loss did not improve from 0.20971
#
# Epoch 00078: val_loss did not improve from 0.20971
#
# Epoch 00079: val_loss did not improve from 0.20971
#
# Epoch 00080: val_loss did not improve from 0.20971
#
# Epoch 00081: val_loss did not improve from 0.20971
#
# Epoch 00082: val_loss did not improve from 0.20971
#
# Epoch 00083: val_loss did not improve from 0.20971
#
# Epoch 00084: val_loss did not improve from 0.20971
#
# Epoch 00085: val_loss did not improve from 0.20971
#
# Epoch 00086: val_loss did not improve from 0.20971
#
# Epoch 00087: val_loss did not improve from 0.20971
#
# Epoch 00088: val_loss did not improve from 0.20971
#
# Epoch 00089: val_loss did not improve from 0.20971
#
# Epoch 00090: val_loss did not improve from 0.20971
#
# Epoch 00091: val_loss did not improve from 0.20971
#
# Epoch 00092: val_loss improved from 0.20971 to 0.20920, saving model to best_model_elastic.h5
#
# Epoch 00093: val_loss did not improve from 0.20920
#
# Epoch 00094: val_loss did not improve from 0.20920
#
# Epoch 00095: val_loss did not improve from 0.20920
#
# Epoch 00096: val_loss did not improve from 0.20920
#
# Epoch 00097: val_loss did not improve from 0.20920
#
# Epoch 00098: val_loss did not improve from 0.20920
#
# Epoch 00099: val_loss did not improve from 0.20920
#
# Epoch 00100: val_loss improved from 0.20920 to 0.20765, saving model to best_model_elastic.h5
#
# Epoch 00101: val_loss did not improve from 0.20765
#
# Epoch 00102: val_loss did not improve from 0.20765
#
# Epoch 00103: val_loss did not improve from 0.20765
#
# Epoch 00104: val_loss did not improve from 0.20765
#
# Epoch 00105: val_loss did not improve from 0.20765
#
# Epoch 00106: val_loss did not improve from 0.20765
#
# Epoch 00107: val_loss did not improve from 0.20765
#
# Epoch 00108: val_loss did not improve from 0.20765
#
# Epoch 00109: val_loss did not improve from 0.20765
#
# Epoch 00110: val_loss did not improve from 0.20765
#
# Epoch 00111: val_loss did not improve from 0.20765
#
# Epoch 00112: val_loss did not improve from 0.20765
#
# Epoch 00113: val_loss did not improve from 0.20765
#
# Epoch 00114: val_loss did not improve from 0.20765
#
# Epoch 00115: val_loss did not improve from 0.20765
#
# Epoch 00116: val_loss did not improve from 0.20765
#
# Epoch 00117: val_loss did not improve from 0.20765
#
# Epoch 00118: val_loss did not improve from 0.20765
#
# Epoch 00119: val_loss did not improve from 0.20765
#
# Epoch 00120: val_loss did not improve from 0.20765
#
# Epoch 00121: val_loss did not improve from 0.20765
#
# Epoch 00122: val_loss did not improve from 0.20765
#
# Epoch 00123: val_loss did not improve from 0.20765
#
# Epoch 00124: val_loss did not improve from 0.20765
#
# Epoch 00125: val_loss did not improve from 0.20765
#
# Epoch 00126: val_loss did not improve from 0.20765
#
# Epoch 00127: val_loss did not improve from 0.20765
#
# Epoch 00128: val_loss did not improve from 0.20765
#
# Epoch 00129: val_loss did not improve from 0.20765
#
# Epoch 00130: val_loss did not improve from 0.20765
#
# Epoch 00131: val_loss did not improve from 0.20765
#
# Epoch 00132: val_loss did not improve from 0.20765
#
# Epoch 00133: val_loss improved from 0.20765 to 0.20315, saving model to best_model_elastic.h5
#
# Epoch 00134: val_loss did not improve from 0.20315
#
# Epoch 00135: val_loss did not improve from 0.20315
#
# Epoch 00136: val_loss did not improve from 0.20315
#
# Epoch 00137: val_loss did not improve from 0.20315
#
# Epoch 00138: val_loss did not improve from 0.20315
#
# Epoch 00139: val_loss did not improve from 0.20315
# Epoch 00140: val_loss did not improve from 0.20315
#
# Epoch 00141: val_loss did not improve from 0.20315
#
# Epoch 00142: val_loss did not improve from 0.20315
#
# Epoch 00143: val_loss did not improve from 0.20315
#
# Epoch 00144: val_loss did not improve from 0.20315
#
# Epoch 00145: val_loss did not improve from 0.20315
#
# Epoch 00146: val_loss did not improve from 0.20315
#
# Epoch 00147: val_loss did not improve from 0.20315
#
# Epoch 00148: val_loss did not improve from 0.20315
#
# Epoch 00149: val_loss did not improve from 0.20315
#
# Epoch 00150: val_loss did not improve from 0.20315
#
# Epoch 00151: val_loss did not improve from 0.20315
#
# Epoch 00152: val_loss did not improve from 0.20315
#
# Epoch 00153: val_loss did not improve from 0.20315
#
# Epoch 00154: val_loss did not improve from 0.20315
#
# Epoch 00155: val_loss did not improve from 0.20315
#
# Epoch 00156: val_loss did not improve from 0.20315
#
# Epoch 00157: val_loss did not improve from 0.20315
#
# Epoch 00158: val_loss did not improve from 0.20315
#
# Epoch 00159: val_loss did not improve from 0.20315
#
# Epoch 00160: val_loss did not improve from 0.20315
#
# Epoch 00161: val_loss did not improve from 0.20315
#
# Epoch 00162: val_loss did not improve from 0.20315
#
# Epoch 00163: val_loss improved from 0.20315 to 0.20145, saving model to best_model_elastic.h5
#
# Epoch 00164: val_loss did not improve from 0.20145
#
# Epoch 00165: val_loss did not improve from 0.20145
#
# Epoch 00166: val_loss did not improve from 0.20145
#
# Epoch 00167: val_loss did not improve from 0.20145
#
# Epoch 00168: val_loss did not improve from 0.20145
#
# Epoch 00169: val_loss did not improve from 0.20145
#
# Epoch 00170: val_loss did not improve from 0.20145
#
# Epoch 00171: val_loss did not improve from 0.20145
#
# Epoch 00172: val_loss did not improve from 0.20145
#
# Epoch 00173: val_loss did not improve from 0.20145
#
# Epoch 00174: val_loss did not improve from 0.20145
#
# Epoch 00175: val_loss did not improve from 0.20145
#
# Epoch 00176: val_loss did not improve from 0.20145
#
# Epoch 00177: val_loss did not improve from 0.20145
#
# Epoch 00178: val_loss did not improve from 0.20145
#
# Epoch 00179: val_loss did not improve from 0.20145
#
# Epoch 00180: val_loss did not improve from 0.20145
#
# Epoch 00181: val_loss did not improve from 0.20145
#
# Epoch 00182: val_loss did not improve from 0.20145
#
# Epoch 00183: val_loss did not improve from 0.20145
#
# Epoch 00184: val_loss did not improve from 0.20145
#
# Epoch 00185: val_loss did not improve from 0.20145
#
# Epoch 00186: val_loss did not improve from 0.20145
#
# Epoch 00187: val_loss did not improve from 0.20145
#
# Epoch 00188: val_loss did not improve from 0.20145
#
# Epoch 00189: val_loss did not improve from 0.20145
#
# Epoch 00190: val_loss did not improve from 0.20145
#
# Epoch 00191: val_loss did not improve from 0.20145
#
# Epoch 00192: val_loss did not improve from 0.20145
#
# Epoch 00193: val_loss did not improve from 0.20145
#
# Epoch 00194: val_loss did not improve from 0.20145
#
# Epoch 00195: val_loss did not improve from 0.20145
#
# Epoch 00196: val_loss did not improve from 0.20145
#
# Epoch 00197: val_loss did not improve from 0.20145
#
# Epoch 00198: val_loss did not improve from 0.20145
#
# Epoch 00199: val_loss did not improve from 0.20145
#
# Epoch 00200: val_loss did not improve from 0.20145
#
# Epoch 00201: val_loss did not improve from 0.20145
#
# Epoch 00202: val_loss did not improve from 0.20145
#
# Epoch 00203: val_loss did not improve from 0.20145
#
# Epoch 00204: val_loss did not improve from 0.20145
#
# Epoch 00205: val_loss did not improve from 0.20145
#
# Epoch 00206: val_loss did not improve from 0.20145
#
# Epoch 00207: val_loss did not improve from 0.20145
#
# Epoch 00208: val_loss did not improve from 0.20145
#
# Epoch 00209: val_loss did not improve from 0.20145
#
# Epoch 00210: val_loss did not improve from 0.20145
#
# Epoch 00211: val_loss did not improve from 0.20145
#
# Epoch 00212: val_loss did not improve from 0.20145
#
# Epoch 00213: val_loss did not improve from 0.20145
#
# Epoch 00214: val_loss did not improve from 0.20145
#
# Epoch 00215: val_loss did not improve from 0.20145
#
# Epoch 00216: val_loss did not improve from 0.20145
#
# Epoch 00217: val_loss did not improve from 0.20145
#
# Epoch 00218: val_loss did not improve from 0.20145
#
# Epoch 00219: val_loss did not improve from 0.20145
#
# Epoch 00220: val_loss did not improve from 0.20145
#
# Epoch 00221: val_loss did not improve from 0.20145
#
# Epoch 00222: val_loss did not improve from 0.20145
#
# Epoch 00223: val_loss did not improve from 0.20145
#
# Epoch 00224: val_loss did not improve from 0.20145
#
# Epoch 00225: val_loss did not improve from 0.20145
#
# Epoch 00226: val_loss did not improve from 0.20145
#
# Epoch 00227: val_loss did not improve from 0.20145
#
# Epoch 00228: val_loss did not improve from 0.20145
#
# Epoch 00229: val_loss did not improve from 0.20145
#
# Epoch 00230: val_loss did not improve from 0.20145
#
# Epoch 00231: val_loss did not improve from 0.20145
#
# Epoch 00232: val_loss did not improve from 0.20145
#
# Epoch 00233: val_loss did not improve from 0.20145
#
# Epoch 00234: val_loss did not improve from 0.20145
#
# Epoch 00235: val_loss did not improve from 0.20145
#
# Epoch 00236: val_loss improved from 0.20145 to 0.20097, saving model to best_model_elastic.h5
#
# Epoch 00237: val_loss improved from 0.20097 to 0.20064, saving model to best_model_elastic.h5
#
# Epoch 00238: val_loss did not improve from 0.20064
#
# Epoch 00239: val_loss did not improve from 0.20064
#
# Epoch 00240: val_loss did not improve from 0.20064
#
# Epoch 00241: val_loss did not improve from 0.20064
#
# Epoch 00242: val_loss did not improve from 0.20064
#
# Epoch 00243: val_loss did not improve from 0.20064
#
# Epoch 00244: val_loss did not improve from 0.20064
#
# Epoch 00245: val_loss did not improve from 0.20064
#
# Epoch 00246: val_loss did not improve from 0.20064
#
# Epoch 00247: val_loss did not improve from 0.20064
#
# Epoch 00248: val_loss did not improve from 0.20064
#
# Epoch 00249: val_loss did not improve from 0.20064
#
# Epoch 00250: val_loss did not improve from 0.20064
#
# Epoch 00251: val_loss did not improve from 0.20064
#
# Epoch 00252: val_loss did not improve from 0.20064
#
# Epoch 00253: val_loss did not improve from 0.20064
#
# Epoch 00254: val_loss did not improve from 0.20064
#
# Epoch 00255: val_loss did not improve from 0.20064
#
# Epoch 00256: val_loss did not improve from 0.20064
#
# Epoch 00257: val_loss did not improve from 0.20064
#
# Epoch 00258: val_loss did not improve from 0.20064
#
# Epoch 00259: val_loss improved from 0.20064 to 0.20035, saving model to best_model_elastic.h5
#
# Epoch 00260: val_loss improved from 0.20035 to 0.19995, saving model to best_model_elastic.h5
#
# Epoch 00261: val_loss did not improve from 0.19995
#
# Epoch 00262: val_loss did not improve from 0.19995
#
# Epoch 00263: val_loss did not improve from 0.19995
#
# Epoch 00264: val_loss did not improve from 0.19995
#
# Epoch 00265: val_loss did not improve from 0.19995
#
# Epoch 00266: val_loss did not improve from 0.19995
#
# Epoch 00267: val_loss did not improve from 0.19995
#
# Epoch 00268: val_loss did not improve from 0.19995
#
# Epoch 00269: val_loss improved from 0.19995 to 0.19947, saving model to best_model_elastic.h5
#
# Epoch 00270: val_loss did not improve from 0.19947
#
# Epoch 00271: val_loss did not improve from 0.19947
#
# Epoch 00272: val_loss did not improve from 0.19947
#
# Epoch 00273: val_loss did not improve from 0.19947
#
# Epoch 00274: val_loss did not improve from 0.19947
#
# Epoch 00275: val_loss did not improve from 0.19947
#
# Epoch 00276: val_loss did not improve from 0.19947
#
# Epoch 00277: val_loss did not improve from 0.19947
#
# Epoch 00278: val_loss did not improve from 0.19947
#
# Epoch 00279: val_loss did not improve from 0.19947
#
# Epoch 00280: val_loss did not improve from 0.19947
#
# Epoch 00281: val_loss did not improve from 0.19947
#
# Epoch 00282: val_loss did not improve from 0.19947
#
# Epoch 00283: val_loss did not improve from 0.19947
#
# Epoch 00284: val_loss did not improve from 0.19947
#
# Epoch 00285: val_loss did not improve from 0.19947
#
# Epoch 00286: val_loss did not improve from 0.19947
#
# Epoch 00287: val_loss did not improve from 0.19947
#
# Epoch 00288: val_loss improved from 0.19947 to 0.19894, saving model to best_model_elastic.h5
#
# Epoch 00289: val_loss did not improve from 0.19894
#
# Epoch 00290: val_loss did not improve from 0.19894
#
# Epoch 00291: val_loss did not improve from 0.19894
# Epoch 00292: val_loss did not improve from 0.19894
#
# Epoch 00293: val_loss did not improve from 0.19894
#
# Epoch 00294: val_loss did not improve from 0.19894
#
# Epoch 00295: val_loss did not improve from 0.19894
#
# Epoch 00296: val_loss did not improve from 0.19894
#
# Epoch 00297: val_loss did not improve from 0.19894
#
# Epoch 00298: val_loss did not improve from 0.19894
#
# Epoch 00299: val_loss did not improve from 0.19894
#
# Epoch 00300: val_loss did not improve from 0.19894
#
# Epoch 00301: val_loss did not improve from 0.19894
#
# Epoch 00302: val_loss did not improve from 0.19894
#
# Epoch 00303: val_loss did not improve from 0.19894
#
# Epoch 00304: val_loss did not improve from 0.19894
#
# Epoch 00305: val_loss did not improve from 0.19894
#
# Epoch 00306: val_loss did not improve from 0.19894
#
# Epoch 00307: val_loss did not improve from 0.19894
#
# Epoch 00308: val_loss did not improve from 0.19894
#
# Epoch 00309: val_loss did not improve from 0.19894
#
# Epoch 00310: val_loss did not improve from 0.19894
#
# Epoch 00311: val_loss did not improve from 0.19894
#
# Epoch 00312: val_loss did not improve from 0.19894
#
# Epoch 00313: val_loss did not improve from 0.19894
#
# Epoch 00314: val_loss did not improve from 0.19894
#
# Epoch 00315: val_loss did not improve from 0.19894
#
# Epoch 00316: val_loss did not improve from 0.19894
#
# Epoch 00317: val_loss improved from 0.19894 to 0.19869, saving model to best_model_elastic.h5
#
# Epoch 00318: val_loss did not improve from 0.19869
#
# Epoch 00319: val_loss did not improve from 0.19869
#
# Epoch 00320: val_loss improved from 0.19869 to 0.19783, saving model to best_model_elastic.h5
#
# Epoch 00321: val_loss did not improve from 0.19783
#
# Epoch 00322: val_loss did not improve from 0.19783
#
# Epoch 00323: val_loss did not improve from 0.19783
#
# Epoch 00324: val_loss did not improve from 0.19783
#
# Epoch 00325: val_loss did not improve from 0.19783
#
# Epoch 00326: val_loss did not improve from 0.19783
#
# Epoch 00327: val_loss did not improve from 0.19783
#
# Epoch 00328: val_loss did not improve from 0.19783
#
# Epoch 00329: val_loss did not improve from 0.19783
#
# Epoch 00330: val_loss improved from 0.19783 to 0.19750, saving model to best_model_elastic.h5
#
# Epoch 00331: val_loss did not improve from 0.19750
#
# Epoch 00332: val_loss did not improve from 0.19750
#
# Epoch 00333: val_loss did not improve from 0.19750
#
# Epoch 00334: val_loss did not improve from 0.19750
#
# Epoch 00335: val_loss did not improve from 0.19750
#
# Epoch 00336: val_loss did not improve from 0.19750
#
# Epoch 00337: val_loss did not improve from 0.19750
#
# Epoch 00338: val_loss did not improve from 0.19750
#
# Epoch 00339: val_loss did not improve from 0.19750
#
# Epoch 00340: val_loss did not improve from 0.19750
#
# Epoch 00341: val_loss did not improve from 0.19750
#
# Epoch 00342: val_loss did not improve from 0.19750
#
# Epoch 00343: val_loss did not improve from 0.19750
#
# Epoch 00344: val_loss did not improve from 0.19750
#
# Epoch 00345: val_loss did not improve from 0.19750
#
# Epoch 00346: val_loss did not improve from 0.19750
#
# Epoch 00347: val_loss did not improve from 0.19750
#
# Epoch 00348: val_loss did not improve from 0.19750
#
# Epoch 00349: val_loss did not improve from 0.19750
#
# Epoch 00350: val_loss did not improve from 0.19750
#
# Epoch 00351: val_loss did not improve from 0.19750
#
# Epoch 00352: val_loss did not improve from 0.19750
#
# Epoch 00353: val_loss did not improve from 0.19750
#
# Epoch 00354: val_loss did not improve from 0.19750
#
# Epoch 00355: val_loss did not improve from 0.19750
#
# Epoch 00356: val_loss did not improve from 0.19750
#
# Epoch 00357: val_loss did not improve from 0.19750
#
# Epoch 00358: val_loss did not improve from 0.19750
#
# Epoch 00359: val_loss did not improve from 0.19750
#
# Epoch 00360: val_loss did not improve from 0.19750
#
# Epoch 00361: val_loss did not improve from 0.19750
#
# Epoch 00362: val_loss did not improve from 0.19750
#
# Epoch 00363: val_loss did not improve from 0.19750
#
# Epoch 00364: val_loss did not improve from 0.19750
#
# Epoch 00365: val_loss did not improve from 0.19750
#
# Epoch 00366: val_loss improved from 0.19750 to 0.19722, saving model to best_model_elastic.h5
#
# Epoch 00367: val_loss did not improve from 0.19722
#
# Epoch 00368: val_loss did not improve from 0.19722
#
# Epoch 00369: val_loss did not improve from 0.19722
#
# Epoch 00370: val_loss did not improve from 0.19722
#
# Epoch 00371: val_loss did not improve from 0.19722
#
# Epoch 00372: val_loss did not improve from 0.19722
#
# Epoch 00373: val_loss did not improve from 0.19722
#
# Epoch 00374: val_loss did not improve from 0.19722
#
# Epoch 00375: val_loss did not improve from 0.19722
#
# Epoch 00376: val_loss did not improve from 0.19722
#
# Epoch 00377: val_loss did not improve from 0.19722
#
# Epoch 00378: val_loss did not improve from 0.19722
#
# Epoch 00379: val_loss did not improve from 0.19722
#
# Epoch 00380: val_loss did not improve from 0.19722
#
# Epoch 00381: val_loss did not improve from 0.19722
#
# Epoch 00382: val_loss did not improve from 0.19722
#
# Epoch 00383: val_loss did not improve from 0.19722
#
# Epoch 00384: val_loss did not improve from 0.19722
#
# Epoch 00385: val_loss did not improve from 0.19722
#
# Epoch 00386: val_loss did not improve from 0.19722
#
# Epoch 00387: val_loss did not improve from 0.19722
#
# Epoch 00388: val_loss did not improve from 0.19722
#
# Epoch 00389: val_loss did not improve from 0.19722
#
# Epoch 00390: val_loss did not improve from 0.19722
#
# Epoch 00391: val_loss did not improve from 0.19722
#
# Epoch 00392: val_loss did not improve from 0.19722
#
# Epoch 00393: val_loss did not improve from 0.19722
#
# Epoch 00394: val_loss did not improve from 0.19722
#
# Epoch 00395: val_loss did not improve from 0.19722
#
# Epoch 00396: val_loss did not improve from 0.19722
#
# Epoch 00397: val_loss did not improve from 0.19722
#
# Epoch 00398: val_loss did not improve from 0.19722
#
# Epoch 00399: val_loss did not improve from 0.19722
#
# Epoch 00400: val_loss did not improve from 0.19722
#
# Epoch 00401: val_loss did not improve from 0.19722
#
# Epoch 00402: val_loss did not improve from 0.19722
#
# Epoch 00403: val_loss did not improve from 0.19722
#
# Epoch 00404: val_loss did not improve from 0.19722
#
# Epoch 00405: val_loss did not improve from 0.19722
#
# Epoch 00406: val_loss did not improve from 0.19722
#
# Epoch 00407: val_loss did not improve from 0.19722
#
# Epoch 00408: val_loss did not improve from 0.19722
#
# Epoch 00409: val_loss did not improve from 0.19722
#
# Epoch 00410: val_loss did not improve from 0.19722
#
# Epoch 00411: val_loss did not improve from 0.19722
#
# Epoch 00412: val_loss did not improve from 0.19722
#
# Epoch 00413: val_loss improved from 0.19722 to 0.19643, saving model to best_model_elastic.h5
#
# Epoch 00414: val_loss did not improve from 0.19643
#
# Epoch 00415: val_loss did not improve from 0.19643
#
# Epoch 00416: val_loss did not improve from 0.19643
#
# Epoch 00417: val_loss did not improve from 0.19643
#
# Epoch 00418: val_loss did not improve from 0.19643
#
# Epoch 00419: val_loss did not improve from 0.19643
#
# Epoch 00420: val_loss did not improve from 0.19643
#
# Epoch 00421: val_loss did not improve from 0.19643
#
# Epoch 00422: val_loss did not improve from 0.19643
#
# Epoch 00423: val_loss did not improve from 0.19643
#
# Epoch 00424: val_loss did not improve from 0.19643
#
# Epoch 00425: val_loss did not improve from 0.19643
#
# Epoch 00426: val_loss did not improve from 0.19643
#
# Epoch 00427: val_loss did not improve from 0.19643
#
# Epoch 00428: val_loss did not improve from 0.19643
#
# Epoch 00429: val_loss did not improve from 0.19643
#
# Epoch 00430: val_loss did not improve from 0.19643
#
# Epoch 00431: val_loss did not improve from 0.19643
#
# Epoch 00432: val_loss did not improve from 0.19643
#
# Epoch 00433: val_loss did not improve from 0.19643
#
# Epoch 00434: val_loss did not improve from 0.19643
#
# Epoch 00435: val_loss did not improve from 0.19643
#
# Epoch 00436: val_loss did not improve from 0.19643
#
# Epoch 00437: val_loss did not improve from 0.19643
#
# Epoch 00438: val_loss did not improve from 0.19643
#
# Epoch 00439: val_loss did not improve from 0.19643
#
# Epoch 00440: val_loss did not improve from 0.19643
#
# Epoch 00441: val_loss did not improve from 0.19643
#
# Epoch 00442: val_loss did not improve from 0.19643
#
# Epoch 00443: val_loss did not improve from 0.19643
#
# Epoch 00444: val_loss did not improve from 0.19643
#
# Epoch 00445: val_loss did not improve from 0.19643
# Epoch 00446: val_loss did not improve from 0.19643
#
# Epoch 00447: val_loss did not improve from 0.19643
#
# Epoch 00448: val_loss did not improve from 0.19643
#
# Epoch 00449: val_loss did not improve from 0.19643
#
# Epoch 00450: val_loss did not improve from 0.19643
#
# Epoch 00451: val_loss did not improve from 0.19643
#
# Epoch 00452: val_loss improved from 0.19643 to 0.19509, saving model to best_model_elastic.h5
#
# Epoch 00453: val_loss did not improve from 0.19509
#
# Epoch 00454: val_loss did not improve from 0.19509
#
# Epoch 00455: val_loss did not improve from 0.19509
#
# Epoch 00456: val_loss did not improve from 0.19509
#
# Epoch 00457: val_loss did not improve from 0.19509
#
# Epoch 00458: val_loss did not improve from 0.19509
#
# Epoch 00459: val_loss did not improve from 0.19509
#
# Epoch 00460: val_loss did not improve from 0.19509
#
# Epoch 00461: val_loss did not improve from 0.19509
#
# Epoch 00462: val_loss did not improve from 0.19509
#
# Epoch 00463: val_loss did not improve from 0.19509
#
# Epoch 00464: val_loss did not improve from 0.19509
#
# Epoch 00465: val_loss did not improve from 0.19509
#
# Epoch 00466: val_loss did not improve from 0.19509
#
# Epoch 00467: val_loss did not improve from 0.19509
#
# Epoch 00468: val_loss did not improve from 0.19509
#
# Epoch 00469: val_loss did not improve from 0.19509
#
# Epoch 00470: val_loss did not improve from 0.19509
#
# Epoch 00471: val_loss did not improve from 0.19509
#
# Epoch 00472: val_loss did not improve from 0.19509
#
# Epoch 00473: val_loss did not improve from 0.19509
#
# Epoch 00474: val_loss did not improve from 0.19509
#
# Epoch 00475: val_loss did not improve from 0.19509
#
# Epoch 00476: val_loss did not improve from 0.19509
#
# Epoch 00477: val_loss did not improve from 0.19509
#
# Epoch 00478: val_loss did not improve from 0.19509
#
# Epoch 00479: val_loss did not improve from 0.19509
#
# Epoch 00480: val_loss did not improve from 0.19509
#
# Epoch 00481: val_loss did not improve from 0.19509
#
# Epoch 00482: val_loss did not improve from 0.19509
#
# Epoch 00483: val_loss did not improve from 0.19509
#
# Epoch 00484: val_loss did not improve from 0.19509
#
# Epoch 00485: val_loss did not improve from 0.19509
#
# Epoch 00486: val_loss did not improve from 0.19509
#
# Epoch 00487: val_loss did not improve from 0.19509
#
# Epoch 00488: val_loss did not improve from 0.19509
#
# Epoch 00489: val_loss did not improve from 0.19509
#
# Epoch 00490: val_loss did not improve from 0.19509
#
# Epoch 00491: val_loss did not improve from 0.19509
#
# Epoch 00492: val_loss did not improve from 0.19509
#
# Epoch 00493: val_loss did not improve from 0.19509
#
# Epoch 00494: val_loss did not improve from 0.19509
#
# Epoch 00495: val_loss did not improve from 0.19509
#
# Epoch 00496: val_loss did not improve from 0.19509
#
# Epoch 00497: val_loss did not improve from 0.19509
#
# Epoch 00498: val_loss did not improve from 0.19509
#
# Epoch 00499: val_loss did not improve from 0.19509
#
# Epoch 00500: val_loss did not improve from 0.19509
#
# Epoch 00501: val_loss did not improve from 0.19509
#
# Epoch 00502: val_loss did not improve from 0.19509
#
# Epoch 00503: val_loss did not improve from 0.19509
#
# Epoch 00504: val_loss did not improve from 0.19509
#
# Epoch 00505: val_loss did not improve from 0.19509
#
# Epoch 00506: val_loss did not improve from 0.19509
#
# Epoch 00507: val_loss did not improve from 0.19509
#
# Epoch 00508: val_loss did not improve from 0.19509
#
# Epoch 00509: val_loss improved from 0.19509 to 0.19501, saving model to best_model_elastic.h5
#
# Epoch 00510: val_loss did not improve from 0.19501
#
# Epoch 00511: val_loss did not improve from 0.19501
#
# Epoch 00512: val_loss did not improve from 0.19501
#
# Epoch 00513: val_loss did not improve from 0.19501
#
# Epoch 00514: val_loss did not improve from 0.19501
#
# Epoch 00515: val_loss did not improve from 0.19501
#
# Epoch 00516: val_loss did not improve from 0.19501
#
# Epoch 00517: val_loss did not improve from 0.19501
#
# Epoch 00518: val_loss did not improve from 0.19501
#
# Epoch 00519: val_loss did not improve from 0.19501
#
# Epoch 00520: val_loss did not improve from 0.19501
#
# Epoch 00521: val_loss did not improve from 0.19501
#
# Epoch 00522: val_loss did not improve from 0.19501
#
# Epoch 00523: val_loss did not improve from 0.19501
#
# Epoch 00524: val_loss did not improve from 0.19501
#
# Epoch 00525: val_loss did not improve from 0.19501
#
# Epoch 00526: val_loss did not improve from 0.19501
#
# Epoch 00527: val_loss did not improve from 0.19501
#
# Epoch 00528: val_loss did not improve from 0.19501
#
# Epoch 00529: val_loss did not improve from 0.19501
#
# Epoch 00530: val_loss did not improve from 0.19501
#
# Epoch 00531: val_loss did not improve from 0.19501
#
# Epoch 00532: val_loss did not improve from 0.19501
#
# Epoch 00533: val_loss did not improve from 0.19501
#
# Epoch 00534: val_loss did not improve from 0.19501
#
# Epoch 00535: val_loss did not improve from 0.19501
#
# Epoch 00536: val_loss did not improve from 0.19501
#
# Epoch 00537: val_loss did not improve from 0.19501
#
# Epoch 00538: val_loss did not improve from 0.19501
#
# Epoch 00539: val_loss did not improve from 0.19501
#
# Epoch 00540: val_loss did not improve from 0.19501
#
# Epoch 00541: val_loss did not improve from 0.19501
#
# Epoch 00542: val_loss did not improve from 0.19501
#
# Epoch 00543: val_loss did not improve from 0.19501
#
# Epoch 00544: val_loss did not improve from 0.19501
#
# Epoch 00545: val_loss did not improve from 0.19501
#
# Epoch 00546: val_loss did not improve from 0.19501
#
# Epoch 00547: val_loss did not improve from 0.19501
#
# Epoch 00548: val_loss did not improve from 0.19501
#
# Epoch 00549: val_loss did not improve from 0.19501
#
# Epoch 00550: val_loss did not improve from 0.19501
#
# Epoch 00551: val_loss did not improve from 0.19501
#
# Epoch 00552: val_loss did not improve from 0.19501
#
# Epoch 00553: val_loss did not improve from 0.19501
#
# Epoch 00554: val_loss did not improve from 0.19501
#
# Epoch 00555: val_loss did not improve from 0.19501
#
# Epoch 00556: val_loss did not improve from 0.19501
#
# Epoch 00557: val_loss did not improve from 0.19501
#
# Epoch 00558: val_loss did not improve from 0.19501
#
# Epoch 00559: val_loss did not improve from 0.19501
#
# Epoch 00560: val_loss did not improve from 0.19501
#
# Epoch 00561: val_loss did not improve from 0.19501
#
# Epoch 00562: val_loss did not improve from 0.19501
#
# Epoch 00563: val_loss did not improve from 0.19501
#
# Epoch 00564: val_loss did not improve from 0.19501
#
# Epoch 00565: val_loss did not improve from 0.19501
#
# Epoch 00566: val_loss did not improve from 0.19501
#
# Epoch 00567: val_loss did not improve from 0.19501
#
# Epoch 00568: val_loss did not improve from 0.19501
#
# Epoch 00569: val_loss did not improve from 0.19501
#
# Epoch 00570: val_loss did not improve from 0.19501
#
# Epoch 00571: val_loss did not improve from 0.19501
#
# Epoch 00572: val_loss did not improve from 0.19501
#
# Epoch 00573: val_loss did not improve from 0.19501
#
# Epoch 00574: val_loss did not improve from 0.19501
#
# Epoch 00575: val_loss did not improve from 0.19501
#
# Epoch 00576: val_loss did not improve from 0.19501
#
# Epoch 00577: val_loss did not improve from 0.19501
#
# Epoch 00578: val_loss did not improve from 0.19501
#
# Epoch 00579: val_loss improved from 0.19501 to 0.19493, saving model to best_model_elastic.h5
#
# Epoch 00580: val_loss did not improve from 0.19493
#
# Epoch 00581: val_loss did not improve from 0.19493
#
# Epoch 00582: val_loss did not improve from 0.19493
#
# Epoch 00583: val_loss did not improve from 0.19493
#
# Epoch 00584: val_loss did not improve from 0.19493
#
# Epoch 00585: val_loss improved from 0.19493 to 0.19479, saving model to best_model_elastic.h5
#
# Epoch 00586: val_loss did not improve from 0.19479
#
# Epoch 00587: val_loss did not improve from 0.19479
#
# Epoch 00588: val_loss did not improve from 0.19479
#
# Epoch 00589: val_loss did not improve from 0.19479
#
# Epoch 00590: val_loss did not improve from 0.19479
#
# Epoch 00591: val_loss did not improve from 0.19479
#
# Epoch 00592: val_loss did not improve from 0.19479
#
# Epoch 00593: val_loss did not improve from 0.19479
#
# Epoch 00594: val_loss did not improve from 0.19479
#
# Epoch 00595: val_loss did not improve from 0.19479
#
# Epoch 00596: val_loss did not improve from 0.19479
#
# Epoch 00597: val_loss did not improve from 0.19479
#
# Epoch 00598: val_loss did not improve from 0.19479
#
# Epoch 00599: val_loss improved from 0.19479 to 0.19335, saving model to best_model_elastic.h5
# Epoch 00600: val_loss did not improve from 0.19335
#
# Epoch 00601: val_loss did not improve from 0.19335
#
# Epoch 00602: val_loss did not improve from 0.19335
#
# Epoch 00603: val_loss did not improve from 0.19335
#
# Epoch 00604: val_loss did not improve from 0.19335
#
# Epoch 00605: val_loss did not improve from 0.19335
#
# Epoch 00606: val_loss did not improve from 0.19335
#
# Epoch 00607: val_loss did not improve from 0.19335
#
# Epoch 00608: val_loss did not improve from 0.19335
#
# Epoch 00609: val_loss did not improve from 0.19335
#
# Epoch 00610: val_loss did not improve from 0.19335
#
# Epoch 00611: val_loss did not improve from 0.19335
#
# Epoch 00612: val_loss did not improve from 0.19335
#
# Epoch 00613: val_loss did not improve from 0.19335
#
# Epoch 00614: val_loss did not improve from 0.19335
#
# Epoch 00615: val_loss did not improve from 0.19335
#
# Epoch 00616: val_loss did not improve from 0.19335
#
# Epoch 00617: val_loss did not improve from 0.19335
#
# Epoch 00618: val_loss did not improve from 0.19335
#
# Epoch 00619: val_loss did not improve from 0.19335
#
# Epoch 00620: val_loss did not improve from 0.19335
#
# Epoch 00621: val_loss did not improve from 0.19335
#
# Epoch 00622: val_loss did not improve from 0.19335
#
# Epoch 00623: val_loss did not improve from 0.19335
#
# Epoch 00624: val_loss did not improve from 0.19335
#
# Epoch 00625: val_loss did not improve from 0.19335
#
# Epoch 00626: val_loss did not improve from 0.19335
#
# Epoch 00627: val_loss improved from 0.19335 to 0.19238, saving model to best_model_elastic.h5
#
# Epoch 00628: val_loss did not improve from 0.19238
#
# Epoch 00629: val_loss did not improve from 0.19238
#
# Epoch 00630: val_loss did not improve from 0.19238
#
# Epoch 00631: val_loss did not improve from 0.19238
#
# Epoch 00632: val_loss did not improve from 0.19238
#
# Epoch 00633: val_loss did not improve from 0.19238
#
# Epoch 00634: val_loss did not improve from 0.19238
#
# Epoch 00635: val_loss did not improve from 0.19238
#
# Epoch 00636: val_loss did not improve from 0.19238
#
# Epoch 00637: val_loss did not improve from 0.19238
#
# Epoch 00638: val_loss did not improve from 0.19238
#
# Epoch 00639: val_loss did not improve from 0.19238
#
# Epoch 00640: val_loss did not improve from 0.19238
#
# Epoch 00641: val_loss did not improve from 0.19238
#
# Epoch 00642: val_loss did not improve from 0.19238
#
# Epoch 00643: val_loss did not improve from 0.19238
#
# Epoch 00644: val_loss did not improve from 0.19238
#
# Epoch 00645: val_loss did not improve from 0.19238
#
# Epoch 00646: val_loss did not improve from 0.19238
#
# Epoch 00647: val_loss did not improve from 0.19238
#
# Epoch 00648: val_loss did not improve from 0.19238
#
# Epoch 00649: val_loss did not improve from 0.19238
#
# Epoch 00650: val_loss did not improve from 0.19238
#
# Epoch 00651: val_loss did not improve from 0.19238
#
# Epoch 00652: val_loss did not improve from 0.19238
#
# Epoch 00653: val_loss did not improve from 0.19238
#
# Epoch 00654: val_loss did not improve from 0.19238
#
# Epoch 00655: val_loss did not improve from 0.19238
#
# Epoch 00656: val_loss did not improve from 0.19238
#
# Epoch 00657: val_loss did not improve from 0.19238
#
# Epoch 00658: val_loss did not improve from 0.19238
#
# Epoch 00659: val_loss did not improve from 0.19238
#
# Epoch 00660: val_loss did not improve from 0.19238
#
# Epoch 00661: val_loss did not improve from 0.19238
#
# Epoch 00662: val_loss did not improve from 0.19238
#
# Epoch 00663: val_loss did not improve from 0.19238
#
# Epoch 00664: val_loss did not improve from 0.19238
#
# Epoch 00665: val_loss did not improve from 0.19238
#
# Epoch 00666: val_loss did not improve from 0.19238
#
# Epoch 00667: val_loss did not improve from 0.19238
#
# Epoch 00668: val_loss did not improve from 0.19238
#
# Epoch 00669: val_loss did not improve from 0.19238
#
# Epoch 00670: val_loss did not improve from 0.19238
#
# Epoch 00671: val_loss did not improve from 0.19238
#
# Epoch 00672: val_loss did not improve from 0.19238
#
# Epoch 00673: val_loss did not improve from 0.19238
#
# Epoch 00674: val_loss improved from 0.19238 to 0.19170, saving model to best_model_elastic.h5
#
# Epoch 00675: val_loss did not improve from 0.19170
#
# Epoch 00676: val_loss did not improve from 0.19170
#
# Epoch 00677: val_loss did not improve from 0.19170
#
# Epoch 00678: val_loss did not improve from 0.19170
#
# Epoch 00679: val_loss did not improve from 0.19170
#
# Epoch 00680: val_loss did not improve from 0.19170
#
# Epoch 00681: val_loss did not improve from 0.19170
#
# Epoch 00682: val_loss did not improve from 0.19170
#
# Epoch 00683: val_loss improved from 0.19170 to 0.19158, saving model to best_model_elastic.h5
#
# Epoch 00684: val_loss did not improve from 0.19158
#
# Epoch 00685: val_loss did not improve from 0.19158
#
# Epoch 00686: val_loss did not improve from 0.19158
#
# Epoch 00687: val_loss did not improve from 0.19158
#
# Epoch 00688: val_loss did not improve from 0.19158
#
# Epoch 00689: val_loss did not improve from 0.19158
#
# Epoch 00690: val_loss did not improve from 0.19158
#
# Epoch 00691: val_loss did not improve from 0.19158
#
# Epoch 00692: val_loss did not improve from 0.19158
#
# Epoch 00693: val_loss did not improve from 0.19158
#
# Epoch 00694: val_loss did not improve from 0.19158
#
# Epoch 00695: val_loss did not improve from 0.19158
#
# Epoch 00696: val_loss did not improve from 0.19158
#
# Epoch 00697: val_loss did not improve from 0.19158
#
# Epoch 00698: val_loss did not improve from 0.19158
#
# Epoch 00699: val_loss did not improve from 0.19158
#
# Epoch 00700: val_loss did not improve from 0.19158
#
# Epoch 00701: val_loss did not improve from 0.19158
#
# Epoch 00702: val_loss did not improve from 0.19158
#
# Epoch 00703: val_loss did not improve from 0.19158
#
# Epoch 00704: val_loss did not improve from 0.19158
#
# Epoch 00705: val_loss did not improve from 0.19158
#
# Epoch 00706: val_loss did not improve from 0.19158
#
# Epoch 00707: val_loss did not improve from 0.19158
#
# Epoch 00708: val_loss did not improve from 0.19158
#
# Epoch 00709: val_loss did not improve from 0.19158
#
# Epoch 00710: val_loss did not improve from 0.19158
#
# Epoch 00711: val_loss did not improve from 0.19158
#
# Epoch 00712: val_loss did not improve from 0.19158
#
# Epoch 00713: val_loss did not improve from 0.19158
#
# Epoch 00714: val_loss did not improve from 0.19158
#
# Epoch 00715: val_loss did not improve from 0.19158
#
# Epoch 00716: val_loss did not improve from 0.19158
#
# Epoch 00717: val_loss did not improve from 0.19158
#
# Epoch 00718: val_loss did not improve from 0.19158
#
# Epoch 00719: val_loss did not improve from 0.19158
#
# Epoch 00720: val_loss did not improve from 0.19158
#
# Epoch 00721: val_loss did not improve from 0.19158
#
# Epoch 00722: val_loss did not improve from 0.19158
#
# Epoch 00723: val_loss did not improve from 0.19158
#
# Epoch 00724: val_loss did not improve from 0.19158
#
# Epoch 00725: val_loss did not improve from 0.19158
#
# Epoch 00726: val_loss did not improve from 0.19158
#
# Epoch 00727: val_loss did not improve from 0.19158
#
# Epoch 00728: val_loss did not improve from 0.19158
#
# Epoch 00729: val_loss did not improve from 0.19158
#
# Epoch 00730: val_loss did not improve from 0.19158
#
# Epoch 00731: val_loss did not improve from 0.19158
#
# Epoch 00732: val_loss did not improve from 0.19158
#
# Epoch 00733: val_loss did not improve from 0.19158
#
# Epoch 00734: val_loss did not improve from 0.19158
#
# Epoch 00735: val_loss did not improve from 0.19158
#
# Epoch 00736: val_loss did not improve from 0.19158
#
# Epoch 00737: val_loss did not improve from 0.19158
#
# Epoch 00738: val_loss did not improve from 0.19158
#
# Epoch 00739: val_loss did not improve from 0.19158
#
# Epoch 00740: val_loss did not improve from 0.19158
#
# Epoch 00741: val_loss did not improve from 0.19158
#
# Epoch 00742: val_loss did not improve from 0.19158
#
# Epoch 00743: val_loss improved from 0.19158 to 0.19076, saving model to best_model_elastic.h5
#
# Epoch 00744: val_loss did not improve from 0.19076
#
# Epoch 00745: val_loss did not improve from 0.19076
#
# Epoch 00746: val_loss did not improve from 0.19076
#
# Epoch 00747: val_loss did not improve from 0.19076
#
# Epoch 00748: val_loss did not improve from 0.19076
#
# Epoch 00749: val_loss did not improve from 0.19076
#
# Epoch 00750: val_loss did not improve from 0.19076
#
# Epoch 00751: val_loss did not improve from 0.19076
#
# Epoch 00752: val_loss did not improve from 0.19076
#
# Epoch 00753: val_loss did not improve from 0.19076
#
# Epoch 00754: val_loss did not improve from 0.19076
# Epoch 00755: val_loss did not improve from 0.19076
#
# Epoch 00756: val_loss did not improve from 0.19076
#
# Epoch 00757: val_loss did not improve from 0.19076
#
# Epoch 00758: val_loss did not improve from 0.19076
#
# Epoch 00759: val_loss did not improve from 0.19076
#
# Epoch 00760: val_loss did not improve from 0.19076
#
# Epoch 00761: val_loss did not improve from 0.19076
#
# Epoch 00762: val_loss did not improve from 0.19076
#
# Epoch 00763: val_loss did not improve from 0.19076
#
# Epoch 00764: val_loss did not improve from 0.19076
#
# Epoch 00765: val_loss improved from 0.19076 to 0.18778, saving model to best_model_elastic.h5
#
# Epoch 00766: val_loss did not improve from 0.18778
#
# Epoch 00767: val_loss did not improve from 0.18778
#
# Epoch 00768: val_loss did not improve from 0.18778
#
# Epoch 00769: val_loss did not improve from 0.18778
#
# Epoch 00770: val_loss did not improve from 0.18778
#
# Epoch 00771: val_loss did not improve from 0.18778
#
# Epoch 00772: val_loss did not improve from 0.18778
#
# Epoch 00773: val_loss did not improve from 0.18778
#
# Epoch 00774: val_loss did not improve from 0.18778
#
# Epoch 00775: val_loss did not improve from 0.18778
#
# Epoch 00776: val_loss did not improve from 0.18778
#
# Epoch 00777: val_loss did not improve from 0.18778
#
# Epoch 00778: val_loss did not improve from 0.18778
#
# Epoch 00779: val_loss did not improve from 0.18778
#
# Epoch 00780: val_loss did not improve from 0.18778
#
# Epoch 00781: val_loss did not improve from 0.18778
#
# Epoch 00782: val_loss did not improve from 0.18778
#
# Epoch 00783: val_loss did not improve from 0.18778
#
# Epoch 00784: val_loss did not improve from 0.18778
#
# Epoch 00785: val_loss did not improve from 0.18778
#
# Epoch 00786: val_loss did not improve from 0.18778
#
# Epoch 00787: val_loss did not improve from 0.18778
#
# Epoch 00788: val_loss did not improve from 0.18778
#
# Epoch 00789: val_loss did not improve from 0.18778
#
# Epoch 00790: val_loss did not improve from 0.18778
#
# Epoch 00791: val_loss did not improve from 0.18778
#
# Epoch 00792: val_loss did not improve from 0.18778
#
# Epoch 00793: val_loss did not improve from 0.18778
#
# Epoch 00794: val_loss did not improve from 0.18778
#
# Epoch 00795: val_loss did not improve from 0.18778
#
# Epoch 00796: val_loss did not improve from 0.18778
#
# Epoch 00797: val_loss did not improve from 0.18778
#
# Epoch 00798: val_loss did not improve from 0.18778
#
# Epoch 00799: val_loss did not improve from 0.18778
#
# Epoch 00800: val_loss did not improve from 0.18778
#
# Epoch 00801: val_loss did not improve from 0.18778
#
# Epoch 00802: val_loss did not improve from 0.18778
#
# Epoch 00803: val_loss did not improve from 0.18778
#
# Epoch 00804: val_loss did not improve from 0.18778
#
# Epoch 00805: val_loss did not improve from 0.18778
#
# Epoch 00806: val_loss did not improve from 0.18778
#
# Epoch 00807: val_loss did not improve from 0.18778
#
# Epoch 00808: val_loss did not improve from 0.18778
#
# Epoch 00809: val_loss did not improve from 0.18778
#
# Epoch 00810: val_loss did not improve from 0.18778
#
# Epoch 00811: val_loss did not improve from 0.18778
#
# Epoch 00812: val_loss did not improve from 0.18778
#
# Epoch 00813: val_loss did not improve from 0.18778
#
# Epoch 00814: val_loss did not improve from 0.18778
#
# Epoch 00815: val_loss improved from 0.18778 to 0.18749, saving model to best_model_elastic.h5
#
# Epoch 00816: val_loss did not improve from 0.18749
#
# Epoch 00817: val_loss did not improve from 0.18749
#
# Epoch 00818: val_loss did not improve from 0.18749
#
# Epoch 00819: val_loss did not improve from 0.18749
#
# Epoch 00820: val_loss did not improve from 0.18749
#
# Epoch 00821: val_loss did not improve from 0.18749
#
# Epoch 00822: val_loss did not improve from 0.18749
#
# Epoch 00823: val_loss did not improve from 0.18749
#
# Epoch 00824: val_loss did not improve from 0.18749
#
# Epoch 00825: val_loss did not improve from 0.18749
#
# Epoch 00826: val_loss did not improve from 0.18749
#
# Epoch 00827: val_loss did not improve from 0.18749
#
# Epoch 00828: val_loss did not improve from 0.18749
#
# Epoch 00829: val_loss did not improve from 0.18749
#
# Epoch 00830: val_loss did not improve from 0.18749
#
# Epoch 00831: val_loss did not improve from 0.18749
#
# Epoch 00832: val_loss did not improve from 0.18749
#
# Epoch 00833: val_loss did not improve from 0.18749
#
# Epoch 00834: val_loss did not improve from 0.18749
#
# Epoch 00835: val_loss did not improve from 0.18749
#
# Epoch 00836: val_loss improved from 0.18749 to 0.18590, saving model to best_model_elastic.h5
#
# Epoch 00837: val_loss did not improve from 0.18590
#
# Epoch 00838: val_loss did not improve from 0.18590
#
# Epoch 00839: val_loss did not improve from 0.18590
#
# Epoch 00840: val_loss did not improve from 0.18590
#
# Epoch 00841: val_loss did not improve from 0.18590
#
# Epoch 00842: val_loss did not improve from 0.18590
#
# Epoch 00843: val_loss did not improve from 0.18590
#
# Epoch 00844: val_loss did not improve from 0.18590
#
# Epoch 00845: val_loss did not improve from 0.18590
#
# Epoch 00846: val_loss did not improve from 0.18590
#
# Epoch 00847: val_loss did not improve from 0.18590
#
# Epoch 00848: val_loss did not improve from 0.18590
#
# Epoch 00849: val_loss did not improve from 0.18590
#
# Epoch 00850: val_loss did not improve from 0.18590
#
# Epoch 00851: val_loss did not improve from 0.18590
#
# Epoch 00852: val_loss did not improve from 0.18590
#
# Epoch 00853: val_loss did not improve from 0.18590
#
# Epoch 00854: val_loss did not improve from 0.18590
#
# Epoch 00855: val_loss did not improve from 0.18590
#
# Epoch 00856: val_loss improved from 0.18590 to 0.18475, saving model to best_model_elastic.h5
#
# Epoch 00857: val_loss did not improve from 0.18475
#
# Epoch 00858: val_loss did not improve from 0.18475
#
# Epoch 00859: val_loss did not improve from 0.18475
#
# Epoch 00860: val_loss did not improve from 0.18475
#
# Epoch 00861: val_loss did not improve from 0.18475
#
# Epoch 00862: val_loss did not improve from 0.18475
#
# Epoch 00863: val_loss did not improve from 0.18475
#
# Epoch 00864: val_loss did not improve from 0.18475
#
# Epoch 00865: val_loss did not improve from 0.18475
#
# Epoch 00866: val_loss did not improve from 0.18475
#
# Epoch 00867: val_loss did not improve from 0.18475
#
# Epoch 00868: val_loss did not improve from 0.18475
#
# Epoch 00869: val_loss did not improve from 0.18475
#
# Epoch 00870: val_loss did not improve from 0.18475
#
# Epoch 00871: val_loss did not improve from 0.18475
#
# Epoch 00872: val_loss did not improve from 0.18475
#
# Epoch 00873: val_loss did not improve from 0.18475
#
# Epoch 00874: val_loss did not improve from 0.18475
#
# Epoch 00875: val_loss did not improve from 0.18475
#
# Epoch 00876: val_loss did not improve from 0.18475
#
# Epoch 00877: val_loss did not improve from 0.18475
#
# Epoch 00878: val_loss did not improve from 0.18475
#
# Epoch 00879: val_loss did not improve from 0.18475
#
# Epoch 00880: val_loss did not improve from 0.18475
#
# Epoch 00881: val_loss did not improve from 0.18475
#
# Epoch 00882: val_loss did not improve from 0.18475
#
# Epoch 00883: val_loss did not improve from 0.18475
#
# ...
#
# Epoch 01197: val_loss did not improve from 0.10706
#
# Epoch 01198: val_loss did not improve from 0.10706
#
# Epoch 01199: val_loss did not improve from 0.10706
#
# Epoch 01200: val_loss did not improve from 0.10706
#
# Epoch 01201: val_loss did not improve from 0.10706
#
# Epoch 01202: val_loss did not improve from 0.10706
#
# Epoch 01203: val_loss did not improve from 0.10706
#
# Epoch 01204: val_loss did not improve from 0.10706
#
# Epoch 01205: val_loss did not improve from 0.10706
#
# Epoch 01206: val_loss did not improve from 0.10706
#
# Epoch 01207: val_loss did not improve from 0.10706
#
# Epoch 01208: val_loss did not improve from 0.10706
#
# Epoch 01209: val_loss did not improve from 0.10706
#
# Epoch 01210: val_loss did not improve from 0.10706
#
# Epoch 01211: val_loss did not improve from 0.10706
#
# Epoch 01212: val_loss did not improve from 0.10706
#
# Epoch 01213: val_loss did not improve from 0.10706
#
# Epoch 01214: val_loss did not improve from 0.10706
#
# Epoch 01215: val_loss did not improve from 0.10706
#
# Epoch 01216: val_loss did not improve from 0.10706
#
# Epoch 01217: val_loss did not improve from 0.10706
#
# Epoch 01218: val_loss did not improve from 0.10706
# Epoch 01219: val_loss did not improve from 0.10706
#
# Epoch 01220: val_loss did not improve from 0.10706
#
# Epoch 01221: val_loss did not improve from 0.10706
#
# Epoch 01222: val_loss did not improve from 0.10706
#
# Epoch 01223: val_loss did not improve from 0.10706
#
# Epoch 01224: val_loss did not improve from 0.10706
#
# Epoch 01225: val_loss did not improve from 0.10706
#
# Epoch 01226: val_loss did not improve from 0.10706
#
# Epoch 01227: val_loss did not improve from 0.10706
#
# Epoch 01228: val_loss did not improve from 0.10706
#
# Epoch 01229: val_loss did not improve from 0.10706
#
# Epoch 01230: val_loss did not improve from 0.10706
#
# Epoch 01231: val_loss did not improve from 0.10706
#
# Epoch 01232: val_loss did not improve from 0.10706
#
# Epoch 01233: val_loss did not improve from 0.10706
#
# Epoch 01234: val_loss did not improve from 0.10706
#
# Epoch 01235: val_loss did not improve from 0.10706
#
# Epoch 01236: val_loss did not improve from 0.10706
#
# Epoch 01237: val_loss did not improve from 0.10706
#
# Epoch 01238: val_loss did not improve from 0.10706
#
# Epoch 01239: val_loss did not improve from 0.10706
#
# Epoch 01240: val_loss did not improve from 0.10706
#
# Epoch 01241: val_loss did not improve from 0.10706
#
# Epoch 01242: val_loss did not improve from 0.10706
#
# Epoch 01243: val_loss did not improve from 0.10706
#
# Epoch 01244: val_loss did not improve from 0.10706
#
# Epoch 01245: val_loss did not improve from 0.10706
#
# Epoch 01246: val_loss did not improve from 0.10706
#
# Epoch 01247: val_loss did not improve from 0.10706
#
# Epoch 01248: val_loss did not improve from 0.10706
#
# Epoch 01249: val_loss did not improve from 0.10706
#
# Epoch 01250: val_loss did not improve from 0.10706
#
# Epoch 01251: val_loss did not improve from 0.10706
#
# Epoch 01252: val_loss did not improve from 0.10706
#
# Epoch 01253: val_loss did not improve from 0.10706
#
# Epoch 01254: val_loss did not improve from 0.10706
#
# Epoch 01255: val_loss did not improve from 0.10706
#
# Epoch 01256: val_loss did not improve from 0.10706
#
# Epoch 01257: val_loss did not improve from 0.10706
#
# Epoch 01258: val_loss did not improve from 0.10706
#
# Epoch 01259: val_loss did not improve from 0.10706
#
# Epoch 01260: val_loss did not improve from 0.10706
#
# Epoch 01261: val_loss did not improve from 0.10706
#
# Epoch 01262: val_loss did not improve from 0.10706
#
# Epoch 01263: val_loss did not improve from 0.10706
#
# Epoch 01264: val_loss did not improve from 0.10706
#
# Epoch 01265: val_loss did not improve from 0.10706
#
# Epoch 01266: val_loss did not improve from 0.10706
#
# Epoch 01267: val_loss did not improve from 0.10706
#
# Epoch 01268: val_loss did not improve from 0.10706
#
# Epoch 01269: val_loss did not improve from 0.10706
#
# Epoch 01270: val_loss did not improve from 0.10706
#
# Epoch 01271: val_loss did not improve from 0.10706
#
# Epoch 01272: val_loss did not improve from 0.10706
#
# Epoch 01273: val_loss did not improve from 0.10706
#
# Epoch 01274: val_loss did not improve from 0.10706
#
# Epoch 01275: val_loss did not improve from 0.10706
#
# Epoch 01276: val_loss improved from 0.10706 to 0.10359, saving model to best_model_elastic.h5
#
# Epoch 01277: val_loss did not improve from 0.10359
#
# Epoch 01278: val_loss improved from 0.10359 to 0.10307, saving model to best_model_elastic.h5
#
# Epoch 01279: val_loss did not improve from 0.10307
#
# Epoch 01280: val_loss did not improve from 0.10307
#
# Epoch 01281: val_loss did not improve from 0.10307
#
# Epoch 01282: val_loss did not improve from 0.10307
#
# Epoch 01283: val_loss did not improve from 0.10307
#
# Epoch 01284: val_loss did not improve from 0.10307
#
# Epoch 01285: val_loss did not improve from 0.10307
#
# Epoch 01286: val_loss did not improve from 0.10307
#
# Epoch 01287: val_loss did not improve from 0.10307
#
# Epoch 01288: val_loss did not improve from 0.10307
#
# Epoch 01289: val_loss did not improve from 0.10307
#
# Epoch 01290: val_loss did not improve from 0.10307
#
# Epoch 01291: val_loss did not improve from 0.10307
#
# Epoch 01292: val_loss did not improve from 0.10307
#
# Epoch 01293: val_loss did not improve from 0.10307
#
# Epoch 01294: val_loss did not improve from 0.10307
#
# Epoch 01295: val_loss did not improve from 0.10307
#
# Epoch 01296: val_loss did not improve from 0.10307
#
# Epoch 01297: val_loss did not improve from 0.10307
#
# Epoch 01298: val_loss did not improve from 0.10307
#
# Epoch 01299: val_loss did not improve from 0.10307
#
# Epoch 01300: val_loss did not improve from 0.10307
#
# Epoch 01301: val_loss did not improve from 0.10307
#
# Epoch 01302: val_loss did not improve from 0.10307
#
# Epoch 01303: val_loss did not improve from 0.10307
#
# Epoch 01304: val_loss did not improve from 0.10307
#
# Epoch 01305: val_loss did not improve from 0.10307
#
# Epoch 01306: val_loss did not improve from 0.10307
#
# Epoch 01307: val_loss did not improve from 0.10307
#
# Epoch 01308: val_loss did not improve from 0.10307
#
# Epoch 01309: val_loss did not improve from 0.10307
#
# Epoch 01310: val_loss did not improve from 0.10307
#
# Epoch 01311: val_loss did not improve from 0.10307
#
# Epoch 01312: val_loss did not improve from 0.10307
#
# Epoch 01313: val_loss did not improve from 0.10307
#
# Epoch 01314: val_loss did not improve from 0.10307
#
# Epoch 01315: val_loss did not improve from 0.10307
#
# Epoch 01316: val_loss did not improve from 0.10307
#
# Epoch 01317: val_loss did not improve from 0.10307
#
# Epoch 01318: val_loss did not improve from 0.10307
#
# Epoch 01319: val_loss did not improve from 0.10307
#
# Epoch 01320: val_loss did not improve from 0.10307
#
# Epoch 01321: val_loss did not improve from 0.10307
#
# Epoch 01322: val_loss did not improve from 0.10307
#
# Epoch 01323: val_loss did not improve from 0.10307
#
# Epoch 01324: val_loss did not improve from 0.10307
#
# Epoch 01325: val_loss did not improve from 0.10307
#
# Epoch 01326: val_loss did not improve from 0.10307
#
# Epoch 01327: val_loss did not improve from 0.10307
#
# Epoch 01328: val_loss did not improve from 0.10307
#
# Epoch 01329: val_loss did not improve from 0.10307
#
# Epoch 01330: val_loss did not improve from 0.10307
#
# Epoch 01331: val_loss did not improve from 0.10307
#
# Epoch 01332: val_loss did not improve from 0.10307
#
# Epoch 01333: val_loss did not improve from 0.10307
#
# Epoch 01334: val_loss did not improve from 0.10307
#
# Epoch 01335: val_loss did not improve from 0.10307
#
# Epoch 01336: val_loss did not improve from 0.10307
#
# Epoch 01337: val_loss did not improve from 0.10307
#
# Epoch 01338: val_loss did not improve from 0.10307
#
# Epoch 01339: val_loss did not improve from 0.10307
#
# Epoch 01340: val_loss did not improve from 0.10307
#
# Epoch 01341: val_loss did not improve from 0.10307
#
# Epoch 01342: val_loss did not improve from 0.10307
#
# Epoch 01343: val_loss did not improve from 0.10307
#
# Epoch 01344: val_loss did not improve from 0.10307
#
# Epoch 01345: val_loss did not improve from 0.10307
#
# Epoch 01346: val_loss did not improve from 0.10307
#
# Epoch 01347: val_loss did not improve from 0.10307
#
# Epoch 01348: val_loss did not improve from 0.10307
#
# Epoch 01349: val_loss did not improve from 0.10307
#
# Epoch 01350: val_loss did not improve from 0.10307
#
# Epoch 01351: val_loss did not improve from 0.10307
#
# Epoch 01352: val_loss did not improve from 0.10307
#
# Epoch 01353: val_loss did not improve from 0.10307
#
# Epoch 01354: val_loss did not improve from 0.10307
#
# Epoch 01355: val_loss did not improve from 0.10307
#
# Epoch 01356: val_loss did not improve from 0.10307
#
# Epoch 01357: val_loss did not improve from 0.10307
#
# Epoch 01358: val_loss did not improve from 0.10307
#
# Epoch 01359: val_loss did not improve from 0.10307
#
# Epoch 01360: val_loss did not improve from 0.10307
#
# Epoch 01361: val_loss did not improve from 0.10307
#
# Epoch 01362: val_loss did not improve from 0.10307
#
# Epoch 01363: val_loss did not improve from 0.10307
#
# Epoch 01364: val_loss did not improve from 0.10307
#
# Epoch 01365: val_loss did not improve from 0.10307
#
# Epoch 01366: val_loss did not improve from 0.10307
#
# Epoch 01367: val_loss did not improve from 0.10307
#
# Epoch 01368: val_loss did not improve from 0.10307
#
# Epoch 01369: val_loss did not improve from 0.10307
#
# Epoch 01370: val_loss did not improve from 0.10307
#
# Epoch 01371: val_loss did not improve from 0.10307
#
# Epoch 01372: val_loss did not improve from 0.10307
#
# Epoch 01373: val_loss did not improve from 0.10307
#
# Epoch 01374: val_loss did not improve from 0.10307
# Epoch 01375: val_loss did not improve from 0.10307
#
# Epoch 01376: val_loss did not improve from 0.10307
#
# Epoch 01377: val_loss did not improve from 0.10307
#
# Epoch 01378: val_loss did not improve from 0.10307
#
# Epoch 01379: val_loss did not improve from 0.10307
#
# Epoch 01380: val_loss did not improve from 0.10307
#
# Epoch 01381: val_loss did not improve from 0.10307
#
# Epoch 01382: val_loss did not improve from 0.10307
#
# Epoch 01383: val_loss did not improve from 0.10307
#
# Epoch 01384: val_loss did not improve from 0.10307
#
# Epoch 01385: val_loss did not improve from 0.10307
#
# Epoch 01386: val_loss improved from 0.10307 to 0.10136, saving model to best_model_elastic.h5
#
# Epoch 01387: val_loss did not improve from 0.10136
#
# Epoch 01388: val_loss did not improve from 0.10136
#
# Epoch 01389: val_loss did not improve from 0.10136
#
# Epoch 01390: val_loss did not improve from 0.10136
#
# Epoch 01391: val_loss did not improve from 0.10136
#
# Epoch 01392: val_loss did not improve from 0.10136
#
# Epoch 01393: val_loss did not improve from 0.10136
#
# Epoch 01394: val_loss did not improve from 0.10136
#
# Epoch 01395: val_loss did not improve from 0.10136
#
# Epoch 01396: val_loss did not improve from 0.10136
#
# Epoch 01397: val_loss did not improve from 0.10136
#
# Epoch 01398: val_loss did not improve from 0.10136
#
# Epoch 01399: val_loss did not improve from 0.10136
#
# Epoch 01400: val_loss did not improve from 0.10136
#
# Epoch 01401: val_loss did not improve from 0.10136
#
# Epoch 01402: val_loss did not improve from 0.10136
#
# Epoch 01403: val_loss did not improve from 0.10136
#
# Epoch 01404: val_loss did not improve from 0.10136
#
# Epoch 01405: val_loss did not improve from 0.10136
#
# Epoch 01406: val_loss did not improve from 0.10136
#
# Epoch 01407: val_loss did not improve from 0.10136
#
# Epoch 01408: val_loss did not improve from 0.10136
#
# Epoch 01409: val_loss did not improve from 0.10136
#
# Epoch 01410: val_loss did not improve from 0.10136
#
# Epoch 01411: val_loss did not improve from 0.10136
#
# Epoch 01412: val_loss did not improve from 0.10136
#
# Epoch 01413: val_loss did not improve from 0.10136
#
# Epoch 01414: val_loss did not improve from 0.10136
#
# Epoch 01415: val_loss did not improve from 0.10136
#
# Epoch 01416: val_loss did not improve from 0.10136
#
# Epoch 01417: val_loss did not improve from 0.10136
#
# Epoch 01418: val_loss did not improve from 0.10136
#
# Epoch 01419: val_loss did not improve from 0.10136
#
# Epoch 01420: val_loss did not improve from 0.10136
#
# Epoch 01421: val_loss did not improve from 0.10136
#
# Epoch 01422: val_loss did not improve from 0.10136
#
# Epoch 01423: val_loss did not improve from 0.10136
#
# Epoch 01424: val_loss did not improve from 0.10136
#
# Epoch 01425: val_loss did not improve from 0.10136
#
# Epoch 01426: val_loss did not improve from 0.10136
#
# Epoch 01427: val_loss did not improve from 0.10136
#
# Epoch 01428: val_loss did not improve from 0.10136
#
# Epoch 01429: val_loss did not improve from 0.10136
#
# Epoch 01430: val_loss did not improve from 0.10136
#
# Epoch 01431: val_loss did not improve from 0.10136
#
# Epoch 01432: val_loss did not improve from 0.10136
#
# Epoch 01433: val_loss did not improve from 0.10136
#
# Epoch 01434: val_loss did not improve from 0.10136
#
# Epoch 01435: val_loss did not improve from 0.10136
#
# Epoch 01436: val_loss did not improve from 0.10136
#
# Epoch 01437: val_loss did not improve from 0.10136
#
# Epoch 01438: val_loss did not improve from 0.10136
#
# Epoch 01439: val_loss did not improve from 0.10136
#
# Epoch 01440: val_loss did not improve from 0.10136
#
# Epoch 01441: val_loss did not improve from 0.10136
#
# Epoch 01442: val_loss did not improve from 0.10136
#
# Epoch 01443: val_loss did not improve from 0.10136
#
# Epoch 01444: val_loss did not improve from 0.10136
#
# Epoch 01445: val_loss did not improve from 0.10136
#
# Epoch 01446: val_loss did not improve from 0.10136
#
# Epoch 01447: val_loss did not improve from 0.10136
#
# Epoch 01448: val_loss did not improve from 0.10136
#
# Epoch 01449: val_loss did not improve from 0.10136
#
# Epoch 01450: val_loss did not improve from 0.10136
#
# Epoch 01451: val_loss did not improve from 0.10136
#
# Epoch 01452: val_loss did not improve from 0.10136
#
# Epoch 01453: val_loss did not improve from 0.10136
#
# Epoch 01454: val_loss did not improve from 0.10136
#
# Epoch 01455: val_loss did not improve from 0.10136
#
# Epoch 01456: val_loss did not improve from 0.10136
#
# Epoch 01457: val_loss did not improve from 0.10136
#
# Epoch 01458: val_loss did not improve from 0.10136
#
# Epoch 01459: val_loss did not improve from 0.10136
#
# Epoch 01460: val_loss did not improve from 0.10136
#
# Epoch 01461: val_loss did not improve from 0.10136
#
# Epoch 01462: val_loss did not improve from 0.10136
#
# Epoch 01463: val_loss did not improve from 0.10136
#
# Epoch 01464: val_loss did not improve from 0.10136
#
# Epoch 01465: val_loss did not improve from 0.10136
#
# Epoch 01466: val_loss did not improve from 0.10136
#
# Epoch 01467: val_loss did not improve from 0.10136
#
# Epoch 01468: val_loss did not improve from 0.10136
#
# Epoch 01469: val_loss did not improve from 0.10136
#
# Epoch 01470: val_loss did not improve from 0.10136
#
# Epoch 01471: val_loss did not improve from 0.10136
#
# Epoch 01472: val_loss did not improve from 0.10136
#
# Epoch 01473: val_loss did not improve from 0.10136
#
# Epoch 01474: val_loss did not improve from 0.10136
#
# Epoch 01475: val_loss did not improve from 0.10136
#
# Epoch 01476: val_loss did not improve from 0.10136
#
# Epoch 01477: val_loss did not improve from 0.10136
#
# Epoch 01478: val_loss did not improve from 0.10136
#
# Epoch 01479: val_loss did not improve from 0.10136
#
# Epoch 01480: val_loss did not improve from 0.10136
#
# Epoch 01481: val_loss did not improve from 0.10136
#
# Epoch 01482: val_loss did not improve from 0.10136
#
# Epoch 01483: val_loss did not improve from 0.10136
#
# Epoch 01484: val_loss did not improve from 0.10136
#
# Epoch 01485: val_loss did not improve from 0.10136
#
# Epoch 01486: val_loss did not improve from 0.10136
#
# Epoch 01487: val_loss did not improve from 0.10136
#
# Epoch 01488: val_loss did not improve from 0.10136
#
# Epoch 01489: val_loss did not improve from 0.10136
#
# Epoch 01490: val_loss did not improve from 0.10136
#
# Epoch 01491: val_loss did not improve from 0.10136
#
# Epoch 01492: val_loss did not improve from 0.10136
#
# Epoch 01493: val_loss did not improve from 0.10136
#
# Epoch 01494: val_loss did not improve from 0.10136
#
# Epoch 01495: val_loss did not improve from 0.10136
#
# Epoch 01496: val_loss improved from 0.10136 to 0.09632, saving model to best_model_elastic.h5
#
# Epoch 01497: val_loss did not improve from 0.09632
#
# Epoch 01498: val_loss did not improve from 0.09632
#
# Epoch 01499: val_loss did not improve from 0.09632
#
# Epoch 01500: val_loss did not improve from 0.09632

# %%
# load the saved model
ElasticModel = load_model('best_model_elastic.h5')

# %%
# Testing and evaluating the model
preds = ElasticModel.evaluate(X_test, Y_test, batch_size=32, verbose=0, sample_weight=None)
print()
print ("Loss = " + str(preds))
# print ("Test Accuracy = " + str(preds[1]))
# Out:
# Loss = 0.09648749685287475

# %%
# Plotting the learning curve 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# plt.plot(history.history['loss']/np.max(history.history['loss']))
# plt.plot(history.history['val_loss']/np.max(history.history['val_loss']))
# plt.yscale("log")
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])


plt.title('Learning curve')
# plt.ylabel('Error/Accuracy')
plt.ylabel('Error')
plt.xlabel('epochs')
plt.legend(['train loss', 'validation loss'], loc='center right')
# plt.savefig('/Figures/learning_curve_08Nov.png', bbox_inches='tight')

# %%
# Save trained model 
# serialize model to JSON
model_json = ElasticModel.to_json()
with open("elastic_model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
ElasticModel.save_weights("ElasticModel.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Load saved model
# load json and create model
json_file = open('elastic_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("ElasticModel.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
adam = optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)


ElasticModel.compile(loss='mean_squared_error', optimizer = adam)


# To evaluate run the "Testing and evaluating the model" cell
# Out:
# Loaded model from disk

# %%
# Predict training and test data using the trained network
test_output = ElasticModel.predict(X_test)
train_output = ElasticModel.predict(X_train)

# %%
# Checking training data

sample_number = 25
f, axarr = plt.subplots(1, 2, sharey = True)

axarr[0].plot(train_output[sample_number, 0, :], time_upscaled, '-k')
axarr[0].plot(Y_train[sample_number, 0, :], time_upscaled, '--r')
axarr[0].set_xlabel("Ip")
axarr[0].set_ylabel("Time")
axarr[0].invert_yaxis()
# axarr[0].set_xlim(1.5,3.1)

axarr[1].plot(train_output[sample_number, 1, :], time_upscaled, '-k')
axarr[1].plot(Y_train[sample_number, 1, :], time_upscaled, '--r')
axarr[1].set_xlabel("Vp/Vs")
axarr[1].set_ylabel("Time")
# axarr[1].invert_yaxis()
# axarr[1].set_xlim(1,2)

# axarr[2].plot(train_output[sample_number, 2, :], time_upscaled, '-k')
# axarr[2].plot(Y_train[sample_number, 2, :], time_upscaled, '--r')
# axarr[2].set_xlabel("RHOB")
# axarr[2].set_ylabel("Time")
# axarr[2].invert_yaxis()
# axarr[2].set_xlim(1.5,3)
# Out:
# Text(0,0.5,'Time')

# %%
# Checking testing data

sample_number = 12
f, axarr = plt.subplots(1, 2, sharey = True)

axarr[0].plot(test_output[sample_number, 0, :], time_upscaled, '-k')
axarr[0].plot(Y_test[sample_number, 0, :], time_upscaled, '--r')
axarr[0].set_xlabel("Ip")
axarr[0].set_ylabel("Time")
axarr[0].invert_yaxis()
# axarr[0].set_xlim(1.5,3.1)

axarr[1].plot(test_output[sample_number, 1, :], time_upscaled, '-k')
axarr[1].plot(Y_test[sample_number, 1, :], time_upscaled, '--r')
axarr[1].set_xlabel("Vp/Vs")
axarr[1].set_ylabel("Time")
axarr[1].invert_yaxis()
axarr[1].set_xlim(1,2.5)

# axarr[2].plot(test_output[sample_number, 2, :], time_upscaled, '-k')
# axarr[2].plot(Y_test[sample_number, 2, :], time_upscaled, '--r')
# axarr[2].set_xlabel("RHOB")
# axarr[2].set_ylabel("Time")
# axarr[2].invert_yaxis()
# axarr[2].set_xlim(1.5,3)
# Out:
# (1, 2.5)

# %%
# Correlation coefficient between true and predicted traces 

Ip_corr_train = np.zeros(train_output.shape[0])
Vp_Vs_corr_train = np.zeros(train_output.shape[0])
# RHOB_corr_train = np.zeros(train_output.shape[0])
for i in range(train_output.shape[0]):
    Ip_corr_train[i] = np.corrcoef(train_output[i,0,:], Y_train[i,0,:])[0,1]
    Vp_Vs_corr_train[i] = np.corrcoef(train_output[i,1,:], Y_train[i,1,:])[0,1]
#     RHOB_corr_train[i] = np.corrcoef(train_output[i,2,:], Y_train[i,2,:])[0,1]
    
Ip_corr_test = np.zeros(test_output.shape[0])
Vp_Vs_corr_test = np.zeros(test_output.shape[0])
# RHOB_corr_test = np.zeros(test_output.shape[0])
for i in range(test_output.shape[0]):
    Ip_corr_test[i] = np.corrcoef(test_output[i,0,:], Y_test[i,0,:])[0,1]
    Vp_Vs_corr_test[i] = np.corrcoef(test_output[i,1,:], Y_test[i,1,:])[0,1]
#     RHOB_corr_test[i] = np.corrcoef(test_output[i,2,:], Y_test[i,2,:])[0,1]

    
# Average correlation coefficient
print("Average correlation in Ip for training data = ", np.mean(Ip_corr_train))
print("Average correlation in Vp_Vs for training data = ", np.mean(Vp_Vs_corr_train))
# print("Average correlation in RHOB for training data = ", np.mean(RHOB_corr_train))

print("Average correlation in Ip for training data = ", np.mean(Ip_corr_test))
print("Average correlation in Vp_Vs for training data = ", np.mean(Vp_Vs_corr_test))
# print("Average correlation in RHOB for training data = ", np.mean(RHOB_corr_test))
# Out:
# Average correlation in Ip for training data =  0.799504427479399
# Average correlation in Vp_Vs for training data =  0.7904172483595701
# Average correlation in Ip for training data =  0.773477842234761
# Average correlation in Vp_Vs for training data =  0.7647236314374728

# %%
# Box plot of correlation coefficients 

from pylab import plot, show, savefig, xlim, figure, \
                hold, ylim, legend, boxplot, setp, axes

# function for setting the colors of the box plots pairs
def setBoxColors(bp):
    setp(bp['boxes'][0], color='blue')
    setp(bp['caps'][0], color='blue')
    setp(bp['caps'][1], color='blue')
    setp(bp['whiskers'][0], color='blue')
    setp(bp['whiskers'][1], color='blue')
#     setp(bp['fliers'][0], color='blue')
#     setp(bp['fliers'][1], color='blue')
    setp(bp['medians'][0], color='blue')

    setp(bp['boxes'][1], color='red')
    setp(bp['caps'][2], color='red')
    setp(bp['caps'][3], color='red')
    setp(bp['whiskers'][2], color='red')
    setp(bp['whiskers'][3], color='red')
#     setp(bp['fliers'][2], color='red')
#     setp(bp['fliers'][3], color='red')
    setp(bp['medians'][1], color='red')

A= [Ip_corr_train, Ip_corr_test]
B = [Vp_Vs_corr_train, Vp_Vs_corr_test]
# C = [RHOB_corr_train, RHOB_corr_test]

fig = figure()
ax = axes()

# first boxplot pair
bp = boxplot(A, positions = [1, 2], widths = 0.6, showfliers=False)
setBoxColors(bp)

# second boxplot pair
bp = boxplot(B, positions = [4, 5], widths = 0.6, showfliers=False)
setBoxColors(bp)

# # thrid boxplot pair
# bp = boxplot(C, positions = [7, 8], widths = 0.6, showfliers=False)
# setBoxColors(bp)

# set axes limits and labels
# xlim(0,9)
xlim(0,6)
ylim(0,1)
# ax.set_xticklabels(['Vp', 'Vs', 'RHOB'])
ax.set_xticklabels(['Ip', 'Vp/Vs'])
# ax.set_xticks([1.5, 4.5, 7.5])
ax.set_xticks([1.5, 4.5])
plt.ylabel('Correlation coefficient')

# draw temporary red and blue lines and use them to create a legend
hB, = plot([1,1],'b-')
hR, = plot([1,1],'r-')
legend((hB, hR),('Training', 'Test'), loc='lower left')
hB.set_visible(False)
hR.set_visible(False)

# %%
# Spectral coherence between true and predicted (training data)

sample_number = 25
Cxy_ip, wavenumber_ip = plt.cohere(Y_train[sample_number,0,:], train_output[sample_number,0,:], NFFT=16, Fs=1, color="blue")
Cxy_vp_vs, wavenumber_vp_vs = plt.cohere(Y_train[sample_number,1,:], train_output[sample_number,1,:], NFFT=16, Fs=1, color="red") 
# Cxy_rhob, wavenumber_rhob = plt.cohere(Y_train[sample_number,2,:], train_output[sample_number,2,:], NFFT=16, Fs=1, color="black")

# Adding epsilon to the first wavenumber value
wavenumber_ip[0] = wavenumber_ip[0] + 0.001
wavenumber_vp_vs[0] = wavenumber_vp_vs[0] + 0.001
# wavenumber_rhob[0] = wavenumber_rhob[0] + 0.001

plt.plot(1/wavenumber_ip, Cxy_ip, color="blue")
plt.plot(1/wavenumber_vp_vs, Cxy_vp_vs, color="red")
# plt.plot(1/wavenumber_rhob, Cxy_rhob, color="black")

plt.xlim(100,2)
plt.gca().invert_xaxis()
plt.xscale("log")

# plt.gca().legend(('Vp','Vs', 'RHOB'))
plt.gca().legend(('Ip','Vp/Vs'))
plt.xlabel('1/Frequency')
plt.ylabel('Coherence')
plt.title('Training example')
plt.grid(b=False)

# %%
# Spectral coherence between true and predicted (training data)

sample_number = 12
Cxy_ip, wavenumber_ip = plt.cohere(Y_test[sample_number,0,:], test_output[sample_number,0,:], NFFT=16, Fs=1, color="blue")
Cxy_vp_vs, wavenumber_vp_vs = plt.cohere(Y_test[sample_number,1,:], test_output[sample_number,1,:], NFFT=16, Fs=1, color="red") 
# Cxy_rhob, wavenumber_rhob = plt.cohere(Y_test[sample_number,2,:], test_output[sample_number,2,:], NFFT=16, Fs=1, color="black")

# Adding epsilon to the first wavenumber value
wavenumber_ip[0] = wavenumber_ip[0] + 0.001
wavenumber_vp_vs[0] = wavenumber_vp_vs[0] + 0.001
# wavenumber_rhob[0] = wavenumber_rhob[0] + 0.001

plt.plot(1/wavenumber_ip, Cxy_ip, color="blue")
plt.plot(1/wavenumber_vp_vs, Cxy_vp_vs, color="red")
# plt.plot(1/wavenumber_rhob, Cxy_rhob, color="black")

plt.xlim(100,2)
plt.gca().invert_xaxis()
plt.xscale("log")

# plt.gca().legend(('Vp','Vs', 'RHOB'))
plt.gca().legend(('Ip','Vp/Vs'))
plt.xlabel('1/Frequency')
plt.ylabel('Coherence')
plt.title('Test example')
plt.grid(b=False)

# %% [markdown]
# ## Predicting petrophysical properties from elastic properties of previous network

# %%
# Use predicted Ip, Vp/Vs from network
# Concatenate Ip, Vp/Vs

num_examples = Vp_time.shape[0]
emodel_true = np.concatenate((Vp_time*RHOB_time,Vp_time/Vs_time,), axis=1)
emodel_true = emodel.reshape((num_examples, 2, nt))

# emodel_norm = ElasticModel.predict(np.expand_dims(seis_reshaped_normalized, axis=3))
emodel = ElasticModel.predict(np.expand_dims(angle_seis_reshaped_normalized, axis=3))


# Concatenate Porosity, Vclay
num_examples = porosity.shape[0]
ndepth = porosity.shape[1]

# Normalize porosity
porosity_norm = (porosity - np.min(porosity))/(np.max(porosity) - np.min(porosity))

# petromodel = np.concatenate((porosity,vclay,Sw), axis=1)
# petromodel = petromodel.reshape((num_examples, 3, ndepth))
petromodel = np.concatenate((porosity_norm,vclay), axis=1)
petromodel = petromodel.reshape((num_examples, 2, ndepth))

# Split data into train and test set - elastic model predicted
X_train, X_test, Y_train_norm, Y_test_norm = sklearn.model_selection.train_test_split(emodel, 
                                                                            petromodel, test_size=0.2, random_state=1)

# Split data into train and test set - elastic model true
X_train_true, X_test_true, Y_train_true_norm, Y_test_true_norm = sklearn.model_selection.train_test_split(emodel_true, 
                                                                            petromodel, test_size=0.2, random_state=1)


# Add 4th dimension of number of channels=1 to the input data
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)


print ("number of training examples = " + str(X_train.shape[0]))
# print ("number of validation examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train_norm.shape))
# print ("X_val shape: " + str(X_val.shape))
# print ("Y_val shape: " + str(Y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test_norm.shape))
# Out:
# number of training examples = 2000
# number of test examples = 500
# X_train shape: (2000, 2, 246, 1)
# Y_train shape: (2000, 2, 199)
# X_test shape: (500, 2, 246, 1)
# Y_test shape: (500, 2, 199)

# %%
# Building neural network for petrophysical properties prediction in Keras 
given_seed = 3 # For repeatibility

def elastic_petronet(input_shape):
    """
    Implementation of the AVONet.
    
    Arguments:
    input_shape -- shape of the images of the dataset

    Returns:
    model -- a Model() instance in Keras
    """
    

    # Define the input placeholder as a tensor with shape input_shape. Input = input angle gather 
    X_input = Input(input_shape)

    X = X_input

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(8, (1, 30), strides=(1, 2), name='conv0', padding='same',
               kernel_initializer=initializers.he_normal(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn0')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv0')(X)
    # MAXPOOL
#     X = MaxPooling2D((2, 2), strides=(1,1),name='max_pool0')(X)
    
    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(5, (1, 60), strides=(1, 2), name='conv1', padding='same',
               kernel_initializer=initializers.he_normal(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn1')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv1')(X)
    # MAXPOOL
#     X = MaxPooling2D((2, 2), strides=(1,1),name='max_pool1')(X)

#     # CONV -> BN -> RELU Block applied to X
#     X = Conv2D(16, (1, 30), strides=(1, 2), name='conv2', padding='same',
#                kernel_initializer=initializers.he_normal(seed=given_seed), bias_initializer='zeros')(X)
#     X = BatchNormalization(axis=-1, name='bn2')(X)
#     X = Activation('relu')(X)
#     X = Dropout(rate=0.3, name='drop_conv2')(X)
#     # MAXPOOL
# #     X = MaxPooling2D((2, 2), strides=(1,1),name='max_pool1')(X)

#     # CONV -> BN -> RELU Block applied to X
#     X = Conv2D(8, (1, 60), strides=(1, 2), name='conv3', padding='same',
#                kernel_initializer=initializers.he_normal(seed=given_seed), bias_initializer='zeros')(X)
#     X = BatchNormalization(axis=-1, name='bn3')(X)
#     X = Activation('relu')(X)
#     X = Dropout(rate=0.3, name='drop_conv3')(X)
#     # MAXPOOL
# #     X = MaxPooling2D((2, 2), strides=(1,1),name='max_pool1')(X)



    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
#     X = Dense(1200, name='fc1')(X)
#     X = Activation('relu')(X)
    X = Dense(199*2, name='fc1')(X)
    X = Activation('relu')(X)
    
    X = Reshape((2, 199))(X)
    
    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs=X_input, outputs=X, name='ElasticPetroModel')

    return model
    ### END CODE HERE ###

# %%
# Create the model
ElasticPetroModel = elastic_petronet(X_train.shape[1:])

# %%
# Summary and plot of the model

ElasticPetroModel.summary()


# plot_model(AVOModel)
# SVG(model_to_dot(ElasticModel).create(prog='dot', format='svg'))
# plot_model(ElasticModel, to_file='./Figures/model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 2, 246, 1)         0
# _________________________________________________________________
# conv0 (Conv2D)               (None, 2, 123, 8)         248
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 2, 123, 8)         32
# _________________________________________________________________
# activation_30 (Activation)   (None, 2, 123, 8)         0
# _________________________________________________________________
# drop_conv0 (Dropout)         (None, 2, 123, 8)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 2, 62, 5)          2405
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 2, 62, 5)          20
# _________________________________________________________________
# activation_31 (Activation)   (None, 2, 62, 5)          0
# _________________________________________________________________
# drop_conv1 (Dropout)         (None, 2, 62, 5)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 620)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 398)               247158
# _________________________________________________________________
# activation_32 (Activation)   (None, 398)               0
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 2, 199)            0
# =================================================================
# Total params: 249,863
# Trainable params: 249,837
# Non-trainable params: 26
# _________________________________________________________________

# %%
# Learning rate scheduler
from keras.callbacks import LearningRateScheduler
# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.1
    epochs_drop = 50.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

# %%
# Compile the model with optimization algorithm, loss function
adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

ElasticPetroModel.compile(loss='mean_squared_error', optimizer = adam)

# %%
# Removing previous best_model.h5 file
import os
os.remove("best_model_elastic_petro.h5")

# %%
# Using early stopping and Model Checkpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)
mc = ModelCheckpoint('best_model_elastic_petro.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
# Start the training
# Using learning rate scheduler
# lrate = LearningRateScheduler(step_decay)
# callbacks_list = [es, mc, lrate]
# history = ElasticModel.fit(X_train, Y_train, validation_split=0.2, 
#                            epochs=1500, batch_size=32, callbacks=callbacks_list, verbose=0)

history = ElasticPetroModel.fit(X_train, Y_train_norm, validation_split=0.2, 
                           epochs=1500, batch_size=32, callbacks=[es, mc],
                          verbose = 0)
# Out:
# Epoch 00001: val_loss improved from inf to 0.14789, saving model to best_model_elastic_petro.h5
#
# Epoch 00002: val_loss improved from 0.14789 to 0.11427, saving model to best_model_elastic_petro.h5
#
# Epoch 00003: val_loss improved from 0.11427 to 0.09867, saving model to best_model_elastic_petro.h5
#
# Epoch 00004: val_loss improved from 0.09867 to 0.09309, saving model to best_model_elastic_petro.h5
#
# Epoch 00005: val_loss improved from 0.09309 to 0.08488, saving model to best_model_elastic_petro.h5
#
# Epoch 00006: val_loss improved from 0.08488 to 0.07482, saving model to best_model_elastic_petro.h5
#
# Epoch 00007: val_loss improved from 0.07482 to 0.07430, saving model to best_model_elastic_petro.h5
#
# Epoch 00008: val_loss did not improve from 0.07430
#
# Epoch 00009: val_loss did not improve from 0.07430
#
# Epoch 00010: val_loss did not improve from 0.07430
#
# Epoch 00011: val_loss did not improve from 0.07430
#
# Epoch 00012: val_loss did not improve from 0.07430
#
# Epoch 00013: val_loss did not improve from 0.07430
#
# Epoch 00014: val_loss improved from 0.07430 to 0.06983, saving model to best_model_elastic_petro.h5
#
# Epoch 00015: val_loss did not improve from 0.06983
#
# Epoch 00016: val_loss improved from 0.06983 to 0.06333, saving model to best_model_elastic_petro.h5
#
# Epoch 00017: val_loss improved from 0.06333 to 0.06257, saving model to best_model_elastic_petro.h5
#
# Epoch 00018: val_loss improved from 0.06257 to 0.05309, saving model to best_model_elastic_petro.h5
#
# Epoch 00019: val_loss improved from 0.05309 to 0.05114, saving model to best_model_elastic_petro.h5
#
# Epoch 00020: val_loss did not improve from 0.05114
#
# Epoch 00021: val_loss improved from 0.05114 to 0.04994, saving model to best_model_elastic_petro.h5
#
# Epoch 00022: val_loss did not improve from 0.04994
#
# Epoch 00023: val_loss did not improve from 0.04994
#
# Epoch 00024: val_loss did not improve from 0.04994
#
# Epoch 00025: val_loss did not improve from 0.04994
#
# Epoch 00026: val_loss did not improve from 0.04994
#
# Epoch 00027: val_loss did not improve from 0.04994
#
# Epoch 00028: val_loss did not improve from 0.04994
#
# Epoch 00029: val_loss did not improve from 0.04994
#
# Epoch 00030: val_loss did not improve from 0.04994
#
# Epoch 00031: val_loss did not improve from 0.04994
#
# Epoch 00032: val_loss did not improve from 0.04994
#
# Epoch 00033: val_loss did not improve from 0.04994
#
# Epoch 00034: val_loss did not improve from 0.04994
#
# Epoch 00035: val_loss improved from 0.04994 to 0.04499, saving model to best_model_elastic_petro.h5
#
# Epoch 00036: val_loss improved from 0.04499 to 0.04073, saving model to best_model_elastic_petro.h5
#
# Epoch 00037: val_loss did not improve from 0.04073
#
# Epoch 00038: val_loss did not improve from 0.04073
#
# Epoch 00039: val_loss did not improve from 0.04073
#
# Epoch 00040: val_loss did not improve from 0.04073
#
# Epoch 00041: val_loss did not improve from 0.04073
#
# Epoch 00042: val_loss improved from 0.04073 to 0.04062, saving model to best_model_elastic_petro.h5
#
# Epoch 00043: val_loss improved from 0.04062 to 0.03909, saving model to best_model_elastic_petro.h5
#
# Epoch 00044: val_loss did not improve from 0.03909
#
# Epoch 00045: val_loss improved from 0.03909 to 0.03840, saving model to best_model_elastic_petro.h5
#
# Epoch 00046: val_loss improved from 0.03840 to 0.03780, saving model to best_model_elastic_petro.h5
#
# Epoch 00047: val_loss did not improve from 0.03780
#
# Epoch 00048: val_loss improved from 0.03780 to 0.03561, saving model to best_model_elastic_petro.h5
#
# Epoch 00049: val_loss did not improve from 0.03561
#
# Epoch 00050: val_loss did not improve from 0.03561
#
# Epoch 00051: val_loss improved from 0.03561 to 0.03514, saving model to best_model_elastic_petro.h5
#
# Epoch 00052: val_loss did not improve from 0.03514
#
# Epoch 00053: val_loss did not improve from 0.03514
#
# Epoch 00054: val_loss did not improve from 0.03514
#
# Epoch 00055: val_loss improved from 0.03514 to 0.03506, saving model to best_model_elastic_petro.h5
#
# Epoch 00056: val_loss did not improve from 0.03506
#
# Epoch 00057: val_loss did not improve from 0.03506
#
# Epoch 00058: val_loss did not improve from 0.03506
#
# Epoch 00059: val_loss did not improve from 0.03506
#
# Epoch 00060: val_loss improved from 0.03506 to 0.03494, saving model to best_model_elastic_petro.h5
#
# Epoch 00061: val_loss did not improve from 0.03494
#
# Epoch 00062: val_loss improved from 0.03494 to 0.03392, saving model to best_model_elastic_petro.h5
#
# Epoch 00063: val_loss did not improve from 0.03392
#
# Epoch 00064: val_loss did not improve from 0.03392
#
# Epoch 00065: val_loss did not improve from 0.03392
#
# Epoch 00066: val_loss did not improve from 0.03392
#
# Epoch 00067: val_loss did not improve from 0.03392
#
# Epoch 00068: val_loss did not improve from 0.03392
#
# Epoch 00069: val_loss did not improve from 0.03392
#
# Epoch 00070: val_loss did not improve from 0.03392
#
# Epoch 00071: val_loss did not improve from 0.03392
#
# Epoch 00072: val_loss did not improve from 0.03392
#
# Epoch 00073: val_loss did not improve from 0.03392
#
# Epoch 00074: val_loss did not improve from 0.03392
#
# Epoch 00075: val_loss did not improve from 0.03392
#
# Epoch 00076: val_loss did not improve from 0.03392
#
# Epoch 00077: val_loss did not improve from 0.03392
#
# Epoch 00078: val_loss did not improve from 0.03392
#
# Epoch 00079: val_loss did not improve from 0.03392
#
# Epoch 00080: val_loss did not improve from 0.03392
#
# Epoch 00081: val_loss did not improve from 0.03392
#
# Epoch 00082: val_loss did not improve from 0.03392
#
# Epoch 00083: val_loss improved from 0.03392 to 0.03391, saving model to best_model_elastic_petro.h5
#
# Epoch 00084: val_loss improved from 0.03391 to 0.03351, saving model to best_model_elastic_petro.h5
#
# Epoch 00085: val_loss did not improve from 0.03351
#
# Epoch 00086: val_loss did not improve from 0.03351
#
# Epoch 00087: val_loss did not improve from 0.03351
#
# Epoch 00088: val_loss did not improve from 0.03351
#
# Epoch 00089: val_loss did not improve from 0.03351
#
# Epoch 00090: val_loss did not improve from 0.03351
#
# Epoch 00091: val_loss did not improve from 0.03351
#
# Epoch 00092: val_loss improved from 0.03351 to 0.03343, saving model to best_model_elastic_petro.h5
#
# Epoch 00093: val_loss did not improve from 0.03343
#
# Epoch 00094: val_loss did not improve from 0.03343
#
# Epoch 00095: val_loss did not improve from 0.03343
#
# Epoch 00096: val_loss did not improve from 0.03343
#
# Epoch 00097: val_loss did not improve from 0.03343
#
# Epoch 00098: val_loss did not improve from 0.03343
#
# Epoch 00099: val_loss did not improve from 0.03343
#
# Epoch 00100: val_loss did not improve from 0.03343
#
# Epoch 00101: val_loss did not improve from 0.03343
#
# Epoch 00102: val_loss did not improve from 0.03343
#
# Epoch 00103: val_loss did not improve from 0.03343
#
# Epoch 00104: val_loss did not improve from 0.03343
#
# Epoch 00105: val_loss did not improve from 0.03343
#
# Epoch 00106: val_loss did not improve from 0.03343
#
# Epoch 00107: val_loss did not improve from 0.03343
#
# Epoch 00108: val_loss did not improve from 0.03343
#
# Epoch 00109: val_loss did not improve from 0.03343
#
# Epoch 00110: val_loss did not improve from 0.03343
#
# Epoch 00111: val_loss improved from 0.03343 to 0.03336, saving model to best_model_elastic_petro.h5
#
# Epoch 00112: val_loss did not improve from 0.03336
#
# Epoch 00113: val_loss did not improve from 0.03336
#
# Epoch 00114: val_loss improved from 0.03336 to 0.03333, saving model to best_model_elastic_petro.h5
#
# Epoch 00115: val_loss did not improve from 0.03333
#
# Epoch 00116: val_loss did not improve from 0.03333
#
# Epoch 00117: val_loss did not improve from 0.03333
#
# Epoch 00118: val_loss did not improve from 0.03333
#
# Epoch 00119: val_loss did not improve from 0.03333
#
# Epoch 00120: val_loss did not improve from 0.03333
#
# Epoch 00121: val_loss did not improve from 0.03333
#
# Epoch 00122: val_loss did not improve from 0.03333
#
# Epoch 00123: val_loss did not improve from 0.03333
#
# Epoch 00124: val_loss did not improve from 0.03333
#
# Epoch 00125: val_loss did not improve from 0.03333
#
# Epoch 00126: val_loss did not improve from 0.03333
#
# Epoch 00127: val_loss did not improve from 0.03333
#
# Epoch 00128: val_loss did not improve from 0.03333
#
# Epoch 00129: val_loss did not improve from 0.03333
#
# Epoch 00130: val_loss did not improve from 0.03333
#
# Epoch 00131: val_loss did not improve from 0.03333
# Epoch 00132: val_loss did not improve from 0.03333
#
# Epoch 00133: val_loss did not improve from 0.03333
#
# Epoch 00134: val_loss did not improve from 0.03333
#
# Epoch 00135: val_loss did not improve from 0.03333
#
# Epoch 00136: val_loss did not improve from 0.03333
#
# Epoch 00137: val_loss did not improve from 0.03333
#
# Epoch 00138: val_loss did not improve from 0.03333
#
# Epoch 00139: val_loss did not improve from 0.03333
#
# Epoch 00140: val_loss did not improve from 0.03333
#
# Epoch 00141: val_loss did not improve from 0.03333
#
# Epoch 00142: val_loss did not improve from 0.03333
#
# Epoch 00143: val_loss did not improve from 0.03333
#
# Epoch 00144: val_loss did not improve from 0.03333
#
# Epoch 00145: val_loss did not improve from 0.03333
#
# Epoch 00146: val_loss did not improve from 0.03333
#
# Epoch 00147: val_loss did not improve from 0.03333
#
# Epoch 00148: val_loss did not improve from 0.03333
#
# Epoch 00149: val_loss did not improve from 0.03333
#
# Epoch 00150: val_loss did not improve from 0.03333
#
# Epoch 00151: val_loss did not improve from 0.03333
#
# Epoch 00152: val_loss did not improve from 0.03333
#
# Epoch 00153: val_loss did not improve from 0.03333
#
# Epoch 00154: val_loss did not improve from 0.03333
#
# Epoch 00155: val_loss did not improve from 0.03333
#
# Epoch 00156: val_loss did not improve from 0.03333
#
# Epoch 00157: val_loss did not improve from 0.03333
#
# Epoch 00158: val_loss did not improve from 0.03333
#
# Epoch 00159: val_loss did not improve from 0.03333
#
# Epoch 00160: val_loss did not improve from 0.03333
#
# Epoch 00161: val_loss did not improve from 0.03333
#
# Epoch 00162: val_loss did not improve from 0.03333
#
# Epoch 00163: val_loss did not improve from 0.03333
#
# Epoch 00164: val_loss did not improve from 0.03333
#
# Epoch 00165: val_loss did not improve from 0.03333
#
# Epoch 00166: val_loss did not improve from 0.03333
#
# Epoch 00167: val_loss did not improve from 0.03333
#
# Epoch 00168: val_loss did not improve from 0.03333
#
# Epoch 00169: val_loss did not improve from 0.03333
#
# Epoch 00170: val_loss did not improve from 0.03333
#
# Epoch 00171: val_loss did not improve from 0.03333
#
# Epoch 00172: val_loss did not improve from 0.03333
#
# Epoch 00173: val_loss did not improve from 0.03333
#
# Epoch 00174: val_loss did not improve from 0.03333
#
# Epoch 00175: val_loss did not improve from 0.03333
#
# Epoch 00176: val_loss did not improve from 0.03333
#
# Epoch 00177: val_loss did not improve from 0.03333
#
# Epoch 00178: val_loss did not improve from 0.03333
#
# Epoch 00179: val_loss improved from 0.03333 to 0.03332, saving model to best_model_elastic_petro.h5
#
# Epoch 00180: val_loss did not improve from 0.03332
#
# Epoch 00181: val_loss did not improve from 0.03332
#
# Epoch 00182: val_loss did not improve from 0.03332
#
# Epoch 00183: val_loss did not improve from 0.03332
#
# Epoch 00184: val_loss did not improve from 0.03332
#
# Epoch 00185: val_loss did not improve from 0.03332
#
# Epoch 00186: val_loss did not improve from 0.03332
#
# Epoch 00187: val_loss did not improve from 0.03332
#
# Epoch 00188: val_loss did not improve from 0.03332
#
# Epoch 00189: val_loss did not improve from 0.03332
#
# Epoch 00190: val_loss did not improve from 0.03332
#
# Epoch 00191: val_loss did not improve from 0.03332
#
# Epoch 00192: val_loss did not improve from 0.03332
#
# Epoch 00193: val_loss did not improve from 0.03332
#
# Epoch 00194: val_loss did not improve from 0.03332
#
# Epoch 00195: val_loss did not improve from 0.03332
#
# Epoch 00196: val_loss did not improve from 0.03332
#
# Epoch 00197: val_loss did not improve from 0.03332
#
# Epoch 00198: val_loss did not improve from 0.03332
#
# Epoch 00199: val_loss did not improve from 0.03332
#
# Epoch 00200: val_loss did not improve from 0.03332
#
# Epoch 00201: val_loss did not improve from 0.03332
#
# Epoch 00202: val_loss did not improve from 0.03332
#
# Epoch 00203: val_loss did not improve from 0.03332
#
# Epoch 00204: val_loss did not improve from 0.03332
#
# Epoch 00205: val_loss did not improve from 0.03332
#
# Epoch 00206: val_loss did not improve from 0.03332
#
# Epoch 00207: val_loss did not improve from 0.03332
#
# Epoch 00208: val_loss did not improve from 0.03332
#
# Epoch 00209: val_loss did not improve from 0.03332
#
# Epoch 00210: val_loss did not improve from 0.03332
#
# Epoch 00211: val_loss did not improve from 0.03332
#
# Epoch 00212: val_loss did not improve from 0.03332
#
# Epoch 00213: val_loss did not improve from 0.03332
#
# Epoch 00214: val_loss did not improve from 0.03332
#
# Epoch 00215: val_loss did not improve from 0.03332
#
# Epoch 00216: val_loss did not improve from 0.03332
#
# Epoch 00217: val_loss did not improve from 0.03332
#
# Epoch 00218: val_loss did not improve from 0.03332
#
# Epoch 00219: val_loss did not improve from 0.03332
#
# Epoch 00220: val_loss did not improve from 0.03332
#
# Epoch 00221: val_loss did not improve from 0.03332
#
# Epoch 00222: val_loss did not improve from 0.03332
#
# Epoch 00223: val_loss did not improve from 0.03332
#
# Epoch 00224: val_loss did not improve from 0.03332
#
# Epoch 00225: val_loss did not improve from 0.03332
#
# Epoch 00226: val_loss did not improve from 0.03332
#
# Epoch 00227: val_loss did not improve from 0.03332
#
# Epoch 00228: val_loss did not improve from 0.03332
#
# Epoch 00229: val_loss did not improve from 0.03332
#
# Epoch 00230: val_loss did not improve from 0.03332
#
# Epoch 00231: val_loss did not improve from 0.03332
#
# Epoch 00232: val_loss did not improve from 0.03332
#
# Epoch 00233: val_loss did not improve from 0.03332
#
# Epoch 00234: val_loss did not improve from 0.03332
#
# Epoch 00235: val_loss did not improve from 0.03332
#
# Epoch 00236: val_loss did not improve from 0.03332
#
# Epoch 00237: val_loss did not improve from 0.03332
#
# Epoch 00238: val_loss did not improve from 0.03332
#
# Epoch 00239: val_loss did not improve from 0.03332
#
# Epoch 00240: val_loss did not improve from 0.03332
#
# Epoch 00241: val_loss did not improve from 0.03332
#
# Epoch 00242: val_loss did not improve from 0.03332
#
# Epoch 00243: val_loss did not improve from 0.03332
#
# Epoch 00244: val_loss did not improve from 0.03332
#
# Epoch 00245: val_loss did not improve from 0.03332
#
# Epoch 00246: val_loss did not improve from 0.03332
#
# Epoch 00247: val_loss did not improve from 0.03332
#
# Epoch 00248: val_loss did not improve from 0.03332
#
# Epoch 00249: val_loss did not improve from 0.03332
#
# Epoch 00250: val_loss did not improve from 0.03332
#
# Epoch 00251: val_loss did not improve from 0.03332
#
# Epoch 00252: val_loss did not improve from 0.03332
#
# Epoch 00253: val_loss did not improve from 0.03332
#
# Epoch 00254: val_loss did not improve from 0.03332
#
# Epoch 00255: val_loss did not improve from 0.03332
#
# Epoch 00256: val_loss did not improve from 0.03332
#
# Epoch 00257: val_loss did not improve from 0.03332
#
# Epoch 00258: val_loss did not improve from 0.03332
#
# Epoch 00259: val_loss did not improve from 0.03332
#
# Epoch 00260: val_loss did not improve from 0.03332
#
# Epoch 00261: val_loss did not improve from 0.03332
#
# Epoch 00262: val_loss did not improve from 0.03332
#
# Epoch 00263: val_loss did not improve from 0.03332
#
# Epoch 00264: val_loss did not improve from 0.03332
#
# Epoch 00265: val_loss did not improve from 0.03332
#
# Epoch 00266: val_loss did not improve from 0.03332
#
# Epoch 00267: val_loss did not improve from 0.03332
#
# Epoch 00268: val_loss did not improve from 0.03332
#
# Epoch 00269: val_loss did not improve from 0.03332
#
# Epoch 00270: val_loss did not improve from 0.03332
#
# Epoch 00271: val_loss did not improve from 0.03332
#
# Epoch 00272: val_loss did not improve from 0.03332
#
# Epoch 00273: val_loss did not improve from 0.03332
#
# Epoch 00274: val_loss did not improve from 0.03332
#
# Epoch 00275: val_loss did not improve from 0.03332
#
# Epoch 00276: val_loss did not improve from 0.03332
#
# Epoch 00277: val_loss did not improve from 0.03332
#
# Epoch 00278: val_loss did not improve from 0.03332
#
# Epoch 00279: val_loss did not improve from 0.03332
# Epoch 00279: early stopping

# %%
# load the saved model
ElasticPetroModel = load_model('best_model_elastic_petro.h5')

# %%
# Testing and evaluating the model
preds = ElasticPetroModel.evaluate(X_test, Y_test_norm, batch_size=32, verbose=0, sample_weight=None)
print()
print ("Loss = " + str(preds))
# print ("Test Accuracy = " + str(preds[1]))
# Out:
# Loss = 0.033284989535808565

# %%
# Plotting the learning curve 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# plt.plot(history.history['loss']/np.max(history.history['loss']))
# plt.plot(history.history['val_loss']/np.max(history.history['val_loss']))
# plt.yscale("log")
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])


plt.title('Learning curve')
# plt.ylabel('Error/Accuracy')
plt.ylabel('Error')
plt.xlabel('epochs')
plt.legend(['train loss', 'validation loss'], loc='center right')
# plt.savefig('/Figures/learning_curve_08Nov.png', bbox_inches='tight')

# %%
# Save trained model 
# serialize model to JSON
model_json = ElasticPetroModel.to_json()
with open("elastic_petromodel.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
ElasticPetroModel.save_weights("ElasticPetroModel.h5")
print("Saved model to disk")

# %%
# Load saved model
# load json and create model
json_file = open('elastic_petromodel.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
ElasticPetroModel = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("ElasticPetroModel.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
adam = optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

ElasticPetroModel.compile(loss='mean_squared_error', optimizer = adam)


# To evaluate run the "Testing and evaluating the model" cell

# %%
# Predict training and test data using the trained network
test_output_norm = ElasticPetroModel.predict(X_test)
train_output_norm = ElasticPetroModel.predict(X_train)

# Initialization
train_output = np.zeros(train_output_norm.shape)
test_output = np.zeros(test_output_norm.shape)
Y_train = np.zeros(Y_train_norm.shape)
Y_test = np.zeros(Y_test_norm.shape)

# Back transforming porosity to unnormalized values 
train_output[:,0,:] = train_output_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)
test_output[:,0,:] = test_output_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)

train_output[:,1,:] = train_output_norm[:,1,:]
test_output[:,1,:] = test_output_norm[:,1,:]

Y_train[:,0,:] = Y_train_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)
Y_test[:,0,:] = Y_test_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)

Y_train[:,1,:] = Y_train_norm[:,1,:]
Y_test[:,1,:] = Y_test_norm[:,1,:]

# %%
# RMSE with respect to mean 
rmse_train = np.sqrt(np.mean(((train_output - Y_train)**2).mean(axis=2), axis = 0))/np.mean(np.mean(Y_train, axis = 0), axis=1)
rmse_test = np.sqrt(np.mean(((test_output - Y_test)**2).mean(axis=2), axis = 0))/np.mean(np.mean(Y_test, axis = 0), axis=1)

print("Training error = ", rmse_train)
print("Test error = ", rmse_test)
# Out:
# Training error =  [0.17795548 0.34605713]
# Test error =  [0.18924002 0.37196291]

# %%
# Checking training data

sample_number = 25
f, axarr = plt.subplots(1, 2, sharey = True)

axarr[0].plot(train_output[sample_number, 0, :], depth, '-k')
axarr[0].plot(Y_train[sample_number, 0, :], depth, '--r')
axarr[0].set_xlabel("Porosity")
axarr[0].set_ylabel("Depth")
axarr[0].invert_yaxis()
# axarr[0].set_xlim(1.5,3.1)

axarr[1].plot(train_output[sample_number, 1, :], depth, '-k')
axarr[1].plot(Y_train[sample_number, 1, :], depth, '--r')
axarr[1].set_xlabel("Vclay")
axarr[1].set_ylabel("Depth")
# axarr[1].invert_yaxis()
# axarr[1].set_xlim(1,2)

# axarr[2].plot(train_output[sample_number, 2, :], depth, '-k')
# axarr[2].plot(Y_train[sample_number, 2, :], depth, '--r')
# axarr[2].set_xlabel("Sw")
# axarr[2].set_ylabel("Depth")
# axarr[2].invert_yaxis()
# axarr[2].set_xlim(1.5,3)
# Out:
# Text(0,0.5,'Depth')

# %%
# Checking testing data

sample_number = 12
f, axarr = plt.subplots(1, 2, sharey = True)

axarr[0].plot(test_output[sample_number, 0, :], depth, '-k')
axarr[0].plot(Y_test[sample_number, 0, :], depth, '--r')
axarr[0].set_xlabel("Porosity")
axarr[0].set_ylabel("Depth")
axarr[0].invert_yaxis()
# axarr[0].set_xlim(1.5,3.1)

axarr[1].plot(test_output[sample_number, 1, :], depth, '-k')
axarr[1].plot(Y_test[sample_number, 1, :], depth, '--r')
axarr[1].set_xlabel("Vclay")
axarr[1].set_ylabel("Depth")
# axarr[1].invert_yaxis()
# axarr[1].set_xlim(1,2)

# axarr[2].plot(test_output[sample_number, 2, :], depth, '-k')
# axarr[2].plot(Y_test[sample_number, 2, :], depth, '--r')
# axarr[2].set_xlabel("Sw")
# axarr[2].set_ylabel("Depth")
# axarr[2].invert_yaxis()
# axarr[2].set_xlim(1.5,3)
# Out:
# Text(0,0.5,'Depth')

# %%
# Correlation coefficient between true and predicted traces 

Porosity_corr_train = np.zeros(train_output.shape[0])
Vclay_corr_train = np.zeros(train_output.shape[0])
# Sw_corr_train = np.zeros(train_output.shape[0])
for i in range(train_output.shape[0]):
    Porosity_corr_train[i] = np.corrcoef(train_output[i,0,:], Y_train[i,0,:])[0,1]
    Vclay_corr_train[i] = np.corrcoef(train_output[i,1,:], Y_train[i,1,:])[0,1]
#     Sw_corr_train[i] = np.corrcoef(train_output[i,2,:], Y_train[i,2,:])[0,1]
    
Porosity_corr_test = np.zeros(test_output.shape[0])
Vclay_corr_test = np.zeros(test_output.shape[0])
# Sw_corr_test = np.zeros(test_output.shape[0])
for i in range(test_output.shape[0]):
    Porosity_corr_test[i] = np.corrcoef(test_output[i,0,:], Y_test[i,0,:])[0,1]
    Vclay_corr_test[i] = np.corrcoef(test_output[i,1,:], Y_test[i,1,:])[0,1]
#     Sw_corr_test[i] = np.corrcoef(test_output[i,2,:], Y_test[i,2,:])[0,1]

    
# Average correlation coefficient
print("Average correlation in porosity for training data = ", np.mean(Porosity_corr_train))
print("Average correlation in Vclay for training data = ", np.mean(Vclay_corr_train))
# print("Average correlation in Sw for training data = ", np.mean(Sw_corr_train))

print("Average correlation in porosity for test data = ", np.mean(Porosity_corr_test))
print("Average correlation in Vclay for test data = ", np.mean(Vclay_corr_test))
# print("Average correlation in Sw for test data = ", np.mean(Sw_corr_test))
# Out:
# Average correlation in porosity for training data =  0.7088948411373972
# Average correlation in Vclay for training data =  0.7580491014158026
# Average correlation in porosity for test data =  0.6252251150378126
# Average correlation in Vclay for test data =  0.685778046005916

# %%
# Box plot of correlation coefficients 

from pylab import plot, show, savefig, xlim, figure, \
                hold, ylim, legend, boxplot, setp, axes

# function for setting the colors of the box plots pairs
def setBoxColors(bp):
    setp(bp['boxes'][0], color='blue')
    setp(bp['caps'][0], color='blue')
    setp(bp['caps'][1], color='blue')
    setp(bp['whiskers'][0], color='blue')
    setp(bp['whiskers'][1], color='blue')
#     setp(bp['fliers'][0], color='blue')
#     setp(bp['fliers'][1], color='blue')
    setp(bp['medians'][0], color='blue')

    setp(bp['boxes'][1], color='red')
    setp(bp['caps'][2], color='red')
    setp(bp['caps'][3], color='red')
    setp(bp['whiskers'][2], color='red')
    setp(bp['whiskers'][3], color='red')
#     setp(bp['fliers'][2], color='red')
#     setp(bp['fliers'][3], color='red')
    setp(bp['medians'][1], color='red')

# Some fake data to plot
A= [Porosity_corr_train, Porosity_corr_test]
B = [Vclay_corr_train, Vclay_corr_test]
# C = [Sw_corr_train, Sw_corr_test]

fig = figure()
ax = axes()

# first boxplot pair
bp = boxplot(A, positions = [1, 2], widths = 0.6, showfliers=False)
setBoxColors(bp)

# second boxplot pair
bp = boxplot(B, positions = [4, 5], widths = 0.6, showfliers=False)
setBoxColors(bp)

# thrid boxplot pair
# bp = boxplot(C, positions = [7, 8], widths = 0.6, showfliers=False)
# setBoxColors(bp)

# set axes limits and labels
# xlim(0,9)
xlim(0,6)
ylim(0,1)
# ax.set_xticklabels(['Porosity', 'Vclay', 'Sw'])
ax.set_xticklabels(['Porosity', 'Vclay'])
# ax.set_xticks([1.5, 4.5, 7.5])
ax.set_xticks([1.5, 4.5])
plt.ylabel('Correlation coefficient')

# draw temporary red and blue lines and use them to create a legend
hB, = plot([1,1],'b-')
hR, = plot([1,1],'r-')
legend((hB, hR),('Training', 'Test'), loc='lower left')
hB.set_visible(False)
hR.set_visible(False)

# %%
# Histogram plot for true vs predicted values
for i in np.arange(0,train_output.shape[0],100):
    hist, bin_edges = np.histogram(Y_train[i,0,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(train_output[i,0,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
#     plt.hist(train_output[i,0,:], histtype='step', color='red')
    plt.xlabel('Porosity')
    plt.ylabel('Probability')
    plt.title('Training examples')

plt.legend(['True', 'Predicted'])

# %%
# Histogram plot for true vs predicted values
for i in np.arange(0,train_output.shape[0],100):
    hist, bin_edges = np.histogram(Y_train[i,1,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(train_output[i,1,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
    plt.xlabel('Vclay')
    plt.ylabel('Probability')
    plt.title('Training examples')
    
plt.legend(['True', 'Predicted'])

# %%
# Histogram plot for true vs predicted values
for i in np.arange(0,train_output.shape[0],100):
    hist, bin_edges = np.histogram(Y_train[i,2,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(train_output[i,2,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
    plt.xlabel('Sw')
    plt.ylabel('Probability')
    plt.title('Training examples')
plt.legend(['True', 'Predicted'])

# %%
for i in np.arange(0,test_output.shape[0],20):
    hist, bin_edges = np.histogram(Y_test[i,0,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(test_output[i,0,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
    plt.xlabel('Porosity')
    plt.ylabel('Probability')
    plt.title('Test examples')
plt.legend(['True', 'Predicted'])

# %%
for i in np.arange(0,test_output.shape[0],20):
    hist, bin_edges = np.histogram(Y_test[i,1,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(test_output[i,1,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
    plt.xlabel('Vclay')
    plt.ylabel('Probability')
    plt.title('Test examples')
    
plt.legend(['True', 'Predicted'])

# %%
for i in np.arange(0,test_output.shape[0],20):
    hist, bin_edges = np.histogram(Y_test[i,2,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(test_output[i,2,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
    plt.xlabel('Sw')
    plt.ylabel('Probability')
    plt.title('Test examples')
    
plt.legend(['True', 'Predicted'])

# %%
# Density estimate for true vs predicted (test example) Porosity

import seaborn as sns

sample_number = 12
sns.kdeplot(test_output[sample_number,0,:],  
             color='red', label='Predicted', linewidth=3,
            bw=0.01,
             clip=(np.min(test_output[sample_number,0,:]), np.max(test_output[sample_number,0,:])))
sns.kdeplot(Y_test[sample_number,0,:],  
             color='black', label='True', linewidth=3,
            bw=0.01,
             clip=(np.min(Y_test[sample_number,0,:]), np.max(Y_test[sample_number,0,:])))
plt.xlabel('Porosity')
plt.ylabel('Density')
plt.title('Test example')
plt.legend()

# %%
# Density estimate for true vs predicted (test example) Vclay

sample_number = 12

sns.kdeplot(test_output[sample_number,1,:],  
             color='red', label='Predicted', linewidth=3,
             bw=0.04,
           clip=(np.min(test_output[sample_number,1,:]), np.max(test_output[sample_number,1,:])))
sns.kdeplot(Y_test[sample_number,1,:],  
             color='black', label='True', linewidth=3,
            bw=0.04,
             clip=(np.min(Y_test[sample_number,1,:]), np.max(Y_test[sample_number,1,:])))
plt.xlabel('Vclay')
plt.ylabel('Density')
plt.title('Test example')
plt.legend()
plt.xlim(-0.1,1.1)
# Out:
# (-0.1, 1.1)

# %%
# Density estimate for true vs predicted (test example) Water saturation 

sample_number = 12

sns.kdeplot(test_output[sample_number,2,:],  
             color='red', label='Predicted', linewidth=3,
             bw=0.04,
           clip=(np.min(test_output[sample_number,2,:]), np.max(test_output[sample_number,2,:])))
sns.kdeplot(Y_test[sample_number,2,:],  
             color='black', label='True', linewidth=3,
            bw=0.04,
             clip=(np.min(Y_test[sample_number,2,:]), np.max(Y_test[sample_number,2,:])))
plt.xlabel('Sw')
plt.ylabel('Density')
plt.title('Test example')
plt.legend()
plt.xlim(-0.1,1.1)
# Out:
# (-0.1, 1.1)

# %%
# Compute variograms for true and predicted data

from gstools import vario_estimate_unstructured, Spherical
from gstools.covmodel.plot import plot_variogram

# estimate the variogram of the field with 40 bins
bins = np.arange(50)

sample_number = 12
bin_center, gamma = vario_estimate_unstructured(depth.T, Y_test[sample_number,0,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="black")
plt.xlabel('Distance/ Lag')
plt.ylabel('Normalized semi-variance')
plt.title('Test dataset (Porosity)')
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
    
bin_center, gamma = vario_estimate_unstructured(depth.T, test_output[sample_number,0,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="red")
plt.gca().legend(('True','Predicted'))
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
# Out:
# ({'var': 0.0010859955301064145,
#   'len_scale': 22.687711991922512,
#   'nugget': 1.251989725980032e-21},
#  array([[ 3.40136722e-09, -3.53529614e-05, -3.10487353e-09],
#         [-3.53529614e-05,  2.38026723e+00,  4.90040356e-05],
#         [-3.10487353e-09,  4.90040356e-05,  3.20026215e-09]]))

# %%
# Compute variograms for true and predicted data

from gstools import vario_estimate_unstructured, Spherical
from gstools.covmodel.plot import plot_variogram

# estimate the variogram of the field with 40 bins
bins = np.arange(50)

sample_number = 12
bin_center, gamma = vario_estimate_unstructured(depth.T, Y_test[sample_number,1,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="black")
plt.xlabel('Distance/ Lag')
plt.ylabel('Normalized semi-variance')
plt.title('Test dataset (Vclay)')
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
    
bin_center, gamma = vario_estimate_unstructured(depth.T, test_output[sample_number,1,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="red")
plt.gca().legend(('True','Predicted'))
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
# Out:
# ({'var': 0.03937952248890184,
#   'len_scale': 24.140893600658845,
#   'nugget': 5.428179450433089e-34},
#  array([[ 8.12771207e-06, -2.37532528e-03, -7.34289907e-06],
#         [-2.37532528e-03,  4.97598554e+00,  3.43730461e-03],
#         [-7.34289907e-06,  3.43730461e-03,  7.59618690e-06]]))

# %%
# Spectral coherence between true and predicted 

sample_number = 25
plt.cohere(Y_train[sample_number,0,:], train_output[sample_number,0,:], NFFT=16, Fs=1, color="blue")
plt.cohere(Y_train[sample_number,1,:], train_output[sample_number,1,:], NFFT=16, Fs=1, color="red") 
plt.cohere(Y_train[sample_number,2,:], train_output[sample_number,2,:], NFFT=16, Fs=1, color="black")


plt.gca().legend(('Porosity','Vclay', 'Sw'))
plt.xlabel('Wavenumber')
plt.ylabel('Coherence')
plt.title('Training example')
plt.grid(b=False)

# %%
# Spectral coherence between true and predicted (training data)

sample_number = 25
Cxy_poro, wavenumber_poro = plt.cohere(Y_train[sample_number,0,:], train_output[sample_number,0,:], NFFT=16, Fs=1, color="blue")
Cxy_vclay, wavenumber_vclay = plt.cohere(Y_train[sample_number,1,:], train_output[sample_number,1,:], NFFT=16, Fs=1, color="red") 
# Cxy_sw, wavenumber_sw = plt.cohere(Y_test_petro[sample_number,2,:], test_output_petro[sample_number,2,:], NFFT=16, Fs=1, color="black")

# Adding epsilon to the first wavenumber value
wavenumber_poro[0] = wavenumber_poro[0] + 0.001
wavenumber_vclay[0] = wavenumber_vclay[0] + 0.001
# wavenumber_sw[0] = wavenumber_sw[0] + 0.001

plt.plot(1/wavenumber_poro, Cxy_poro, color="blue")
plt.plot(1/wavenumber_vclay, Cxy_vclay, color="red")
# plt.plot(1/wavenumber_sw, Cxy_sw, color="black")

plt.xlim(100,2)
plt.gca().invert_xaxis()
plt.xscale("log")

# plt.gca().legend(('Porosity','Vclay', 'Sw'))
plt.gca().legend(('Porosity','Vclay'))
plt.xlabel('1/Wavenumber')
plt.ylabel('Coherence')
plt.title('Training example')
plt.grid(b=False)

# %%
# Spectral coherence between true and predicted (test data)

sample_number = 12
Cxy_poro, wavenumber_poro = plt.cohere(Y_test[sample_number,0,:], test_output[sample_number,0,:], NFFT=16, Fs=1, color="blue")
Cxy_vclay, wavenumber_vclay = plt.cohere(Y_test[sample_number,1,:], test_output[sample_number,1,:], NFFT=16, Fs=1, color="red") 
# Cxy_sw, wavenumber_sw = plt.cohere(Y_test_petro[sample_number,2,:], test_output_petro[sample_number,2,:], NFFT=16, Fs=1, color="black")

# Adding epsilon to the first wavenumber value
wavenumber_poro[0] = wavenumber_poro[0] + 0.001
wavenumber_vclay[0] = wavenumber_vclay[0] + 0.001
# wavenumber_sw[0] = wavenumber_sw[0] + 0.001

plt.plot(1/wavenumber_poro, Cxy_poro, color="blue")
plt.plot(1/wavenumber_vclay, Cxy_vclay, color="red")
# plt.plot(1/wavenumber_sw, Cxy_sw, color="black")

plt.xlim(100,2)
plt.gca().invert_xaxis()
plt.xscale("log")

# plt.gca().legend(('Porosity','Vclay', 'Sw'))
plt.gca().legend(('Porosity','Vclay'))
plt.xlabel('1/Wavenumber')
plt.ylabel('Coherence')
plt.title('Test example')
plt.grid(b=False)

# %%
import scipy.signal as sp


# Checking training data (smoothed)

sample_number = 25
f, axarr = plt.subplots(1, 2, sharey = True)

ker_width = 15

axarr[0].plot(sp.medfilt(train_output[sample_number, 0, :],ker_width), depth, '-k')
axarr[0].plot(sp.medfilt(Y_train[sample_number, 0, :], ker_width), depth, '--r')
axarr[0].set_xlabel("Porosity")
axarr[0].set_ylabel("Depth")
axarr[0].invert_yaxis()
# axarr[0].set_xlim(1.5,3.1)

axarr[1].plot(sp.medfilt(train_output[sample_number, 1, :], ker_width), depth, '-k')
axarr[1].plot(sp.medfilt(Y_train[sample_number, 1, :],ker_width), depth, '--r')
axarr[1].set_xlabel("Vclay")
axarr[1].set_ylabel("Depth")
# axarr[1].invert_yaxis()
# axarr[1].set_xlim(1,2)
# Out:
# Text(0,0.5,'Depth')

# %%
por_corr_coeff_smooth_train = np.corrcoef(sp.medfilt(train_output[sample_number, 0, :],ker_width),
                                                     sp.medfilt(Y_train[sample_number, 0, :], ker_width))
                                          
vclay_corr_coeff_smooth_train = np.corrcoef(sp.medfilt(train_output[sample_number, 1, :],ker_width),
                                                     sp.medfilt(Y_train[sample_number, 1, :], ker_width))

print("Correlation coefficient between smoothed true and predicted porosity for training example = ", 
     '%.3f'%(por_corr_coeff_smooth_train[0,1]))
print("Correlation coefficient between smoothed true and predicted vclay for training example = ", 
     '%.3f'%(vclay_corr_coeff_smooth_train[0,1]))
# Out:
# Correlation coefficient between smoothed true and predicted porosity for training example =  0.885
# Correlation coefficient between smoothed true and predicted vclay for training example =  0.857

# %%
# Checking testing data (smoothed)

sample_number = 12
f, axarr = plt.subplots(1, 2, sharey = True)

ker_width = 15

axarr[0].plot(sp.medfilt(test_output[sample_number, 0, :],ker_width), depth, '-k')
axarr[0].plot(sp.medfilt(Y_test[sample_number, 0, :], ker_width), depth, '--r')
axarr[0].set_xlabel("Porosity")
axarr[0].set_ylabel("Depth")
axarr[0].invert_yaxis()
# axarr[0].set_xlim(1.5,3.1)

axarr[1].plot(sp.medfilt(test_output[sample_number, 1, :],ker_width), depth, '-k')
axarr[1].plot(sp.medfilt(Y_test[sample_number, 1, :],ker_width), depth, '--r')
axarr[1].set_xlabel("Vclay")
axarr[1].set_ylabel("Depth")
# axarr[1].invert_yaxis()
# axarr[1].set_xlim(1,2)
# Out:
# Text(0,0.5,'Depth')

# %%
por_corr_coeff_smooth_test = np.corrcoef(sp.medfilt(test_output[sample_number, 0, :],ker_width),
                                                     sp.medfilt(Y_test[sample_number, 0, :], ker_width))
                                          
vclay_corr_coeff_smooth_test = np.corrcoef(sp.medfilt(test_output[sample_number, 1, :],ker_width),
                                                     sp.medfilt(Y_test[sample_number, 1, :], ker_width))

print("Correlation coefficient between smoothed true and predicted porosity for test example = ", 
     '%.3f'%(por_corr_coeff_smooth_test[0,1]))
print("Correlation coefficient between smoothed true and predicted vclay for test example = ", 
     '%.3f'%(vclay_corr_coeff_smooth_test[0,1]))
# Out:
# Correlation coefficient between smoothed true and predicted porosity for test example =  0.798
# Correlation coefficient between smoothed true and predicted vclay for test example =  0.834
