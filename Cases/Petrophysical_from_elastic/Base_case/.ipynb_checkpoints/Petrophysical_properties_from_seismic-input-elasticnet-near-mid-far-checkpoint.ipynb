# %% [markdown]
# ## Petrophysical properties inversion from seismic data

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import numpy as np
from random import randint
from wiggle.wiggle import wiggle
from matplotlib.pyplot import figure
import math
import tensorflow as tf

# %%
# Checking the devices available for use in AWS
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7465323681700268173
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 11295485657626718022
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14694720518763152078
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11326753997
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16588912855794482841
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7"
# ]

# %%
# Loading the Vp, Vs and Density data

dataframe = sio.loadmat('../../../Data_generation_base_case/Train_DataSyn1_time_clip.mat')
Vp = dataframe['VpMat']
Vp = np.reshape(Vp, (Vp.shape[0]*Vp.shape[1], Vp.shape[2]))
Vs = dataframe['VsMat']
Vs = np.reshape(Vs, (Vs.shape[0]*Vs.shape[1], Vs.shape[2]))
RHOB = dataframe['RHOBMat']
RHOB = np.reshape(RHOB, (RHOB.shape[0]*RHOB.shape[1], RHOB.shape[2]))

depth = dataframe['depthVec']

# Loading facies, porosity, vclay and water saturation data 
dataframe_facies = sio.loadmat('../../../Data_generation_base_case/Train_FaciesMat.mat')
facies = dataframe_facies['zFaciesMat']
facies = np.reshape(facies, (facies.shape[0]*facies.shape[1], facies.shape[2]))

dataframe_porosity = sio.loadmat('../../../Data_generation_base_case/Train_PhiMat.mat')
porosity = dataframe_porosity['zPhiMat']
porosity = np.reshape(porosity, (porosity.shape[0]*porosity.shape[1], porosity.shape[2]))

dataframe_vclay = sio.loadmat('../../../Data_generation_base_case/Train_ClayMat.mat')
vclay = dataframe_vclay['zClayMat']
vclay = np.reshape(vclay, (vclay.shape[0]*vclay.shape[1], vclay.shape[2]))

dataframe_Sw = sio.loadmat('../../../Data_generation_base_case/Train_SwMat.mat')
Sw = dataframe_Sw['zSwMat']
Sw = np.reshape(Sw, (Sw.shape[0]*Sw.shape[1], Sw.shape[2]))

# %%
# Plot of loaded data

sample_number = 12
f, axarr = plt.subplots(1, 8, sharey = True, figsize=(10,6))

axarr[0].plot(facies[sample_number, :], depth)
axarr[0].set_xlabel("Facies")
axarr[0].set_ylabel("Depth")

axarr[1].plot(porosity[sample_number, :], depth)
axarr[1].set_xlabel("Porosity")
axarr[1].set_xlim(0,0.4)

axarr[2].plot(vclay[sample_number, :], depth)
axarr[2].set_xlabel("Vclay")
axarr[2].set_xlim(0,1)

axarr[3].plot(Sw[sample_number, :], depth)
axarr[3].set_xlabel("Sw")
axarr[3].set_xlim(0,1)

axarr[4].plot(Vp[sample_number, :], depth)
axarr[4].set_xlabel("Vp")
# plt.xlim(0,1)

axarr[5].plot(Vs[sample_number, :], depth)
axarr[5].set_xlabel("Vs")
# plt.xlim(0,1)

axarr[6].plot(RHOB[sample_number, :], depth)
axarr[6].set_xlabel("RHOB")
# plt.xlim(0,1)

axarr[7].plot(Vp[sample_number, :]*RHOB[sample_number, :], depth)
axarr[7].set_xlabel("Ip")
# Out:
# Text(0.5,0,'Ip')

# %%
# AVO and source parameters 
src_len=np.int(60)
freq=40
dt=7e-4
# ntheta=46
thetaStart=0
thetaEnd=30
thetaInc=5
theta=np.arange(thetaStart,thetaEnd+thetaInc,thetaInc)
ntheta=theta.size
# nt=201
# ncdp=1111
angle=np.reshape(theta,[1,ntheta])
# theta=np.arange(0,ntheta,1)
print('angle:', angle.shape)
print('angle:', angle)
# Out:
# angle: (1, 7)
# angle: [[ 0  5 10 15 20 25 30]]

# %%
# Generate the seismic wavelet
def ricker(f,n,dt,t0):

    T = dt*(np.floor(n/2));
    t = np.linspace(-T,T,n)
    tau = t-t0;
    pi=np.pi
    s = (1-tau*tau*f**2*pi**2)*np.exp(-tau**2*pi**2*f**2);
    rw = s;

    return rw,t
src,tsrc=ricker(freq,src_len,dt,0)
plt.plot(tsrc,src, '-ok')
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Source Wavelet")
plt.show()

# %%
# Full Zoeppritz using tensorflow

def gather(input1,tftheta,tfsrc):
    print('input1:',input1)
    vp = tf.expand_dims(input1[:,:,0],2)
    vs = tf.expand_dims(input1[:,:,1],2)
    rho = tf.expand_dims(input1[:,:,2],2)
    vp=tf.check_numerics(vp,"Nan at vp start")
    vs=tf.check_numerics(vs,"Nan at vp start")
    rho=tf.check_numerics(rho,"Nan at vp start")
    

    nref= tf.shape(input1)[1]#vp.get_shape()[1]#.as_list()[1]
    bs=tf.shape(input1)[0]
    ntheta=tf.shape(tftheta)[1]
    #nt=tf.shape(input1)[1]
    
    tfzero=tf.zeros([bs,1,ntheta], dtype=tf.float32)
    
    tfangle = tf.expand_dims(tf.convert_to_tensor(tftheta, 
                                                  dtype=tf.float32),0)
    tfangle=tf.tile(tfangle,[bs,nref-1,1])

  
    vp1=tf.tile(vp[:,0:nref-1],[1, 1, ntheta])
    vs1=tf.tile(vs[:,0:nref-1],[1, 1, ntheta])
    d1=tf.tile(rho[:,0:nref-1],[1, 1, ntheta])

    vp2=tf.tile(vp[:,1:nref],[1, 1, ntheta])
    vs2=tf.tile(vs[:,1:nref],[1, 1, ntheta])
    d2=tf.tile(rho[:,1:nref],[1, 1, ntheta])
    
    
    vpj1=tf.complex(vp1,tf.zeros_like(vp1))
    vsj1=tf.complex(vs1,tf.zeros_like(vs1))
    dj1=tf.complex(d1,tf.zeros_like(d1))

    vpj2=tf.complex(vp2,tf.zeros_like(vp2))
    vsj2=tf.complex(vs2,tf.zeros_like(vs2))
    dj2=tf.complex(d2,tf.zeros_like(d2))
    
    
    t=tf.scalar_mul(np.pi/180,tfangle)    
    p=tf.divide(tf.sin(t),vp1)
    ct=tf.cos(t)
    
    sint=tf.complex(tf.sin(t),tf.zeros_like(t))
    
    # FULL ZOEPPRITZ
    ct2=tf.real(tf.sqrt(np.subtract(1+0j,tf.multiply(tf.square(sint)
                , tf.divide(tf.square(vpj2),tf.square(vpj1))))))
    
    cj1=tf.real(tf.sqrt(np.subtract(1+0j,tf.multiply(tf.square(sint)
                , tf.divide(tf.square(vsj1),tf.square(vpj1))))))
    
    cj2=tf.real(tf.sqrt(np.subtract(1+0j,tf.multiply(tf.square(sint)
                , tf.divide(tf.square(vsj2),tf.square(vpj1))))))
    
    a=tf.subtract(
            tf.multiply(d2, tf.subtract(1.0, tf.scalar_mul(2.0,tf.multiply(tf.square(vs2), tf.square(p))))),
            tf.multiply(d1, tf.subtract(1.0, tf.scalar_mul(2.0,tf.multiply(tf.square(vs1), tf.square(p)))))
            )
    
    b=tf.add(
            tf.multiply(d2, tf.subtract(1.0, tf.scalar_mul(2.0,tf.multiply(tf.square(vs2), tf.square(p))))),
            tf.multiply(d1,tf.scalar_mul(2.0,tf.multiply(tf.square(vs1), tf.square(p))))
            )
    c=tf.add(
            tf.multiply(d1, tf.subtract(1.0, tf.scalar_mul(2.0,tf.multiply(tf.square(vs1), tf.square(p))))),
            tf.multiply(d2,tf.scalar_mul(2.0,tf.multiply(tf.square(vs2), tf.square(p))))
            )
    
    d=tf.scalar_mul(2.0, 
            tf.subtract(
                    tf.multiply(d2,tf.square(vs2)),
                    tf.multiply(d1,tf.square(vs1)))
            )
            
    E=tf.add(
            tf.multiply(b,tf.divide(ct,vp1)),
            tf.multiply(c,tf.divide(ct2,vp2))
            )
    F=tf.add(
            tf.multiply(b,tf.divide(cj1,vs1)),
            tf.multiply(c,tf.divide(cj2,vs2))
            )
    G=tf.subtract(a,
                  tf.divide(
                          tf.multiply(d,tf.multiply(ct,cj2)),
                          tf.multiply(vp1,vs2))
                  )
    H=tf.subtract(a,
                  tf.divide(
                          tf.multiply(d,tf.multiply(ct2,cj1)),
                          tf.multiply(vp2,vs1))
                  )
    D=tf.add(
            tf.multiply(E,F),
            tf.multiply(G,tf.multiply(H,tf.square(p)))
            )
    
    Rpp=tf.real(tf.divide(tf.subtract(
            tf.multiply(tf.subtract( tf.multiply(b,tf.divide(ct,vp1)), tf.multiply(c,tf.divide(ct2,vp2))),F),
            tf.multiply( tf.add(a, tf.multiply(d,tf.multiply(ct,tf.divide(cj2,tf.multiply(vp1,vs2))))) ,tf.multiply(H,tf.square(p)))            
            ),D))
    #print('Rpp1:',Rpp)
    Rpp=tf.concat([Rpp,tfzero],1)
    #print('Rpp2:',Rpp)
    # Rpp1=tf.zeros()
    Rpp1=tf.expand_dims(Rpp,axis=3)
    #Rpp1=tf.where(tf.is_nan(Rpp1), tf.zeros_like(Rpp1), Rpp1)
    #print('Rpp11:',Rpp1)
    #print('tfsrc:',tfsrc)
    seis=tf.transpose(tf.nn.conv2d(Rpp1,tfsrc,strides=[1,1,1,1],padding='SAME'),perm=[0,2,1,3])
    #print("seis:",seis)
    seis=tf.reshape(seis,[-1,nt*ntheta])
    #seis=tf.Print(seis,[tf.shape(seis)])

    #print('seis:',seis)
    
    return seis,Rpp

# %%
# Convert Vp, Vs and Density logs from depth to time 
time = np.zeros((Vp.shape[0], Vp.shape[1]+1))

for i in range(time.shape[0]):
    depth_diff = np.mean(np.diff(depth.T))
    time[i,0] = 0
    time[i,1:] = 2*np.cumsum(depth_diff/(Vp[i,:]*1e3))

time = time[:,0:-1]
# Interpolate the time values such that all logs have the same dt_log
end_time = (np.max(time))
time_upscaled = np.arange(0, end_time, dt)

Vp_time = np.zeros((Vp.shape[0], time_upscaled.shape[0]))
Vs_time = np.zeros((Vs.shape[0], time_upscaled.shape[0]))
RHOB_time = np.zeros((RHOB.shape[0], time_upscaled.shape[0]))
for i in range(time.shape[0]):
    Vp_time[i,:] = np.interp(time_upscaled, time[i,:], Vp[i,:])
    Vs_time[i,:] = np.interp(time_upscaled, time[i,:], Vs[i,:])
    RHOB_time[i,:] = np.interp(time_upscaled, time[i,:], RHOB[i,:])
    
nt = time_upscaled.shape[0]

# %%
sample_number = 10
plt.subplot(1,2,1)
plt.plot(Vp_time[sample_number,:], time_upscaled)
plt.subplot(1,2,2)
plt.plot(Vp[sample_number,:], depth)

# %%
# Forward modeling results (Seismic gathers) (DONOT RUN IF NEW DATA IS NOT GENERATED)

# Test the forward modeling
bs=Vp_time.shape[0]
input11=np.zeros([bs,nt,3],dtype=np.float32)

input11[0:bs,:,0]=Vp_time[0:bs,:]
input11[0:bs,:,1]=Vs_time[0:bs,:]
input11[0:bs,:,2]=RHOB_time[0:bs,:]
# plt.plot(np.squeeze(input11))
# plt.show()

input111=tf.convert_to_tensor(input11,dtype=tf.float32)
# print("src:",src.shape)


tfsrc=tf.reshape(tf.constant(src,dtype=tf.float32),[src_len,1,1,1])


# print('tfsrc:',tfsrc)
# print('angle:',angle.shape)
tftheta=tf.convert_to_tensor(angle,dtype=tf.float32)
# print('tftheta:',tftheta)
seisgen=gather(input111,tftheta,tfsrc)


sess=tf.Session()
seis11,Rpp11=sess.run(seisgen)

sess.close()

seis=np.transpose(np.reshape(seis11,[-1,ntheta,nt]),[0,2,1])
Rpp=Rpp11#np.reshape(Rpp11,[bs,nt,ntheta])

sample_number = 20
wiggle(np.squeeze(seis[sample_number,:,:]),time_upscaled,theta)
plt.title("Seismogram")
plt.xlabel("$\\theta$")
plt.ylabel("Time (s)")
plt.show()

impedance_time = Vp_time * RHOB_time
impedance_time_sample = impedance_time[sample_number,:]
plt.subplot(1,3,1)
plt.plot((impedance_time_sample - np.min(impedance_time_sample))/(np.max(impedance_time_sample)-np.min(impedance_time_sample)), time_upscaled)
plt.gca().invert_yaxis()
plt.subplot(1,3,2)
seis_sample = np.squeeze(seis[sample_number,:,0])
plt.plot((seis_sample - np.min(seis_sample))/(np.max(seis_sample) - np.min(seis_sample)), time_upscaled)
plt.gca().invert_yaxis()
plt.subplot(1,3,3)
plt.plot(np.squeeze(Rpp[sample_number,:,0]), time_upscaled)
plt.gca().invert_yaxis()
# Out:
# input1: Tensor("Const:0", shape=(2500, 246, 3), dtype=float32)

# %%
# Exporting generated seismic data
np.save('../../../Data_generation_base_case/seismic_forward_modeled.npy', seis)
np.save('../../../Data_generation_base_case/Rpp_forward_modeled.npy', Rpp)

# %%
# Load forward modeled seismic data and Rpp
seis = np.load('../../../Data_generation_base_case/seismic_forward_modeled.npy')
Rpp = np.load('../../../Data_generation_base_case/Rpp_forward_modeled.npy')

sample_number = 12
wiggle(np.squeeze(seis[sample_number,:,:]),time_upscaled,theta)
plt.title("Seismogram")
plt.xlabel("$\\theta$")
plt.ylabel("Time (s)")
plt.show()

impedance_time = Vp_time * RHOB_time
impedance_time_sample = impedance_time[sample_number,:]
plt.subplot(1,3,1)
plt.plot((impedance_time_sample - np.min(impedance_time_sample))/(np.max(impedance_time_sample)-np.min(impedance_time_sample)), time_upscaled)
plt.gca().invert_yaxis()
plt.subplot(1,3,2)
seis_sample = np.squeeze(seis[sample_number,:,0])
plt.plot((seis_sample - np.min(seis_sample))/(np.max(seis_sample) - np.min(seis_sample)), time_upscaled)
plt.gca().invert_yaxis()
plt.subplot(1,3,3)
plt.plot(np.squeeze(Rpp[sample_number,:,0]), time_upscaled)
plt.gca().invert_yaxis()

# %%
# Import keras modules for CNN

from keras import layers, initializers, optimizers
from keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling1D, MaxPooling2D, Dropout, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers import LeakyReLU, Reshape
from keras.models import Model, model_from_json, load_model
from keras.preprocessing import image
from keras.utils import layer_utils, normalize
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.utils import np_utils
from keras.callbacks import EarlyStopping, ModelCheckpoint
# from kt_utils import *

import keras.backend as K
K.set_image_data_format('channels_last')

import sklearn.model_selection
import pydot

# %%
# Getting the input data (normalized) and output data 

# Reshape seismic gathers into (number of examples, angle, time) and normalize such that seismic traces have positive values
seis_reshaped = np.swapaxes(seis,1,2)
seis_reshaped_normalized = (seis_reshaped - np.min(seis_reshaped))/(np.max(seis_reshaped)-np.min(seis_reshaped))

# Selecting near(0 degree), mid (15 degree) and far (30 degree) angle traces from the full seismic gathers
row_idx = np.array([0, 3, 6])
angle_seis_reshaped_normalized = seis_reshaped_normalized[:,row_idx,:]

# Concatenate Vp, Vs and Density 
num_examples = Vp_time.shape[0]

# Normalize Vp, Vs and Density
Vp_time_norm = (Vp_time - np.min(Vp_time))/(np.max(Vp_time) - np.min(Vp_time))
Vs_time_norm = (Vs_time - np.min(Vs_time))/(np.max(Vs_time) - np.min(Vs_time))
RHOB_time_norm = (RHOB_time - np.min(RHOB_time))/(np.max(RHOB_time) - np.min(RHOB_time))

emodel = np.concatenate((Vp_time,Vs_time,RHOB_time), axis=1)
# emodel = np.concatenate((Vp_time_norm,Vs_time_norm,RHOB_time_norm), axis=1)
emodel = emodel.reshape((num_examples, 3, nt))


# Split data into train and test set - elastic model
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(angle_seis_reshaped_normalized, 
                                                                            emodel, test_size=0.2, random_state=1)
# X_train, X_test, Y_train_norm, Y_test_norm = sklearn.model_selection.train_test_split(angle_seis_reshaped_normalized, 
#                                                                             emodel, test_size=0.2, random_state=1)


# Add 4th dimension of number of channels=1 to the input data
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)


print ("number of training examples = " + str(X_train.shape[0]))
# print ("number of validation examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
# print ("Y_train shape: " + str(Y_train_norm.shape))
# print ("X_val shape: " + str(X_val.shape))
# print ("Y_val shape: " + str(Y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# print ("Y_test shape: " + str(Y_test_norm.shape))
# Out:
# number of training examples = 2000
# number of test examples = 500
# X_train shape: (2000, 3, 246, 1)
# Y_train shape: (2000, 3, 246)
# X_test shape: (500, 3, 246, 1)
# Y_test shape: (500, 3, 246)

# %%
sample_number = 10

plt.subplot(1,2,1)
plt.plot(Y_train_norm[sample_number, 0, :], time_upscaled)

plt.subplot(1,2,2)
plt.plot(Y_train_norm[sample_number, 0, :], time_upscaled)

# %%
seis_reshaped_normalized = (seis_reshaped - np.min(seis_reshaped))/(np.max(seis_reshaped)-np.min(seis_reshaped))

plt.subplot(1,2,1)
plt.plot(np.squeeze(seis_reshaped[2,1,:]),time_upscaled)
plt.subplot(1,2,2)
plt.plot(np.squeeze(seis_reshaped_normalized[2,1,:]),time_upscaled)

# %%
# Building neural network for elastic properties prediction in Keras 
given_seed = 3 # For repeatibility

def elasticnet(input_shape):
    """
    Implementation of the AVONet.
    
    Arguments:
    input_shape -- shape of the images of the dataset

    Returns:
    model -- a Model() instance in Keras
    """
    

    # Define the input placeholder as a tensor with shape input_shape. Input = input angle gather 
    X_input = Input(input_shape)

    X = X_input

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(60, (1, 60), strides=(1, 1), name='conv0', padding='same',
               kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn0')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv0')(X)
    # MAXPOOL
#     X = MaxPooling2D((2, 2), strides=(1,1),name='max_pool0')(X)
    
    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(1, (1, 60), strides=(1, 1), name='conv1', padding='same',
               kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn1')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv1')(X)
    # MAXPOOL
#     X = MaxPooling2D((2, 2), strides=(1,1),name='max_pool1')(X)
      

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
#     X = Dense(200, name='fc0',
#              kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
#     X = Activation('relu')(X)
    X = Dense(246*3, name='fc1',
             kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = Activation('relu')(X)
    X = Reshape((3, 246))(X)
    
    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs=X_input, outputs=X, name='ElasticModel')

    return model
    ### END CODE HERE ###

# %%
# Create the model
ElasticModel = elasticnet(X_train.shape[1:])

# %%
# Summary and plot of the model

ElasticModel.summary()


# plot_model(AVOModel)
# SVG(model_to_dot(ElasticModel).create(prog='dot', format='svg'))
# plot_model(ElasticModel, to_file='./Figures/model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_33 (InputLayer)        (None, 3, 246, 1)         0
# _________________________________________________________________
# conv0 (Conv2D)               (None, 3, 246, 60)        3660
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 3, 246, 60)        240
# _________________________________________________________________
# activation_99 (Activation)   (None, 3, 246, 60)        0
# _________________________________________________________________
# drop_conv0 (Dropout)         (None, 3, 246, 60)        0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 3, 246, 1)         3601
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 3, 246, 1)         4
# _________________________________________________________________
# activation_100 (Activation)  (None, 3, 246, 1)         0
# _________________________________________________________________
# drop_conv1 (Dropout)         (None, 3, 246, 1)         0
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 738)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 738)               545382
# _________________________________________________________________
# activation_101 (Activation)  (None, 738)               0
# _________________________________________________________________
# reshape_31 (Reshape)         (None, 3, 246)            0
# =================================================================
# Total params: 552,887
# Trainable params: 552,765
# Non-trainable params: 122
# _________________________________________________________________

# %%
# Learning rate scheduler
from keras.callbacks import LearningRateScheduler
# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.01
    drop = 0.1
    epochs_drop = 250.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

# %%
# Compile the model with optimization algorithm, loss function
adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

ElasticModel.compile(loss='mean_squared_error', optimizer = adam)

# %%
# Removing previous best_model.h5 file
import os
os.remove("best_model_elastic.h5")

# %%
# Using early stopping and Model Checkpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)
mc = ModelCheckpoint('best_model_elastic.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
# Start the training
# Using learning rate scheduler
# lrate = LearningRateScheduler(step_decay)
# callbacks_list = [lrate]
# history = ElasticModel.fit(X_train, Y_train, validation_split=0.2, epochs=1000, batch_size=32, callbacks=callbacks_list)

history = ElasticModel.fit(X_train, Y_train, validation_split=0.2, 
                           epochs=1500, batch_size=32, callbacks=[es, mc],
                          verbose = 0)
# Out:
# Epoch 00001: val_loss improved from inf to 0.68130, saving model to best_model_elastic.h5
#
# Epoch 00002: val_loss improved from 0.68130 to 0.04718, saving model to best_model_elastic.h5
#
# Epoch 00003: val_loss did not improve from 0.04718
#
# Epoch 00004: val_loss did not improve from 0.04718
#
# Epoch 00005: val_loss did not improve from 0.04718
#
# Epoch 00006: val_loss did not improve from 0.04718
#
# Epoch 00007: val_loss did not improve from 0.04718
#
# Epoch 00008: val_loss did not improve from 0.04718
#
# Epoch 00009: val_loss did not improve from 0.04718
#
# Epoch 00010: val_loss did not improve from 0.04718
#
# Epoch 00011: val_loss improved from 0.04718 to 0.03610, saving model to best_model_elastic.h5
#
# Epoch 00012: val_loss did not improve from 0.03610
#
# Epoch 00013: val_loss did not improve from 0.03610
#
# Epoch 00014: val_loss improved from 0.03610 to 0.02969, saving model to best_model_elastic.h5
#
# Epoch 00015: val_loss did not improve from 0.02969
#
# Epoch 00016: val_loss improved from 0.02969 to 0.02690, saving model to best_model_elastic.h5
#
# Epoch 00017: val_loss did not improve from 0.02690
#
# Epoch 00018: val_loss did not improve from 0.02690
#
# Epoch 00019: val_loss did not improve from 0.02690
#
# Epoch 00020: val_loss did not improve from 0.02690
#
# Epoch 00021: val_loss did not improve from 0.02690
#
# Epoch 00022: val_loss improved from 0.02690 to 0.02619, saving model to best_model_elastic.h5
#
# Epoch 00023: val_loss did not improve from 0.02619
#
# Epoch 00024: val_loss improved from 0.02619 to 0.02508, saving model to best_model_elastic.h5
#
# Epoch 00025: val_loss did not improve from 0.02508
#
# Epoch 00026: val_loss did not improve from 0.02508
#
# Epoch 00027: val_loss did not improve from 0.02508
#
# Epoch 00028: val_loss did not improve from 0.02508
#
# Epoch 00029: val_loss did not improve from 0.02508
#
# Epoch 00030: val_loss did not improve from 0.02508
#
# Epoch 00031: val_loss improved from 0.02508 to 0.02480, saving model to best_model_elastic.h5
#
# Epoch 00032: val_loss did not improve from 0.02480
#
# Epoch 00033: val_loss did not improve from 0.02480
#
# Epoch 00034: val_loss improved from 0.02480 to 0.02410, saving model to best_model_elastic.h5
#
# Epoch 00035: val_loss did not improve from 0.02410
#
# Epoch 00036: val_loss did not improve from 0.02410
#
# Epoch 00037: val_loss did not improve from 0.02410
#
# Epoch 00038: val_loss did not improve from 0.02410
#
# Epoch 00039: val_loss did not improve from 0.02410
#
# Epoch 00040: val_loss did not improve from 0.02410
#
# Epoch 00041: val_loss did not improve from 0.02410
#
# Epoch 00042: val_loss improved from 0.02410 to 0.02321, saving model to best_model_elastic.h5
#
# Epoch 00043: val_loss did not improve from 0.02321
#
# Epoch 00044: val_loss did not improve from 0.02321
#
# Epoch 00045: val_loss did not improve from 0.02321
#
# Epoch 00046: val_loss did not improve from 0.02321
#
# Epoch 00047: val_loss did not improve from 0.02321
#
# Epoch 00048: val_loss did not improve from 0.02321
#
# Epoch 00049: val_loss did not improve from 0.02321
#
# Epoch 00050: val_loss did not improve from 0.02321
#
# Epoch 00051: val_loss did not improve from 0.02321
#
# Epoch 00052: val_loss did not improve from 0.02321
#
# Epoch 00053: val_loss did not improve from 0.02321
#
# Epoch 00054: val_loss did not improve from 0.02321
#
# Epoch 00055: val_loss improved from 0.02321 to 0.02275, saving model to best_model_elastic.h5
#
# Epoch 00056: val_loss did not improve from 0.02275
#
# Epoch 00057: val_loss improved from 0.02275 to 0.02234, saving model to best_model_elastic.h5
#
# Epoch 00058: val_loss did not improve from 0.02234
#
# Epoch 00059: val_loss did not improve from 0.02234
#
# Epoch 00060: val_loss did not improve from 0.02234
#
# Epoch 00061: val_loss did not improve from 0.02234
#
# Epoch 00062: val_loss did not improve from 0.02234
#
# Epoch 00063: val_loss did not improve from 0.02234
#
# Epoch 00064: val_loss did not improve from 0.02234
#
# Epoch 00065: val_loss did not improve from 0.02234
#
# Epoch 00066: val_loss did not improve from 0.02234
#
# Epoch 00067: val_loss did not improve from 0.02234
#
# Epoch 00068: val_loss did not improve from 0.02234
#
# Epoch 00069: val_loss did not improve from 0.02234
#
# Epoch 00070: val_loss did not improve from 0.02234
#
# Epoch 00071: val_loss did not improve from 0.02234
#
# Epoch 00072: val_loss did not improve from 0.02234
#
# Epoch 00073: val_loss did not improve from 0.02234
#
# Epoch 00074: val_loss improved from 0.02234 to 0.02220, saving model to best_model_elastic.h5
#
# Epoch 00075: val_loss did not improve from 0.02220
#
# Epoch 00076: val_loss did not improve from 0.02220
#
# Epoch 00077: val_loss did not improve from 0.02220
#
# Epoch 00078: val_loss did not improve from 0.02220
#
# Epoch 00079: val_loss did not improve from 0.02220
#
# Epoch 00080: val_loss did not improve from 0.02220
#
# Epoch 00081: val_loss did not improve from 0.02220
#
# Epoch 00082: val_loss did not improve from 0.02220
#
# Epoch 00083: val_loss did not improve from 0.02220
#
# Epoch 00084: val_loss did not improve from 0.02220
#
# Epoch 00085: val_loss did not improve from 0.02220
#
# Epoch 00086: val_loss did not improve from 0.02220
#
# Epoch 00087: val_loss improved from 0.02220 to 0.02215, saving model to best_model_elastic.h5
#
# Epoch 00088: val_loss did not improve from 0.02215
#
# Epoch 00089: val_loss did not improve from 0.02215
#
# Epoch 00090: val_loss did not improve from 0.02215
#
# Epoch 00091: val_loss did not improve from 0.02215
#
# Epoch 00092: val_loss did not improve from 0.02215
#
# Epoch 00093: val_loss did not improve from 0.02215
#
# Epoch 00094: val_loss did not improve from 0.02215
#
# Epoch 00095: val_loss did not improve from 0.02215
#
# Epoch 00096: val_loss did not improve from 0.02215
#
# Epoch 00097: val_loss did not improve from 0.02215
#
# Epoch 00098: val_loss did not improve from 0.02215
#
# Epoch 00099: val_loss did not improve from 0.02215
#
# Epoch 00100: val_loss did not improve from 0.02215
#
# Epoch 00101: val_loss improved from 0.02215 to 0.02160, saving model to best_model_elastic.h5
#
# Epoch 00102: val_loss did not improve from 0.02160
#
# Epoch 00103: val_loss did not improve from 0.02160
#
# Epoch 00104: val_loss did not improve from 0.02160
#
# Epoch 00105: val_loss did not improve from 0.02160
#
# Epoch 00106: val_loss did not improve from 0.02160
#
# Epoch 00107: val_loss did not improve from 0.02160
#
# Epoch 00108: val_loss did not improve from 0.02160
#
# Epoch 00109: val_loss did not improve from 0.02160
#
# Epoch 00110: val_loss did not improve from 0.02160
#
# Epoch 00111: val_loss did not improve from 0.02160
#
# Epoch 00112: val_loss did not improve from 0.02160
#
# Epoch 00113: val_loss did not improve from 0.02160
#
# Epoch 00114: val_loss did not improve from 0.02160
#
# Epoch 00115: val_loss improved from 0.02160 to 0.02127, saving model to best_model_elastic.h5
#
# Epoch 00116: val_loss did not improve from 0.02127
#
# Epoch 00117: val_loss did not improve from 0.02127
#
# Epoch 00118: val_loss did not improve from 0.02127
#
# Epoch 00119: val_loss did not improve from 0.02127
#
# Epoch 00120: val_loss did not improve from 0.02127
#
# Epoch 00121: val_loss did not improve from 0.02127
#
# Epoch 00122: val_loss did not improve from 0.02127
#
# Epoch 00123: val_loss did not improve from 0.02127
#
# Epoch 00124: val_loss did not improve from 0.02127
#
# Epoch 00125: val_loss did not improve from 0.02127
#
# Epoch 00126: val_loss did not improve from 0.02127
#
# Epoch 00127: val_loss did not improve from 0.02127
#
# Epoch 00128: val_loss did not improve from 0.02127
#
# Epoch 00129: val_loss did not improve from 0.02127
#
# Epoch 00130: val_loss did not improve from 0.02127
#
# Epoch 00131: val_loss did not improve from 0.02127
#
# Epoch 00132: val_loss did not improve from 0.02127
#
# Epoch 00133: val_loss did not improve from 0.02127
#
# Epoch 00134: val_loss did not improve from 0.02127
#
# Epoch 00135: val_loss did not improve from 0.02127
#
# Epoch 00136: val_loss did not improve from 0.02127
#
# Epoch 00137: val_loss did not improve from 0.02127
#
# Epoch 00138: val_loss did not improve from 0.02127
#
# Epoch 00139: val_loss did not improve from 0.02127
#
# Epoch 00140: val_loss did not improve from 0.02127
#
# Epoch 00141: val_loss did not improve from 0.02127
#
# Epoch 00142: val_loss did not improve from 0.02127
#
# Epoch 00143: val_loss did not improve from 0.02127
#
# Epoch 00144: val_loss did not improve from 0.02127
#
# Epoch 00145: val_loss did not improve from 0.02127
# Epoch 00146: val_loss did not improve from 0.02127
#
# Epoch 00147: val_loss did not improve from 0.02127
#
# Epoch 00148: val_loss did not improve from 0.02127
#
# Epoch 00149: val_loss did not improve from 0.02127
#
# Epoch 00150: val_loss did not improve from 0.02127
#
# Epoch 00151: val_loss did not improve from 0.02127
#
# Epoch 00152: val_loss did not improve from 0.02127
#
# Epoch 00153: val_loss did not improve from 0.02127
#
# Epoch 00154: val_loss did not improve from 0.02127
#
# Epoch 00155: val_loss did not improve from 0.02127
#
# Epoch 00156: val_loss improved from 0.02127 to 0.02113, saving model to best_model_elastic.h5
#
# Epoch 00157: val_loss did not improve from 0.02113
#
# Epoch 00158: val_loss did not improve from 0.02113
#
# Epoch 00159: val_loss did not improve from 0.02113
#
# Epoch 00160: val_loss did not improve from 0.02113
#
# Epoch 00161: val_loss did not improve from 0.02113
#
# Epoch 00162: val_loss did not improve from 0.02113
#
# Epoch 00163: val_loss did not improve from 0.02113
#
# Epoch 00164: val_loss did not improve from 0.02113
#
# Epoch 00165: val_loss did not improve from 0.02113
#
# Epoch 00166: val_loss improved from 0.02113 to 0.02078, saving model to best_model_elastic.h5
#
# Epoch 00167: val_loss did not improve from 0.02078
#
# Epoch 00168: val_loss did not improve from 0.02078
#
# Epoch 00169: val_loss did not improve from 0.02078
#
# Epoch 00170: val_loss did not improve from 0.02078
#
# Epoch 00171: val_loss improved from 0.02078 to 0.02073, saving model to best_model_elastic.h5
#
# Epoch 00172: val_loss did not improve from 0.02073
#
# Epoch 00173: val_loss did not improve from 0.02073
#
# Epoch 00174: val_loss did not improve from 0.02073
#
# Epoch 00175: val_loss did not improve from 0.02073
#
# Epoch 00176: val_loss did not improve from 0.02073
#
# Epoch 00177: val_loss did not improve from 0.02073
#
# Epoch 00178: val_loss did not improve from 0.02073
#
# Epoch 00179: val_loss did not improve from 0.02073
#
# Epoch 00180: val_loss did not improve from 0.02073
#
# Epoch 00181: val_loss did not improve from 0.02073
#
# Epoch 00182: val_loss did not improve from 0.02073
#
# Epoch 00183: val_loss did not improve from 0.02073
#
# Epoch 00184: val_loss did not improve from 0.02073
#
# Epoch 00185: val_loss did not improve from 0.02073
#
# Epoch 00186: val_loss did not improve from 0.02073
#
# Epoch 00187: val_loss did not improve from 0.02073
#
# Epoch 00188: val_loss did not improve from 0.02073
#
# Epoch 00189: val_loss did not improve from 0.02073
#
# Epoch 00190: val_loss did not improve from 0.02073
#
# Epoch 00191: val_loss did not improve from 0.02073
#
# Epoch 00192: val_loss did not improve from 0.02073
#
# Epoch 00193: val_loss did not improve from 0.02073
#
# Epoch 00194: val_loss did not improve from 0.02073
#
# Epoch 00195: val_loss did not improve from 0.02073
#
# Epoch 00196: val_loss did not improve from 0.02073
#
# Epoch 00197: val_loss did not improve from 0.02073
#
# Epoch 00198: val_loss improved from 0.02073 to 0.02054, saving model to best_model_elastic.h5
#
# Epoch 00199: val_loss did not improve from 0.02054
#
# Epoch 00200: val_loss did not improve from 0.02054
#
# Epoch 00201: val_loss did not improve from 0.02054
#
# Epoch 00202: val_loss did not improve from 0.02054
#
# Epoch 00203: val_loss did not improve from 0.02054
#
# Epoch 00204: val_loss did not improve from 0.02054
#
# Epoch 00205: val_loss did not improve from 0.02054
#
# Epoch 00206: val_loss did not improve from 0.02054
#
# Epoch 00207: val_loss did not improve from 0.02054
#
# Epoch 00208: val_loss did not improve from 0.02054
#
# Epoch 00209: val_loss did not improve from 0.02054
#
# Epoch 00210: val_loss did not improve from 0.02054
#
# Epoch 00211: val_loss did not improve from 0.02054
#
# Epoch 00212: val_loss did not improve from 0.02054
#
# Epoch 00213: val_loss did not improve from 0.02054
#
# Epoch 00214: val_loss did not improve from 0.02054
#
# Epoch 00215: val_loss did not improve from 0.02054
#
# Epoch 00216: val_loss did not improve from 0.02054
#
# Epoch 00217: val_loss did not improve from 0.02054
#
# Epoch 00218: val_loss did not improve from 0.02054
#
# Epoch 00219: val_loss did not improve from 0.02054
#
# Epoch 00220: val_loss did not improve from 0.02054
#
# Epoch 00221: val_loss did not improve from 0.02054
#
# Epoch 00222: val_loss did not improve from 0.02054
#
# Epoch 00223: val_loss did not improve from 0.02054
#
# Epoch 00224: val_loss did not improve from 0.02054
#
# Epoch 00225: val_loss did not improve from 0.02054
#
# Epoch 00226: val_loss did not improve from 0.02054
#
# Epoch 00227: val_loss did not improve from 0.02054
#
# Epoch 00228: val_loss did not improve from 0.02054
#
# Epoch 00229: val_loss did not improve from 0.02054
#
# Epoch 00230: val_loss did not improve from 0.02054
#
# Epoch 00231: val_loss did not improve from 0.02054
#
# Epoch 00232: val_loss did not improve from 0.02054
#
# Epoch 00233: val_loss did not improve from 0.02054
#
# Epoch 00234: val_loss did not improve from 0.02054
#
# Epoch 00235: val_loss did not improve from 0.02054
#
# Epoch 00236: val_loss did not improve from 0.02054
#
# Epoch 00237: val_loss did not improve from 0.02054
#
# Epoch 00238: val_loss did not improve from 0.02054
#
# Epoch 00239: val_loss did not improve from 0.02054
#
# Epoch 00240: val_loss did not improve from 0.02054
#
# Epoch 00241: val_loss did not improve from 0.02054
#
# Epoch 00242: val_loss did not improve from 0.02054
#
# Epoch 00243: val_loss did not improve from 0.02054
#
# Epoch 00244: val_loss did not improve from 0.02054
#
# Epoch 00245: val_loss did not improve from 0.02054
#
# Epoch 00246: val_loss did not improve from 0.02054
#
# Epoch 00247: val_loss did not improve from 0.02054
#
# Epoch 00248: val_loss did not improve from 0.02054
#
# Epoch 00249: val_loss did not improve from 0.02054
#
# Epoch 00250: val_loss did not improve from 0.02054
#
# Epoch 00251: val_loss did not improve from 0.02054
#
# Epoch 00252: val_loss did not improve from 0.02054
#
# Epoch 00253: val_loss did not improve from 0.02054
#
# Epoch 00254: val_loss did not improve from 0.02054
#
# Epoch 00255: val_loss did not improve from 0.02054
#
# Epoch 00256: val_loss did not improve from 0.02054
#
# Epoch 00257: val_loss did not improve from 0.02054
#
# Epoch 00258: val_loss did not improve from 0.02054
#
# Epoch 00259: val_loss did not improve from 0.02054
#
# Epoch 00260: val_loss did not improve from 0.02054
#
# Epoch 00261: val_loss did not improve from 0.02054
#
# Epoch 00262: val_loss did not improve from 0.02054
#
# Epoch 00263: val_loss did not improve from 0.02054
#
# Epoch 00264: val_loss did not improve from 0.02054
#
# Epoch 00265: val_loss did not improve from 0.02054
#
# Epoch 00266: val_loss did not improve from 0.02054
#
# Epoch 00267: val_loss did not improve from 0.02054
#
# Epoch 00268: val_loss did not improve from 0.02054
#
# Epoch 00269: val_loss did not improve from 0.02054
#
# Epoch 00270: val_loss did not improve from 0.02054
#
# Epoch 00271: val_loss improved from 0.02054 to 0.02036, saving model to best_model_elastic.h5
#
# Epoch 00272: val_loss did not improve from 0.02036
#
# Epoch 00273: val_loss did not improve from 0.02036
#
# Epoch 00274: val_loss did not improve from 0.02036
#
# Epoch 00275: val_loss did not improve from 0.02036
#
# Epoch 00276: val_loss improved from 0.02036 to 0.02031, saving model to best_model_elastic.h5
#
# Epoch 00277: val_loss did not improve from 0.02031
#
# Epoch 00278: val_loss did not improve from 0.02031
#
# Epoch 00279: val_loss did not improve from 0.02031
#
# Epoch 00280: val_loss did not improve from 0.02031
#
# Epoch 00281: val_loss did not improve from 0.02031
#
# Epoch 00282: val_loss did not improve from 0.02031
#
# Epoch 00283: val_loss did not improve from 0.02031
#
# Epoch 00284: val_loss did not improve from 0.02031
#
# Epoch 00285: val_loss did not improve from 0.02031
#
# Epoch 00286: val_loss did not improve from 0.02031
#
# Epoch 00287: val_loss did not improve from 0.02031
#
# Epoch 00288: val_loss did not improve from 0.02031
#
# Epoch 00289: val_loss did not improve from 0.02031
#
# Epoch 00290: val_loss did not improve from 0.02031
#
# Epoch 00291: val_loss did not improve from 0.02031
#
# Epoch 00292: val_loss did not improve from 0.02031
#
# Epoch 00293: val_loss did not improve from 0.02031
#
# Epoch 00294: val_loss did not improve from 0.02031
#
# Epoch 00295: val_loss did not improve from 0.02031
#
# Epoch 00296: val_loss did not improve from 0.02031
#
# Epoch 00297: val_loss did not improve from 0.02031
#
# Epoch 00298: val_loss did not improve from 0.02031
# Epoch 00299: val_loss did not improve from 0.02031
#
# Epoch 00300: val_loss did not improve from 0.02031
#
# Epoch 00301: val_loss did not improve from 0.02031
#
# Epoch 00302: val_loss improved from 0.02031 to 0.02026, saving model to best_model_elastic.h5
#
# Epoch 00303: val_loss did not improve from 0.02026
#
# Epoch 00304: val_loss did not improve from 0.02026
#
# Epoch 00305: val_loss did not improve from 0.02026
#
# Epoch 00306: val_loss did not improve from 0.02026
#
# Epoch 00307: val_loss did not improve from 0.02026
#
# Epoch 00308: val_loss did not improve from 0.02026
#
# Epoch 00309: val_loss did not improve from 0.02026
#
# Epoch 00310: val_loss did not improve from 0.02026
#
# Epoch 00311: val_loss did not improve from 0.02026
#
# Epoch 00312: val_loss did not improve from 0.02026
#
# Epoch 00313: val_loss did not improve from 0.02026
#
# Epoch 00314: val_loss did not improve from 0.02026
#
# Epoch 00315: val_loss did not improve from 0.02026
#
# Epoch 00316: val_loss did not improve from 0.02026
#
# Epoch 00317: val_loss did not improve from 0.02026
#
# Epoch 00318: val_loss did not improve from 0.02026
#
# Epoch 00319: val_loss did not improve from 0.02026
#
# Epoch 00320: val_loss did not improve from 0.02026
#
# Epoch 00321: val_loss did not improve from 0.02026
#
# Epoch 00322: val_loss did not improve from 0.02026
#
# Epoch 00323: val_loss did not improve from 0.02026
#
# Epoch 00324: val_loss did not improve from 0.02026
#
# Epoch 00325: val_loss did not improve from 0.02026
#
# Epoch 00326: val_loss did not improve from 0.02026
#
# Epoch 00327: val_loss did not improve from 0.02026
#
# Epoch 00328: val_loss did not improve from 0.02026
#
# Epoch 00329: val_loss did not improve from 0.02026
#
# Epoch 00330: val_loss did not improve from 0.02026
#
# Epoch 00331: val_loss did not improve from 0.02026
#
# Epoch 00332: val_loss did not improve from 0.02026
#
# Epoch 00333: val_loss improved from 0.02026 to 0.02015, saving model to best_model_elastic.h5
#
# Epoch 00334: val_loss did not improve from 0.02015
#
# Epoch 00335: val_loss did not improve from 0.02015
#
# Epoch 00336: val_loss did not improve from 0.02015
#
# Epoch 00337: val_loss did not improve from 0.02015
#
# Epoch 00338: val_loss did not improve from 0.02015
#
# Epoch 00339: val_loss did not improve from 0.02015
#
# Epoch 00340: val_loss did not improve from 0.02015
#
# Epoch 00341: val_loss did not improve from 0.02015
#
# Epoch 00342: val_loss did not improve from 0.02015
#
# Epoch 00343: val_loss did not improve from 0.02015
#
# Epoch 00344: val_loss did not improve from 0.02015
#
# Epoch 00345: val_loss improved from 0.02015 to 0.02007, saving model to best_model_elastic.h5
#
# Epoch 00346: val_loss did not improve from 0.02007
#
# Epoch 00347: val_loss improved from 0.02007 to 0.02007, saving model to best_model_elastic.h5
#
# Epoch 00348: val_loss did not improve from 0.02007
#
# Epoch 00349: val_loss did not improve from 0.02007
#
# Epoch 00350: val_loss did not improve from 0.02007
#
# Epoch 00351: val_loss did not improve from 0.02007
#
# Epoch 00352: val_loss did not improve from 0.02007
#
# Epoch 00353: val_loss did not improve from 0.02007
#
# Epoch 00354: val_loss did not improve from 0.02007
#
# Epoch 00355: val_loss did not improve from 0.02007
#
# Epoch 00356: val_loss did not improve from 0.02007
#
# Epoch 00357: val_loss did not improve from 0.02007
#
# Epoch 00358: val_loss did not improve from 0.02007
#
# Epoch 00359: val_loss did not improve from 0.02007
#
# Epoch 00360: val_loss did not improve from 0.02007
#
# Epoch 00361: val_loss did not improve from 0.02007
#
# Epoch 00362: val_loss did not improve from 0.02007
#
# Epoch 00363: val_loss did not improve from 0.02007
#
# Epoch 00364: val_loss did not improve from 0.02007
#
# Epoch 00365: val_loss did not improve from 0.02007
#
# Epoch 00366: val_loss did not improve from 0.02007
#
# Epoch 00367: val_loss did not improve from 0.02007
#
# Epoch 00368: val_loss did not improve from 0.02007
#
# Epoch 00369: val_loss did not improve from 0.02007
#
# Epoch 00370: val_loss did not improve from 0.02007
#
# Epoch 00371: val_loss did not improve from 0.02007
#
# Epoch 00372: val_loss did not improve from 0.02007
#
# Epoch 00373: val_loss did not improve from 0.02007
#
# Epoch 00374: val_loss did not improve from 0.02007
#
# Epoch 00375: val_loss did not improve from 0.02007
#
# Epoch 00376: val_loss did not improve from 0.02007
#
# Epoch 00377: val_loss did not improve from 0.02007
#
# Epoch 00378: val_loss did not improve from 0.02007
#
# Epoch 00379: val_loss did not improve from 0.02007
#
# Epoch 00380: val_loss did not improve from 0.02007
#
# Epoch 00381: val_loss did not improve from 0.02007
#
# Epoch 00382: val_loss did not improve from 0.02007
#
# Epoch 00383: val_loss did not improve from 0.02007
#
# Epoch 00384: val_loss did not improve from 0.02007
#
# Epoch 00385: val_loss did not improve from 0.02007
#
# Epoch 00386: val_loss did not improve from 0.02007
#
# Epoch 00387: val_loss did not improve from 0.02007
#
# Epoch 00388: val_loss did not improve from 0.02007
#
# Epoch 00389: val_loss did not improve from 0.02007
#
# Epoch 00390: val_loss did not improve from 0.02007
#
# Epoch 00391: val_loss improved from 0.02007 to 0.02001, saving model to best_model_elastic.h5
#
# Epoch 00392: val_loss did not improve from 0.02001
#
# Epoch 00393: val_loss did not improve from 0.02001
#
# Epoch 00394: val_loss did not improve from 0.02001
#
# Epoch 00395: val_loss did not improve from 0.02001
#
# Epoch 00396: val_loss improved from 0.02001 to 0.01992, saving model to best_model_elastic.h5
#
# Epoch 00397: val_loss did not improve from 0.01992
#
# Epoch 00398: val_loss did not improve from 0.01992
#
# Epoch 00399: val_loss did not improve from 0.01992
#
# Epoch 00400: val_loss did not improve from 0.01992
#
# Epoch 00401: val_loss did not improve from 0.01992
#
# Epoch 00402: val_loss did not improve from 0.01992
#
# Epoch 00403: val_loss did not improve from 0.01992
#
# Epoch 00404: val_loss did not improve from 0.01992
#
# Epoch 00405: val_loss did not improve from 0.01992
#
# Epoch 00406: val_loss did not improve from 0.01992
#
# Epoch 00407: val_loss did not improve from 0.01992
#
# Epoch 00408: val_loss did not improve from 0.01992
#
# Epoch 00409: val_loss did not improve from 0.01992
#
# Epoch 00410: val_loss did not improve from 0.01992
#
# Epoch 00411: val_loss did not improve from 0.01992
#
# Epoch 00412: val_loss did not improve from 0.01992
#
# Epoch 00413: val_loss did not improve from 0.01992
#
# Epoch 00414: val_loss did not improve from 0.01992
#
# Epoch 00415: val_loss did not improve from 0.01992
#
# Epoch 00416: val_loss did not improve from 0.01992
#
# Epoch 00417: val_loss did not improve from 0.01992
#
# Epoch 00418: val_loss did not improve from 0.01992
#
# Epoch 00419: val_loss did not improve from 0.01992
#
# Epoch 00420: val_loss did not improve from 0.01992
#
# Epoch 00421: val_loss did not improve from 0.01992
#
# Epoch 00422: val_loss did not improve from 0.01992
#
# Epoch 00423: val_loss did not improve from 0.01992
#
# Epoch 00424: val_loss did not improve from 0.01992
#
# Epoch 00425: val_loss did not improve from 0.01992
#
# Epoch 00426: val_loss did not improve from 0.01992
#
# Epoch 00427: val_loss did not improve from 0.01992
#
# Epoch 00428: val_loss did not improve from 0.01992
#
# Epoch 00429: val_loss did not improve from 0.01992
#
# Epoch 00430: val_loss did not improve from 0.01992
#
# Epoch 00431: val_loss did not improve from 0.01992
#
# Epoch 00432: val_loss did not improve from 0.01992
#
# Epoch 00433: val_loss did not improve from 0.01992
#
# Epoch 00434: val_loss did not improve from 0.01992
#
# Epoch 00435: val_loss did not improve from 0.01992
#
# Epoch 00436: val_loss did not improve from 0.01992
#
# Epoch 00437: val_loss did not improve from 0.01992
#
# Epoch 00438: val_loss did not improve from 0.01992
#
# Epoch 00439: val_loss did not improve from 0.01992
#
# Epoch 00440: val_loss did not improve from 0.01992
#
# Epoch 00441: val_loss did not improve from 0.01992
#
# Epoch 00442: val_loss did not improve from 0.01992
#
# Epoch 00443: val_loss did not improve from 0.01992
#
# Epoch 00444: val_loss did not improve from 0.01992
#
# Epoch 00445: val_loss did not improve from 0.01992
#
# Epoch 00446: val_loss did not improve from 0.01992
#
# Epoch 00447: val_loss did not improve from 0.01992
#
# Epoch 00448: val_loss did not improve from 0.01992
#
# Epoch 00449: val_loss did not improve from 0.01992
#
# Epoch 00450: val_loss improved from 0.01992 to 0.01988, saving model to best_model_elastic.h5
# Epoch 00451: val_loss did not improve from 0.01988
#
# Epoch 00452: val_loss did not improve from 0.01988
#
# Epoch 00453: val_loss did not improve from 0.01988
#
# Epoch 00454: val_loss did not improve from 0.01988
#
# Epoch 00455: val_loss did not improve from 0.01988
#
# Epoch 00456: val_loss did not improve from 0.01988
#
# Epoch 00457: val_loss did not improve from 0.01988
#
# Epoch 00458: val_loss did not improve from 0.01988
#
# Epoch 00459: val_loss did not improve from 0.01988
#
# Epoch 00460: val_loss did not improve from 0.01988
#
# Epoch 00461: val_loss did not improve from 0.01988
#
# Epoch 00462: val_loss did not improve from 0.01988
#
# Epoch 00463: val_loss did not improve from 0.01988
#
# Epoch 00464: val_loss did not improve from 0.01988
#
# Epoch 00465: val_loss did not improve from 0.01988
#
# Epoch 00466: val_loss did not improve from 0.01988
#
# Epoch 00467: val_loss did not improve from 0.01988
#
# Epoch 00468: val_loss did not improve from 0.01988
#
# Epoch 00469: val_loss did not improve from 0.01988
#
# Epoch 00470: val_loss did not improve from 0.01988
#
# Epoch 00471: val_loss improved from 0.01988 to 0.01982, saving model to best_model_elastic.h5
#
# Epoch 00472: val_loss did not improve from 0.01982
#
# Epoch 00473: val_loss did not improve from 0.01982
#
# Epoch 00474: val_loss did not improve from 0.01982
#
# Epoch 00475: val_loss did not improve from 0.01982
#
# Epoch 00476: val_loss did not improve from 0.01982
#
# Epoch 00477: val_loss did not improve from 0.01982
#
# Epoch 00478: val_loss did not improve from 0.01982
#
# Epoch 00479: val_loss did not improve from 0.01982
#
# Epoch 00480: val_loss did not improve from 0.01982
#
# Epoch 00481: val_loss did not improve from 0.01982
#
# Epoch 00482: val_loss did not improve from 0.01982
#
# Epoch 00483: val_loss did not improve from 0.01982
#
# Epoch 00484: val_loss did not improve from 0.01982
#
# Epoch 00485: val_loss did not improve from 0.01982
#
# Epoch 00486: val_loss did not improve from 0.01982
#
# Epoch 00487: val_loss did not improve from 0.01982
#
# Epoch 00488: val_loss did not improve from 0.01982
#
# Epoch 00489: val_loss did not improve from 0.01982
#
# Epoch 00490: val_loss did not improve from 0.01982
#
# Epoch 00491: val_loss did not improve from 0.01982
#
# Epoch 00492: val_loss did not improve from 0.01982
#
# Epoch 00493: val_loss did not improve from 0.01982
#
# Epoch 00494: val_loss did not improve from 0.01982
#
# Epoch 00495: val_loss did not improve from 0.01982
#
# Epoch 00496: val_loss did not improve from 0.01982
#
# Epoch 00497: val_loss did not improve from 0.01982
#
# Epoch 00498: val_loss did not improve from 0.01982
#
# Epoch 00499: val_loss did not improve from 0.01982
#
# Epoch 00500: val_loss did not improve from 0.01982
#
# Epoch 00501: val_loss did not improve from 0.01982
#
# Epoch 00502: val_loss did not improve from 0.01982
#
# Epoch 00503: val_loss did not improve from 0.01982
#
# Epoch 00504: val_loss did not improve from 0.01982
#
# Epoch 00505: val_loss did not improve from 0.01982
#
# Epoch 00506: val_loss did not improve from 0.01982
#
# Epoch 00507: val_loss did not improve from 0.01982
#
# Epoch 00508: val_loss did not improve from 0.01982
#
# Epoch 00509: val_loss did not improve from 0.01982
#
# Epoch 00510: val_loss did not improve from 0.01982
#
# Epoch 00511: val_loss did not improve from 0.01982
#
# Epoch 00512: val_loss did not improve from 0.01982
#
# Epoch 00513: val_loss did not improve from 0.01982
#
# Epoch 00514: val_loss did not improve from 0.01982
#
# Epoch 00515: val_loss did not improve from 0.01982
#
# Epoch 00516: val_loss did not improve from 0.01982
#
# Epoch 00517: val_loss did not improve from 0.01982
#
# Epoch 00518: val_loss did not improve from 0.01982
#
# Epoch 00519: val_loss improved from 0.01982 to 0.01976, saving model to best_model_elastic.h5
#
# Epoch 00520: val_loss did not improve from 0.01976
#
# Epoch 00521: val_loss did not improve from 0.01976
#
# Epoch 00522: val_loss did not improve from 0.01976
#
# Epoch 00523: val_loss did not improve from 0.01976
#
# Epoch 00524: val_loss did not improve from 0.01976
#
# Epoch 00525: val_loss did not improve from 0.01976
#
# Epoch 00526: val_loss did not improve from 0.01976
#
# Epoch 00527: val_loss did not improve from 0.01976
#
# Epoch 00528: val_loss did not improve from 0.01976
#
# Epoch 00529: val_loss did not improve from 0.01976
#
# Epoch 00530: val_loss did not improve from 0.01976
#
# Epoch 00531: val_loss did not improve from 0.01976
#
# Epoch 00532: val_loss did not improve from 0.01976
#
# Epoch 00533: val_loss did not improve from 0.01976
#
# Epoch 00534: val_loss did not improve from 0.01976
#
# Epoch 00535: val_loss did not improve from 0.01976
#
# Epoch 00536: val_loss did not improve from 0.01976
#
# Epoch 00537: val_loss did not improve from 0.01976
#
# Epoch 00538: val_loss did not improve from 0.01976
#
# Epoch 00539: val_loss did not improve from 0.01976
#
# Epoch 00540: val_loss did not improve from 0.01976
#
# Epoch 00541: val_loss did not improve from 0.01976
#
# Epoch 00542: val_loss did not improve from 0.01976
#
# Epoch 00543: val_loss did not improve from 0.01976
#
# Epoch 00544: val_loss did not improve from 0.01976
#
# Epoch 00545: val_loss did not improve from 0.01976
#
# Epoch 00546: val_loss did not improve from 0.01976
#
# Epoch 00547: val_loss did not improve from 0.01976
#
# Epoch 00548: val_loss did not improve from 0.01976
#
# Epoch 00549: val_loss did not improve from 0.01976
#
# Epoch 00550: val_loss did not improve from 0.01976
#
# Epoch 00551: val_loss did not improve from 0.01976
#
# Epoch 00552: val_loss did not improve from 0.01976
#
# Epoch 00553: val_loss did not improve from 0.01976
#
# Epoch 00554: val_loss did not improve from 0.01976
#
# Epoch 00555: val_loss did not improve from 0.01976
#
# Epoch 00556: val_loss did not improve from 0.01976
#
# Epoch 00557: val_loss did not improve from 0.01976
#
# Epoch 00558: val_loss did not improve from 0.01976
#
# Epoch 00559: val_loss did not improve from 0.01976
#
# Epoch 00560: val_loss did not improve from 0.01976
#
# Epoch 00561: val_loss did not improve from 0.01976
#
# Epoch 00562: val_loss did not improve from 0.01976
#
# Epoch 00563: val_loss did not improve from 0.01976
#
# Epoch 00564: val_loss did not improve from 0.01976
#
# Epoch 00565: val_loss did not improve from 0.01976
#
# Epoch 00566: val_loss did not improve from 0.01976
#
# Epoch 00567: val_loss did not improve from 0.01976
#
# Epoch 00568: val_loss did not improve from 0.01976
#
# Epoch 00569: val_loss improved from 0.01976 to 0.01970, saving model to best_model_elastic.h5
#
# Epoch 00570: val_loss did not improve from 0.01970
#
# Epoch 00571: val_loss did not improve from 0.01970
#
# Epoch 00572: val_loss did not improve from 0.01970
#
# Epoch 00573: val_loss did not improve from 0.01970
#
# Epoch 00574: val_loss did not improve from 0.01970
#
# Epoch 00575: val_loss did not improve from 0.01970
#
# Epoch 00576: val_loss did not improve from 0.01970
#
# Epoch 00577: val_loss did not improve from 0.01970
#
# Epoch 00578: val_loss did not improve from 0.01970
#
# Epoch 00579: val_loss did not improve from 0.01970
#
# Epoch 00580: val_loss did not improve from 0.01970
#
# Epoch 00581: val_loss did not improve from 0.01970
#
# Epoch 00582: val_loss did not improve from 0.01970
#
# Epoch 00583: val_loss improved from 0.01970 to 0.01970, saving model to best_model_elastic.h5
#
# Epoch 00584: val_loss did not improve from 0.01970
#
# Epoch 00585: val_loss did not improve from 0.01970
#
# Epoch 00586: val_loss did not improve from 0.01970
#
# Epoch 00587: val_loss did not improve from 0.01970
#
# Epoch 00588: val_loss did not improve from 0.01970
#
# Epoch 00589: val_loss did not improve from 0.01970
#
# Epoch 00590: val_loss did not improve from 0.01970
#
# Epoch 00591: val_loss did not improve from 0.01970
#
# Epoch 00592: val_loss did not improve from 0.01970
#
# Epoch 00593: val_loss did not improve from 0.01970
#
# Epoch 00594: val_loss did not improve from 0.01970
#
# Epoch 00595: val_loss did not improve from 0.01970
#
# Epoch 00596: val_loss did not improve from 0.01970
#
# Epoch 00597: val_loss did not improve from 0.01970
#
# Epoch 00598: val_loss did not improve from 0.01970
#
# Epoch 00599: val_loss did not improve from 0.01970
#
# Epoch 00600: val_loss did not improve from 0.01970
#
# Epoch 00601: val_loss did not improve from 0.01970
#
# Epoch 00602: val_loss did not improve from 0.01970
#
# Epoch 00603: val_loss did not improve from 0.01970
#
# Epoch 00604: val_loss did not improve from 0.01970
#
# Epoch 00605: val_loss did not improve from 0.01970
# Epoch 00606: val_loss did not improve from 0.01970
#
# Epoch 00607: val_loss did not improve from 0.01970
#
# Epoch 00608: val_loss did not improve from 0.01970
#
# Epoch 00609: val_loss did not improve from 0.01970
#
# Epoch 00610: val_loss did not improve from 0.01970
#
# Epoch 00611: val_loss did not improve from 0.01970
#
# Epoch 00612: val_loss did not improve from 0.01970
#
# Epoch 00613: val_loss improved from 0.01970 to 0.01963, saving model to best_model_elastic.h5
#
# Epoch 00614: val_loss did not improve from 0.01963
#
# Epoch 00615: val_loss did not improve from 0.01963
#
# Epoch 00616: val_loss did not improve from 0.01963
#
# Epoch 00617: val_loss did not improve from 0.01963
#
# Epoch 00618: val_loss improved from 0.01963 to 0.01958, saving model to best_model_elastic.h5
#
# Epoch 00619: val_loss did not improve from 0.01958
#
# Epoch 00620: val_loss did not improve from 0.01958
#
# Epoch 00621: val_loss did not improve from 0.01958
#
# Epoch 00622: val_loss did not improve from 0.01958
#
# Epoch 00623: val_loss did not improve from 0.01958
#
# Epoch 00624: val_loss did not improve from 0.01958
#
# Epoch 00625: val_loss did not improve from 0.01958
#
# Epoch 00626: val_loss did not improve from 0.01958
#
# Epoch 00627: val_loss did not improve from 0.01958
#
# Epoch 00628: val_loss did not improve from 0.01958
#
# Epoch 00629: val_loss did not improve from 0.01958
#
# Epoch 00630: val_loss did not improve from 0.01958
#
# Epoch 00631: val_loss did not improve from 0.01958
#
# Epoch 00632: val_loss did not improve from 0.01958
#
# Epoch 00633: val_loss did not improve from 0.01958
#
# Epoch 00634: val_loss did not improve from 0.01958
#
# Epoch 00635: val_loss did not improve from 0.01958
#
# Epoch 00636: val_loss did not improve from 0.01958
#
# Epoch 00637: val_loss did not improve from 0.01958
#
# Epoch 00638: val_loss did not improve from 0.01958
#
# Epoch 00639: val_loss did not improve from 0.01958
#
# Epoch 00640: val_loss did not improve from 0.01958
#
# Epoch 00641: val_loss did not improve from 0.01958
#
# Epoch 00642: val_loss did not improve from 0.01958
#
# Epoch 00643: val_loss did not improve from 0.01958
#
# Epoch 00644: val_loss improved from 0.01958 to 0.01955, saving model to best_model_elastic.h5
#
# Epoch 00645: val_loss did not improve from 0.01955
#
# Epoch 00646: val_loss did not improve from 0.01955
#
# Epoch 00647: val_loss did not improve from 0.01955
#
# Epoch 00648: val_loss did not improve from 0.01955
#
# Epoch 00649: val_loss did not improve from 0.01955
#
# Epoch 00650: val_loss did not improve from 0.01955
#
# Epoch 00651: val_loss did not improve from 0.01955
#
# Epoch 00652: val_loss did not improve from 0.01955
#
# Epoch 00653: val_loss did not improve from 0.01955
#
# Epoch 00654: val_loss did not improve from 0.01955
#
# Epoch 00655: val_loss did not improve from 0.01955
#
# Epoch 00656: val_loss did not improve from 0.01955
#
# Epoch 00657: val_loss did not improve from 0.01955
#
# Epoch 00658: val_loss did not improve from 0.01955
#
# Epoch 00659: val_loss did not improve from 0.01955
#
# Epoch 00660: val_loss did not improve from 0.01955
#
# Epoch 00661: val_loss did not improve from 0.01955
#
# Epoch 00662: val_loss did not improve from 0.01955
#
# Epoch 00663: val_loss did not improve from 0.01955
#
# Epoch 00664: val_loss did not improve from 0.01955
#
# Epoch 00665: val_loss improved from 0.01955 to 0.01952, saving model to best_model_elastic.h5
#
# Epoch 00666: val_loss did not improve from 0.01952
#
# Epoch 00667: val_loss did not improve from 0.01952
#
# Epoch 00668: val_loss did not improve from 0.01952
#
# Epoch 00669: val_loss did not improve from 0.01952
#
# Epoch 00670: val_loss did not improve from 0.01952
#
# Epoch 00671: val_loss did not improve from 0.01952
#
# Epoch 00672: val_loss did not improve from 0.01952
#
# Epoch 00673: val_loss did not improve from 0.01952
#
# Epoch 00674: val_loss did not improve from 0.01952
#
# Epoch 00675: val_loss did not improve from 0.01952
#
# Epoch 00676: val_loss did not improve from 0.01952
#
# Epoch 00677: val_loss did not improve from 0.01952
#
# Epoch 00678: val_loss did not improve from 0.01952
#
# Epoch 00679: val_loss did not improve from 0.01952
#
# Epoch 00680: val_loss did not improve from 0.01952
#
# Epoch 00681: val_loss did not improve from 0.01952
#
# Epoch 00682: val_loss did not improve from 0.01952
#
# Epoch 00683: val_loss did not improve from 0.01952
#
# Epoch 00684: val_loss did not improve from 0.01952
#
# Epoch 00685: val_loss did not improve from 0.01952
#
# Epoch 00686: val_loss did not improve from 0.01952
#
# Epoch 00687: val_loss did not improve from 0.01952
#
# Epoch 00688: val_loss did not improve from 0.01952
#
# Epoch 00689: val_loss did not improve from 0.01952
#
# Epoch 00690: val_loss did not improve from 0.01952
#
# Epoch 00691: val_loss did not improve from 0.01952
#
# Epoch 00692: val_loss did not improve from 0.01952
#
# Epoch 00693: val_loss did not improve from 0.01952
#
# Epoch 00694: val_loss did not improve from 0.01952
#
# Epoch 00695: val_loss did not improve from 0.01952
#
# Epoch 00696: val_loss did not improve from 0.01952
#
# Epoch 00697: val_loss did not improve from 0.01952
#
# Epoch 00698: val_loss did not improve from 0.01952
#
# Epoch 00699: val_loss did not improve from 0.01952
#
# Epoch 00700: val_loss did not improve from 0.01952
#
# Epoch 00701: val_loss did not improve from 0.01952
#
# Epoch 00702: val_loss did not improve from 0.01952
#
# Epoch 00703: val_loss did not improve from 0.01952
#
# Epoch 00704: val_loss did not improve from 0.01952
#
# Epoch 00705: val_loss did not improve from 0.01952
#
# Epoch 00706: val_loss did not improve from 0.01952
#
# Epoch 00707: val_loss did not improve from 0.01952
#
# Epoch 00708: val_loss did not improve from 0.01952
#
# Epoch 00709: val_loss did not improve from 0.01952
#
# Epoch 00710: val_loss did not improve from 0.01952
#
# Epoch 00711: val_loss did not improve from 0.01952
#
# Epoch 00712: val_loss did not improve from 0.01952
#
# Epoch 00713: val_loss did not improve from 0.01952
#
# Epoch 00714: val_loss did not improve from 0.01952
#
# Epoch 00715: val_loss did not improve from 0.01952
#
# Epoch 00716: val_loss did not improve from 0.01952
#
# Epoch 00717: val_loss did not improve from 0.01952
#
# Epoch 00718: val_loss did not improve from 0.01952
#
# Epoch 00719: val_loss did not improve from 0.01952
#
# Epoch 00720: val_loss improved from 0.01952 to 0.01948, saving model to best_model_elastic.h5
#
# Epoch 00721: val_loss did not improve from 0.01948
#
# Epoch 00722: val_loss did not improve from 0.01948
#
# Epoch 00723: val_loss did not improve from 0.01948
#
# Epoch 00724: val_loss did not improve from 0.01948
#
# Epoch 00725: val_loss did not improve from 0.01948
#
# Epoch 00726: val_loss did not improve from 0.01948
#
# Epoch 00727: val_loss did not improve from 0.01948
#
# Epoch 00728: val_loss did not improve from 0.01948
#
# Epoch 00729: val_loss did not improve from 0.01948
#
# Epoch 00730: val_loss did not improve from 0.01948
#
# Epoch 00731: val_loss did not improve from 0.01948
#
# Epoch 00732: val_loss did not improve from 0.01948
#
# Epoch 00733: val_loss did not improve from 0.01948
#
# Epoch 00734: val_loss did not improve from 0.01948
#
# Epoch 00735: val_loss did not improve from 0.01948
#
# Epoch 00736: val_loss did not improve from 0.01948
#
# Epoch 00737: val_loss did not improve from 0.01948
#
# Epoch 00738: val_loss did not improve from 0.01948
#
# Epoch 00739: val_loss did not improve from 0.01948
#
# Epoch 00740: val_loss did not improve from 0.01948
#
# Epoch 00741: val_loss did not improve from 0.01948
#
# Epoch 00742: val_loss did not improve from 0.01948
#
# Epoch 00743: val_loss did not improve from 0.01948
#
# Epoch 00744: val_loss did not improve from 0.01948
#
# Epoch 00745: val_loss did not improve from 0.01948
#
# Epoch 00746: val_loss did not improve from 0.01948
#
# Epoch 00747: val_loss did not improve from 0.01948
#
# Epoch 00748: val_loss did not improve from 0.01948
#
# Epoch 00749: val_loss did not improve from 0.01948
#
# Epoch 00750: val_loss did not improve from 0.01948
#
# Epoch 00751: val_loss did not improve from 0.01948
#
# Epoch 00752: val_loss did not improve from 0.01948
#
# Epoch 00753: val_loss did not improve from 0.01948
#
# Epoch 00754: val_loss did not improve from 0.01948
#
# Epoch 00755: val_loss did not improve from 0.01948
#
# Epoch 00756: val_loss did not improve from 0.01948
#
# Epoch 00757: val_loss did not improve from 0.01948
#
# Epoch 00758: val_loss did not improve from 0.01948
#
# Epoch 00759: val_loss did not improve from 0.01948
# Epoch 00760: val_loss did not improve from 0.01948
#
# Epoch 00761: val_loss did not improve from 0.01948
#
# Epoch 00762: val_loss improved from 0.01948 to 0.01946, saving model to best_model_elastic.h5
#
# Epoch 00763: val_loss did not improve from 0.01946
#
# Epoch 00764: val_loss improved from 0.01946 to 0.01934, saving model to best_model_elastic.h5
#
# Epoch 00765: val_loss did not improve from 0.01934
#
# Epoch 00766: val_loss did not improve from 0.01934
#
# Epoch 00767: val_loss did not improve from 0.01934
#
# Epoch 00768: val_loss did not improve from 0.01934
#
# Epoch 00769: val_loss did not improve from 0.01934
#
# Epoch 00770: val_loss did not improve from 0.01934
#
# Epoch 00771: val_loss did not improve from 0.01934
#
# Epoch 00772: val_loss did not improve from 0.01934
#
# Epoch 00773: val_loss did not improve from 0.01934
#
# Epoch 00774: val_loss did not improve from 0.01934
#
# Epoch 00775: val_loss did not improve from 0.01934
#
# Epoch 00776: val_loss improved from 0.01934 to 0.01931, saving model to best_model_elastic.h5
#
# Epoch 00777: val_loss did not improve from 0.01931
#
# Epoch 00778: val_loss did not improve from 0.01931
#
# Epoch 00779: val_loss did not improve from 0.01931
#
# Epoch 00780: val_loss did not improve from 0.01931
#
# Epoch 00781: val_loss did not improve from 0.01931
#
# Epoch 00782: val_loss did not improve from 0.01931
#
# Epoch 00783: val_loss did not improve from 0.01931
#
# Epoch 00784: val_loss did not improve from 0.01931
#
# Epoch 00785: val_loss did not improve from 0.01931
#
# Epoch 00786: val_loss did not improve from 0.01931
#
# Epoch 00787: val_loss did not improve from 0.01931
#
# Epoch 00788: val_loss did not improve from 0.01931
#
# Epoch 00789: val_loss did not improve from 0.01931
#
# Epoch 00790: val_loss did not improve from 0.01931
#
# Epoch 00791: val_loss improved from 0.01931 to 0.01930, saving model to best_model_elastic.h5
#
# Epoch 00792: val_loss did not improve from 0.01930
#
# Epoch 00793: val_loss did not improve from 0.01930
#
# Epoch 00794: val_loss did not improve from 0.01930
#
# Epoch 00795: val_loss did not improve from 0.01930
#
# Epoch 00796: val_loss did not improve from 0.01930
#
# Epoch 00797: val_loss did not improve from 0.01930
#
# Epoch 00798: val_loss did not improve from 0.01930
#
# Epoch 00799: val_loss did not improve from 0.01930
#
# Epoch 00800: val_loss did not improve from 0.01930
#
# Epoch 00801: val_loss did not improve from 0.01930
#
# Epoch 00802: val_loss did not improve from 0.01930
#
# Epoch 00803: val_loss did not improve from 0.01930
#
# Epoch 00804: val_loss did not improve from 0.01930
#
# Epoch 00805: val_loss did not improve from 0.01930
#
# Epoch 00806: val_loss did not improve from 0.01930
#
# Epoch 00807: val_loss did not improve from 0.01930
#
# Epoch 00808: val_loss did not improve from 0.01930
#
# Epoch 00809: val_loss did not improve from 0.01930
#
# Epoch 00810: val_loss did not improve from 0.01930
#
# Epoch 00811: val_loss did not improve from 0.01930
#
# Epoch 00812: val_loss did not improve from 0.01930
#
# Epoch 00813: val_loss did not improve from 0.01930
#
# Epoch 00814: val_loss did not improve from 0.01930
#
# Epoch 00815: val_loss did not improve from 0.01930
#
# Epoch 00816: val_loss improved from 0.01930 to 0.01924, saving model to best_model_elastic.h5
#
# Epoch 00817: val_loss did not improve from 0.01924
#
# Epoch 00818: val_loss did not improve from 0.01924
#
# Epoch 00819: val_loss did not improve from 0.01924
#
# Epoch 00820: val_loss did not improve from 0.01924
#
# Epoch 00821: val_loss did not improve from 0.01924
#
# Epoch 00822: val_loss did not improve from 0.01924
#
# Epoch 00823: val_loss did not improve from 0.01924
#
# Epoch 00824: val_loss did not improve from 0.01924
#
# Epoch 00825: val_loss did not improve from 0.01924
#
# Epoch 00826: val_loss did not improve from 0.01924
#
# Epoch 00827: val_loss did not improve from 0.01924
#
# Epoch 00828: val_loss did not improve from 0.01924
#
# Epoch 00829: val_loss did not improve from 0.01924
#
# Epoch 00830: val_loss did not improve from 0.01924
#
# Epoch 00831: val_loss improved from 0.01924 to 0.01915, saving model to best_model_elastic.h5
#
# Epoch 00832: val_loss did not improve from 0.01915
#
# Epoch 00833: val_loss did not improve from 0.01915
#
# Epoch 00834: val_loss did not improve from 0.01915
#
# Epoch 00835: val_loss did not improve from 0.01915
#
# Epoch 00836: val_loss did not improve from 0.01915
#
# Epoch 00837: val_loss did not improve from 0.01915
#
# Epoch 00838: val_loss did not improve from 0.01915
#
# Epoch 00839: val_loss did not improve from 0.01915
#
# Epoch 00840: val_loss did not improve from 0.01915
#
# Epoch 00841: val_loss did not improve from 0.01915
#
# Epoch 00842: val_loss did not improve from 0.01915
#
# Epoch 00843: val_loss did not improve from 0.01915
#
# Epoch 00844: val_loss did not improve from 0.01915
#
# Epoch 00845: val_loss did not improve from 0.01915
#
# Epoch 00846: val_loss did not improve from 0.01915
#
# Epoch 00847: val_loss did not improve from 0.01915
#
# Epoch 00848: val_loss did not improve from 0.01915
#
# Epoch 00849: val_loss did not improve from 0.01915
#
# Epoch 00850: val_loss improved from 0.01915 to 0.01908, saving model to best_model_elastic.h5
#
# Epoch 00851: val_loss did not improve from 0.01908
#
# Epoch 00852: val_loss did not improve from 0.01908
#
# Epoch 00853: val_loss did not improve from 0.01908
#
# Epoch 00854: val_loss did not improve from 0.01908
#
# Epoch 00855: val_loss did not improve from 0.01908
#
# Epoch 00856: val_loss did not improve from 0.01908
#
# Epoch 00857: val_loss did not improve from 0.01908
#
# Epoch 00858: val_loss did not improve from 0.01908
#
# Epoch 00859: val_loss did not improve from 0.01908
#
# Epoch 00860: val_loss did not improve from 0.01908
#
# Epoch 00861: val_loss did not improve from 0.01908
#
# Epoch 00862: val_loss did not improve from 0.01908
#
# Epoch 00863: val_loss did not improve from 0.01908
#
# Epoch 00864: val_loss did not improve from 0.01908
#
# Epoch 00865: val_loss did not improve from 0.01908
#
# Epoch 00866: val_loss did not improve from 0.01908
#
# Epoch 00867: val_loss did not improve from 0.01908
#
# Epoch 00868: val_loss improved from 0.01908 to 0.01902, saving model to best_model_elastic.h5
#
# Epoch 00869: val_loss did not improve from 0.01902
#
# Epoch 00870: val_loss did not improve from 0.01902
#
# Epoch 00871: val_loss did not improve from 0.01902
#
# Epoch 00872: val_loss did not improve from 0.01902
#
# Epoch 00873: val_loss did not improve from 0.01902
#
# Epoch 00874: val_loss did not improve from 0.01902
#
# Epoch 00875: val_loss did not improve from 0.01902
#
# Epoch 00876: val_loss did not improve from 0.01902
#
# Epoch 00877: val_loss improved from 0.01902 to 0.01902, saving model to best_model_elastic.h5
#
# Epoch 00878: val_loss did not improve from 0.01902
#
# Epoch 00879: val_loss did not improve from 0.01902
#
# Epoch 00880: val_loss did not improve from 0.01902
#
# Epoch 00881: val_loss did not improve from 0.01902
#
# Epoch 00882: val_loss did not improve from 0.01902
#
# Epoch 00883: val_loss did not improve from 0.01902
#
# Epoch 00884: val_loss did not improve from 0.01902
#
# ...
#
# Epoch 01053: val_loss did not improve from 0.01800
#
# Epoch 01054: val_loss did not improve from 0.01800
#
# Epoch 01055: val_loss did not improve from 0.01800
#
# Epoch 01056: val_loss did not improve from 0.01800
#
# Epoch 01057: val_loss did not improve from 0.01800
# Epoch 01058: val_loss did not improve from 0.01800
#
# Epoch 01059: val_loss did not improve from 0.01800
#
# Epoch 01060: val_loss did not improve from 0.01800
#
# Epoch 01061: val_loss did not improve from 0.01800
#
# Epoch 01062: val_loss did not improve from 0.01800
#
# Epoch 01063: val_loss did not improve from 0.01800
#
# Epoch 01064: val_loss did not improve from 0.01800
#
# Epoch 01065: val_loss did not improve from 0.01800
#
# Epoch 01066: val_loss did not improve from 0.01800
#
# Epoch 01067: val_loss did not improve from 0.01800
#
# Epoch 01068: val_loss did not improve from 0.01800
#
# Epoch 01069: val_loss did not improve from 0.01800
#
# Epoch 01070: val_loss did not improve from 0.01800
#
# Epoch 01071: val_loss did not improve from 0.01800
#
# Epoch 01072: val_loss did not improve from 0.01800
#
# Epoch 01073: val_loss improved from 0.01800 to 0.01797, saving model to best_model_elastic.h5
#
# Epoch 01074: val_loss did not improve from 0.01797
#
# Epoch 01075: val_loss did not improve from 0.01797
#
# Epoch 01076: val_loss did not improve from 0.01797
#
# Epoch 01077: val_loss did not improve from 0.01797
#
# Epoch 01078: val_loss did not improve from 0.01797
#
# Epoch 01079: val_loss did not improve from 0.01797
#
# Epoch 01080: val_loss did not improve from 0.01797
#
# Epoch 01081: val_loss improved from 0.01797 to 0.01796, saving model to best_model_elastic.h5
#
# Epoch 01082: val_loss did not improve from 0.01796
#
# Epoch 01083: val_loss did not improve from 0.01796
#
# Epoch 01084: val_loss did not improve from 0.01796
#
# Epoch 01085: val_loss did not improve from 0.01796
#
# Epoch 01086: val_loss did not improve from 0.01796
#
# Epoch 01087: val_loss did not improve from 0.01796
#
# Epoch 01088: val_loss did not improve from 0.01796
#
# Epoch 01089: val_loss did not improve from 0.01796
#
# Epoch 01090: val_loss did not improve from 0.01796
#
# Epoch 01091: val_loss improved from 0.01796 to 0.01771, saving model to best_model_elastic.h5
#
# Epoch 01092: val_loss did not improve from 0.01771
#
# Epoch 01093: val_loss did not improve from 0.01771
#
# Epoch 01094: val_loss did not improve from 0.01771
#
# Epoch 01095: val_loss did not improve from 0.01771
#
# Epoch 01096: val_loss did not improve from 0.01771
#
# Epoch 01097: val_loss did not improve from 0.01771
#
# Epoch 01098: val_loss did not improve from 0.01771
#
# Epoch 01099: val_loss did not improve from 0.01771
#
# Epoch 01100: val_loss did not improve from 0.01771
#
# Epoch 01101: val_loss did not improve from 0.01771
#
# Epoch 01102: val_loss did not improve from 0.01771
#
# Epoch 01103: val_loss improved from 0.01771 to 0.01763, saving model to best_model_elastic.h5
#
# Epoch 01104: val_loss did not improve from 0.01763
#
# Epoch 01105: val_loss did not improve from 0.01763
#
# Epoch 01106: val_loss did not improve from 0.01763
#
# Epoch 01107: val_loss did not improve from 0.01763
#
# Epoch 01108: val_loss did not improve from 0.01763
#
# Epoch 01109: val_loss did not improve from 0.01763
#
# Epoch 01110: val_loss did not improve from 0.01763
#
# Epoch 01111: val_loss improved from 0.01763 to 0.01761, saving model to best_model_elastic.h5
#
# Epoch 01112: val_loss did not improve from 0.01761
#
# Epoch 01113: val_loss did not improve from 0.01761
#
# Epoch 01114: val_loss did not improve from 0.01761
#
# Epoch 01115: val_loss did not improve from 0.01761
#
# Epoch 01116: val_loss did not improve from 0.01761
#
# Epoch 01117: val_loss did not improve from 0.01761
#
# Epoch 01118: val_loss did not improve from 0.01761
#
# Epoch 01119: val_loss did not improve from 0.01761
#
# Epoch 01120: val_loss improved from 0.01761 to 0.01753, saving model to best_model_elastic.h5
#
# Epoch 01121: val_loss did not improve from 0.01753
#
# Epoch 01122: val_loss did not improve from 0.01753
#
# Epoch 01123: val_loss did not improve from 0.01753
#
# Epoch 01124: val_loss did not improve from 0.01753
#
# Epoch 01125: val_loss did not improve from 0.01753
#
# Epoch 01126: val_loss did not improve from 0.01753
#
# Epoch 01127: val_loss did not improve from 0.01753
#
# Epoch 01128: val_loss did not improve from 0.01753
#
# Epoch 01129: val_loss did not improve from 0.01753
#
# Epoch 01130: val_loss did not improve from 0.01753
#
# Epoch 01131: val_loss did not improve from 0.01753
#
# Epoch 01132: val_loss did not improve from 0.01753
#
# Epoch 01133: val_loss improved from 0.01753 to 0.01749, saving model to best_model_elastic.h5
#
# Epoch 01134: val_loss did not improve from 0.01749
#
# Epoch 01135: val_loss did not improve from 0.01749
#
# Epoch 01136: val_loss improved from 0.01749 to 0.01740, saving model to best_model_elastic.h5
#
# Epoch 01137: val_loss did not improve from 0.01740
#
# Epoch 01138: val_loss did not improve from 0.01740
#
# Epoch 01139: val_loss did not improve from 0.01740
#
# Epoch 01140: val_loss did not improve from 0.01740
#
# Epoch 01141: val_loss did not improve from 0.01740
#
# Epoch 01142: val_loss did not improve from 0.01740
#
# Epoch 01143: val_loss did not improve from 0.01740
#
# Epoch 01144: val_loss improved from 0.01740 to 0.01739, saving model to best_model_elastic.h5
#
# Epoch 01145: val_loss did not improve from 0.01739
#
# Epoch 01146: val_loss did not improve from 0.01739
#
# Epoch 01147: val_loss improved from 0.01739 to 0.01726, saving model to best_model_elastic.h5
#
# Epoch 01148: val_loss did not improve from 0.01726
#
# Epoch 01149: val_loss did not improve from 0.01726
#
# Epoch 01150: val_loss did not improve from 0.01726
#
# Epoch 01151: val_loss did not improve from 0.01726
#
# Epoch 01152: val_loss did not improve from 0.01726
#
# Epoch 01153: val_loss did not improve from 0.01726
#
# Epoch 01154: val_loss did not improve from 0.01726
#
# Epoch 01155: val_loss did not improve from 0.01726
#
# Epoch 01156: val_loss did not improve from 0.01726
#
# Epoch 01157: val_loss did not improve from 0.01726
#
# Epoch 01158: val_loss did not improve from 0.01726
#
# Epoch 01159: val_loss did not improve from 0.01726
#
# Epoch 01160: val_loss did not improve from 0.01726
#
# Epoch 01161: val_loss did not improve from 0.01726
#
# Epoch 01162: val_loss did not improve from 0.01726
#
# Epoch 01163: val_loss did not improve from 0.01726
#
# Epoch 01164: val_loss did not improve from 0.01726
#
# Epoch 01165: val_loss did not improve from 0.01726
#
# Epoch 01166: val_loss did not improve from 0.01726
#
# Epoch 01167: val_loss did not improve from 0.01726
#
# Epoch 01168: val_loss did not improve from 0.01726
#
# Epoch 01169: val_loss did not improve from 0.01726
#
# Epoch 01170: val_loss did not improve from 0.01726
#
# Epoch 01171: val_loss improved from 0.01726 to 0.01715, saving model to best_model_elastic.h5
#
# Epoch 01172: val_loss did not improve from 0.01715
#
# Epoch 01173: val_loss did not improve from 0.01715
#
# Epoch 01174: val_loss did not improve from 0.01715
#
# Epoch 01175: val_loss did not improve from 0.01715
#
# Epoch 01176: val_loss did not improve from 0.01715
#
# Epoch 01177: val_loss did not improve from 0.01715
#
# Epoch 01178: val_loss did not improve from 0.01715
#
# Epoch 01179: val_loss did not improve from 0.01715
#
# Epoch 01180: val_loss did not improve from 0.01715
#
# Epoch 01181: val_loss did not improve from 0.01715
#
# Epoch 01182: val_loss did not improve from 0.01715
#
# Epoch 01183: val_loss did not improve from 0.01715
#
# Epoch 01184: val_loss did not improve from 0.01715
#
# Epoch 01185: val_loss did not improve from 0.01715
#
# Epoch 01186: val_loss did not improve from 0.01715
#
# Epoch 01187: val_loss did not improve from 0.01715
#
# Epoch 01188: val_loss did not improve from 0.01715
#
# Epoch 01189: val_loss did not improve from 0.01715
#
# Epoch 01190: val_loss improved from 0.01715 to 0.01705, saving model to best_model_elastic.h5
#
# Epoch 01191: val_loss did not improve from 0.01705
#
# Epoch 01192: val_loss did not improve from 0.01705
#
# Epoch 01193: val_loss did not improve from 0.01705
#
# Epoch 01194: val_loss did not improve from 0.01705
#
# Epoch 01195: val_loss did not improve from 0.01705
#
# Epoch 01196: val_loss did not improve from 0.01705
#
# Epoch 01197: val_loss did not improve from 0.01705
#
# Epoch 01198: val_loss did not improve from 0.01705
#
# Epoch 01199: val_loss did not improve from 0.01705
#
# Epoch 01200: val_loss did not improve from 0.01705
#
# Epoch 01201: val_loss did not improve from 0.01705
#
# Epoch 01202: val_loss did not improve from 0.01705
#
# Epoch 01203: val_loss improved from 0.01705 to 0.01697, saving model to best_model_elastic.h5
#
# Epoch 01204: val_loss did not improve from 0.01697
# Epoch 01205: val_loss did not improve from 0.01697
#
# Epoch 01206: val_loss did not improve from 0.01697
#
# Epoch 01207: val_loss did not improve from 0.01697
#
# Epoch 01208: val_loss did not improve from 0.01697
#
# Epoch 01209: val_loss did not improve from 0.01697
#
# Epoch 01210: val_loss did not improve from 0.01697
#
# Epoch 01211: val_loss did not improve from 0.01697
#
# Epoch 01212: val_loss did not improve from 0.01697
#
# Epoch 01213: val_loss did not improve from 0.01697
#
# Epoch 01214: val_loss did not improve from 0.01697
#
# Epoch 01215: val_loss did not improve from 0.01697
#
# Epoch 01216: val_loss did not improve from 0.01697
#
# Epoch 01217: val_loss did not improve from 0.01697
#
# Epoch 01218: val_loss did not improve from 0.01697
#
# Epoch 01219: val_loss did not improve from 0.01697
#
# Epoch 01220: val_loss did not improve from 0.01697
#
# Epoch 01221: val_loss did not improve from 0.01697
#
# Epoch 01222: val_loss did not improve from 0.01697
#
# Epoch 01223: val_loss did not improve from 0.01697
#
# Epoch 01224: val_loss did not improve from 0.01697
#
# Epoch 01225: val_loss did not improve from 0.01697
#
# Epoch 01226: val_loss did not improve from 0.01697
#
# Epoch 01227: val_loss did not improve from 0.01697
#
# Epoch 01228: val_loss did not improve from 0.01697
#
# Epoch 01229: val_loss did not improve from 0.01697
#
# Epoch 01230: val_loss did not improve from 0.01697
#
# Epoch 01231: val_loss did not improve from 0.01697
#
# Epoch 01232: val_loss did not improve from 0.01697
#
# Epoch 01233: val_loss did not improve from 0.01697
#
# Epoch 01234: val_loss did not improve from 0.01697
#
# Epoch 01235: val_loss did not improve from 0.01697
#
# Epoch 01236: val_loss did not improve from 0.01697
#
# Epoch 01237: val_loss did not improve from 0.01697
#
# Epoch 01238: val_loss improved from 0.01697 to 0.01697, saving model to best_model_elastic.h5
#
# Epoch 01239: val_loss did not improve from 0.01697
#
# Epoch 01240: val_loss did not improve from 0.01697
#
# Epoch 01241: val_loss did not improve from 0.01697
#
# Epoch 01242: val_loss did not improve from 0.01697
#
# Epoch 01243: val_loss did not improve from 0.01697
#
# Epoch 01244: val_loss did not improve from 0.01697
#
# Epoch 01245: val_loss improved from 0.01697 to 0.01681, saving model to best_model_elastic.h5
#
# Epoch 01246: val_loss did not improve from 0.01681
#
# Epoch 01247: val_loss did not improve from 0.01681
#
# Epoch 01248: val_loss did not improve from 0.01681
#
# Epoch 01249: val_loss did not improve from 0.01681
#
# Epoch 01250: val_loss did not improve from 0.01681
#
# Epoch 01251: val_loss did not improve from 0.01681
#
# Epoch 01252: val_loss did not improve from 0.01681
#
# Epoch 01253: val_loss did not improve from 0.01681
#
# Epoch 01254: val_loss did not improve from 0.01681
#
# Epoch 01255: val_loss did not improve from 0.01681
#
# Epoch 01256: val_loss did not improve from 0.01681
#
# Epoch 01257: val_loss did not improve from 0.01681
#
# Epoch 01258: val_loss did not improve from 0.01681
#
# Epoch 01259: val_loss did not improve from 0.01681
#
# Epoch 01260: val_loss did not improve from 0.01681
#
# Epoch 01261: val_loss did not improve from 0.01681
#
# Epoch 01262: val_loss did not improve from 0.01681
#
# Epoch 01263: val_loss did not improve from 0.01681
#
# Epoch 01264: val_loss did not improve from 0.01681
#
# Epoch 01265: val_loss did not improve from 0.01681
#
# Epoch 01266: val_loss did not improve from 0.01681
#
# Epoch 01267: val_loss did not improve from 0.01681
#
# Epoch 01268: val_loss did not improve from 0.01681
#
# Epoch 01269: val_loss did not improve from 0.01681
#
# Epoch 01270: val_loss did not improve from 0.01681
#
# Epoch 01271: val_loss did not improve from 0.01681
#
# Epoch 01272: val_loss did not improve from 0.01681
#
# Epoch 01273: val_loss did not improve from 0.01681
#
# Epoch 01274: val_loss did not improve from 0.01681
#
# Epoch 01275: val_loss did not improve from 0.01681
#
# Epoch 01276: val_loss did not improve from 0.01681
#
# Epoch 01277: val_loss did not improve from 0.01681
#
# Epoch 01278: val_loss did not improve from 0.01681
#
# Epoch 01279: val_loss did not improve from 0.01681
#
# Epoch 01280: val_loss did not improve from 0.01681
#
# Epoch 01281: val_loss did not improve from 0.01681
#
# Epoch 01282: val_loss did not improve from 0.01681
#
# Epoch 01283: val_loss did not improve from 0.01681
#
# Epoch 01284: val_loss did not improve from 0.01681
#
# Epoch 01285: val_loss did not improve from 0.01681
#
# Epoch 01286: val_loss did not improve from 0.01681
#
# Epoch 01287: val_loss did not improve from 0.01681
#
# Epoch 01288: val_loss did not improve from 0.01681
#
# Epoch 01289: val_loss did not improve from 0.01681
#
# Epoch 01290: val_loss did not improve from 0.01681
#
# Epoch 01291: val_loss did not improve from 0.01681
#
# Epoch 01292: val_loss did not improve from 0.01681
#
# Epoch 01293: val_loss did not improve from 0.01681
#
# Epoch 01294: val_loss did not improve from 0.01681
#
# Epoch 01295: val_loss did not improve from 0.01681
#
# Epoch 01296: val_loss did not improve from 0.01681
#
# Epoch 01297: val_loss did not improve from 0.01681
#
# Epoch 01298: val_loss did not improve from 0.01681
#
# Epoch 01299: val_loss did not improve from 0.01681
#
# Epoch 01300: val_loss did not improve from 0.01681
#
# Epoch 01301: val_loss did not improve from 0.01681
#
# Epoch 01302: val_loss did not improve from 0.01681
#
# Epoch 01303: val_loss did not improve from 0.01681
#
# Epoch 01304: val_loss did not improve from 0.01681
#
# Epoch 01305: val_loss did not improve from 0.01681
#
# Epoch 01306: val_loss did not improve from 0.01681
#
# Epoch 01307: val_loss did not improve from 0.01681
#
# Epoch 01308: val_loss did not improve from 0.01681
#
# Epoch 01309: val_loss did not improve from 0.01681
#
# Epoch 01310: val_loss did not improve from 0.01681
#
# Epoch 01311: val_loss did not improve from 0.01681
#
# Epoch 01312: val_loss did not improve from 0.01681
#
# Epoch 01313: val_loss did not improve from 0.01681
#
# Epoch 01314: val_loss did not improve from 0.01681
#
# Epoch 01315: val_loss did not improve from 0.01681
#
# Epoch 01316: val_loss did not improve from 0.01681
#
# Epoch 01317: val_loss did not improve from 0.01681
#
# Epoch 01318: val_loss did not improve from 0.01681
#
# Epoch 01319: val_loss did not improve from 0.01681
#
# Epoch 01320: val_loss did not improve from 0.01681
#
# Epoch 01321: val_loss did not improve from 0.01681
#
# Epoch 01322: val_loss did not improve from 0.01681
#
# Epoch 01323: val_loss did not improve from 0.01681
#
# Epoch 01324: val_loss did not improve from 0.01681
#
# Epoch 01325: val_loss did not improve from 0.01681
#
# Epoch 01326: val_loss did not improve from 0.01681
#
# Epoch 01327: val_loss did not improve from 0.01681
#
# Epoch 01328: val_loss did not improve from 0.01681
#
# Epoch 01329: val_loss did not improve from 0.01681
#
# Epoch 01330: val_loss did not improve from 0.01681
#
# Epoch 01331: val_loss did not improve from 0.01681
#
# Epoch 01332: val_loss did not improve from 0.01681
#
# Epoch 01333: val_loss did not improve from 0.01681
#
# Epoch 01334: val_loss did not improve from 0.01681
#
# Epoch 01335: val_loss did not improve from 0.01681
#
# Epoch 01336: val_loss did not improve from 0.01681
#
# Epoch 01337: val_loss did not improve from 0.01681
#
# Epoch 01338: val_loss did not improve from 0.01681
#
# Epoch 01339: val_loss did not improve from 0.01681
#
# Epoch 01340: val_loss did not improve from 0.01681
#
# Epoch 01341: val_loss did not improve from 0.01681
#
# Epoch 01342: val_loss did not improve from 0.01681
#
# Epoch 01343: val_loss did not improve from 0.01681
#
# Epoch 01344: val_loss did not improve from 0.01681
#
# Epoch 01345: val_loss did not improve from 0.01681
# Epoch 01345: early stopping

# %%
# load the saved model
ElasticModel = load_model('best_model_elastic.h5')

# %%
# Testing and evaluating the model
preds = ElasticModel.evaluate(X_test, Y_test, batch_size=32, verbose=0, sample_weight=None)
print()
print ("Loss = " + str(preds))
# print ("Test Accuracy = " + str(preds[1]))
# Out:
# Loss = 0.0167906763702631

# %%
# Plotting the learning curve 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# plt.plot(history.history['loss']/np.max(history.history['loss']))
# plt.plot(history.history['val_loss']/np.max(history.history['val_loss']))
# plt.yscale("log")
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])


plt.title('Learning curve')
# plt.ylabel('Error/Accuracy')
plt.ylabel('Error')
plt.xlabel('epochs')
plt.legend(['train loss', 'validation loss'], loc='center right')
# plt.savefig('/Figures/learning_curve_08Nov.png', bbox_inches='tight')

# %%
# Save trained model 
# serialize model to JSON
model_json = ElasticModel.to_json()
with open("elastic_model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
ElasticModel.save_weights("ElasticModel.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Load saved model
# load json and create model
json_file = open('elastic_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("ElasticModel.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
adam = optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)


ElasticModel.compile(loss='mean_squared_error', optimizer = adam)


# To evaluate run the "Testing and evaluating the model" cell
# Out:
# Loaded model from disk

# %%
# Predict training and test data using the trained network
test_output_norm = ElasticModel.predict(X_test)
train_output_norm = ElasticModel.predict(X_train)

# Initialization
train_output = np.zeros(train_output_norm.shape)
test_output = np.zeros(test_output_norm.shape)
Y_train = np.zeros(Y_train_norm.shape)
Y_test = np.zeros(Y_test_norm.shape)

# Back transforming Vp, Vs and RHOB to unnormalized values 
train_output[:,0,:] = train_output_norm[:,0,:]*(np.max(Vp_time) - np.min(Vp_time)) + np.min(Vp_time)
test_output[:,0,:] = test_output_norm[:,0,:]*(np.max(Vp_time) - np.min(Vp_time)) + np.min(Vp_time)

train_output[:,1,:] = train_output_norm[:,1,:]*(np.max(Vs_time) - np.min(Vs_time)) + np.min(Vs_time)
test_output[:,1,:] = test_output_norm[:,1,:]*(np.max(Vs_time) - np.min(Vs_time)) + np.min(Vs_time)

train_output[:,2,:] = train_output_norm[:,2,:]*(np.max(RHOB_time) - np.min(RHOB_time)) + np.min(RHOB_time)
test_output[:,2,:] = test_output_norm[:,2,:]*(np.max(RHOB_time) - np.min(RHOB_time)) + np.min(RHOB_time)

Y_train[:,0,:] = Y_train_norm[:,0,:]*(np.max(Vp_time) - np.min(Vp_time)) + np.min(Vp_time)
Y_test[:,0,:] = Y_test_norm[:,0,:]*(np.max(Vp_time) - np.min(Vp_time)) + np.min(Vp_time)

Y_train[:,1,:] = Y_train_norm[:,1,:]*(np.max(Vs_time) - np.min(Vs_time)) + np.min(Vs_time)
Y_test[:,1,:] = Y_test_norm[:,1,:]*(np.max(Vs_time) - np.min(Vs_time)) + np.min(Vs_time)

Y_train[:,2,:] = Y_train_norm[:,2,:]*(np.max(RHOB_time) - np.min(RHOB_time)) + np.min(RHOB_time)
Y_test[:,2,:] = Y_test_norm[:,2,:]*(np.max(RHOB_time) - np.min(RHOB_time)) + np.min(RHOB_time)

# %%
# Predict training and test data using the trained network
test_output = ElasticModel.predict(X_test)
train_output = ElasticModel.predict(X_train)

# %%
# Checking training data

sample_number = 25
f, axarr = plt.subplots(1, 3, sharey = True)

axarr[0].plot(train_output[sample_number, 0, :], time_upscaled, '-k')
axarr[0].plot(Y_train[sample_number, 0, :], time_upscaled, '--r')
axarr[0].set_xlabel("Vp")
axarr[0].set_ylabel("Time")
axarr[0].invert_yaxis()
# axarr[0].set_xlim(1.5,3.1)

axarr[1].plot(train_output[sample_number, 1, :], time_upscaled, '-k')
axarr[1].plot(Y_train[sample_number, 1, :], time_upscaled, '--r')
axarr[1].set_xlabel("Vs")
axarr[1].set_ylabel("Time")
axarr[1].invert_yaxis()
# axarr[1].set_xlim(1,2)

axarr[2].plot(train_output[sample_number, 2, :], time_upscaled, '-k')
axarr[2].plot(Y_train[sample_number, 2, :], time_upscaled, '--r')
axarr[2].set_xlabel("RHOB")
axarr[2].set_ylabel("Time")
axarr[2].invert_yaxis()
# axarr[2].set_xlim(1.5,3)

# %%
# Checking testing data

sample_number = 12
f, axarr = plt.subplots(1, 3, sharey = True)

axarr[0].plot(test_output[sample_number, 0, :], time_upscaled, '-k')
axarr[0].plot(Y_test[sample_number, 0, :], time_upscaled, '--r')
axarr[0].set_xlabel("Vp")
axarr[0].set_ylabel("Time")
axarr[0].invert_yaxis()
axarr[0].set_xlim(1.5,3.1)

axarr[1].plot(test_output[sample_number, 1, :], time_upscaled, '-k')
axarr[1].plot(Y_test[sample_number, 1, :], time_upscaled, '--r')
axarr[1].set_xlabel("Vs")
axarr[1].set_ylabel("Time")
axarr[1].invert_yaxis()
axarr[1].set_xlim(1,2)

axarr[2].plot(test_output[sample_number, 2, :], time_upscaled, '-k')
axarr[2].plot(Y_test[sample_number, 2, :], time_upscaled, '--r')
axarr[2].set_xlabel("RHOB")
axarr[2].set_ylabel("Time")
axarr[2].invert_yaxis()
axarr[2].set_xlim(1.5,3)
# Out:
# (1.5, 3)

# %%
# Correlation coefficient between true and predicted traces 

Vp_corr_train = np.zeros(train_output.shape[0])
Vs_corr_train = np.zeros(train_output.shape[0])
RHOB_corr_train = np.zeros(train_output.shape[0])
for i in range(train_output.shape[0]):
    Vp_corr_train[i] = np.corrcoef(train_output[i,0,:], Y_train[i,0,:])[0,1]
    Vs_corr_train[i] = np.corrcoef(train_output[i,1,:], Y_train[i,1,:])[0,1]
    RHOB_corr_train[i] = np.corrcoef(train_output[i,2,:], Y_train[i,2,:])[0,1]
    
Vp_corr_test = np.zeros(test_output.shape[0])
Vs_corr_test = np.zeros(test_output.shape[0])
RHOB_corr_test = np.zeros(test_output.shape[0])
for i in range(test_output.shape[0]):
    Vp_corr_test[i] = np.corrcoef(test_output[i,0,:], Y_test[i,0,:])[0,1]
    Vs_corr_test[i] = np.corrcoef(test_output[i,1,:], Y_test[i,1,:])[0,1]
    RHOB_corr_test[i] = np.corrcoef(test_output[i,2,:], Y_test[i,2,:])[0,1]

    
# Average correlation coefficient
print("Average correlation in Vp for training data = ", np.mean(Vp_corr_train))
print("Average correlation in Vs for training data = ", np.mean(Vs_corr_train))
print("Average correlation in RHOB for training data = ", np.mean(RHOB_corr_train))

print("Average correlation in Vp for training data = ", np.mean(Vp_corr_test))
print("Average correlation in Vs for training data = ", np.mean(Vs_corr_test))
print("Average correlation in RHOB for training data = ", np.mean(RHOB_corr_test))
# Out:
# Average correlation in Vp for training data =  0.5321851188017265
# Average correlation in Vs for training data =  0.6918674926763783
# Average correlation in RHOB for training data =  0.841071697194581
# Average correlation in Vp for training data =  0.37922835257155413
# Average correlation in Vs for training data =  0.5807486851521866
# Average correlation in RHOB for training data =  0.7919483637882461

# %% [markdown]
# ## Predicting petrophysical properties from elastic properties of previous network

# %%
# Use predicted Vp, Vs and RHOB from network
# Concatenate Vp, Vs and Density 

num_examples = Vp_time.shape[0]
emodel_true = np.concatenate((Vp_time,Vs_time,RHOB_time), axis=1)
emodel_true = emodel.reshape((num_examples, 3, nt))

# emodel_norm = ElasticModel.predict(np.expand_dims(seis_reshaped_normalized, axis=3))
emodel_norm = ElasticModel.predict(np.expand_dims(angle_seis_reshaped_normalized, axis=3))

# # Initialize emodel
# emodel = np.zeros(emodel_norm.shape)
# emodel[:,0,:] = emodel_norm[:,0,:]*(np.max(Vp_time) - np.min(Vp_time)) + np.min(Vp_time)
# emodel[:,1,:] = emodel_norm[:,1,:]*(np.max(Vs_time) - np.min(Vs_time)) + np.min(Vs_time)
# emodel[:,2,:] = emodel_norm[:,2,:]*(np.max(RHOB_time) - np.min(RHOB_time)) + np.min(RHOB_time)

# Concatenate Porosity, Vclay
num_examples = porosity.shape[0]
ndepth = porosity.shape[1]

# Normalize porosity
porosity_norm = (porosity - np.min(porosity))/(np.max(porosity) - np.min(porosity))

# petromodel = np.concatenate((porosity,vclay,Sw), axis=1)
# petromodel = petromodel.reshape((num_examples, 3, ndepth))
petromodel = np.concatenate((porosity_norm,vclay), axis=1)
petromodel = petromodel.reshape((num_examples, 2, ndepth))

# Split data into train and test set - elastic model normalized
X_train, X_test, Y_train_norm, Y_test_norm = sklearn.model_selection.train_test_split(emodel_norm, 
                                                                            petromodel, test_size=0.2, random_state=1)

# Split data into train and test set - elastic model
X_train_true, X_test_true, Y_train_true_norm, Y_test_true_norm = sklearn.model_selection.train_test_split(emodel_true, 
                                                                            petromodel, test_size=0.2, random_state=1)


# Add 4th dimension of number of channels=1 to the input data
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)


print ("number of training examples = " + str(X_train.shape[0]))
# print ("number of validation examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train_norm.shape))
# print ("X_val shape: " + str(X_val.shape))
# print ("Y_val shape: " + str(Y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test_norm.shape))
# Out:
# number of training examples = 2000
# number of test examples = 500
# X_train shape: (2000, 3, 246, 1)
# Y_train shape: (2000, 2, 199)
# X_test shape: (500, 3, 246, 1)
# Y_test shape: (500, 2, 199)

# %%
# Building neural network for petrophysical properties prediction in Keras 
given_seed = 3 # For repeatibility

def elastic_petronet(input_shape):
    """
    Implementation of the AVONet.
    
    Arguments:
    input_shape -- shape of the images of the dataset

    Returns:
    model -- a Model() instance in Keras
    """
    

    # Define the input placeholder as a tensor with shape input_shape. Input = input angle gather 
    X_input = Input(input_shape)

    X = X_input

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(16, (1, 60), strides=(1, 2), name='conv0', padding='same',
               kernel_initializer=initializers.he_normal(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn0')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv0')(X)
    # MAXPOOL
#     X = MaxPooling2D((2, 2), strides=(1,1),name='max_pool0')(X)
    
    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(4, (1, 60), strides=(1, 2), name='conv1', padding='same',
               kernel_initializer=initializers.he_normal(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn1')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv1')(X)
    # MAXPOOL
#     X = MaxPooling2D((2, 2), strides=(1,1),name='max_pool1')(X)
      

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
#     X = Dense(1200, name='fc1')(X)
#     X = Activation('relu')(X)
    X = Dense(199*2, name='fc1')(X)
    X = Activation('sigmoid')(X)
    
    X = Reshape((2, 199))(X)
    
    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs=X_input, outputs=X, name='ElasticPetroModel')

    return model
    ### END CODE HERE ###

# %%
# Create the model
ElasticPetroModel = elastic_petronet(X_train.shape[1:])

# %%
# Summary and plot of the model

ElasticPetroModel.summary()


# plot_model(AVOModel)
# SVG(model_to_dot(ElasticModel).create(prog='dot', format='svg'))
# plot_model(ElasticModel, to_file='./Figures/model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 3, 246, 1)         0
# _________________________________________________________________
# conv0 (Conv2D)               (None, 3, 123, 16)        976
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 3, 123, 16)        64
# _________________________________________________________________
# activation_49 (Activation)   (None, 3, 123, 16)        0
# _________________________________________________________________
# drop_conv0 (Dropout)         (None, 3, 123, 16)        0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 3, 62, 4)          3844
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 3, 62, 4)          16
# _________________________________________________________________
# activation_50 (Activation)   (None, 3, 62, 4)          0
# _________________________________________________________________
# drop_conv1 (Dropout)         (None, 3, 62, 4)          0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 744)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 398)               296510
# _________________________________________________________________
# activation_51 (Activation)   (None, 398)               0
# _________________________________________________________________
# reshape_17 (Reshape)         (None, 2, 199)            0
# =================================================================
# Total params: 301,410
# Trainable params: 301,370
# Non-trainable params: 40
# _________________________________________________________________

# %%
# Learning rate scheduler
from keras.callbacks import LearningRateScheduler
# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.1
    epochs_drop = 50.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

# %%
# Compile the model with optimization algorithm, loss function
adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

ElasticPetroModel.compile(loss='mean_squared_error', optimizer = adam)

# %%
# Start the training
# Using learning rate scheduler
# lrate = LearningRateScheduler(step_decay)
# callbacks_list = [lrate]
# history = ElasticPetroModel.fit(X_train, Y_train_norm, validation_split=0.2, epochs=250, batch_size=32, callbacks=callbacks_list)

history = ElasticPetroModel.fit(X_train, Y_train_norm, validation_split=0.2, epochs=500, batch_size=32)
# Out:
# Train on 1600 samples, validate on 400 samples
# Epoch 1/500
# 1600/1600 [==============================] - 2s 2ms/step - loss: 0.0748 - val_loss: 0.0623
# Epoch 2/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0621 - val_loss: 0.0593
# Epoch 3/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0520 - val_loss: 0.0496
# Epoch 4/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0453 - val_loss: 0.0423
# Epoch 5/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0420 - val_loss: 0.0396
# Epoch 6/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0398 - val_loss: 0.0404
# Epoch 7/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0381 - val_loss: 0.0365
# Epoch 8/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0369 - val_loss: 0.0359
# Epoch 9/500
# 1600/1600 [==============================] - 0s 292us/step - loss: 0.0358 - val_loss: 0.0383
# Epoch 10/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0351 - val_loss: 0.0421
# Epoch 11/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0344 - val_loss: 0.0354
# Epoch 12/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0339 - val_loss: 0.0435
# Epoch 13/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0335 - val_loss: 0.0480
# Epoch 14/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0328 - val_loss: 0.0371
# Epoch 15/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0324 - val_loss: 0.0343
# Epoch 16/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0320 - val_loss: 0.0405
# Epoch 17/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0316 - val_loss: 0.0355
# Epoch 18/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0315 - val_loss: 0.0461
# Epoch 19/500
# 1600/1600 [==============================] - 0s 265us/step - loss: 0.0312 - val_loss: 0.0352
# Epoch 20/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0308 - val_loss: 0.0342
# Epoch 21/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0306 - val_loss: 0.0334
# Epoch 22/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0304 - val_loss: 0.0328
# Epoch 23/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0301 - val_loss: 0.0320
# Epoch 24/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0299 - val_loss: 0.0323
# Epoch 25/500
# 1600/1600 [==============================] - 0s 292us/step - loss: 0.0298 - val_loss: 0.0328
# Epoch 26/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0296 - val_loss: 0.0319
# Epoch 27/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0294 - val_loss: 0.0324
# Epoch 28/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0292 - val_loss: 0.0341
# Epoch 29/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0292 - val_loss: 0.0335
# Epoch 30/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0289 - val_loss: 0.0320
# Epoch 31/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0289 - val_loss: 0.0333
# Epoch 32/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0289 - val_loss: 0.0327
# Epoch 33/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0287 - val_loss: 0.0329
# Epoch 34/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0286 - val_loss: 0.0312
# Epoch 35/500
# 1600/1600 [==============================] - 0s 288us/step - loss: 0.0286 - val_loss: 0.0323
# Epoch 36/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0284 - val_loss: 0.0324
# Epoch 37/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0282 - val_loss: 0.0321
# Epoch 38/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0283 - val_loss: 0.0318
# Epoch 39/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0282 - val_loss: 0.0318
# Epoch 40/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0281 - val_loss: 0.0326
# Epoch 41/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0281 - val_loss: 0.0374
# Epoch 42/500
# 1600/1600 [==============================] - 0s 266us/step - loss: 0.0279 - val_loss: 0.0324
# Epoch 43/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0278 - val_loss: 0.0315
# Epoch 44/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0278 - val_loss: 0.0318
# Epoch 45/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0277 - val_loss: 0.0316
# Epoch 46/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0277 - val_loss: 0.0320
# Epoch 47/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0275 - val_loss: 0.0314
# Epoch 48/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0275 - val_loss: 0.0357
# Epoch 49/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0275 - val_loss: 0.0323
# Epoch 50/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0272 - val_loss: 0.0315
# Epoch 51/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0273 - val_loss: 0.0317
# Epoch 52/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0273 - val_loss: 0.0320
# Epoch 53/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0273 - val_loss: 0.0332
# Epoch 54/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0271 - val_loss: 0.0315
# Epoch 55/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0270 - val_loss: 0.0315
# Epoch 56/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0269 - val_loss: 0.0351
# Epoch 57/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0271 - val_loss: 0.0317
# Epoch 58/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0269 - val_loss: 0.0319
# Epoch 59/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0268 - val_loss: 0.0361
# Epoch 60/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0267 - val_loss: 0.0328
# Epoch 61/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0267 - val_loss: 0.0319
# Epoch 62/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0266 - val_loss: 0.0361
# Epoch 63/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0266 - val_loss: 0.0320
# Epoch 64/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0266 - val_loss: 0.0338
# Epoch 65/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0265 - val_loss: 0.0344
# Epoch 66/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0263 - val_loss: 0.0314
# Epoch 67/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0262 - val_loss: 0.0319
# Epoch 68/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0261 - val_loss: 0.0316
# Epoch 69/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0262 - val_loss: 0.0337
# Epoch 70/500
# 1600/1600 [==============================] - 0s 265us/step - loss: 0.0262 - val_loss: 0.0321
# Epoch 71/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0262 - val_loss: 0.0318
# Epoch 72/500
# 1600/1600 [==============================] - 0s 266us/step - loss: 0.0261 - val_loss: 0.0320
# Epoch 73/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0258 - val_loss: 0.0323
# Epoch 74/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0259 - val_loss: 0.0318
# Epoch 75/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0258 - val_loss: 0.0316
# Epoch 76/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0258 - val_loss: 0.0320
# Epoch 77/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0257 - val_loss: 0.0314
# Epoch 78/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0257 - val_loss: 0.0317
# Epoch 79/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0255 - val_loss: 0.0312
# Epoch 80/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0257 - val_loss: 0.0311
# Epoch 81/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0255 - val_loss: 0.0319
# Epoch 82/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0255 - val_loss: 0.0331
# Epoch 83/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0255 - val_loss: 0.0316
# Epoch 84/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0253 - val_loss: 0.0347
# Epoch 85/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0254 - val_loss: 0.0317
# Epoch 86/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0254 - val_loss: 0.0319
# Epoch 87/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0253 - val_loss: 0.0320
# Epoch 88/500
# 1600/1600 [==============================] - 0s 297us/step - loss: 0.0253 - val_loss: 0.0324
# Epoch 89/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0252 - val_loss: 0.0328
# Epoch 90/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0251 - val_loss: 0.0322
# Epoch 91/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0252 - val_loss: 0.0325
# Epoch 92/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0251 - val_loss: 0.0314
# Epoch 93/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0251 - val_loss: 0.0384
# Epoch 94/500
# 1600/1600 [==============================] - 0s 265us/step - loss: 0.0251 - val_loss: 0.0316
# Epoch 95/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0250 - val_loss: 0.0317
# Epoch 96/500
# 1600/1600 [==============================] - 0s 262us/step - loss: 0.0250 - val_loss: 0.0312
# Epoch 97/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0249 - val_loss: 0.0343
# Epoch 98/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0250 - val_loss: 0.0321
# Epoch 99/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0249 - val_loss: 0.0335
# Epoch 100/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0249 - val_loss: 0.0321
# Epoch 101/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0248 - val_loss: 0.0316
# Epoch 102/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0248 - val_loss: 0.0377
# Epoch 103/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0248 - val_loss: 0.0334
# Epoch 104/500
# 1600/1600 [==============================] - 0s 295us/step - loss: 0.0248 - val_loss: 0.0323
# Epoch 105/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0247 - val_loss: 0.0321
# Epoch 106/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0247 - val_loss: 0.0315
# Epoch 107/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0245 - val_loss: 0.0367
# Epoch 108/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0246 - val_loss: 0.0322
# Epoch 109/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0246 - val_loss: 0.0370
# Epoch 110/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0246 - val_loss: 0.0323
# Epoch 111/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0246 - val_loss: 0.0339
# Epoch 112/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0245 - val_loss: 0.0317
# Epoch 113/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0245 - val_loss: 0.0329
# Epoch 114/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0243 - val_loss: 0.0348
# Epoch 115/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0244 - val_loss: 0.0332
# Epoch 116/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0244 - val_loss: 0.0344
# Epoch 117/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0244 - val_loss: 0.0326
# Epoch 118/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0244 - val_loss: 0.0381
# Epoch 119/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0244 - val_loss: 0.0327
# Epoch 120/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0242 - val_loss: 0.0315
# Epoch 121/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0243 - val_loss: 0.0317
# Epoch 122/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0243 - val_loss: 0.0320
# Epoch 123/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0243 - val_loss: 0.0330
# Epoch 124/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0242 - val_loss: 0.0380
# Epoch 125/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0241 - val_loss: 0.0314
# Epoch 126/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0242 - val_loss: 0.0339
# Epoch 127/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0241 - val_loss: 0.0336
# Epoch 128/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0241 - val_loss: 0.0315
# Epoch 129/500
# 1600/1600 [==============================] - 0s 292us/step - loss: 0.0241 - val_loss: 0.0318
# Epoch 130/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0240 - val_loss: 0.0323
# Epoch 131/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0240 - val_loss: 0.0351
# Epoch 132/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0240 - val_loss: 0.0331
# Epoch 133/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0240 - val_loss: 0.0312
# Epoch 134/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0238 - val_loss: 0.0317
# Epoch 135/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0241 - val_loss: 0.0317
# Epoch 136/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0241 - val_loss: 0.0390
# Epoch 137/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0239 - val_loss: 0.0326
# Epoch 138/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0240 - val_loss: 0.0338
# Epoch 139/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0239 - val_loss: 0.0319
# Epoch 140/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0239 - val_loss: 0.0352
# Epoch 141/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0238 - val_loss: 0.0318
# Epoch 142/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0239 - val_loss: 0.0315
# Epoch 143/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0238 - val_loss: 0.0353
# Epoch 144/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0237 - val_loss: 0.0325
# Epoch 145/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0238 - val_loss: 0.0315
# Epoch 146/500
# 1600/1600 [==============================] - 0s 263us/step - loss: 0.0239 - val_loss: 0.0361
# Epoch 147/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0238 - val_loss: 0.0325
# Epoch 148/500
# 1600/1600 [==============================] - 0s 263us/step - loss: 0.0238 - val_loss: 0.0337
# Epoch 149/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0236 - val_loss: 0.0316
# Epoch 150/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0237 - val_loss: 0.0326
# Epoch 151/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0237 - val_loss: 0.0314
# Epoch 152/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0237 - val_loss: 0.0326
# Epoch 153/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0237 - val_loss: 0.0315
# Epoch 154/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0237 - val_loss: 0.0317
# Epoch 155/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0235 - val_loss: 0.0318
# Epoch 156/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0238 - val_loss: 0.0324
# Epoch 157/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0235 - val_loss: 0.0366
# Epoch 158/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0236 - val_loss: 0.0331
# Epoch 159/500
# 1600/1600 [==============================] - 0s 265us/step - loss: 0.0236 - val_loss: 0.0312
# Epoch 160/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0236 - val_loss: 0.0380
# Epoch 161/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0237 - val_loss: 0.0321
# Epoch 162/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0236 - val_loss: 0.0336
# Epoch 163/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0235 - val_loss: 0.0355
# Epoch 164/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0235 - val_loss: 0.0320
# Epoch 165/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0236 - val_loss: 0.0322
# Epoch 166/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0236 - val_loss: 0.0317
# Epoch 167/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0235 - val_loss: 0.0336
# Epoch 168/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0234 - val_loss: 0.0314
# Epoch 169/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0235 - val_loss: 0.0321
# Epoch 170/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0235 - val_loss: 0.0328
# Epoch 171/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0234 - val_loss: 0.0338
# Epoch 172/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0236 - val_loss: 0.0332
# Epoch 173/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0235 - val_loss: 0.0319
# Epoch 174/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0234 - val_loss: 0.0313
# Epoch 175/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0235 - val_loss: 0.0318
# Epoch 176/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0233 - val_loss: 0.0318
# Epoch 177/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0235 - val_loss: 0.0335
# Epoch 178/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0233 - val_loss: 0.0317
# Epoch 179/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0235 - val_loss: 0.0350
# Epoch 180/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0234 - val_loss: 0.0316
# Epoch 181/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0233 - val_loss: 0.0310
# Epoch 182/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0234 - val_loss: 0.0359
# Epoch 183/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0234 - val_loss: 0.0337
# Epoch 184/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0235 - val_loss: 0.0374
# Epoch 185/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0234 - val_loss: 0.0317
# Epoch 186/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0233 - val_loss: 0.0323
# Epoch 187/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0233 - val_loss: 0.0320
# Epoch 188/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0234 - val_loss: 0.0329
# Epoch 189/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0233 - val_loss: 0.0342
# Epoch 190/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0233 - val_loss: 0.0363
# Epoch 191/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0234 - val_loss: 0.0315
# Epoch 192/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0233 - val_loss: 0.0322
# Epoch 193/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0232 - val_loss: 0.0326
# Epoch 194/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0232 - val_loss: 0.0331
# Epoch 195/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0232 - val_loss: 0.0331
# Epoch 196/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0232 - val_loss: 0.0329
# Epoch 197/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0233 - val_loss: 0.0315
# Epoch 198/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0232 - val_loss: 0.0318
# Epoch 199/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0232 - val_loss: 0.0318
# Epoch 200/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0232 - val_loss: 0.0318
# Epoch 201/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0233 - val_loss: 0.0390
# Epoch 202/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0233 - val_loss: 0.0315
# Epoch 203/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0232 - val_loss: 0.0313
# Epoch 204/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0233 - val_loss: 0.0327
# Epoch 205/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0231 - val_loss: 0.0316
# Epoch 206/500
# 1600/1600 [==============================] - 0s 294us/step - loss: 0.0233 - val_loss: 0.0342
# Epoch 207/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0231 - val_loss: 0.0328
# Epoch 208/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0231 - val_loss: 0.0317
# Epoch 209/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0232 - val_loss: 0.0325
# Epoch 210/500
# 1600/1600 [==============================] - 0s 265us/step - loss: 0.0230 - val_loss: 0.0348
# Epoch 211/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0232 - val_loss: 0.0340
# Epoch 212/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0230 - val_loss: 0.0324
# Epoch 213/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0232 - val_loss: 0.0320
# Epoch 214/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0231 - val_loss: 0.0348
# Epoch 215/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0232 - val_loss: 0.0323
# Epoch 216/500
# 1600/1600 [==============================] - 0s 290us/step - loss: 0.0231 - val_loss: 0.0332
# Epoch 217/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0231 - val_loss: 0.0316
# Epoch 218/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0232 - val_loss: 0.0323
# Epoch 219/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0231 - val_loss: 0.0322
# Epoch 220/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0232 - val_loss: 0.0318
# Epoch 221/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0231 - val_loss: 0.0326
# Epoch 222/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0231 - val_loss: 0.0323
# Epoch 223/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0231 - val_loss: 0.0325
# Epoch 224/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0230 - val_loss: 0.0320
# Epoch 225/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0230 - val_loss: 0.0318
# Epoch 226/500
# 1600/1600 [==============================] - 0s 264us/step - loss: 0.0232 - val_loss: 0.0327
# Epoch 227/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0230 - val_loss: 0.0316
# Epoch 228/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0230 - val_loss: 0.0335
# Epoch 229/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0231 - val_loss: 0.0317
# Epoch 230/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0231 - val_loss: 0.0317
# Epoch 231/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0231 - val_loss: 0.0321
# Epoch 232/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0231 - val_loss: 0.0340
# Epoch 233/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0230 - val_loss: 0.0320
# Epoch 234/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0230 - val_loss: 0.0354
# Epoch 235/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0232 - val_loss: 0.0321
# Epoch 236/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0230 - val_loss: 0.0336
# Epoch 237/500
# 1600/1600 [==============================] - 0s 265us/step - loss: 0.0230 - val_loss: 0.0326
# Epoch 238/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0229 - val_loss: 0.0333
# Epoch 239/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0230 - val_loss: 0.0320
# Epoch 240/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0228 - val_loss: 0.0332
# Epoch 241/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0228 - val_loss: 0.0313
# Epoch 242/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0230 - val_loss: 0.0325
# Epoch 243/500
# 1600/1600 [==============================] - 0s 292us/step - loss: 0.0230 - val_loss: 0.0331
# Epoch 244/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0230 - val_loss: 0.0353
# Epoch 245/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0230 - val_loss: 0.0323
# Epoch 246/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0229 - val_loss: 0.0333
# Epoch 247/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0229 - val_loss: 0.0316
# Epoch 248/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0229 - val_loss: 0.0331
# Epoch 249/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0230 - val_loss: 0.0351
# Epoch 250/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0229 - val_loss: 0.0332
# Epoch 251/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0229 - val_loss: 0.0321
# Epoch 252/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0229 - val_loss: 0.0324
# Epoch 253/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0229 - val_loss: 0.0333
# Epoch 254/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0229 - val_loss: 0.0319
# Epoch 255/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0229 - val_loss: 0.0369
# Epoch 256/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0228 - val_loss: 0.0321
# Epoch 257/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0230 - val_loss: 0.0324
# Epoch 258/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0230 - val_loss: 0.0313
# Epoch 259/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0229 - val_loss: 0.0314
# Epoch 260/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0230 - val_loss: 0.0314
# Epoch 261/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0230 - val_loss: 0.0339
# Epoch 262/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0229 - val_loss: 0.0319
# Epoch 263/500
# 1600/1600 [==============================] - 0s 266us/step - loss: 0.0229 - val_loss: 0.0325
# Epoch 264/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0229 - val_loss: 0.0352
# Epoch 265/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0229 - val_loss: 0.0324
# Epoch 266/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0228 - val_loss: 0.0333
# Epoch 267/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0228 - val_loss: 0.0325
# Epoch 268/500
# 1600/1600 [==============================] - 0s 294us/step - loss: 0.0228 - val_loss: 0.0321
# Epoch 269/500
# 1600/1600 [==============================] - 0s 288us/step - loss: 0.0228 - val_loss: 0.0324
# Epoch 270/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0228 - val_loss: 0.0324
# Epoch 271/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0229 - val_loss: 0.0320
# Epoch 272/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0229 - val_loss: 0.0322
# Epoch 273/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0228 - val_loss: 0.0317
# Epoch 274/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0228 - val_loss: 0.0317
# Epoch 275/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0228 - val_loss: 0.0326
# Epoch 276/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0228 - val_loss: 0.0322
# Epoch 277/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0226 - val_loss: 0.0316
# Epoch 278/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0228 - val_loss: 0.0330
# Epoch 279/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0228 - val_loss: 0.0319
# Epoch 280/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0228 - val_loss: 0.0321
# Epoch 281/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0229 - val_loss: 0.0322
# Epoch 282/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0227 - val_loss: 0.0329
# Epoch 283/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0227 - val_loss: 0.0318
# Epoch 284/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0228 - val_loss: 0.0336
# Epoch 285/500
# 1600/1600 [==============================] - 0s 290us/step - loss: 0.0228 - val_loss: 0.0339
# Epoch 286/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0228 - val_loss: 0.0322
# Epoch 287/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0228 - val_loss: 0.0332
# Epoch 288/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0228 - val_loss: 0.0319
# Epoch 289/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0227 - val_loss: 0.0326
# Epoch 290/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0228 - val_loss: 0.0330
# Epoch 291/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0227 - val_loss: 0.0318
# Epoch 292/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0228 - val_loss: 0.0322
# Epoch 293/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0227 - val_loss: 0.0315
# Epoch 294/500
# 1600/1600 [==============================] - 0s 293us/step - loss: 0.0228 - val_loss: 0.0321
# Epoch 295/500
# 1600/1600 [==============================] - 0s 296us/step - loss: 0.0227 - val_loss: 0.0351
# Epoch 296/500
# 1600/1600 [==============================] - 0s 295us/step - loss: 0.0228 - val_loss: 0.0319
# Epoch 297/500
# 1600/1600 [==============================] - 0s 292us/step - loss: 0.0227 - val_loss: 0.0334
# Epoch 298/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0228 - val_loss: 0.0328
# Epoch 299/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0227 - val_loss: 0.0318
# Epoch 300/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0228 - val_loss: 0.0319
# Epoch 301/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0227 - val_loss: 0.0318
# Epoch 302/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0227 - val_loss: 0.0317
# Epoch 303/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0227 - val_loss: 0.0325
# Epoch 304/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0227 - val_loss: 0.0330
# Epoch 305/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0226 - val_loss: 0.0330
# Epoch 306/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0227 - val_loss: 0.0320
# Epoch 307/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0226 - val_loss: 0.0324
# Epoch 308/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0226 - val_loss: 0.0315
# Epoch 309/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0228 - val_loss: 0.0323
# Epoch 310/500
# 1600/1600 [==============================] - 0s 294us/step - loss: 0.0226 - val_loss: 0.0327
# Epoch 311/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0227 - val_loss: 0.0315
# Epoch 312/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0227 - val_loss: 0.0341
# Epoch 313/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0228 - val_loss: 0.0319
# Epoch 314/500
# 1600/1600 [==============================] - 0s 288us/step - loss: 0.0227 - val_loss: 0.0331
# Epoch 315/500
# 1600/1600 [==============================] - 0s 292us/step - loss: 0.0227 - val_loss: 0.0340
# Epoch 316/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0226 - val_loss: 0.0316
# Epoch 317/500
# 1600/1600 [==============================] - 0s 301us/step - loss: 0.0226 - val_loss: 0.0316
# Epoch 318/500
# 1600/1600 [==============================] - 1s 322us/step - loss: 0.0227 - val_loss: 0.0325
# Epoch 319/500
# 1600/1600 [==============================] - 0s 296us/step - loss: 0.0227 - val_loss: 0.0344
# Epoch 320/500
# 1600/1600 [==============================] - 0s 288us/step - loss: 0.0226 - val_loss: 0.0318
# Epoch 321/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0227 - val_loss: 0.0319
# Epoch 322/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0227 - val_loss: 0.0323
# Epoch 323/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0227 - val_loss: 0.0318
# Epoch 324/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0226 - val_loss: 0.0325
# Epoch 325/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0227 - val_loss: 0.0347
# Epoch 326/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0227 - val_loss: 0.0332
# Epoch 327/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0226 - val_loss: 0.0317
# Epoch 328/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0226 - val_loss: 0.0323
# Epoch 329/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0228 - val_loss: 0.0317
# Epoch 330/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0225 - val_loss: 0.0318
# Epoch 331/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0228 - val_loss: 0.0322
# Epoch 332/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0227 - val_loss: 0.0316
# Epoch 333/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0226 - val_loss: 0.0341
# Epoch 334/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0225 - val_loss: 0.0318
# Epoch 335/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0225 - val_loss: 0.0322
# Epoch 336/500
# 1600/1600 [==============================] - 0s 294us/step - loss: 0.0226 - val_loss: 0.0327
# Epoch 337/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0226 - val_loss: 0.0320
# Epoch 338/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0227 - val_loss: 0.0320
# Epoch 339/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0226 - val_loss: 0.0316
# Epoch 340/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0225 - val_loss: 0.0324
# Epoch 341/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0227 - val_loss: 0.0323
# Epoch 342/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0226 - val_loss: 0.0325
# Epoch 343/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0226 - val_loss: 0.0333
# Epoch 344/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0226 - val_loss: 0.0322
# Epoch 345/500
# 1600/1600 [==============================] - 0s 303us/step - loss: 0.0226 - val_loss: 0.0316
# Epoch 346/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0226 - val_loss: 0.0318
# Epoch 347/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0226 - val_loss: 0.0320
# Epoch 348/500
# 1600/1600 [==============================] - 0s 297us/step - loss: 0.0227 - val_loss: 0.0325
# Epoch 349/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0226 - val_loss: 0.0325
# Epoch 350/500
# 1600/1600 [==============================] - 0s 301us/step - loss: 0.0227 - val_loss: 0.0324
# Epoch 351/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0226 - val_loss: 0.0322
# Epoch 352/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0225 - val_loss: 0.0330
# Epoch 353/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0227 - val_loss: 0.0322
# Epoch 354/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0225 - val_loss: 0.0318
# Epoch 355/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0224 - val_loss: 0.0324
# Epoch 356/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0225 - val_loss: 0.0322
# Epoch 357/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0226 - val_loss: 0.0320
# Epoch 358/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0226 - val_loss: 0.0322
# Epoch 359/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0225 - val_loss: 0.0321
# Epoch 360/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0226 - val_loss: 0.0323
# Epoch 361/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0228 - val_loss: 0.0379
# Epoch 362/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0225 - val_loss: 0.0320
# Epoch 363/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0226 - val_loss: 0.0322
# Epoch 364/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0225 - val_loss: 0.0321
# Epoch 365/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0225 - val_loss: 0.0324
# Epoch 366/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0226 - val_loss: 0.0318
# Epoch 367/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0225 - val_loss: 0.0332
# Epoch 368/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0225 - val_loss: 0.0324
# Epoch 369/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0225 - val_loss: 0.0324
# Epoch 370/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0226 - val_loss: 0.0316
# Epoch 371/500
# 1600/1600 [==============================] - 0s 290us/step - loss: 0.0226 - val_loss: 0.0319
# Epoch 372/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0226 - val_loss: 0.0322
# Epoch 373/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0225 - val_loss: 0.0320
# Epoch 374/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0226 - val_loss: 0.0316
# Epoch 375/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0226 - val_loss: 0.0320
# Epoch 376/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0225 - val_loss: 0.0335
# Epoch 377/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0225 - val_loss: 0.0329
# Epoch 378/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0226 - val_loss: 0.0333
# Epoch 379/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0226 - val_loss: 0.0327
# Epoch 380/500
# 1600/1600 [==============================] - 0s 266us/step - loss: 0.0226 - val_loss: 0.0317
# Epoch 381/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0224 - val_loss: 0.0322
# Epoch 382/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0226 - val_loss: 0.0322
# Epoch 383/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0225 - val_loss: 0.0320
# Epoch 384/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0226 - val_loss: 0.0324
# Epoch 385/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0224 - val_loss: 0.0326
# Epoch 386/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0225 - val_loss: 0.0324
# Epoch 387/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0225 - val_loss: 0.0318
# Epoch 388/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0225 - val_loss: 0.0346
# Epoch 389/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0225 - val_loss: 0.0327
# Epoch 390/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0225 - val_loss: 0.0319
# Epoch 391/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0224 - val_loss: 0.0322
# Epoch 392/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0224 - val_loss: 0.0323
# Epoch 393/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0226 - val_loss: 0.0321
# Epoch 394/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0225 - val_loss: 0.0321
# Epoch 395/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0225 - val_loss: 0.0315
# Epoch 396/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0225 - val_loss: 0.0329
# Epoch 397/500
# 1600/1600 [==============================] - 0s 291us/step - loss: 0.0224 - val_loss: 0.0322
# Epoch 398/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0226 - val_loss: 0.0319
# Epoch 399/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0226 - val_loss: 0.0322
# Epoch 400/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0225 - val_loss: 0.0320
# Epoch 401/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0223 - val_loss: 0.0337
# Epoch 402/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0224 - val_loss: 0.0313
# Epoch 403/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0225 - val_loss: 0.0320
# Epoch 404/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0225 - val_loss: 0.0319
# Epoch 405/500
# 1600/1600 [==============================] - 0s 266us/step - loss: 0.0224 - val_loss: 0.0317
# Epoch 406/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0224 - val_loss: 0.0323
# Epoch 407/500
# 1600/1600 [==============================] - 0s 263us/step - loss: 0.0225 - val_loss: 0.0318
# Epoch 408/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0224 - val_loss: 0.0324
# Epoch 409/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0225 - val_loss: 0.0316
# Epoch 410/500
# 1600/1600 [==============================] - 0s 272us/step - loss: 0.0225 - val_loss: 0.0318
# Epoch 411/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0224 - val_loss: 0.0319
# Epoch 412/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0224 - val_loss: 0.0320
# Epoch 413/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0225 - val_loss: 0.0314
# Epoch 414/500
# 1600/1600 [==============================] - 0s 288us/step - loss: 0.0225 - val_loss: 0.0315
# Epoch 415/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0224 - val_loss: 0.0329
# Epoch 416/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0225 - val_loss: 0.0331
# Epoch 417/500
# 1600/1600 [==============================] - 0s 266us/step - loss: 0.0224 - val_loss: 0.0321
# Epoch 418/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0224 - val_loss: 0.0318
# Epoch 419/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0224 - val_loss: 0.0327
# Epoch 420/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0225 - val_loss: 0.0328
# Epoch 421/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0224 - val_loss: 0.0332
# Epoch 422/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0224 - val_loss: 0.0325
# Epoch 423/500
# 1600/1600 [==============================] - 0s 294us/step - loss: 0.0224 - val_loss: 0.0321
# Epoch 424/500
# 1600/1600 [==============================] - 0s 283us/step - loss: 0.0224 - val_loss: 0.0316
# Epoch 425/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0225 - val_loss: 0.0328
# Epoch 426/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0224 - val_loss: 0.0318
# Epoch 427/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0223 - val_loss: 0.0348
# Epoch 428/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0224 - val_loss: 0.0326
# Epoch 429/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0225 - val_loss: 0.0334
# Epoch 430/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0225 - val_loss: 0.0326
# Epoch 431/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0224 - val_loss: 0.0320
# Epoch 432/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0223 - val_loss: 0.0325
# Epoch 433/500
# 1600/1600 [==============================] - 0s 266us/step - loss: 0.0225 - val_loss: 0.0313
# Epoch 434/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0225 - val_loss: 0.0318
# Epoch 435/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0224 - val_loss: 0.0320
# Epoch 436/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0224 - val_loss: 0.0321
# Epoch 437/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0223 - val_loss: 0.0323
# Epoch 438/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0223 - val_loss: 0.0320
# Epoch 439/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0223 - val_loss: 0.0319
# Epoch 440/500
# 1600/1600 [==============================] - 0s 294us/step - loss: 0.0225 - val_loss: 0.0321
# Epoch 441/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0224 - val_loss: 0.0322
# Epoch 442/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0224 - val_loss: 0.0317
# Epoch 443/500
# 1600/1600 [==============================] - 0s 267us/step - loss: 0.0224 - val_loss: 0.0323
# Epoch 444/500
# 1600/1600 [==============================] - 0s 266us/step - loss: 0.0225 - val_loss: 0.0315
# Epoch 445/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0224 - val_loss: 0.0328
# Epoch 446/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0224 - val_loss: 0.0319
# Epoch 447/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0224 - val_loss: 0.0317
# Epoch 448/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0225 - val_loss: 0.0327
# Epoch 449/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0224 - val_loss: 0.0329
# Epoch 450/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0224 - val_loss: 0.0331
# Epoch 451/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0223 - val_loss: 0.0320
# Epoch 452/500
# 1600/1600 [==============================] - 0s 286us/step - loss: 0.0224 - val_loss: 0.0332
# Epoch 453/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0223 - val_loss: 0.0316
# Epoch 454/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0224 - val_loss: 0.0316
# Epoch 455/500
# 1600/1600 [==============================] - 0s 276us/step - loss: 0.0223 - val_loss: 0.0324
# Epoch 456/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0223 - val_loss: 0.0323
# Epoch 457/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0224 - val_loss: 0.0317
# Epoch 458/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0223 - val_loss: 0.0323
# Epoch 459/500
# 1600/1600 [==============================] - 0s 266us/step - loss: 0.0224 - val_loss: 0.0339
# Epoch 460/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0224 - val_loss: 0.0326
# Epoch 461/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0223 - val_loss: 0.0318
# Epoch 462/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0225 - val_loss: 0.0323
# Epoch 463/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0225 - val_loss: 0.0317
# Epoch 464/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0225 - val_loss: 0.0317
# Epoch 465/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0224 - val_loss: 0.0319
# Epoch 466/500
# 1600/1600 [==============================] - 0s 289us/step - loss: 0.0224 - val_loss: 0.0316
# Epoch 467/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0223 - val_loss: 0.0321
# Epoch 468/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0223 - val_loss: 0.0322
# Epoch 469/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0223 - val_loss: 0.0321
# Epoch 470/500
# 1600/1600 [==============================] - 0s 271us/step - loss: 0.0223 - val_loss: 0.0339
# Epoch 471/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0223 - val_loss: 0.0318
# Epoch 472/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0223 - val_loss: 0.0320
# Epoch 473/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0224 - val_loss: 0.0323
# Epoch 474/500
# 1600/1600 [==============================] - 0s 282us/step - loss: 0.0224 - val_loss: 0.0329
# Epoch 475/500
# 1600/1600 [==============================] - 0s 285us/step - loss: 0.0223 - val_loss: 0.0323
# Epoch 476/500
# 1600/1600 [==============================] - 0s 288us/step - loss: 0.0222 - val_loss: 0.0323
# Epoch 477/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0223 - val_loss: 0.0336
# Epoch 478/500
# 1600/1600 [==============================] - 0s 281us/step - loss: 0.0223 - val_loss: 0.0322
# Epoch 479/500
# 1600/1600 [==============================] - 0s 277us/step - loss: 0.0223 - val_loss: 0.0316
# Epoch 480/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0223 - val_loss: 0.0323
# Epoch 481/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0224 - val_loss: 0.0332
# Epoch 482/500
# 1600/1600 [==============================] - 0s 270us/step - loss: 0.0223 - val_loss: 0.0337
# Epoch 483/500
# 1600/1600 [==============================] - 0s 273us/step - loss: 0.0225 - val_loss: 0.0321
# Epoch 484/500
# 1600/1600 [==============================] - 0s 268us/step - loss: 0.0223 - val_loss: 0.0319
# Epoch 485/500
# 1600/1600 [==============================] - 0s 264us/step - loss: 0.0223 - val_loss: 0.0320
# Epoch 486/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0224 - val_loss: 0.0325
# Epoch 487/500
# 1600/1600 [==============================] - 0s 264us/step - loss: 0.0224 - val_loss: 0.0316
# Epoch 488/500
# 1600/1600 [==============================] - 0s 275us/step - loss: 0.0225 - val_loss: 0.0324
# Epoch 489/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0223 - val_loss: 0.0322
# Epoch 490/500
# 1600/1600 [==============================] - 0s 278us/step - loss: 0.0224 - val_loss: 0.0321
# Epoch 491/500
# 1600/1600 [==============================] - 0s 288us/step - loss: 0.0223 - val_loss: 0.0328
# Epoch 492/500
# 1600/1600 [==============================] - 0s 287us/step - loss: 0.0224 - val_loss: 0.0324
# Epoch 493/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0224 - val_loss: 0.0319
# Epoch 494/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0222 - val_loss: 0.0324
# Epoch 495/500
# 1600/1600 [==============================] - 0s 269us/step - loss: 0.0224 - val_loss: 0.0319
# Epoch 496/500
# 1600/1600 [==============================] - 0s 265us/step - loss: 0.0224 - val_loss: 0.0319
# Epoch 497/500
# 1600/1600 [==============================] - 0s 274us/step - loss: 0.0224 - val_loss: 0.0318
# Epoch 498/500
# 1600/1600 [==============================] - 0s 280us/step - loss: 0.0223 - val_loss: 0.0334
# Epoch 499/500
# 1600/1600 [==============================] - 0s 279us/step - loss: 0.0224 - val_loss: 0.0327
# Epoch 500/500
# 1600/1600 [==============================] - 0s 284us/step - loss: 0.0223 - val_loss: 0.0324

# %%
# Testing and evaluating the model
preds = ElasticPetroModel.evaluate(X_test, Y_test_norm, batch_size=32, verbose=1, sample_weight=None)
print()
print ("Loss = " + str(preds))
# print ("Test Accuracy = " + str(preds[1]))
# Out:
# 500/500 [==============================] - 0s 90us/step
#
# Loss = 0.032301033616065976

# %%
# Plotting the learning curve 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# plt.plot(history.history['loss']/np.max(history.history['loss']))
# plt.plot(history.history['val_loss']/np.max(history.history['val_loss']))
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])


plt.title('Learning curve')
# plt.ylabel('Error/Accuracy')
plt.ylabel('Error')
plt.xlabel('epochs')
plt.legend(['train loss', 'validation loss'], loc='center right')
# plt.savefig('/Figures/learning_curve_08Nov.png', bbox_inches='tight')

# %%
# Save trained model 
# serialize model to JSON
model_json = ElasticPetroModel.to_json()
with open("elastic_petromodel.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
ElasticPetroModel.save_weights("ElasticPetroModel.h5")
print("Saved model to disk")

# %%
# Load saved model
# load json and create model
json_file = open('elastic_petromodel.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
ElasticPetroModel = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("ElasticPetroModel.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
adam = optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

ElasticPetroModel.compile(loss='mean_squared_error', optimizer = adam)


# To evaluate run the "Testing and evaluating the model" cell

# %%
# Predict training and test data using the trained network
test_output_norm = ElasticPetroModel.predict(X_test)
train_output_norm = ElasticPetroModel.predict(X_train)

# Initialization
train_output = np.zeros(train_output_norm.shape)
test_output = np.zeros(test_output_norm.shape)
Y_train = np.zeros(Y_train_norm.shape)
Y_test = np.zeros(Y_test_norm.shape)

# Back transforming porosity to unnormalized values 
train_output[:,0,:] = train_output_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)
test_output[:,0,:] = test_output_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)

train_output[:,1,:] = train_output_norm[:,1,:]
test_output[:,1,:] = test_output_norm[:,1,:]

Y_train[:,0,:] = Y_train_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)
Y_test[:,0,:] = Y_test_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)

Y_train[:,1,:] = Y_train_norm[:,1,:]
Y_test[:,1,:] = Y_test_norm[:,1,:]

# %%
# RMSE with respect to mean 
rmse_train = np.sqrt(np.mean(((train_output - Y_train)**2).mean(axis=2), axis = 0))/np.mean(np.mean(Y_train, axis = 0), axis=1)
rmse_test = np.sqrt(np.mean(((test_output - Y_test)**2).mean(axis=2), axis = 0))/np.mean(np.mean(Y_test, axis = 0), axis=1)

print("Training error = ", rmse_train)
print("Test error = ", rmse_test)
# Out:
# Training error =  [0.16669661 0.29407367]
# Test error =  [0.19362529 0.36330433]

# %%
# Checking training data

sample_number = 25
f, axarr = plt.subplots(1, 3, sharey = True)

axarr[0].plot(train_output[sample_number, 0, :], depth, '-k')
axarr[0].plot(Y_train[sample_number, 0, :], depth, '--r')
axarr[0].set_xlabel("Porosity")
axarr[0].set_ylabel("Depth")
axarr[0].invert_yaxis()
# axarr[0].set_xlim(1.5,3.1)

axarr[1].plot(train_output[sample_number, 1, :], depth, '-k')
axarr[1].plot(Y_train[sample_number, 1, :], depth, '--r')
axarr[1].set_xlabel("Vclay")
axarr[1].set_ylabel("Depth")
axarr[1].invert_yaxis()
# axarr[1].set_xlim(1,2)

# axarr[2].plot(train_output[sample_number, 2, :], depth, '-k')
# axarr[2].plot(Y_train[sample_number, 2, :], depth, '--r')
# axarr[2].set_xlabel("Sw")
# axarr[2].set_ylabel("Depth")
axarr[2].invert_yaxis()
# axarr[2].set_xlim(1.5,3)

# %%
# Checking testing data

sample_number = 12
f, axarr = plt.subplots(1, 3, sharey = True)

axarr[0].plot(test_output[sample_number, 0, :], depth, '-k')
axarr[0].plot(Y_test[sample_number, 0, :], depth, '--r')
axarr[0].set_xlabel("Porosity")
axarr[0].set_ylabel("Depth")
axarr[0].invert_yaxis()
# axarr[0].set_xlim(1.5,3.1)

axarr[1].plot(test_output[sample_number, 1, :], depth, '-k')
axarr[1].plot(Y_test[sample_number, 1, :], depth, '--r')
axarr[1].set_xlabel("Vclay")
axarr[1].set_ylabel("Depth")
axarr[1].invert_yaxis()
# axarr[1].set_xlim(1,2)

# axarr[2].plot(test_output[sample_number, 2, :], depth, '-k')
# axarr[2].plot(Y_test[sample_number, 2, :], depth, '--r')
# axarr[2].set_xlabel("Sw")
# axarr[2].set_ylabel("Depth")
axarr[2].invert_yaxis()
# axarr[2].set_xlim(1.5,3)

# %%
# Correlation coefficient between true and predicted traces 

Porosity_corr_train = np.zeros(train_output.shape[0])
Vclay_corr_train = np.zeros(train_output.shape[0])
# Sw_corr_train = np.zeros(train_output.shape[0])
for i in range(train_output.shape[0]):
    Porosity_corr_train[i] = np.corrcoef(train_output[i,0,:], Y_train[i,0,:])[0,1]
    Vclay_corr_train[i] = np.corrcoef(train_output[i,1,:], Y_train[i,1,:])[0,1]
#     Sw_corr_train[i] = np.corrcoef(train_output[i,2,:], Y_train[i,2,:])[0,1]
    
Porosity_corr_test = np.zeros(test_output.shape[0])
Vclay_corr_test = np.zeros(test_output.shape[0])
# Sw_corr_test = np.zeros(test_output.shape[0])
for i in range(test_output.shape[0]):
    Porosity_corr_test[i] = np.corrcoef(test_output[i,0,:], Y_test[i,0,:])[0,1]
    Vclay_corr_test[i] = np.corrcoef(test_output[i,1,:], Y_test[i,1,:])[0,1]
#     Sw_corr_test[i] = np.corrcoef(test_output[i,2,:], Y_test[i,2,:])[0,1]

    
# Average correlation coefficient
print("Average correlation in porosity for training data = ", np.mean(Porosity_corr_train))
print("Average correlation in Vclay for training data = ", np.mean(Vclay_corr_train))
# print("Average correlation in Sw for training data = ", np.mean(Sw_corr_train))

print("Average correlation in porosity for test data = ", np.mean(Porosity_corr_test))
print("Average correlation in Vclay for test data = ", np.mean(Vclay_corr_test))
# print("Average correlation in Sw for test data = ", np.mean(Sw_corr_test))
# Out:
# Average correlation in porosity for training data =  0.7406945362135692
# Average correlation in Vclay for training data =  0.8220602003232143
# Average correlation in porosity for test data =  0.6123675316979932
# Average correlation in Vclay for test data =  0.7085238320506562

# %%
# Box plot of correlation coefficients 

from pylab import plot, show, savefig, xlim, figure, \
                hold, ylim, legend, boxplot, setp, axes

# function for setting the colors of the box plots pairs
def setBoxColors(bp):
    setp(bp['boxes'][0], color='blue')
    setp(bp['caps'][0], color='blue')
    setp(bp['caps'][1], color='blue')
    setp(bp['whiskers'][0], color='blue')
    setp(bp['whiskers'][1], color='blue')
#     setp(bp['fliers'][0], color='blue')
#     setp(bp['fliers'][1], color='blue')
    setp(bp['medians'][0], color='blue')

    setp(bp['boxes'][1], color='red')
    setp(bp['caps'][2], color='red')
    setp(bp['caps'][3], color='red')
    setp(bp['whiskers'][2], color='red')
    setp(bp['whiskers'][3], color='red')
#     setp(bp['fliers'][2], color='red')
#     setp(bp['fliers'][3], color='red')
    setp(bp['medians'][1], color='red')

# Some fake data to plot
A= [Porosity_corr_train, Porosity_corr_test]
B = [Vclay_corr_train, Vclay_corr_test]
# C = [Sw_corr_train, Sw_corr_test]

fig = figure()
ax = axes()

# first boxplot pair
bp = boxplot(A, positions = [1, 2], widths = 0.6, showfliers=False)
setBoxColors(bp)

# second boxplot pair
bp = boxplot(B, positions = [4, 5], widths = 0.6, showfliers=False)
setBoxColors(bp)

# thrid boxplot pair
# bp = boxplot(C, positions = [7, 8], widths = 0.6, showfliers=False)
# setBoxColors(bp)

# set axes limits and labels
# xlim(0,9)
xlim(0,6)
ylim(0,1)
# ax.set_xticklabels(['Porosity', 'Vclay', 'Sw'])
ax.set_xticklabels(['Porosity', 'Vclay'])
# ax.set_xticks([1.5, 4.5, 7.5])
ax.set_xticks([1.5, 4.5])
plt.ylabel('Correlation coefficient')

# draw temporary red and blue lines and use them to create a legend
hB, = plot([1,1],'b-')
hR, = plot([1,1],'r-')
legend((hB, hR),('Training', 'Test'), loc='lower left')
hB.set_visible(False)
hR.set_visible(False)

# %%
# Histogram plot for true vs predicted values
for i in np.arange(0,train_output.shape[0],100):
    hist, bin_edges = np.histogram(Y_train[i,0,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(train_output[i,0,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
#     plt.hist(train_output[i,0,:], histtype='step', color='red')
    plt.xlabel('Porosity')
    plt.ylabel('Probability')
    plt.title('Training examples')

plt.legend(['True', 'Predicted'])

# %%
# Histogram plot for true vs predicted values
for i in np.arange(0,train_output.shape[0],100):
    hist, bin_edges = np.histogram(Y_train[i,1,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(train_output[i,1,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
    plt.xlabel('Vclay')
    plt.ylabel('Probability')
    plt.title('Training examples')
    
plt.legend(['True', 'Predicted'])

# %%
# Histogram plot for true vs predicted values
for i in np.arange(0,train_output.shape[0],100):
    hist, bin_edges = np.histogram(Y_train[i,2,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(train_output[i,2,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
    plt.xlabel('Sw')
    plt.ylabel('Probability')
    plt.title('Training examples')
plt.legend(['True', 'Predicted'])

# %%
for i in np.arange(0,test_output.shape[0],20):
    hist, bin_edges = np.histogram(Y_test[i,0,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(test_output[i,0,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
    plt.xlabel('Porosity')
    plt.ylabel('Probability')
    plt.title('Test examples')
plt.legend(['True', 'Predicted'])

# %%
for i in np.arange(0,test_output.shape[0],20):
    hist, bin_edges = np.histogram(Y_test[i,1,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(test_output[i,1,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
    plt.xlabel('Vclay')
    plt.ylabel('Probability')
    plt.title('Test examples')
    
plt.legend(['True', 'Predicted'])

# %%
for i in np.arange(0,test_output.shape[0],20):
    hist, bin_edges = np.histogram(Y_test[i,2,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="black")
    hist, bin_edges = np.histogram(test_output[i,2,:], density=True)
    plt.plot(bin_edges[1:],np.cumsum(hist)*(bin_edges[1]-bin_edges[0]), color="red")
    plt.xlabel('Sw')
    plt.ylabel('Probability')
    plt.title('Test examples')
    
plt.legend(['True', 'Predicted'])

# %%
# Density estimate for true vs predicted (test example) Porosity

import seaborn as sns

sample_number = 12
sns.kdeplot(test_output[sample_number,0,:],  
             color='red', label='Predicted', linewidth=3,
            bw=0.01,
             clip=(np.min(test_output[sample_number,0,:]), np.max(test_output[sample_number,0,:])))
sns.kdeplot(Y_test[sample_number,0,:],  
             color='black', label='True', linewidth=3,
            bw=0.01,
             clip=(np.min(Y_test[sample_number,0,:]), np.max(Y_test[sample_number,0,:])))
plt.xlabel('Porosity')
plt.ylabel('Density')
plt.title('Test example')
plt.legend()

# %%
# Density estimate for true vs predicted (test example) Vclay

sample_number = 12

sns.kdeplot(test_output[sample_number,1,:],  
             color='red', label='Predicted', linewidth=3,
             bw=0.04,
           clip=(np.min(test_output[sample_number,1,:]), np.max(test_output[sample_number,1,:])))
sns.kdeplot(Y_test[sample_number,1,:],  
             color='black', label='True', linewidth=3,
            bw=0.04,
             clip=(np.min(Y_test[sample_number,1,:]), np.max(Y_test[sample_number,1,:])))
plt.xlabel('Vclay')
plt.ylabel('Density')
plt.title('Test example')
plt.legend()
plt.xlim(-0.1,1.1)
# Out:
# (-0.1, 1.1)

# %%
# Density estimate for true vs predicted (test example) Water saturation 

sample_number = 12

sns.kdeplot(test_output[sample_number,2,:],  
             color='red', label='Predicted', linewidth=3,
             bw=0.04,
           clip=(np.min(test_output[sample_number,2,:]), np.max(test_output[sample_number,2,:])))
sns.kdeplot(Y_test[sample_number,2,:],  
             color='black', label='True', linewidth=3,
            bw=0.04,
             clip=(np.min(Y_test[sample_number,2,:]), np.max(Y_test[sample_number,2,:])))
plt.xlabel('Sw')
plt.ylabel('Density')
plt.title('Test example')
plt.legend()
plt.xlim(-0.1,1.1)
# Out:
# (-0.1, 1.1)

# %%
# Compute variograms for true and predicted data

from gstools import vario_estimate_unstructured, Spherical
from gstools.covmodel.plot import plot_variogram

# estimate the variogram of the field with 40 bins
bins = np.arange(50)

sample_number = 12
bin_center, gamma = vario_estimate_unstructured(depth.T, Y_test[sample_number,0,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="black")
plt.xlabel('Distance/ Lag')
plt.ylabel('Normalized semi-variance')
plt.title('Test dataset (Porosity)')
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
    
bin_center, gamma = vario_estimate_unstructured(depth.T, test_output[sample_number,0,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="red")
plt.gca().legend(('True','Predicted'))
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
# Out:
# ({'var': 0.00142323644476928,
#   'len_scale': 20.01658360636054,
#   'nugget': 0.00012097541570848353},
#  array([[ 1.89188523e-09, -1.41449103e-05, -1.75645073e-09],
#         [-1.41449103e-05,  5.85120756e-01,  1.83601033e-05],
#         [-1.75645073e-09,  1.83601033e-05,  1.80042817e-09]]))

# %%
# Compute variograms for true and predicted data

from gstools import vario_estimate_unstructured, Spherical
from gstools.covmodel.plot import plot_variogram

# estimate the variogram of the field with 40 bins
bins = np.arange(50)

sample_number = 12
bin_center, gamma = vario_estimate_unstructured(depth.T, Y_test[sample_number,1,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="black")
plt.xlabel('Distance/ Lag')
plt.ylabel('Normalized semi-variance')
plt.title('Test dataset (Vclay)')
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
    
bin_center, gamma = vario_estimate_unstructured(depth.T, test_output[sample_number,1,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="red")
plt.gca().legend(('True','Predicted'))
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
# Out:
# ({'var': 0.05592561361992461,
#   'len_scale': 21.939509963745333,
#   'nugget': 8.53859386444981e-24},
#  array([[ 3.23550378e-06, -6.44180757e-04, -2.96842786e-06],
#         [-6.44180757e-04,  7.93026761e-01,  8.75818946e-04],
#         [-2.96842786e-06,  8.75818946e-04,  3.05494532e-06]]))

# %%
# Spectral coherence between true and predicted 

sample_number = 25
plt.cohere(Y_train[sample_number,0,:], train_output[sample_number,0,:], NFFT=16, Fs=1, color="blue")
plt.cohere(Y_train[sample_number,1,:], train_output[sample_number,1,:], NFFT=16, Fs=1, color="red") 
plt.cohere(Y_train[sample_number,2,:], train_output[sample_number,2,:], NFFT=16, Fs=1, color="black")


plt.gca().legend(('Porosity','Vclay', 'Sw'))
plt.xlabel('Wavenumber')
plt.ylabel('Coherence')
plt.title('Training example')
plt.grid(b=False)

# %%
# Spectral coherence between true and predicted (training data)

sample_number = 25
Cxy_poro, wavenumber_poro = plt.cohere(Y_train[sample_number,0,:], train_output[sample_number,0,:], NFFT=16, Fs=1, color="blue")
Cxy_vclay, wavenumber_vclay = plt.cohere(Y_train[sample_number,1,:], train_output[sample_number,1,:], NFFT=16, Fs=1, color="red") 
# Cxy_sw, wavenumber_sw = plt.cohere(Y_test_petro[sample_number,2,:], test_output_petro[sample_number,2,:], NFFT=16, Fs=1, color="black")

# Adding epsilon to the first wavenumber value
wavenumber_poro[0] = wavenumber_poro[0] + 0.001
wavenumber_vclay[0] = wavenumber_vclay[0] + 0.001
# wavenumber_sw[0] = wavenumber_sw[0] + 0.001

plt.plot(1/wavenumber_poro, Cxy_poro, color="blue")
plt.plot(1/wavenumber_vclay, Cxy_vclay, color="red")
# plt.plot(1/wavenumber_sw, Cxy_sw, color="black")

plt.xlim(100,2)
plt.gca().invert_xaxis()
plt.xscale("log")

# plt.gca().legend(('Porosity','Vclay', 'Sw'))
plt.gca().legend(('Porosity','Vclay'))
plt.xlabel('1/Wavenumber')
plt.ylabel('Coherence')
plt.title('Training example')
plt.grid(b=False)

# %%
# Spectral coherence between true and predicted (test data)

sample_number = 12
Cxy_poro, wavenumber_poro = plt.cohere(Y_test[sample_number,0,:], test_output[sample_number,0,:], NFFT=16, Fs=1, color="blue")
Cxy_vclay, wavenumber_vclay = plt.cohere(Y_test[sample_number,1,:], test_output[sample_number,1,:], NFFT=16, Fs=1, color="red") 
# Cxy_sw, wavenumber_sw = plt.cohere(Y_test_petro[sample_number,2,:], test_output_petro[sample_number,2,:], NFFT=16, Fs=1, color="black")

# Adding epsilon to the first wavenumber value
wavenumber_poro[0] = wavenumber_poro[0] + 0.001
wavenumber_vclay[0] = wavenumber_vclay[0] + 0.001
# wavenumber_sw[0] = wavenumber_sw[0] + 0.001

plt.plot(1/wavenumber_poro, Cxy_poro, color="blue")
plt.plot(1/wavenumber_vclay, Cxy_vclay, color="red")
# plt.plot(1/wavenumber_sw, Cxy_sw, color="black")

plt.xlim(100,2)
plt.gca().invert_xaxis()
plt.xscale("log")

# plt.gca().legend(('Porosity','Vclay', 'Sw'))
plt.gca().legend(('Porosity','Vclay'))
plt.xlabel('1/Wavenumber')
plt.ylabel('Coherence')
plt.title('Test example')
plt.grid(b=False)
