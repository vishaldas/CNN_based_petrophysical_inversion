# %% [markdown]
# ## Petrophysical properties inversion from seismic data

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import numpy as np
from random import randint
from wiggle.wiggle import wiggle
from matplotlib.pyplot import figure
import math
import tensorflow as tf

# %%
# Checking the devices available for use in AWS
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10727081247148124443
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 10879567782228292325
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 11106646463213364036
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11326753997
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17227502338071283584
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7"
# ]

# %%
# Loading the Vp, Vs and Density data

dataframe = sio.loadmat('../../../Data_generation_base_case/Train_DataSyn1_time_clip.mat')
Vp = dataframe['VpMat']
Vp = np.reshape(Vp, (Vp.shape[0]*Vp.shape[1], Vp.shape[2]))
Vs = dataframe['VsMat']
Vs = np.reshape(Vs, (Vs.shape[0]*Vs.shape[1], Vs.shape[2]))
RHOB = dataframe['RHOBMat']
RHOB = np.reshape(RHOB, (RHOB.shape[0]*RHOB.shape[1], RHOB.shape[2]))

depth = dataframe['depthVec']

# Loading facies, porosity, vclay and water saturation data 
dataframe_facies = sio.loadmat('../../../Data_generation_base_case/Train_FaciesMat.mat')
facies = dataframe_facies['zFaciesMat']
facies = np.reshape(facies, (facies.shape[0]*facies.shape[1], facies.shape[2]))

dataframe_porosity = sio.loadmat('../../../Data_generation_base_case/Train_PhiMat.mat')
porosity = dataframe_porosity['zPhiMat']
porosity = np.reshape(porosity, (porosity.shape[0]*porosity.shape[1], porosity.shape[2]))

dataframe_vclay = sio.loadmat('../../../Data_generation_base_case/Train_ClayMat.mat')
vclay = dataframe_vclay['zClayMat']
vclay = np.reshape(vclay, (vclay.shape[0]*vclay.shape[1], vclay.shape[2]))

dataframe_Sw = sio.loadmat('../../../Data_generation_base_case/Train_SwMat.mat')
Sw = dataframe_Sw['zSwMat']
Sw = np.reshape(Sw, (Sw.shape[0]*Sw.shape[1], Sw.shape[2]))

# %%
# Plot of loaded data

plt.figure(figsize=(10,10))

sample_number = 12
f, axarr = plt.subplots(1, 6, sharey = True, figsize=(10,6))

axarr[0].plot(facies[sample_number, :], depth, color = "black")
axarr[0].set_xlabel("Facies")
axarr[0].set_ylabel("Depth [meters]")
axarr[0].set_ylim([0,200])
axarr[0].invert_yaxis()

axarr[1].plot(porosity[sample_number, :], depth, color = "black")
axarr[1].set_xlabel("Porosity [V/V]")
axarr[1].set_xlim(0,0.4)

axarr[2].plot(vclay[sample_number, :], depth, color = "black")
axarr[2].set_xlabel("Vclay [V/V]")
axarr[2].set_xlim(0,1)

axarr[3].plot(Sw[sample_number, :], depth, color = "black")
axarr[3].set_xlabel("Sw [V/V]")
axarr[3].set_xlim(0,1)

axarr[4].plot(Vp[sample_number, :]*RHOB[sample_number, :], depth, color = "black")
axarr[4].set_xlabel("Ip [km/sec gm/cm^3]")
# plt.xlim(0,1)

axarr[5].plot(Vp[sample_number, :]/Vs[sample_number, :], depth, color = "black")
axarr[5].set_xlabel("Vp/Vs [ratio]")
# plt.xlim(0,1)

# axarr[6].plot(RHOB[sample_number, :], depth, color = "black")
# axarr[6].set_xlabel("RHOB")
# # plt.xlim(0,1)

# axarr[7].plot(Vp[sample_number, :]*RHOB[sample_number, :], depth)
# axarr[7].set_xlabel("Ip")
# Out:
# Text(0.5,0,'Vp/Vs [ratio]')

# %%
# AVO and source parameters 
src_len=np.int(60)
freq=40
dt=7e-4
# ntheta=46
thetaStart=0
thetaEnd=30
thetaInc=5
theta=np.arange(thetaStart,thetaEnd+thetaInc,thetaInc)
ntheta=theta.size
# nt=201
# ncdp=1111
angle=np.reshape(theta,[1,ntheta])
# theta=np.arange(0,ntheta,1)
print('angle:', angle.shape)
print('angle:', angle)
# Out:
# angle: (1, 7)
# angle: [[ 0  5 10 15 20 25 30]]

# %%
# Generate the seismic wavelet
def ricker(f,n,dt,t0):

    T = dt*(np.floor(n/2));
    t = np.linspace(-T,T,n)
    tau = t-t0;
    pi=np.pi
    s = (1-2*tau*tau*f**2*pi**2)*np.exp(-tau**2*pi**2*f**2);
    rw = s;

    return rw,t
src,tsrc=ricker(freq,src_len,dt,0)
plt.plot(tsrc,src, '-k')
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Source Wavelet")
plt.show()

# %%
# Convert Vp, Vs and Density logs from depth to time 
time = np.zeros((Vp.shape[0], Vp.shape[1]+1))

for i in range(time.shape[0]):
    depth_diff = np.mean(np.diff(depth.T))
    time[i,0] = 0
    time[i,1:] = 2*np.cumsum(depth_diff/(Vp[i,:]*1e3))

time = time[:,0:-1]
# Interpolate the time values such that all logs have the same dt_log
end_time = (np.max(time))
time_upscaled = np.arange(0, end_time, dt)

Vp_time = np.zeros((Vp.shape[0], time_upscaled.shape[0]))
Vs_time = np.zeros((Vs.shape[0], time_upscaled.shape[0]))
RHOB_time = np.zeros((RHOB.shape[0], time_upscaled.shape[0]))
for i in range(time.shape[0]):
    Vp_time[i,:] = np.interp(time_upscaled, time[i,:], Vp[i,:])
    Vs_time[i,:] = np.interp(time_upscaled, time[i,:], Vs[i,:])
    RHOB_time[i,:] = np.interp(time_upscaled, time[i,:], RHOB[i,:])
    
nt = time_upscaled.shape[0]

# %%
sample_number = 10
plt.subplot(1,2,1)
plt.plot(Vp_time[sample_number,:], time_upscaled)
plt.subplot(1,2,2)
plt.plot(Vp[sample_number,:], depth)

# %%
# Load forward modeled seismic data and Rpp
seis = np.load('../../../Data_generation_base_case/seismic_forward_modeled.npy')
Rpp = np.load('../../../Data_generation_base_case/Rpp_forward_modeled.npy')

sample_number = 12
row_idx = np.array([0, 6])
wiggle(np.squeeze(seis[sample_number,:,row_idx]).T,time_upscaled*1e3,theta[row_idx])
plt.title("Seismogram")
plt.xlabel("$\\theta$")
plt.ylabel("Time [msec]")
plt.show()

impedance_time = Vp_time * RHOB_time
impedance_time_sample = impedance_time[sample_number,:]
plt.subplot(1,3,1)
plt.plot((impedance_time_sample - np.min(impedance_time_sample))/(np.max(impedance_time_sample)-np.min(impedance_time_sample)), time_upscaled)
plt.gca().invert_yaxis()
plt.subplot(1,3,2)
seis_sample = np.squeeze(seis[sample_number,:,0])
plt.plot((seis_sample - np.min(seis_sample))/(np.max(seis_sample) - np.min(seis_sample)), time_upscaled)
plt.gca().invert_yaxis()
plt.subplot(1,3,3)
plt.plot(np.squeeze(Rpp[sample_number,:,0]), time_upscaled)
plt.gca().invert_yaxis()

# %%
# Plot of loaded data

plt.figure(figsize=(10,20))

sample_number = 12
f, axarr = plt.subplots(1, 6, sharey = False, figsize=(18,6))

axarr[0].plot(facies[sample_number, :], depth, color = "black")
axarr[0].set_xlabel("Facies")
axarr[0].set_ylabel("Depth [meters]")
axarr[0].set_ylim([0,200])
axarr[0].invert_yaxis()

axarr[1].plot(porosity[sample_number, :], depth, color = "black")
axarr[1].set_xlabel("Porosity [V/V]")
axarr[1].set_xlim(0,0.4)
# axarr[1].set_ylabel("Depth [meters]")
axarr[1].set_ylim([0,200])
axarr[1].invert_yaxis()

axarr[2].plot(vclay[sample_number, :], depth, color = "black")
axarr[2].set_xlabel("Vclay [V/V]")
axarr[2].set_xlim(0,1)
# axarr[2].set_ylabel("Depth [meters]")
axarr[2].set_ylim([0,200])
axarr[2].invert_yaxis()


axarr[3].plot(Sw[sample_number, :], depth, color = "black")
axarr[3].set_xlabel("Sw [V/V]")
axarr[3].set_xlim(0,1)
# axarr[3].set_ylabel("Depth [meters]")
axarr[3].set_ylim([0,200])
axarr[3].invert_yaxis()


axarr[4].plot(Vp_time[sample_number, :-6]*RHOB_time[sample_number, :-6], time_upscaled[:-6]*1e3, color = "black")
axarr[4].set_xlabel("Ip [km/sec gm/cm^3]")
# axarr[4].set_ylabel("Time [msec]")
axarr[4].set_ylim([np.min(time_upscaled[:-6])*1e3,np.max(time_upscaled[:-6])*1e3])
axarr[4].invert_yaxis()
# plt.xlim(0,1)

axarr[5].plot(Vp_time[sample_number, :-6]/Vs_time[sample_number, :-6], time_upscaled[:-6]*1e3, color = "black")
axarr[5].set_xlabel("Vp/Vs [ratio]")
# axarr[5].set_ylabel("Time [msec]")
axarr[5].set_ylim([np.min(time_upscaled[:-6])*1e3,np.max(time_upscaled[:-6])*1e3])
axarr[5].invert_yaxis()
# plt.xlim(0,1)

# axarr[6].plot(RHOB[sample_number, :], depth, color = "black")
# axarr[6].set_xlabel("RHOB")
# # plt.xlim(0,1)

# axarr[7].plot(Vp[sample_number, :]*RHOB[sample_number, :], depth)
# axarr[7].set_xlabel("Ip")

# %%
# Import keras modules for CNN

from keras import layers, initializers, optimizers
from keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling1D, MaxPooling2D, Dropout, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers import LeakyReLU, Reshape
from keras.models import Model, model_from_json, load_model
from keras.preprocessing import image
from keras.utils import layer_utils, normalize
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.utils import np_utils, normalize
from keras.backend import manual_variable_initialization
from keras.callbacks import EarlyStopping, ModelCheckpoint

# from kt_utils import *

import keras.backend as K
K.set_image_data_format('channels_last')

import sklearn.model_selection
import pydot
# Out:
# Using TensorFlow backend.

# %%
# Getting the input data (normalized) and output data 

# Reshape seismic gathers into (number of examples, angle, time) and normalize such that seismic traces have positive values
seis_reshaped = np.swapaxes(seis,1,2)
seis_reshaped_normalized = (seis_reshaped - np.min(seis_reshaped))/(np.max(seis_reshaped)-np.min(seis_reshaped))
# Normalizing each trace individually
# seis_test = np.reshape(seis_reshaped, (seis_reshaped.shape[0]*seis_reshaped.shape[1], seis_reshaped.shape[2]))
# seis_reshaped_normalized = np.transpose(
#     (seis_test.T - np.min(seis_test, axis=1))/(np.max(seis_test, axis=1) - np.min(seis_test, axis=1)))
# seis_reshaped_normalized = np.reshape(seis_reshaped_normalized, (seis_reshaped.shape[0], seis_reshaped.shape[1], seis_reshaped.shape[2]))


# Selecting near(0 degree) and far (30 degree) angle traces from the full seismic gathers
row_idx = np.array([0, 6])
angle_seis_reshaped_normalized = seis_reshaped_normalized[:,row_idx,:]

# Concatenate Porosity, Vclay, Sw 
num_examples = porosity.shape[0]
ndepth = porosity.shape[1]

# Normalize porosity
porosity_norm = (porosity - np.min(porosity))/(np.max(porosity) - np.min(porosity))

# petromodel = np.concatenate((porosity_norm,vclay,Sw), axis=1)
# petromodel = petromodel.reshape((num_examples, 3, ndepth))
petromodel = np.concatenate((porosity_norm,vclay), axis=1)
petromodel = petromodel.reshape((num_examples, 2, ndepth))


# Split data into train and test set - petro model
# X_train_petro, X_test_petro, Y_train_petro, Y_test_petro = sklearn.model_selection.train_test_split(seis_reshaped_normalized, 
#                                                                             petromodel, test_size=0.2, random_state=1)
X_train_petro, X_test_petro, Y_train_petro_norm, Y_test_petro_norm = sklearn.model_selection.train_test_split(angle_seis_reshaped_normalized, 
                                                                            petromodel, test_size=0.2, random_state=1)

# Add 4th dimension of number of channels=1 to the input data
X_train_petro = np.expand_dims(X_train_petro, axis=3)
X_test_petro = np.expand_dims(X_test_petro, axis=3)

print ("number of training examples petromodel = " + str(X_train_petro.shape[0]))
# print ("number of validation examples = " + str(X_val.shape[0]))
print ("number of test examples petromodel = " + str(X_test_petro.shape[0]))
print ("X_train_petromodel shape: " + str(X_train_petro.shape))
print ("Y_train_petromodel shape: " + str(Y_train_petro_norm.shape))
# print ("X_val shape: " + str(X_val.shape))
# print ("Y_val shape: " + str(Y_val.shape))
print ("X_test_petromodel shape: " + str(X_test_petro.shape))
print ("Y_test_petromodel shape: " + str(Y_test_petro_norm.shape))
# Out:
# number of training examples petromodel = 2000
# number of test examples petromodel = 500
# X_train_petromodel shape: (2000, 2, 246, 1)
# Y_train_petromodel shape: (2000, 2, 199)
# X_test_petromodel shape: (500, 2, 246, 1)
# Y_test_petromodel shape: (500, 2, 199)

# %%
seis_reshaped_normalized = (seis_reshaped - np.min(seis_reshaped))/(np.max(seis_reshaped)-np.min(seis_reshaped))

plt.subplot(1,2,1)
plt.plot(np.squeeze(seis_reshaped[2,1,:]),time_upscaled)
plt.subplot(1,2,2)
plt.plot(np.squeeze(seis_reshaped_normalized[2,1,:]),time_upscaled)

# %%
# Building neural network for petrophysical properties prediction in Keras 
given_seed = 3 # For repeatibility


def petronet(input_shape):
    """
    Implementation of the PetroNet.
    
    Arguments:
    input_shape -- shape of the images of the dataset

    Returns:
    model -- a Model() instance in Keras
    """
    

    # Define the input placeholder as a tensor with shape input_shape. Input = input angle gather 
    X_input = Input(input_shape)

    X = X_input

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(64, (2, 7), strides=(1, 2), name='conv0', padding='same',
               kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn0')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv0')(X)
    # MAXPOOL
#     X = MaxPooling2D((1, 2), strides=(1,2),name='max_pool0')(X)
    
    
    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(32, (2, 15), strides=(1, 2), name='conv1',padding='same',
               kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn1')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv1')(X)
    # MAXPOOL
#     X = MaxPooling2D((1, 2), strides=(1,2),name='max_pool1')(X)
    
    
#     # CONV -> BN -> RELU Block applied to X
    X = Conv2D(16, (1, 30), strides=(1, 2), name='conv2',padding='same',
               kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn2')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv2')(X)
#     # MAXPOOL
#     X = MaxPooling2D((1, 2), strides=(1,2),name='max_pool2')(X)
    
    
#     # CONV -> BN -> RELU Block applied to X
    X = Conv2D(8, (1, 60), strides=(1, 2), name='conv3',padding='same',
               kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = BatchNormalization(axis=-1, name='bn3')(X)
    X = Activation('relu')(X)
    X = Dropout(rate=0.3, name='drop_conv3')(X)
#     # MAXPOOL
#     X = MaxPooling2D((1, 2), strides=(1,2),name='max_pool3')(X)
    

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
    
    # Considering Sw first dimension is 3, without first dimension is 2
    X = Dense(199*2, name='fc1', 
             kernel_initializer=initializers.glorot_uniform(seed=given_seed), bias_initializer='zeros')(X)
    X = Activation('relu')(X)
#     X = LeakyReLU(0.3)(X)
    X = Reshape((2, 199))(X)
    
    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs=X_input, outputs=X, name='PetroModel')

    return model
    ### END CODE HERE ###

# %%
# Create the model
PetroModel = petronet(X_train_petro.shape[1:])
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# Summary and plot of the model

PetroModel.summary()


# plot_model(AVOModel)
# SVG(model_to_dot(ElasticModel).create(prog='dot', format='svg'))
# plot_model(ElasticModel, to_file='./Figures/model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2, 246, 1)         0
# _________________________________________________________________
# conv0 (Conv2D)               (None, 2, 123, 64)        960
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 2, 123, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 2, 123, 64)        0
# _________________________________________________________________
# drop_conv0 (Dropout)         (None, 2, 123, 64)        0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 2, 62, 32)         61472
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 2, 62, 32)         128
# _________________________________________________________________
# activation_2 (Activation)    (None, 2, 62, 32)         0
# _________________________________________________________________
# drop_conv1 (Dropout)         (None, 2, 62, 32)         0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 2, 31, 16)         15376
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 2, 31, 16)         64
# _________________________________________________________________
# activation_3 (Activation)    (None, 2, 31, 16)         0
# _________________________________________________________________
# drop_conv2 (Dropout)         (None, 2, 31, 16)         0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 2, 16, 8)          7688
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 2, 16, 8)          32
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 16, 8)          0
# _________________________________________________________________
# drop_conv3 (Dropout)         (None, 2, 16, 8)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 398)               102286
# _________________________________________________________________
# activation_5 (Activation)    (None, 398)               0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 2, 199)            0
# =================================================================
# Total params: 188,262
# Trainable params: 188,022
# Non-trainable params: 240
# _________________________________________________________________

# %%
# Learning rate scheduler
from keras.callbacks import LearningRateScheduler
# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.01
    drop = 0.1
    epochs_drop = 100.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

# %%
# Compile the model with optimization algorithm, loss function
adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)


PetroModel.compile(loss='mean_squared_error', optimizer = adam)
# PetroModel.compile(loss='mean_squared_logarithmic_error', optimizer = adam)

# %%
# Removing previous best_model.h5 file
import os
os.remove("best_model_new_far.h5")

# %%
# Using early stopping and Model Checkpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)
mc = ModelCheckpoint('best_model_new_far.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
# Start the training
# Using learning rate scheduler
# lrate = LearningRateScheduler(step_decay)
# callbacks_list = [lrate,es,mc]
# history = PetroModel.fit(X_train_petro, Y_train_petro, 
#                          validation_split=0.2, epochs=500, batch_size=32, callbacks=callbacks_list, 
#                         verbose=0)

import time
start = time.time()


history = PetroModel.fit(X_train_petro, Y_train_petro_norm, validation_split=0.2, 
                         epochs=1500, batch_size=32, callbacks=[es, mc],
                        verbose = 0)

end = time.time()
print(end - start)
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# Epoch 00001: val_loss improved from inf to 0.08420, saving model to best_model_new_far_time.h5
#
# Epoch 00002: val_loss improved from 0.08420 to 0.07410, saving model to best_model_new_far_time.h5
#
# Epoch 00003: val_loss improved from 0.07410 to 0.06438, saving model to best_model_new_far_time.h5
#
# Epoch 00004: val_loss improved from 0.06438 to 0.06241, saving model to best_model_new_far_time.h5
#
# Epoch 00005: val_loss improved from 0.06241 to 0.05832, saving model to best_model_new_far_time.h5
#
# Epoch 00006: val_loss did not improve from 0.05832
#
# Epoch 00007: val_loss improved from 0.05832 to 0.05133, saving model to best_model_new_far_time.h5
#
# Epoch 00008: val_loss improved from 0.05133 to 0.04782, saving model to best_model_new_far_time.h5
#
# Epoch 00009: val_loss improved from 0.04782 to 0.04653, saving model to best_model_new_far_time.h5
#
# Epoch 00010: val_loss did not improve from 0.04653
#
# Epoch 00011: val_loss improved from 0.04653 to 0.04553, saving model to best_model_new_far_time.h5
#
# Epoch 00012: val_loss did not improve from 0.04553
#
# Epoch 00013: val_loss improved from 0.04553 to 0.04257, saving model to best_model_new_far_time.h5
#
# Epoch 00014: val_loss improved from 0.04257 to 0.04150, saving model to best_model_new_far_time.h5
#
# Epoch 00015: val_loss improved from 0.04150 to 0.04068, saving model to best_model_new_far_time.h5
#
# Epoch 00016: val_loss did not improve from 0.04068
#
# Epoch 00017: val_loss did not improve from 0.04068
#
# Epoch 00018: val_loss improved from 0.04068 to 0.04055, saving model to best_model_new_far_time.h5
#
# Epoch 00019: val_loss did not improve from 0.04055
#
# Epoch 00020: val_loss did not improve from 0.04055
#
# Epoch 00021: val_loss improved from 0.04055 to 0.03910, saving model to best_model_new_far_time.h5
#
# Epoch 00022: val_loss improved from 0.03910 to 0.03839, saving model to best_model_new_far_time.h5
#
# Epoch 00023: val_loss improved from 0.03839 to 0.03798, saving model to best_model_new_far_time.h5
#
# Epoch 00024: val_loss improved from 0.03798 to 0.03755, saving model to best_model_new_far_time.h5
#
# Epoch 00025: val_loss improved from 0.03755 to 0.03742, saving model to best_model_new_far_time.h5
#
# Epoch 00026: val_loss improved from 0.03742 to 0.03686, saving model to best_model_new_far_time.h5
#
# Epoch 00027: val_loss did not improve from 0.03686
#
# Epoch 00028: val_loss improved from 0.03686 to 0.03681, saving model to best_model_new_far_time.h5
#
# Epoch 00029: val_loss improved from 0.03681 to 0.03639, saving model to best_model_new_far_time.h5
#
# Epoch 00030: val_loss did not improve from 0.03639
#
# Epoch 00031: val_loss did not improve from 0.03639
#
# Epoch 00032: val_loss improved from 0.03639 to 0.03595, saving model to best_model_new_far_time.h5
#
# Epoch 00033: val_loss improved from 0.03595 to 0.03579, saving model to best_model_new_far_time.h5
#
# Epoch 00034: val_loss did not improve from 0.03579
#
# Epoch 00035: val_loss did not improve from 0.03579
#
# Epoch 00036: val_loss improved from 0.03579 to 0.03547, saving model to best_model_new_far_time.h5
#
# Epoch 00037: val_loss did not improve from 0.03547
#
# Epoch 00038: val_loss did not improve from 0.03547
#
# Epoch 00039: val_loss did not improve from 0.03547
#
# Epoch 00040: val_loss did not improve from 0.03547
#
# Epoch 00041: val_loss did not improve from 0.03547
#
# Epoch 00042: val_loss did not improve from 0.03547
#
# Epoch 00043: val_loss improved from 0.03547 to 0.03479, saving model to best_model_new_far_time.h5
#
# Epoch 00044: val_loss improved from 0.03479 to 0.03452, saving model to best_model_new_far_time.h5
#
# Epoch 00045: val_loss did not improve from 0.03452
#
# Epoch 00046: val_loss did not improve from 0.03452
#
# Epoch 00047: val_loss did not improve from 0.03452
#
# Epoch 00048: val_loss improved from 0.03452 to 0.03362, saving model to best_model_new_far_time.h5
#
# Epoch 00049: val_loss did not improve from 0.03362
#
# Epoch 00050: val_loss did not improve from 0.03362
#
# Epoch 00051: val_loss did not improve from 0.03362
#
# Epoch 00052: val_loss improved from 0.03362 to 0.03348, saving model to best_model_new_far_time.h5
#
# Epoch 00053: val_loss improved from 0.03348 to 0.03301, saving model to best_model_new_far_time.h5
#
# Epoch 00054: val_loss did not improve from 0.03301
#
# Epoch 00055: val_loss did not improve from 0.03301
#
# Epoch 00056: val_loss improved from 0.03301 to 0.03294, saving model to best_model_new_far_time.h5
#
# Epoch 00057: val_loss did not improve from 0.03294
#
# Epoch 00058: val_loss did not improve from 0.03294
#
# Epoch 00059: val_loss did not improve from 0.03294
#
# Epoch 00060: val_loss improved from 0.03294 to 0.03252, saving model to best_model_new_far_time.h5
#
# Epoch 00061: val_loss did not improve from 0.03252
#
# Epoch 00062: val_loss did not improve from 0.03252
#
# Epoch 00063: val_loss did not improve from 0.03252
#
# Epoch 00064: val_loss did not improve from 0.03252
#
# Epoch 00065: val_loss did not improve from 0.03252
#
# Epoch 00066: val_loss did not improve from 0.03252
#
# Epoch 00067: val_loss did not improve from 0.03252
#
# Epoch 00068: val_loss did not improve from 0.03252
#
# Epoch 00069: val_loss did not improve from 0.03252
#
# Epoch 00070: val_loss improved from 0.03252 to 0.03250, saving model to best_model_new_far_time.h5
#
# Epoch 00071: val_loss did not improve from 0.03250
#
# Epoch 00072: val_loss improved from 0.03250 to 0.03230, saving model to best_model_new_far_time.h5
#
# Epoch 00073: val_loss did not improve from 0.03230
#
# Epoch 00074: val_loss improved from 0.03230 to 0.03228, saving model to best_model_new_far_time.h5
#
# Epoch 00075: val_loss improved from 0.03228 to 0.03227, saving model to best_model_new_far_time.h5
#
# Epoch 00076: val_loss improved from 0.03227 to 0.03200, saving model to best_model_new_far_time.h5
#
# Epoch 00077: val_loss did not improve from 0.03200
#
# Epoch 00078: val_loss did not improve from 0.03200
#
# Epoch 00079: val_loss did not improve from 0.03200
#
# Epoch 00080: val_loss did not improve from 0.03200
#
# Epoch 00081: val_loss did not improve from 0.03200
#
# Epoch 00082: val_loss did not improve from 0.03200
#
# Epoch 00083: val_loss did not improve from 0.03200
#
# Epoch 00084: val_loss did not improve from 0.03200
#
# Epoch 00085: val_loss did not improve from 0.03200
#
# Epoch 00086: val_loss did not improve from 0.03200
#
# Epoch 00087: val_loss did not improve from 0.03200
#
# Epoch 00088: val_loss did not improve from 0.03200
#
# Epoch 00089: val_loss improved from 0.03200 to 0.03194, saving model to best_model_new_far_time.h5
#
# Epoch 00090: val_loss did not improve from 0.03194
#
# Epoch 00091: val_loss did not improve from 0.03194
#
# Epoch 00092: val_loss did not improve from 0.03194
#
# Epoch 00093: val_loss did not improve from 0.03194
#
# Epoch 00094: val_loss did not improve from 0.03194
#
# Epoch 00095: val_loss did not improve from 0.03194
#
# Epoch 00096: val_loss did not improve from 0.03194
#
# Epoch 00097: val_loss improved from 0.03194 to 0.03172, saving model to best_model_new_far_time.h5
#
# Epoch 00098: val_loss did not improve from 0.03172
#
# Epoch 00099: val_loss did not improve from 0.03172
#
# Epoch 00100: val_loss did not improve from 0.03172
#
# Epoch 00101: val_loss did not improve from 0.03172
#
# Epoch 00102: val_loss did not improve from 0.03172
#
# Epoch 00103: val_loss did not improve from 0.03172
#
# Epoch 00104: val_loss did not improve from 0.03172
#
# Epoch 00105: val_loss did not improve from 0.03172
#
# Epoch 00106: val_loss did not improve from 0.03172
#
# Epoch 00107: val_loss did not improve from 0.03172
#
# Epoch 00108: val_loss did not improve from 0.03172
#
# Epoch 00109: val_loss did not improve from 0.03172
#
# Epoch 00110: val_loss did not improve from 0.03172
#
# Epoch 00111: val_loss did not improve from 0.03172
#
# Epoch 00112: val_loss did not improve from 0.03172
#
# Epoch 00113: val_loss did not improve from 0.03172
#
# Epoch 00114: val_loss did not improve from 0.03172
#
# Epoch 00115: val_loss did not improve from 0.03172
#
# Epoch 00116: val_loss did not improve from 0.03172
#
# Epoch 00117: val_loss did not improve from 0.03172
#
# Epoch 00118: val_loss did not improve from 0.03172
# Epoch 00119: val_loss did not improve from 0.03172
#
# Epoch 00120: val_loss did not improve from 0.03172
#
# Epoch 00121: val_loss did not improve from 0.03172
#
# Epoch 00122: val_loss improved from 0.03172 to 0.03169, saving model to best_model_new_far_time.h5
#
# Epoch 00123: val_loss did not improve from 0.03169
#
# Epoch 00124: val_loss did not improve from 0.03169
#
# Epoch 00125: val_loss improved from 0.03169 to 0.03167, saving model to best_model_new_far_time.h5
#
# Epoch 00126: val_loss improved from 0.03167 to 0.03152, saving model to best_model_new_far_time.h5
#
# Epoch 00127: val_loss did not improve from 0.03152
#
# Epoch 00128: val_loss did not improve from 0.03152
#
# Epoch 00129: val_loss improved from 0.03152 to 0.03151, saving model to best_model_new_far_time.h5
#
# Epoch 00130: val_loss did not improve from 0.03151
#
# Epoch 00131: val_loss improved from 0.03151 to 0.03144, saving model to best_model_new_far_time.h5
#
# Epoch 00132: val_loss improved from 0.03144 to 0.03140, saving model to best_model_new_far_time.h5
#
# Epoch 00133: val_loss did not improve from 0.03140
#
# Epoch 00134: val_loss improved from 0.03140 to 0.03128, saving model to best_model_new_far_time.h5
#
# Epoch 00135: val_loss did not improve from 0.03128
#
# Epoch 00136: val_loss did not improve from 0.03128
#
# Epoch 00137: val_loss did not improve from 0.03128
#
# Epoch 00138: val_loss did not improve from 0.03128
#
# Epoch 00139: val_loss did not improve from 0.03128
#
# Epoch 00140: val_loss did not improve from 0.03128
#
# Epoch 00141: val_loss did not improve from 0.03128
#
# Epoch 00142: val_loss did not improve from 0.03128
#
# Epoch 00143: val_loss did not improve from 0.03128
#
# Epoch 00144: val_loss did not improve from 0.03128
#
# Epoch 00145: val_loss did not improve from 0.03128
#
# Epoch 00146: val_loss did not improve from 0.03128
#
# Epoch 00147: val_loss did not improve from 0.03128
#
# Epoch 00148: val_loss did not improve from 0.03128
#
# Epoch 00149: val_loss did not improve from 0.03128
#
# Epoch 00150: val_loss did not improve from 0.03128
#
# Epoch 00151: val_loss did not improve from 0.03128
#
# Epoch 00152: val_loss did not improve from 0.03128
#
# Epoch 00153: val_loss did not improve from 0.03128
#
# Epoch 00154: val_loss improved from 0.03128 to 0.03123, saving model to best_model_new_far_time.h5
#
# Epoch 00155: val_loss did not improve from 0.03123
#
# Epoch 00156: val_loss did not improve from 0.03123
#
# Epoch 00157: val_loss improved from 0.03123 to 0.03115, saving model to best_model_new_far_time.h5
#
# Epoch 00158: val_loss did not improve from 0.03115
#
# Epoch 00159: val_loss did not improve from 0.03115
#
# Epoch 00160: val_loss did not improve from 0.03115
#
# Epoch 00161: val_loss did not improve from 0.03115
#
# Epoch 00162: val_loss did not improve from 0.03115
#
# Epoch 00163: val_loss did not improve from 0.03115
#
# Epoch 00164: val_loss did not improve from 0.03115
#
# Epoch 00165: val_loss did not improve from 0.03115
#
# Epoch 00166: val_loss did not improve from 0.03115
#
# Epoch 00167: val_loss did not improve from 0.03115
#
# Epoch 00168: val_loss did not improve from 0.03115
#
# Epoch 00169: val_loss did not improve from 0.03115
#
# Epoch 00170: val_loss did not improve from 0.03115
#
# Epoch 00171: val_loss did not improve from 0.03115
#
# Epoch 00172: val_loss did not improve from 0.03115
#
# Epoch 00173: val_loss did not improve from 0.03115
#
# Epoch 00174: val_loss did not improve from 0.03115
#
# Epoch 00175: val_loss did not improve from 0.03115
#
# Epoch 00176: val_loss did not improve from 0.03115
#
# Epoch 00177: val_loss improved from 0.03115 to 0.03114, saving model to best_model_new_far_time.h5
#
# Epoch 00178: val_loss improved from 0.03114 to 0.03111, saving model to best_model_new_far_time.h5
#
# Epoch 00179: val_loss did not improve from 0.03111
#
# Epoch 00180: val_loss did not improve from 0.03111
#
# Epoch 00181: val_loss did not improve from 0.03111
#
# Epoch 00182: val_loss did not improve from 0.03111
#
# Epoch 00183: val_loss did not improve from 0.03111
#
# Epoch 00184: val_loss did not improve from 0.03111
#
# Epoch 00185: val_loss did not improve from 0.03111
#
# Epoch 00186: val_loss did not improve from 0.03111
#
# Epoch 00187: val_loss did not improve from 0.03111
#
# Epoch 00188: val_loss did not improve from 0.03111
#
# Epoch 00189: val_loss did not improve from 0.03111
#
# Epoch 00190: val_loss did not improve from 0.03111
#
# Epoch 00191: val_loss did not improve from 0.03111
#
# Epoch 00192: val_loss did not improve from 0.03111
#
# Epoch 00193: val_loss did not improve from 0.03111
#
# Epoch 00194: val_loss did not improve from 0.03111
#
# Epoch 00195: val_loss did not improve from 0.03111
#
# Epoch 00196: val_loss did not improve from 0.03111
#
# Epoch 00197: val_loss did not improve from 0.03111
#
# Epoch 00198: val_loss did not improve from 0.03111
#
# Epoch 00199: val_loss did not improve from 0.03111
#
# Epoch 00200: val_loss did not improve from 0.03111
#
# Epoch 00201: val_loss did not improve from 0.03111
#
# Epoch 00202: val_loss did not improve from 0.03111
#
# Epoch 00203: val_loss did not improve from 0.03111
#
# Epoch 00204: val_loss improved from 0.03111 to 0.03099, saving model to best_model_new_far_time.h5
#
# Epoch 00205: val_loss did not improve from 0.03099
#
# Epoch 00206: val_loss did not improve from 0.03099
#
# Epoch 00207: val_loss did not improve from 0.03099
#
# Epoch 00208: val_loss did not improve from 0.03099
#
# Epoch 00209: val_loss did not improve from 0.03099
#
# Epoch 00210: val_loss did not improve from 0.03099
#
# Epoch 00211: val_loss improved from 0.03099 to 0.03097, saving model to best_model_new_far_time.h5
#
# Epoch 00212: val_loss did not improve from 0.03097
#
# Epoch 00213: val_loss did not improve from 0.03097
#
# Epoch 00214: val_loss did not improve from 0.03097
#
# Epoch 00215: val_loss improved from 0.03097 to 0.03095, saving model to best_model_new_far_time.h5
#
# Epoch 00216: val_loss did not improve from 0.03095
#
# Epoch 00217: val_loss did not improve from 0.03095
#
# Epoch 00218: val_loss did not improve from 0.03095
#
# Epoch 00219: val_loss did not improve from 0.03095
#
# Epoch 00220: val_loss did not improve from 0.03095
#
# Epoch 00221: val_loss improved from 0.03095 to 0.03082, saving model to best_model_new_far_time.h5
#
# Epoch 00222: val_loss did not improve from 0.03082
#
# Epoch 00223: val_loss did not improve from 0.03082
#
# Epoch 00224: val_loss did not improve from 0.03082
#
# Epoch 00225: val_loss did not improve from 0.03082
#
# Epoch 00226: val_loss did not improve from 0.03082
#
# Epoch 00227: val_loss did not improve from 0.03082
#
# Epoch 00228: val_loss did not improve from 0.03082
#
# Epoch 00229: val_loss did not improve from 0.03082
#
# Epoch 00230: val_loss did not improve from 0.03082
#
# Epoch 00231: val_loss did not improve from 0.03082
#
# Epoch 00232: val_loss did not improve from 0.03082
#
# Epoch 00233: val_loss did not improve from 0.03082
#
# Epoch 00234: val_loss did not improve from 0.03082
#
# Epoch 00235: val_loss did not improve from 0.03082
#
# Epoch 00236: val_loss did not improve from 0.03082
#
# Epoch 00237: val_loss did not improve from 0.03082
#
# Epoch 00238: val_loss did not improve from 0.03082
#
# Epoch 00239: val_loss improved from 0.03082 to 0.03082, saving model to best_model_new_far_time.h5
#
# Epoch 00240: val_loss did not improve from 0.03082
#
# Epoch 00241: val_loss did not improve from 0.03082
#
# Epoch 00242: val_loss did not improve from 0.03082
#
# Epoch 00243: val_loss did not improve from 0.03082
#
# Epoch 00244: val_loss did not improve from 0.03082
#
# Epoch 00245: val_loss did not improve from 0.03082
#
# Epoch 00246: val_loss did not improve from 0.03082
#
# Epoch 00247: val_loss did not improve from 0.03082
#
# Epoch 00248: val_loss improved from 0.03082 to 0.03075, saving model to best_model_new_far_time.h5
#
# Epoch 00249: val_loss did not improve from 0.03075
#
# Epoch 00250: val_loss did not improve from 0.03075
#
# Epoch 00251: val_loss did not improve from 0.03075
#
# Epoch 00252: val_loss did not improve from 0.03075
#
# Epoch 00253: val_loss did not improve from 0.03075
#
# Epoch 00254: val_loss did not improve from 0.03075
#
# Epoch 00255: val_loss improved from 0.03075 to 0.03075, saving model to best_model_new_far_time.h5
#
# Epoch 00256: val_loss did not improve from 0.03075
#
# Epoch 00257: val_loss improved from 0.03075 to 0.03069, saving model to best_model_new_far_time.h5
#
# Epoch 00258: val_loss did not improve from 0.03069
#
# Epoch 00259: val_loss did not improve from 0.03069
# Epoch 00260: val_loss did not improve from 0.03069
#
# Epoch 00261: val_loss did not improve from 0.03069
#
# Epoch 00262: val_loss did not improve from 0.03069
#
# Epoch 00263: val_loss did not improve from 0.03069
#
# Epoch 00264: val_loss did not improve from 0.03069
#
# Epoch 00265: val_loss did not improve from 0.03069
#
# Epoch 00266: val_loss did not improve from 0.03069
#
# Epoch 00267: val_loss did not improve from 0.03069
#
# Epoch 00268: val_loss did not improve from 0.03069
#
# Epoch 00269: val_loss did not improve from 0.03069
#
# Epoch 00270: val_loss did not improve from 0.03069
#
# Epoch 00271: val_loss did not improve from 0.03069
#
# Epoch 00272: val_loss did not improve from 0.03069
#
# Epoch 00273: val_loss did not improve from 0.03069
#
# Epoch 00274: val_loss did not improve from 0.03069
#
# Epoch 00275: val_loss did not improve from 0.03069
#
# Epoch 00276: val_loss improved from 0.03069 to 0.03063, saving model to best_model_new_far_time.h5
#
# Epoch 00277: val_loss did not improve from 0.03063
#
# Epoch 00278: val_loss did not improve from 0.03063
#
# Epoch 00279: val_loss did not improve from 0.03063
#
# Epoch 00280: val_loss did not improve from 0.03063
#
# Epoch 00281: val_loss did not improve from 0.03063
#
# Epoch 00282: val_loss did not improve from 0.03063
#
# Epoch 00283: val_loss did not improve from 0.03063
#
# Epoch 00284: val_loss did not improve from 0.03063
#
# Epoch 00285: val_loss did not improve from 0.03063
#
# Epoch 00286: val_loss did not improve from 0.03063
#
# Epoch 00287: val_loss did not improve from 0.03063
#
# Epoch 00288: val_loss did not improve from 0.03063
#
# Epoch 00289: val_loss did not improve from 0.03063
#
# Epoch 00290: val_loss did not improve from 0.03063
#
# Epoch 00291: val_loss did not improve from 0.03063
#
# Epoch 00292: val_loss did not improve from 0.03063
#
# Epoch 00293: val_loss did not improve from 0.03063
#
# Epoch 00294: val_loss did not improve from 0.03063
#
# Epoch 00295: val_loss did not improve from 0.03063
#
# Epoch 00296: val_loss did not improve from 0.03063
#
# Epoch 00297: val_loss did not improve from 0.03063
#
# Epoch 00298: val_loss improved from 0.03063 to 0.03061, saving model to best_model_new_far_time.h5
#
# Epoch 00299: val_loss did not improve from 0.03061
#
# Epoch 00300: val_loss did not improve from 0.03061
#
# Epoch 00301: val_loss did not improve from 0.03061
#
# Epoch 00302: val_loss improved from 0.03061 to 0.03060, saving model to best_model_new_far_time.h5
#
# Epoch 00303: val_loss did not improve from 0.03060
#
# Epoch 00304: val_loss improved from 0.03060 to 0.03059, saving model to best_model_new_far_time.h5
#
# Epoch 00305: val_loss did not improve from 0.03059
#
# Epoch 00306: val_loss did not improve from 0.03059
#
# Epoch 00307: val_loss did not improve from 0.03059
#
# Epoch 00308: val_loss did not improve from 0.03059
#
# Epoch 00309: val_loss did not improve from 0.03059
#
# Epoch 00310: val_loss did not improve from 0.03059
#
# Epoch 00311: val_loss did not improve from 0.03059
#
# Epoch 00312: val_loss did not improve from 0.03059
#
# Epoch 00313: val_loss did not improve from 0.03059
#
# Epoch 00314: val_loss did not improve from 0.03059
#
# Epoch 00315: val_loss did not improve from 0.03059
#
# Epoch 00316: val_loss improved from 0.03059 to 0.03044, saving model to best_model_new_far_time.h5
#
# Epoch 00317: val_loss did not improve from 0.03044
#
# Epoch 00318: val_loss did not improve from 0.03044
#
# Epoch 00319: val_loss did not improve from 0.03044
#
# Epoch 00320: val_loss did not improve from 0.03044
#
# Epoch 00321: val_loss did not improve from 0.03044
#
# Epoch 00322: val_loss did not improve from 0.03044
#
# Epoch 00323: val_loss did not improve from 0.03044
#
# Epoch 00324: val_loss did not improve from 0.03044
#
# Epoch 00325: val_loss did not improve from 0.03044
#
# Epoch 00326: val_loss did not improve from 0.03044
#
# Epoch 00327: val_loss did not improve from 0.03044
#
# Epoch 00328: val_loss did not improve from 0.03044
#
# Epoch 00329: val_loss did not improve from 0.03044
#
# Epoch 00330: val_loss did not improve from 0.03044
#
# Epoch 00331: val_loss did not improve from 0.03044
#
# Epoch 00332: val_loss did not improve from 0.03044
#
# Epoch 00333: val_loss did not improve from 0.03044
#
# Epoch 00334: val_loss did not improve from 0.03044
#
# Epoch 00335: val_loss did not improve from 0.03044
#
# Epoch 00336: val_loss did not improve from 0.03044
#
# Epoch 00337: val_loss did not improve from 0.03044
#
# Epoch 00338: val_loss did not improve from 0.03044
#
# Epoch 00339: val_loss did not improve from 0.03044
#
# Epoch 00340: val_loss did not improve from 0.03044
#
# Epoch 00341: val_loss improved from 0.03044 to 0.03039, saving model to best_model_new_far_time.h5
#
# Epoch 00342: val_loss did not improve from 0.03039
#
# Epoch 00343: val_loss did not improve from 0.03039
#
# Epoch 00344: val_loss did not improve from 0.03039
#
# Epoch 00345: val_loss did not improve from 0.03039
#
# Epoch 00346: val_loss did not improve from 0.03039
#
# Epoch 00347: val_loss did not improve from 0.03039
#
# Epoch 00348: val_loss did not improve from 0.03039
#
# Epoch 00349: val_loss did not improve from 0.03039
#
# Epoch 00350: val_loss did not improve from 0.03039
#
# Epoch 00351: val_loss did not improve from 0.03039
#
# Epoch 00352: val_loss did not improve from 0.03039
#
# Epoch 00353: val_loss did not improve from 0.03039
#
# Epoch 00354: val_loss did not improve from 0.03039
#
# Epoch 00355: val_loss did not improve from 0.03039
#
# Epoch 00356: val_loss did not improve from 0.03039
#
# Epoch 00357: val_loss did not improve from 0.03039
#
# Epoch 00358: val_loss did not improve from 0.03039
#
# Epoch 00359: val_loss did not improve from 0.03039
#
# Epoch 00360: val_loss did not improve from 0.03039
#
# Epoch 00361: val_loss did not improve from 0.03039
#
# Epoch 00362: val_loss did not improve from 0.03039
#
# Epoch 00363: val_loss did not improve from 0.03039
#
# Epoch 00364: val_loss did not improve from 0.03039
#
# Epoch 00365: val_loss did not improve from 0.03039
#
# Epoch 00366: val_loss did not improve from 0.03039
#
# Epoch 00367: val_loss did not improve from 0.03039
#
# Epoch 00368: val_loss did not improve from 0.03039
#
# Epoch 00369: val_loss improved from 0.03039 to 0.03039, saving model to best_model_new_far_time.h5
#
# Epoch 00370: val_loss did not improve from 0.03039
#
# Epoch 00371: val_loss did not improve from 0.03039
#
# Epoch 00372: val_loss did not improve from 0.03039
#
# Epoch 00373: val_loss did not improve from 0.03039
#
# Epoch 00374: val_loss did not improve from 0.03039
#
# Epoch 00375: val_loss did not improve from 0.03039
#
# Epoch 00376: val_loss did not improve from 0.03039
#
# Epoch 00377: val_loss did not improve from 0.03039
#
# Epoch 00378: val_loss did not improve from 0.03039
#
# Epoch 00379: val_loss did not improve from 0.03039
#
# Epoch 00380: val_loss did not improve from 0.03039
#
# Epoch 00381: val_loss did not improve from 0.03039
#
# Epoch 00382: val_loss did not improve from 0.03039
#
# Epoch 00383: val_loss did not improve from 0.03039
#
# Epoch 00384: val_loss did not improve from 0.03039
#
# Epoch 00385: val_loss did not improve from 0.03039
#
# Epoch 00386: val_loss did not improve from 0.03039
#
# Epoch 00387: val_loss did not improve from 0.03039
#
# Epoch 00388: val_loss did not improve from 0.03039
#
# Epoch 00389: val_loss did not improve from 0.03039
#
# Epoch 00390: val_loss did not improve from 0.03039
#
# Epoch 00391: val_loss did not improve from 0.03039
#
# Epoch 00392: val_loss did not improve from 0.03039
#
# Epoch 00393: val_loss did not improve from 0.03039
#
# Epoch 00394: val_loss did not improve from 0.03039
#
# Epoch 00395: val_loss did not improve from 0.03039
#
# Epoch 00396: val_loss did not improve from 0.03039
#
# Epoch 00397: val_loss improved from 0.03039 to 0.03037, saving model to best_model_new_far_time.h5
#
# Epoch 00398: val_loss improved from 0.03037 to 0.03029, saving model to best_model_new_far_time.h5
#
# Epoch 00399: val_loss did not improve from 0.03029
#
# Epoch 00400: val_loss did not improve from 0.03029
#
# Epoch 00401: val_loss did not improve from 0.03029
#
# Epoch 00402: val_loss did not improve from 0.03029
#
# Epoch 00403: val_loss did not improve from 0.03029
#
# Epoch 00404: val_loss did not improve from 0.03029
#
# Epoch 00405: val_loss did not improve from 0.03029
#
# Epoch 00406: val_loss did not improve from 0.03029
#
# Epoch 00407: val_loss did not improve from 0.03029
#
# Epoch 00408: val_loss did not improve from 0.03029
#
# Epoch 00409: val_loss did not improve from 0.03029
# Epoch 00410: val_loss did not improve from 0.03029
#
# Epoch 00411: val_loss did not improve from 0.03029
#
# Epoch 00412: val_loss improved from 0.03029 to 0.03029, saving model to best_model_new_far_time.h5
#
# Epoch 00413: val_loss did not improve from 0.03029
#
# Epoch 00414: val_loss did not improve from 0.03029
#
# Epoch 00415: val_loss did not improve from 0.03029
#
# Epoch 00416: val_loss did not improve from 0.03029
#
# Epoch 00417: val_loss did not improve from 0.03029
#
# Epoch 00418: val_loss did not improve from 0.03029
#
# Epoch 00419: val_loss did not improve from 0.03029
#
# Epoch 00420: val_loss did not improve from 0.03029
#
# Epoch 00421: val_loss did not improve from 0.03029
#
# Epoch 00422: val_loss did not improve from 0.03029
#
# Epoch 00423: val_loss did not improve from 0.03029
#
# Epoch 00424: val_loss did not improve from 0.03029
#
# Epoch 00425: val_loss did not improve from 0.03029
#
# Epoch 00426: val_loss did not improve from 0.03029
#
# Epoch 00427: val_loss did not improve from 0.03029
#
# Epoch 00428: val_loss did not improve from 0.03029
#
# Epoch 00429: val_loss did not improve from 0.03029
#
# Epoch 00430: val_loss did not improve from 0.03029
#
# Epoch 00431: val_loss did not improve from 0.03029
#
# Epoch 00432: val_loss did not improve from 0.03029
#
# Epoch 00433: val_loss did not improve from 0.03029
#
# Epoch 00434: val_loss did not improve from 0.03029
#
# Epoch 00435: val_loss did not improve from 0.03029
#
# Epoch 00436: val_loss did not improve from 0.03029
#
# Epoch 00437: val_loss did not improve from 0.03029
#
# Epoch 00438: val_loss did not improve from 0.03029
#
# Epoch 00439: val_loss did not improve from 0.03029
#
# Epoch 00440: val_loss improved from 0.03029 to 0.03023, saving model to best_model_new_far_time.h5
#
# Epoch 00441: val_loss did not improve from 0.03023
#
# Epoch 00442: val_loss did not improve from 0.03023
#
# Epoch 00443: val_loss did not improve from 0.03023
#
# Epoch 00444: val_loss did not improve from 0.03023
#
# Epoch 00445: val_loss did not improve from 0.03023
#
# Epoch 00446: val_loss did not improve from 0.03023
#
# Epoch 00447: val_loss did not improve from 0.03023
#
# Epoch 00448: val_loss did not improve from 0.03023
#
# Epoch 00449: val_loss did not improve from 0.03023
#
# Epoch 00450: val_loss did not improve from 0.03023
#
# Epoch 00451: val_loss did not improve from 0.03023
#
# Epoch 00452: val_loss did not improve from 0.03023
#
# Epoch 00453: val_loss did not improve from 0.03023
#
# Epoch 00454: val_loss did not improve from 0.03023
#
# Epoch 00455: val_loss did not improve from 0.03023
#
# Epoch 00456: val_loss did not improve from 0.03023
#
# Epoch 00457: val_loss did not improve from 0.03023
#
# Epoch 00458: val_loss did not improve from 0.03023
#
# Epoch 00459: val_loss did not improve from 0.03023
#
# Epoch 00460: val_loss did not improve from 0.03023
#
# Epoch 00461: val_loss did not improve from 0.03023
#
# Epoch 00462: val_loss did not improve from 0.03023
#
# Epoch 00463: val_loss did not improve from 0.03023
#
# Epoch 00464: val_loss did not improve from 0.03023
#
# Epoch 00465: val_loss did not improve from 0.03023
#
# Epoch 00466: val_loss did not improve from 0.03023
#
# Epoch 00467: val_loss did not improve from 0.03023
#
# Epoch 00468: val_loss improved from 0.03023 to 0.03022, saving model to best_model_new_far_time.h5
#
# Epoch 00469: val_loss did not improve from 0.03022
#
# Epoch 00470: val_loss did not improve from 0.03022
#
# Epoch 00471: val_loss did not improve from 0.03022
#
# Epoch 00472: val_loss did not improve from 0.03022
#
# Epoch 00473: val_loss did not improve from 0.03022
#
# Epoch 00474: val_loss did not improve from 0.03022
#
# Epoch 00475: val_loss did not improve from 0.03022
#
# Epoch 00476: val_loss did not improve from 0.03022
#
# Epoch 00477: val_loss did not improve from 0.03022
#
# Epoch 00478: val_loss did not improve from 0.03022
#
# Epoch 00479: val_loss did not improve from 0.03022
#
# Epoch 00480: val_loss improved from 0.03022 to 0.03017, saving model to best_model_new_far_time.h5
#
# Epoch 00481: val_loss did not improve from 0.03017
#
# Epoch 00482: val_loss did not improve from 0.03017
#
# Epoch 00483: val_loss did not improve from 0.03017
#
# Epoch 00484: val_loss did not improve from 0.03017
#
# Epoch 00485: val_loss did not improve from 0.03017
#
# Epoch 00486: val_loss did not improve from 0.03017
#
# Epoch 00487: val_loss did not improve from 0.03017
#
# Epoch 00488: val_loss did not improve from 0.03017
#
# Epoch 00489: val_loss did not improve from 0.03017
#
# Epoch 00490: val_loss did not improve from 0.03017
#
# Epoch 00491: val_loss did not improve from 0.03017
#
# Epoch 00492: val_loss did not improve from 0.03017
#
# Epoch 00493: val_loss did not improve from 0.03017
#
# Epoch 00494: val_loss did not improve from 0.03017
#
# Epoch 00495: val_loss did not improve from 0.03017
#
# Epoch 00496: val_loss did not improve from 0.03017
#
# Epoch 00497: val_loss did not improve from 0.03017
#
# Epoch 00498: val_loss did not improve from 0.03017
#
# Epoch 00499: val_loss did not improve from 0.03017
#
# Epoch 00500: val_loss did not improve from 0.03017
#
# Epoch 00501: val_loss did not improve from 0.03017
#
# Epoch 00502: val_loss did not improve from 0.03017
#
# Epoch 00503: val_loss did not improve from 0.03017
#
# Epoch 00504: val_loss improved from 0.03017 to 0.03008, saving model to best_model_new_far_time.h5
#
# Epoch 00505: val_loss did not improve from 0.03008
#
# Epoch 00506: val_loss did not improve from 0.03008
#
# Epoch 00507: val_loss did not improve from 0.03008
#
# Epoch 00508: val_loss did not improve from 0.03008
#
# Epoch 00509: val_loss did not improve from 0.03008
#
# Epoch 00510: val_loss did not improve from 0.03008
#
# Epoch 00511: val_loss did not improve from 0.03008
#
# Epoch 00512: val_loss did not improve from 0.03008
#
# Epoch 00513: val_loss did not improve from 0.03008
#
# Epoch 00514: val_loss did not improve from 0.03008
#
# Epoch 00515: val_loss did not improve from 0.03008
#
# Epoch 00516: val_loss did not improve from 0.03008
#
# Epoch 00517: val_loss did not improve from 0.03008
#
# Epoch 00518: val_loss did not improve from 0.03008
#
# Epoch 00519: val_loss did not improve from 0.03008
#
# Epoch 00520: val_loss did not improve from 0.03008
#
# Epoch 00521: val_loss did not improve from 0.03008
#
# Epoch 00522: val_loss did not improve from 0.03008
#
# Epoch 00523: val_loss did not improve from 0.03008
#
# Epoch 00524: val_loss did not improve from 0.03008
#
# Epoch 00525: val_loss did not improve from 0.03008
#
# Epoch 00526: val_loss did not improve from 0.03008
#
# Epoch 00527: val_loss did not improve from 0.03008
#
# Epoch 00528: val_loss did not improve from 0.03008
#
# Epoch 00529: val_loss did not improve from 0.03008
#
# Epoch 00530: val_loss did not improve from 0.03008
#
# Epoch 00531: val_loss improved from 0.03008 to 0.03003, saving model to best_model_new_far_time.h5
#
# Epoch 00532: val_loss did not improve from 0.03003
#
# Epoch 00533: val_loss did not improve from 0.03003
#
# Epoch 00534: val_loss did not improve from 0.03003
#
# Epoch 00535: val_loss did not improve from 0.03003
#
# Epoch 00536: val_loss did not improve from 0.03003
#
# Epoch 00537: val_loss did not improve from 0.03003
#
# Epoch 00538: val_loss improved from 0.03003 to 0.03002, saving model to best_model_new_far_time.h5
#
# Epoch 00539: val_loss did not improve from 0.03002
#
# Epoch 00540: val_loss did not improve from 0.03002
#
# Epoch 00541: val_loss did not improve from 0.03002
#
# Epoch 00542: val_loss did not improve from 0.03002
#
# Epoch 00543: val_loss did not improve from 0.03002
#
# Epoch 00544: val_loss did not improve from 0.03002
#
# Epoch 00545: val_loss did not improve from 0.03002
#
# Epoch 00546: val_loss did not improve from 0.03002
#
# Epoch 00547: val_loss did not improve from 0.03002
#
# Epoch 00548: val_loss did not improve from 0.03002
#
# Epoch 00549: val_loss improved from 0.03002 to 0.03002, saving model to best_model_new_far_time.h5
#
# Epoch 00550: val_loss did not improve from 0.03002
#
# Epoch 00551: val_loss did not improve from 0.03002
#
# Epoch 00552: val_loss did not improve from 0.03002
#
# Epoch 00553: val_loss did not improve from 0.03002
#
# Epoch 00554: val_loss did not improve from 0.03002
#
# Epoch 00555: val_loss did not improve from 0.03002
#
# Epoch 00556: val_loss did not improve from 0.03002
#
# Epoch 00557: val_loss did not improve from 0.03002
#
# Epoch 00558: val_loss did not improve from 0.03002
#
# Epoch 00559: val_loss did not improve from 0.03002
#
# Epoch 00560: val_loss did not improve from 0.03002
# Epoch 00561: val_loss did not improve from 0.03002
#
# Epoch 00562: val_loss did not improve from 0.03002
#
# Epoch 00563: val_loss did not improve from 0.03002
#
# Epoch 00564: val_loss did not improve from 0.03002
#
# Epoch 00565: val_loss did not improve from 0.03002
#
# Epoch 00566: val_loss did not improve from 0.03002
#
# Epoch 00567: val_loss did not improve from 0.03002
#
# Epoch 00568: val_loss did not improve from 0.03002
#
# Epoch 00569: val_loss did not improve from 0.03002
#
# Epoch 00570: val_loss did not improve from 0.03002
#
# Epoch 00571: val_loss did not improve from 0.03002
#
# Epoch 00572: val_loss did not improve from 0.03002
#
# Epoch 00573: val_loss did not improve from 0.03002
#
# Epoch 00574: val_loss did not improve from 0.03002
#
# Epoch 00575: val_loss did not improve from 0.03002
#
# Epoch 00576: val_loss did not improve from 0.03002
#
# Epoch 00577: val_loss did not improve from 0.03002
#
# Epoch 00578: val_loss did not improve from 0.03002
#
# Epoch 00579: val_loss did not improve from 0.03002
#
# Epoch 00580: val_loss did not improve from 0.03002
#
# Epoch 00581: val_loss did not improve from 0.03002
#
# Epoch 00582: val_loss did not improve from 0.03002
#
# Epoch 00583: val_loss did not improve from 0.03002
#
# Epoch 00584: val_loss did not improve from 0.03002
#
# Epoch 00585: val_loss did not improve from 0.03002
#
# Epoch 00586: val_loss did not improve from 0.03002
#
# Epoch 00587: val_loss did not improve from 0.03002
#
# Epoch 00588: val_loss did not improve from 0.03002
#
# Epoch 00589: val_loss did not improve from 0.03002
#
# Epoch 00590: val_loss did not improve from 0.03002
#
# Epoch 00591: val_loss did not improve from 0.03002
#
# Epoch 00592: val_loss did not improve from 0.03002
#
# Epoch 00593: val_loss did not improve from 0.03002
#
# Epoch 00594: val_loss did not improve from 0.03002
#
# Epoch 00595: val_loss did not improve from 0.03002
#
# Epoch 00596: val_loss did not improve from 0.03002
#
# Epoch 00597: val_loss did not improve from 0.03002
#
# Epoch 00598: val_loss did not improve from 0.03002
#
# Epoch 00599: val_loss did not improve from 0.03002
#
# Epoch 00600: val_loss did not improve from 0.03002
#
# Epoch 00601: val_loss improved from 0.03002 to 0.02996, saving model to best_model_new_far_time.h5
#
# Epoch 00602: val_loss did not improve from 0.02996
#
# Epoch 00603: val_loss did not improve from 0.02996
#
# Epoch 00604: val_loss did not improve from 0.02996
#
# Epoch 00605: val_loss did not improve from 0.02996
#
# Epoch 00606: val_loss did not improve from 0.02996
#
# Epoch 00607: val_loss did not improve from 0.02996
#
# Epoch 00608: val_loss did not improve from 0.02996
#
# Epoch 00609: val_loss did not improve from 0.02996
#
# Epoch 00610: val_loss improved from 0.02996 to 0.02995, saving model to best_model_new_far_time.h5
#
# Epoch 00611: val_loss did not improve from 0.02995
#
# Epoch 00612: val_loss did not improve from 0.02995
#
# Epoch 00613: val_loss did not improve from 0.02995
#
# Epoch 00614: val_loss did not improve from 0.02995
#
# Epoch 00615: val_loss did not improve from 0.02995
#
# Epoch 00616: val_loss did not improve from 0.02995
#
# Epoch 00617: val_loss did not improve from 0.02995
#
# Epoch 00618: val_loss did not improve from 0.02995
#
# Epoch 00619: val_loss did not improve from 0.02995
#
# Epoch 00620: val_loss did not improve from 0.02995
#
# Epoch 00621: val_loss did not improve from 0.02995
#
# Epoch 00622: val_loss did not improve from 0.02995
#
# Epoch 00623: val_loss did not improve from 0.02995
#
# Epoch 00624: val_loss did not improve from 0.02995
#
# Epoch 00625: val_loss did not improve from 0.02995
#
# Epoch 00626: val_loss did not improve from 0.02995
#
# Epoch 00627: val_loss did not improve from 0.02995
#
# Epoch 00628: val_loss did not improve from 0.02995
#
# Epoch 00629: val_loss did not improve from 0.02995
#
# Epoch 00630: val_loss did not improve from 0.02995
#
# Epoch 00631: val_loss did not improve from 0.02995
#
# Epoch 00632: val_loss did not improve from 0.02995
#
# Epoch 00633: val_loss did not improve from 0.02995
#
# Epoch 00634: val_loss did not improve from 0.02995
#
# Epoch 00635: val_loss did not improve from 0.02995
#
# Epoch 00636: val_loss did not improve from 0.02995
#
# Epoch 00637: val_loss did not improve from 0.02995
#
# Epoch 00638: val_loss did not improve from 0.02995
#
# Epoch 00639: val_loss did not improve from 0.02995
#
# Epoch 00640: val_loss did not improve from 0.02995
#
# Epoch 00641: val_loss did not improve from 0.02995
#
# Epoch 00642: val_loss did not improve from 0.02995
#
# Epoch 00643: val_loss did not improve from 0.02995
#
# Epoch 00644: val_loss did not improve from 0.02995
#
# Epoch 00645: val_loss did not improve from 0.02995
#
# Epoch 00646: val_loss did not improve from 0.02995
#
# Epoch 00647: val_loss did not improve from 0.02995
#
# Epoch 00648: val_loss did not improve from 0.02995
#
# Epoch 00649: val_loss did not improve from 0.02995
#
# Epoch 00650: val_loss did not improve from 0.02995
#
# Epoch 00651: val_loss did not improve from 0.02995
#
# Epoch 00652: val_loss did not improve from 0.02995
#
# Epoch 00653: val_loss did not improve from 0.02995
#
# Epoch 00654: val_loss did not improve from 0.02995
#
# Epoch 00655: val_loss did not improve from 0.02995
#
# Epoch 00656: val_loss did not improve from 0.02995
#
# Epoch 00657: val_loss did not improve from 0.02995
#
# Epoch 00658: val_loss did not improve from 0.02995
#
# Epoch 00659: val_loss did not improve from 0.02995
#
# Epoch 00660: val_loss did not improve from 0.02995
#
# Epoch 00661: val_loss did not improve from 0.02995
#
# Epoch 00662: val_loss did not improve from 0.02995
#
# Epoch 00663: val_loss did not improve from 0.02995
#
# Epoch 00664: val_loss did not improve from 0.02995
#
# Epoch 00665: val_loss did not improve from 0.02995
#
# Epoch 00666: val_loss did not improve from 0.02995
#
# Epoch 00667: val_loss did not improve from 0.02995
#
# Epoch 00668: val_loss did not improve from 0.02995
#
# Epoch 00669: val_loss did not improve from 0.02995
#
# Epoch 00670: val_loss did not improve from 0.02995
#
# Epoch 00671: val_loss did not improve from 0.02995
#
# Epoch 00672: val_loss did not improve from 0.02995
#
# Epoch 00673: val_loss did not improve from 0.02995
#
# Epoch 00674: val_loss did not improve from 0.02995
#
# Epoch 00675: val_loss did not improve from 0.02995
#
# Epoch 00676: val_loss did not improve from 0.02995
#
# Epoch 00677: val_loss did not improve from 0.02995
#
# Epoch 00678: val_loss did not improve from 0.02995
#
# Epoch 00679: val_loss did not improve from 0.02995
#
# Epoch 00680: val_loss did not improve from 0.02995
#
# Epoch 00681: val_loss did not improve from 0.02995
#
# Epoch 00682: val_loss did not improve from 0.02995
#
# Epoch 00683: val_loss did not improve from 0.02995
#
# Epoch 00684: val_loss did not improve from 0.02995
#
# Epoch 00685: val_loss did not improve from 0.02995
#
# Epoch 00686: val_loss improved from 0.02995 to 0.02989, saving model to best_model_new_far_time.h5
#
# Epoch 00687: val_loss did not improve from 0.02989
#
# Epoch 00688: val_loss did not improve from 0.02989
#
# Epoch 00689: val_loss did not improve from 0.02989
#
# Epoch 00690: val_loss did not improve from 0.02989
#
# Epoch 00691: val_loss did not improve from 0.02989
#
# Epoch 00692: val_loss did not improve from 0.02989
#
# Epoch 00693: val_loss improved from 0.02989 to 0.02987, saving model to best_model_new_far_time.h5
#
# Epoch 00694: val_loss did not improve from 0.02987
#
# Epoch 00695: val_loss did not improve from 0.02987
#
# Epoch 00696: val_loss did not improve from 0.02987
#
# Epoch 00697: val_loss did not improve from 0.02987
#
# Epoch 00698: val_loss did not improve from 0.02987
#
# Epoch 00699: val_loss did not improve from 0.02987
#
# Epoch 00700: val_loss did not improve from 0.02987
#
# Epoch 00701: val_loss did not improve from 0.02987
#
# Epoch 00702: val_loss did not improve from 0.02987
#
# Epoch 00703: val_loss did not improve from 0.02987
#
# Epoch 00704: val_loss did not improve from 0.02987
#
# Epoch 00705: val_loss did not improve from 0.02987
#
# Epoch 00706: val_loss did not improve from 0.02987
#
# Epoch 00707: val_loss did not improve from 0.02987
#
# Epoch 00708: val_loss improved from 0.02987 to 0.02981, saving model to best_model_new_far_time.h5
#
# Epoch 00709: val_loss did not improve from 0.02981
#
# Epoch 00710: val_loss did not improve from 0.02981
#
# Epoch 00711: val_loss did not improve from 0.02981
#
# Epoch 00712: val_loss did not improve from 0.02981
#
# Epoch 00713: val_loss did not improve from 0.02981
# Epoch 00714: val_loss did not improve from 0.02981
#
# Epoch 00715: val_loss did not improve from 0.02981
#
# Epoch 00716: val_loss did not improve from 0.02981
#
# Epoch 00717: val_loss did not improve from 0.02981
#
# Epoch 00718: val_loss did not improve from 0.02981
#
# Epoch 00719: val_loss did not improve from 0.02981
#
# Epoch 00720: val_loss did not improve from 0.02981
#
# Epoch 00721: val_loss did not improve from 0.02981
#
# Epoch 00722: val_loss did not improve from 0.02981
#
# Epoch 00723: val_loss did not improve from 0.02981
#
# Epoch 00724: val_loss did not improve from 0.02981
#
# Epoch 00725: val_loss did not improve from 0.02981
#
# Epoch 00726: val_loss did not improve from 0.02981
#
# Epoch 00727: val_loss did not improve from 0.02981
#
# Epoch 00728: val_loss did not improve from 0.02981
#
# Epoch 00729: val_loss did not improve from 0.02981
#
# Epoch 00730: val_loss did not improve from 0.02981
#
# Epoch 00731: val_loss did not improve from 0.02981
#
# Epoch 00732: val_loss did not improve from 0.02981
#
# Epoch 00733: val_loss did not improve from 0.02981
#
# Epoch 00734: val_loss did not improve from 0.02981
#
# Epoch 00735: val_loss did not improve from 0.02981
#
# Epoch 00736: val_loss did not improve from 0.02981
#
# Epoch 00737: val_loss did not improve from 0.02981
#
# Epoch 00738: val_loss did not improve from 0.02981
#
# Epoch 00739: val_loss did not improve from 0.02981
#
# Epoch 00740: val_loss did not improve from 0.02981
#
# Epoch 00741: val_loss did not improve from 0.02981
#
# Epoch 00742: val_loss did not improve from 0.02981
#
# Epoch 00743: val_loss did not improve from 0.02981
#
# Epoch 00744: val_loss did not improve from 0.02981
#
# Epoch 00745: val_loss did not improve from 0.02981
#
# Epoch 00746: val_loss did not improve from 0.02981
#
# Epoch 00747: val_loss did not improve from 0.02981
#
# Epoch 00748: val_loss did not improve from 0.02981
#
# Epoch 00749: val_loss did not improve from 0.02981
#
# Epoch 00750: val_loss did not improve from 0.02981
#
# Epoch 00751: val_loss did not improve from 0.02981
#
# Epoch 00752: val_loss improved from 0.02981 to 0.02974, saving model to best_model_new_far_time.h5
#
# Epoch 00753: val_loss did not improve from 0.02974
#
# Epoch 00754: val_loss did not improve from 0.02974
#
# Epoch 00755: val_loss did not improve from 0.02974
#
# Epoch 00756: val_loss did not improve from 0.02974
#
# Epoch 00757: val_loss did not improve from 0.02974
#
# Epoch 00758: val_loss did not improve from 0.02974
#
# Epoch 00759: val_loss did not improve from 0.02974
#
# Epoch 00760: val_loss did not improve from 0.02974
#
# Epoch 00761: val_loss did not improve from 0.02974
#
# Epoch 00762: val_loss did not improve from 0.02974
#
# Epoch 00763: val_loss did not improve from 0.02974
#
# Epoch 00764: val_loss did not improve from 0.02974
#
# Epoch 00765: val_loss did not improve from 0.02974
#
# Epoch 00766: val_loss did not improve from 0.02974
#
# Epoch 00767: val_loss did not improve from 0.02974
#
# Epoch 00768: val_loss did not improve from 0.02974
#
# Epoch 00769: val_loss did not improve from 0.02974
#
# Epoch 00770: val_loss did not improve from 0.02974
#
# Epoch 00771: val_loss did not improve from 0.02974
#
# Epoch 00772: val_loss did not improve from 0.02974
#
# Epoch 00773: val_loss did not improve from 0.02974
#
# Epoch 00774: val_loss did not improve from 0.02974
#
# Epoch 00775: val_loss did not improve from 0.02974
#
# Epoch 00776: val_loss did not improve from 0.02974
#
# Epoch 00777: val_loss did not improve from 0.02974
#
# Epoch 00778: val_loss did not improve from 0.02974
#
# Epoch 00779: val_loss did not improve from 0.02974
#
# Epoch 00780: val_loss did not improve from 0.02974
#
# Epoch 00781: val_loss did not improve from 0.02974
#
# Epoch 00782: val_loss did not improve from 0.02974
#
# Epoch 00783: val_loss did not improve from 0.02974
#
# Epoch 00784: val_loss did not improve from 0.02974
#
# Epoch 00785: val_loss did not improve from 0.02974
#
# Epoch 00786: val_loss did not improve from 0.02974
#
# Epoch 00787: val_loss did not improve from 0.02974
#
# Epoch 00788: val_loss improved from 0.02974 to 0.02973, saving model to best_model_new_far_time.h5
#
# Epoch 00789: val_loss did not improve from 0.02973
#
# Epoch 00790: val_loss did not improve from 0.02973
#
# Epoch 00791: val_loss did not improve from 0.02973
#
# Epoch 00792: val_loss did not improve from 0.02973
#
# Epoch 00793: val_loss did not improve from 0.02973
#
# Epoch 00794: val_loss did not improve from 0.02973
#
# Epoch 00795: val_loss did not improve from 0.02973
#
# Epoch 00796: val_loss did not improve from 0.02973
#
# Epoch 00797: val_loss did not improve from 0.02973
#
# Epoch 00798: val_loss did not improve from 0.02973
#
# Epoch 00799: val_loss did not improve from 0.02973
#
# Epoch 00800: val_loss did not improve from 0.02973
#
# Epoch 00801: val_loss did not improve from 0.02973
#
# Epoch 00802: val_loss did not improve from 0.02973
#
# Epoch 00803: val_loss did not improve from 0.02973
#
# Epoch 00804: val_loss did not improve from 0.02973
#
# Epoch 00805: val_loss did not improve from 0.02973
#
# Epoch 00806: val_loss did not improve from 0.02973
#
# Epoch 00807: val_loss did not improve from 0.02973
#
# Epoch 00808: val_loss did not improve from 0.02973
#
# Epoch 00809: val_loss did not improve from 0.02973
#
# Epoch 00810: val_loss did not improve from 0.02973
#
# Epoch 00811: val_loss did not improve from 0.02973
#
# Epoch 00812: val_loss did not improve from 0.02973
#
# Epoch 00813: val_loss did not improve from 0.02973
#
# Epoch 00814: val_loss did not improve from 0.02973
#
# Epoch 00815: val_loss did not improve from 0.02973
#
# Epoch 00816: val_loss did not improve from 0.02973
#
# Epoch 00817: val_loss did not improve from 0.02973
#
# Epoch 00818: val_loss improved from 0.02973 to 0.02967, saving model to best_model_new_far_time.h5
#
# Epoch 00819: val_loss did not improve from 0.02967
#
# Epoch 00820: val_loss did not improve from 0.02967
#
# Epoch 00821: val_loss did not improve from 0.02967
#
# Epoch 00822: val_loss did not improve from 0.02967
#
# Epoch 00823: val_loss did not improve from 0.02967
#
# Epoch 00824: val_loss did not improve from 0.02967
#
# Epoch 00825: val_loss did not improve from 0.02967
#
# Epoch 00826: val_loss did not improve from 0.02967
#
# Epoch 00827: val_loss did not improve from 0.02967
#
# Epoch 00828: val_loss did not improve from 0.02967
#
# Epoch 00829: val_loss did not improve from 0.02967
#
# Epoch 00830: val_loss did not improve from 0.02967
#
# Epoch 00831: val_loss did not improve from 0.02967
#
# Epoch 00832: val_loss did not improve from 0.02967
#
# Epoch 00833: val_loss did not improve from 0.02967
#
# Epoch 00834: val_loss did not improve from 0.02967
#
# Epoch 00835: val_loss did not improve from 0.02967
#
# Epoch 00836: val_loss did not improve from 0.02967
#
# Epoch 00837: val_loss did not improve from 0.02967
#
# Epoch 00838: val_loss did not improve from 0.02967
#
# Epoch 00839: val_loss did not improve from 0.02967
#
# Epoch 00840: val_loss did not improve from 0.02967
#
# Epoch 00841: val_loss did not improve from 0.02967
#
# Epoch 00842: val_loss did not improve from 0.02967
#
# Epoch 00843: val_loss did not improve from 0.02967
#
# Epoch 00844: val_loss did not improve from 0.02967
#
# Epoch 00845: val_loss did not improve from 0.02967
#
# Epoch 00846: val_loss did not improve from 0.02967
#
# Epoch 00847: val_loss did not improve from 0.02967
#
# Epoch 00848: val_loss did not improve from 0.02967
#
# Epoch 00849: val_loss did not improve from 0.02967
#
# Epoch 00850: val_loss did not improve from 0.02967
#
# Epoch 00851: val_loss did not improve from 0.02967
#
# Epoch 00852: val_loss did not improve from 0.02967
#
# Epoch 00853: val_loss did not improve from 0.02967
#
# Epoch 00854: val_loss did not improve from 0.02967
#
# Epoch 00855: val_loss did not improve from 0.02967
#
# Epoch 00856: val_loss did not improve from 0.02967
#
# Epoch 00857: val_loss did not improve from 0.02967
#
# Epoch 00858: val_loss did not improve from 0.02967
#
# Epoch 00859: val_loss did not improve from 0.02967
#
# Epoch 00860: val_loss did not improve from 0.02967
#
# Epoch 00861: val_loss did not improve from 0.02967
#
# Epoch 00862: val_loss did not improve from 0.02967
#
# Epoch 00863: val_loss did not improve from 0.02967
#
# Epoch 00864: val_loss did not improve from 0.02967
#
# Epoch 00865: val_loss did not improve from 0.02967
#
# Epoch 00866: val_loss did not improve from 0.02967
#
# Epoch 00867: val_loss did not improve from 0.02967
#
# Epoch 00868: val_loss did not improve from 0.02967
# Epoch 00869: val_loss did not improve from 0.02967
#
# Epoch 00870: val_loss did not improve from 0.02967
#
# Epoch 00871: val_loss did not improve from 0.02967
#
# Epoch 00872: val_loss did not improve from 0.02967
#
# Epoch 00873: val_loss did not improve from 0.02967
#
# Epoch 00874: val_loss did not improve from 0.02967
#
# Epoch 00875: val_loss did not improve from 0.02967
#
# Epoch 00876: val_loss did not improve from 0.02967
#
# Epoch 00877: val_loss did not improve from 0.02967
#
# Epoch 00878: val_loss did not improve from 0.02967
#
# Epoch 00879: val_loss did not improve from 0.02967
#
# Epoch 00880: val_loss did not improve from 0.02967
#
# Epoch 00881: val_loss did not improve from 0.02967
#
# Epoch 00882: val_loss did not improve from 0.02967
#
# Epoch 00883: val_loss did not improve from 0.02967
#
# Epoch 00884: val_loss did not improve from 0.02967
#
# Epoch 00885: val_loss did not improve from 0.02967
#
# Epoch 00886: val_loss did not improve from 0.02967
#
# Epoch 00887: val_loss did not improve from 0.02967
#
# Epoch 00888: val_loss did not improve from 0.02967
#
# Epoch 00889: val_loss did not improve from 0.02967
#
# Epoch 00890: val_loss improved from 0.02967 to 0.02963, saving model to best_model_new_far_time.h5
#
# Epoch 00891: val_loss did not improve from 0.02963
#
# Epoch 00892: val_loss did not improve from 0.02963
#
# Epoch 00893: val_loss did not improve from 0.02963
#
# Epoch 00894: val_loss did not improve from 0.02963
#
# Epoch 00895: val_loss did not improve from 0.02963
#
# Epoch 00896: val_loss did not improve from 0.02963
#
# Epoch 00897: val_loss did not improve from 0.02963
#
# Epoch 00898: val_loss did not improve from 0.02963
#
# Epoch 00899: val_loss did not improve from 0.02963
#
# Epoch 00900: val_loss did not improve from 0.02963
#
# Epoch 00901: val_loss did not improve from 0.02963
#
# Epoch 00902: val_loss did not improve from 0.02963
#
# Epoch 00903: val_loss did not improve from 0.02963
#
# Epoch 00904: val_loss did not improve from 0.02963
#
# Epoch 00905: val_loss did not improve from 0.02963
#
# Epoch 00906: val_loss did not improve from 0.02963
#
# Epoch 00907: val_loss did not improve from 0.02963
#
# Epoch 00908: val_loss did not improve from 0.02963
#
# Epoch 00909: val_loss did not improve from 0.02963
#
# Epoch 00910: val_loss did not improve from 0.02963
#
# Epoch 00911: val_loss did not improve from 0.02963
#
# Epoch 00912: val_loss did not improve from 0.02963
#
# Epoch 00913: val_loss did not improve from 0.02963
#
# Epoch 00914: val_loss did not improve from 0.02963
#
# Epoch 00915: val_loss did not improve from 0.02963
#
# Epoch 00916: val_loss did not improve from 0.02963
#
# Epoch 00917: val_loss did not improve from 0.02963
#
# Epoch 00918: val_loss did not improve from 0.02963
#
# Epoch 00919: val_loss did not improve from 0.02963
#
# Epoch 00920: val_loss did not improve from 0.02963
#
# Epoch 00921: val_loss did not improve from 0.02963
#
# Epoch 00922: val_loss did not improve from 0.02963
#
# Epoch 00923: val_loss did not improve from 0.02963
#
# Epoch 00924: val_loss did not improve from 0.02963
#
# Epoch 00925: val_loss did not improve from 0.02963
#
# Epoch 00926: val_loss did not improve from 0.02963
#
# Epoch 00927: val_loss did not improve from 0.02963
#
# Epoch 00928: val_loss did not improve from 0.02963
#
# Epoch 00929: val_loss did not improve from 0.02963
#
# Epoch 00930: val_loss did not improve from 0.02963
#
# Epoch 00931: val_loss did not improve from 0.02963
#
# Epoch 00932: val_loss did not improve from 0.02963
#
# Epoch 00933: val_loss did not improve from 0.02963
#
# Epoch 00934: val_loss did not improve from 0.02963
#
# Epoch 00935: val_loss did not improve from 0.02963
#
# Epoch 00936: val_loss did not improve from 0.02963
#
# Epoch 00937: val_loss did not improve from 0.02963
#
# Epoch 00938: val_loss did not improve from 0.02963
#
# Epoch 00939: val_loss did not improve from 0.02963
#
# Epoch 00940: val_loss did not improve from 0.02963
#
# Epoch 00941: val_loss did not improve from 0.02963
#
# Epoch 00942: val_loss did not improve from 0.02963
#
# Epoch 00943: val_loss did not improve from 0.02963
#
# Epoch 00944: val_loss did not improve from 0.02963
#
# Epoch 00945: val_loss did not improve from 0.02963
#
# Epoch 00946: val_loss did not improve from 0.02963
#
# Epoch 00947: val_loss did not improve from 0.02963
#
# Epoch 00948: val_loss did not improve from 0.02963
#
# Epoch 00949: val_loss did not improve from 0.02963
#
# Epoch 00950: val_loss did not improve from 0.02963
#
# Epoch 00951: val_loss did not improve from 0.02963
#
# Epoch 00952: val_loss did not improve from 0.02963
#
# Epoch 00953: val_loss did not improve from 0.02963
#
# Epoch 00954: val_loss did not improve from 0.02963
#
# Epoch 00955: val_loss did not improve from 0.02963
#
# Epoch 00956: val_loss did not improve from 0.02963
#
# Epoch 00957: val_loss did not improve from 0.02963
#
# Epoch 00958: val_loss did not improve from 0.02963
#
# Epoch 00959: val_loss did not improve from 0.02963
#
# Epoch 00960: val_loss did not improve from 0.02963
#
# Epoch 00961: val_loss did not improve from 0.02963
#
# Epoch 00962: val_loss did not improve from 0.02963
#
# Epoch 00963: val_loss did not improve from 0.02963
#
# Epoch 00964: val_loss did not improve from 0.02963
#
# Epoch 00965: val_loss did not improve from 0.02963
#
# Epoch 00966: val_loss did not improve from 0.02963
#
# Epoch 00967: val_loss did not improve from 0.02963
#
# Epoch 00968: val_loss did not improve from 0.02963
#
# Epoch 00969: val_loss did not improve from 0.02963
#
# Epoch 00970: val_loss did not improve from 0.02963
#
# Epoch 00971: val_loss did not improve from 0.02963
#
# Epoch 00972: val_loss did not improve from 0.02963
#
# Epoch 00973: val_loss did not improve from 0.02963
#
# Epoch 00974: val_loss did not improve from 0.02963
#
# Epoch 00975: val_loss did not improve from 0.02963
#
# Epoch 00976: val_loss did not improve from 0.02963
#
# Epoch 00977: val_loss did not improve from 0.02963
#
# Epoch 00978: val_loss did not improve from 0.02963
#
# Epoch 00979: val_loss did not improve from 0.02963
#
# Epoch 00980: val_loss did not improve from 0.02963
#
# Epoch 00981: val_loss did not improve from 0.02963
#
# Epoch 00982: val_loss did not improve from 0.02963
#
# Epoch 00983: val_loss did not improve from 0.02963
#
# Epoch 00984: val_loss did not improve from 0.02963
#
# Epoch 00985: val_loss did not improve from 0.02963
#
# Epoch 00986: val_loss did not improve from 0.02963
#
# Epoch 00987: val_loss did not improve from 0.02963
#
# Epoch 00988: val_loss did not improve from 0.02963
#
# Epoch 00989: val_loss did not improve from 0.02963
#
# Epoch 00990: val_loss did not improve from 0.02963
# Epoch 00990: early stopping
# 563.1067368984222

# %%
# load the saved model
PetroModel = load_model('best_model_new_far.h5')
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
# Testing and evaluating the model
preds = PetroModel.evaluate(X_test_petro, Y_test_petro_norm, batch_size=32, verbose=0, sample_weight=None)
print()
print ("Loss = " + str(preds))
# print ("Test Accuracy = " + str(preds[1]))
# Out:
# Loss = 0.029811111196875573

# %%
# Plotting the learning curve 
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.plot(history.history['loss']/np.max(history.history['loss']))
plt.plot(history.history['val_loss']/np.max(history.history['val_loss']))
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])


plt.title('Learning curve')
# plt.ylabel('Error/Accuracy')
plt.ylabel('Normalized Error')
plt.xlabel('epochs')
plt.legend(['train loss', 'validation loss'], loc='upper right')
# plt.savefig('/Figures/learning_curve_08Nov.png', bbox_inches='tight')

# %%
# Predict training and test data using the trained network
test_output_petro_norm = PetroModel.predict(X_test_petro)
train_output_petro_norm = PetroModel.predict(X_train_petro)

# Initialization
train_output_petro = np.zeros(train_output_petro_norm.shape)
test_output_petro = np.zeros(test_output_petro_norm.shape)
Y_train_petro = np.zeros(Y_train_petro_norm.shape)
Y_test_petro = np.zeros(Y_test_petro_norm.shape)

# Back transforming porosity to unnormalized values 
train_output_petro[:,0,:] = train_output_petro_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)
test_output_petro[:,0,:] = test_output_petro_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)

train_output_petro[:,1,:] = train_output_petro_norm[:,1,:]
test_output_petro[:,1,:] = test_output_petro_norm[:,1,:]

Y_train_petro[:,0,:] = Y_train_petro_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)
Y_test_petro[:,0,:] = Y_test_petro_norm[:,0,:]*(np.max(porosity) - np.min(porosity)) + np.min(porosity)

Y_train_petro[:,1,:] = Y_train_petro_norm[:,1,:]
Y_test_petro[:,1,:] = Y_test_petro_norm[:,1,:]

# %%
# RMSE with respect to mean 
rmse_train = np.sqrt(np.mean(((train_output_petro - Y_train_petro)**2).mean(axis=2), axis = 0))/np.mean(np.mean(Y_train_petro, axis = 0), axis=1)
rmse_test = np.sqrt(np.mean(((test_output_petro - Y_test_petro)**2).mean(axis=2), axis = 0))/np.mean(np.mean(Y_test_petro, axis = 0), axis=1)

print("Training error = ", rmse_train)
print("Test error = ", rmse_test)
# Out:
# Training error =  [0.17052618 0.30260018]
# Test error =  [0.19341821 0.3788528 ]

# %%
# Checking training data

sample_number = 25
f, axarr = plt.subplots(1, 2, sharey = True, figsize=(6,8))

axarr[0].plot(train_output_petro[sample_number, 0, :], depth, '-k', label='predicted', linewidth=3)
axarr[0].plot(Y_train_petro[sample_number, 0, :], depth, '--r', label='true', linewidth=3)
axarr[0].set_xlabel("Porosity [V/V]")
axarr[0].set_ylabel("Depth [meters]")
axarr[0].invert_yaxis()
axarr[0].set_xlim(0,0.4)
axarr[0].set_ylim(0,200)
axarr[0].legend(fontsize = 'small')

axarr[1].plot(train_output_petro[sample_number, 1, :], depth, '-k', linewidth=3)
axarr[1].plot(Y_train_petro[sample_number, 1, :], depth, '--r', linewidth=3)
axarr[1].set_xlabel("Vclay [V/V]")
# axarr[1].set_ylabel("Depth [meters]")
axarr[1].invert_yaxis()
axarr[1].set_xlim(0,1)

# axarr[2].plot(train_output_petro[sample_number, 2, :], depth, '-k')
# axarr[2].plot(Y_train_petro[sample_number, 2, :], depth, '--r')
# axarr[2].set_xlabel("Sw")
# axarr[2].set_ylabel("Depth")
# axarr[2].invert_yaxis()
# axarr[2].set_xlim(0,1)

# axarr[2].plot(train_output_petro_norm[sample_number, 0, :], depth, '-k')
# axarr[2].plot(Y_train_petro_norm[sample_number, 0, :], depth, '--r')
# axarr[2].set_xlabel("Norm_Poro")
# axarr[2].set_ylabel("Depth")
# axarr[2].invert_yaxis()
# axarr[2].set_xlim(0,1)
# Out:
# (0, 1)

# %%
# Checking testing data

sample_number = 12
f, axarr = plt.subplots(1, 2, sharey = True, figsize=(6,8))

axarr[0].plot(test_output_petro[sample_number, 0, :], depth, '-k', label='predicted', linewidth=3)
axarr[0].plot(Y_test_petro[sample_number, 0, :], depth, '--r', label='true', linewidth=3)
axarr[0].set_xlabel("Porosity [V/V]")
axarr[0].set_ylabel("Depth [meters]")
axarr[0].invert_yaxis()
axarr[0].set_xlim(0,0.4)
axarr[0].set_ylim(0,200)
axarr[0].legend(fontsize = 'small')

axarr[1].plot(test_output_petro[sample_number, 1, :], depth, '-k', linewidth=3)
axarr[1].plot(Y_test_petro[sample_number, 1, :], depth, '--r', linewidth=3)
axarr[1].set_xlabel("Vclay [V/V]")
# axarr[1].set_ylabel("Depth")
axarr[1].invert_yaxis()
axarr[1].set_xlim(0,1)

# axarr[2].plot(test_output_petro[sample_number, 2, :], depth, '-k')
# axarr[2].plot(Y_test_petro[sample_number, 2, :], depth, '--r')
# axarr[2].set_xlabel("Sw")
# axarr[2].set_ylabel("Depth")
# axarr[2].invert_yaxis()
# axarr[2].set_xlim(0,1)

# axarr[2].plot(test_output_petro_norm[sample_number, 0, :], depth, '-k')
# axarr[2].plot(Y_test_petro_norm[sample_number, 0, :], depth, '--r')
# axarr[2].set_xlabel("Norm_Poro")
# axarr[2].set_ylabel("Depth")
# axarr[2].invert_yaxis()
# axarr[2].set_xlim(0,1)
# Out:
# (0, 1)

# %%
# Correlation coefficient between true and predicted traces 

Porosity_corr_train = np.zeros(train_output_petro.shape[0])
Vclay_corr_train = np.zeros(train_output_petro.shape[0])
# Sw_corr_train = np.zeros(train_output_petro.shape[0])
for i in range(train_output_petro.shape[0]):
    Porosity_corr_train[i] = np.corrcoef(train_output_petro[i,0,:], Y_train_petro[i,0,:])[0,1]
    Vclay_corr_train[i] = np.corrcoef(train_output_petro[i,1,:], Y_train_petro[i,1,:])[0,1]
#     Sw_corr_train[i] = np.corrcoef(train_output_petro[i,2,:], Y_train_petro[i,2,:])[0,1]
    
Porosity_corr_test = np.zeros(test_output_petro.shape[0])
Vclay_corr_test = np.zeros(test_output_petro.shape[0])
Sw_corr_test = np.zeros(test_output_petro.shape[0])
for i in range(test_output_petro.shape[0]):
    Porosity_corr_test[i] = np.corrcoef(test_output_petro[i,0,:], Y_test_petro[i,0,:])[0,1]
    Vclay_corr_test[i] = np.corrcoef(test_output_petro[i,1,:], Y_test_petro[i,1,:])[0,1]
#     Sw_corr_test[i] = np.corrcoef(test_output_petro[i,2,:], Y_test_petro[i,2,:])[0,1]

    
# Average correlation coefficient
print("Average correlation in porosity for training data = ", np.mean(Porosity_corr_train))
print("Average correlation in Vclay for training data = ", np.mean(Vclay_corr_train))
print("Median correlation in porosity for training data = ", np.median(Porosity_corr_train))
print("Median correlation in Vclay for training data = ", np.median(Vclay_corr_train))
# print("Average correlation in Sw for training data = ", np.mean(Sw_corr_train))

print("Average correlation in porosity for test data = ", np.mean(Porosity_corr_test))
print("Average correlation in Vclay for test data = ", np.mean(Vclay_corr_test))
print("Median correlation in porosity for test data = ", np.median(Porosity_corr_test))
print("Median correlation in Vclay for test data = ", np.median(Vclay_corr_test))
# print("Average correlation in Sw for test data = ", np.mean(Sw_corr_test))
# Out:
# Average correlation in porosity for training data =  0.6918245671591681
# Average correlation in Vclay for training data =  0.8030678810321689
# Median correlation in porosity for training data =  0.7021643913492763
# Median correlation in Vclay for training data =  0.8127388641207649
# Average correlation in porosity for test data =  0.6284633994819817
# Average correlation in Vclay for test data =  0.7427623625755296
# Median correlation in porosity for test data =  0.642015958862853
# Median correlation in Vclay for test data =  0.7644949185399394

# %%
# Box plot of correlation coefficients 

from pylab import plot, show, savefig, xlim, figure, \
                hold, ylim, legend, boxplot, setp, axes

# function for setting the colors of the box plots pairs
def setBoxColors(bp):
    setp(bp['boxes'][0], color='blue')
    setp(bp['caps'][0], color='blue')
    setp(bp['caps'][1], color='blue')
    setp(bp['whiskers'][0], color='blue')
    setp(bp['whiskers'][1], color='blue')
#     setp(bp['fliers'][0], color='blue')
#     setp(bp['fliers'][1], color='blue')
    setp(bp['medians'][0], color='blue')

    setp(bp['boxes'][1], color='red')
    setp(bp['caps'][2], color='red')
    setp(bp['caps'][3], color='red')
    setp(bp['whiskers'][2], color='red')
    setp(bp['whiskers'][3], color='red')
#     setp(bp['fliers'][2], color='red')
#     setp(bp['fliers'][3], color='red')
    setp(bp['medians'][1], color='red')

# Some fake data to plot
A= [Porosity_corr_train, Porosity_corr_test]
B = [Vclay_corr_train, Vclay_corr_test]
# C = [Sw_corr_train, Sw_corr_test]

fig = figure()
ax = axes()

# first boxplot pair
bp = boxplot(A, positions = [1, 2], widths = 0.6, showfliers=False)
setBoxColors(bp)

# second boxplot pair
bp = boxplot(B, positions = [4, 5], widths = 0.6, showfliers=False)
setBoxColors(bp)

# thrid boxplot pair
# bp = boxplot(C, positions = [7, 8], widths = 0.6, showfliers=False)
# setBoxColors(bp)

# set axes limits and labels
# xlim(0,9)
xlim(0,6)
ylim(0,1)
# ax.set_xticklabels(['Porosity', 'Vclay', 'Sw'])
ax.set_xticklabels(['Porosity', 'Vclay'])
# ax.set_xticks([1.5, 4.5, 7.5])
ax.set_xticks([1.5, 4.5])
plt.ylabel('Correlation coefficient')

# draw temporary red and blue lines and use them to create a legend
hB, = plot([1,1],'b-')
hR, = plot([1,1],'r-')
legend((hB, hR),('Training', 'Test'), loc='lower left')
hB.set_visible(False)
hR.set_visible(False)

# %%
# Histogram plot for true vs predicted values
for i in np.arange(0,train_output_petro.shape[0],100):
    plt.hist(Y_train_petro[i,0,:], histtype='step', color='black')
    plt.hist(train_output_petro[i,0,:], histtype='step', color='red')
    plt.xlabel('Porosity')
    plt.ylabel('Frequency')
    plt.title('Training examples')

# %%
# Histogram plot for true vs predicted values
for i in np.arange(0,train_output_petro.shape[0],100):
    plt.hist(Y_train_petro[i,1,:], histtype='step', color='black')
    plt.hist(train_output_petro[i,1,:], histtype='step', color='red')
    plt.xlabel('Vclay')
    plt.ylabel('Frequency')
    plt.title('Training examples')

# %%
# Histogram plot for true vs predicted values
for i in np.arange(0,train_output_petro.shape[0],100):
    plt.hist(Y_train_petro[i,2,:], histtype='step', color='black')
    plt.hist(train_output_petro[i,2,:], histtype='step', color='red')
    plt.xlabel('Sw')
    plt.ylabel('Frequency')
    plt.title('Training examples')

# %%
for i in range(test_output_petro.shape[0]):
    plt.hist(Y_test_petro[i,0,:], histtype='step', color='black')
    plt.hist(test_output_petro[i,0,:], histtype='step', color='red')
    plt.xlabel('Porosity')
    plt.ylabel('Frequency')
    plt.title('Test examples')

# %%
# Density estimate for true vs predicted (test example) Porosity

import seaborn as sns

sample_number = 12
sns.kdeplot(test_output_petro[sample_number,0,:],  
             color='black', label='Predicted', linewidth=3,
            bw=0.01,
             clip=(np.min(test_output_petro[sample_number,0,:]), np.max(test_output_petro[sample_number,0,:])))
sns.kdeplot(Y_test_petro[sample_number,0,:],  
             color='red', label='True', linewidth=3,
            bw=0.01,
             clip=(np.min(Y_test_petro[sample_number,0,:]), np.max(Y_test_petro[sample_number,0,:])))
plt.xlabel('Porosity [V/V]')
plt.ylabel('Density')
plt.title('Test example')
plt.legend()

# %%
# Density estimate for true vs predicted (test example) Vclay

sample_number = 12

sns.kdeplot(test_output_petro[sample_number,1,:],  
             color='black', label='Predicted', linewidth=3,
             bw=0.04,
           clip=(np.min(test_output_petro[sample_number,1,:]), np.max(test_output_petro[sample_number,1,:])))
sns.kdeplot(Y_test_petro[sample_number,1,:],  
             color='red', label='True', linewidth=3,
            bw=0.04,
             clip=(np.min(Y_test_petro[sample_number,1,:]), np.max(Y_test_petro[sample_number,1,:])))
plt.xlabel('Vclay [V/V]')
plt.ylabel('Density')
plt.title('Test example')
plt.legend()
plt.xlim(-0.1,1.1)
# Out:
# (-0.1, 1.1)

# %%
# Density estimate for true vs predicted (test example) Water saturation 

sample_number = 12

sns.kdeplot(test_output_petro[sample_number,2,:],  
             color='red', label='Predicted', linewidth=3,
             bw=0.04,
           clip=(np.min(test_output_petro[sample_number,2,:]), np.max(test_output_petro[sample_number,2,:])))
sns.kdeplot(Y_test_petro[sample_number,2,:],  
             color='black', label='True', linewidth=3,
            bw=0.04,
             clip=(np.min(Y_test_petro[sample_number,2,:]), np.max(Y_test_petro[sample_number,2,:])))
plt.xlabel('Sw')
plt.ylabel('Density')
plt.title('Test example')
plt.legend()
plt.xlim(-0.1,1.1)

# %%
for i in range(test_output_petro.shape[0]):
    plt.hist(Y_test_petro[i,1,:], histtype='step', color='black')
    plt.hist(test_output_petro[i,1,:], histtype='step', color='red')
    plt.xlabel('Vclay')
    plt.ylabel('Frequency')
    plt.title('Test examples')

# %%
for i in range(test_output_petro.shape[0]):
    plt.hist(Y_test_petro[i,2,:], histtype='step', color='black')
    plt.hist(test_output_petro[i,2,:], histtype='step', color='red')
    plt.xlabel('Sw')
    plt.ylabel('Frequency')
    plt.title('Test examples')

# %%
# Compute variograms for true and predicted data

from gstools import vario_estimate_unstructured, Spherical
from gstools.covmodel.plot import plot_variogram

# estimate the variogram of the field with 40 bins
bins = np.arange(50)

sample_number = 25
bin_center, gamma = vario_estimate_unstructured(depth.T, Y_train_petro[sample_number,0,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="black")
plt.xlabel('Distance/ Lag')
plt.ylabel('Normalized semi-variance')
plt.title('Training dataset (Porosity)')
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
    
bin_center, gamma = vario_estimate_unstructured(depth.T, train_output_petro[sample_number,0,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="red")
plt.gca().legend(('True','Predicted'))
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])

# %%
# Compute variograms for true and predicted data

from gstools import vario_estimate_unstructured, Spherical
from gstools.covmodel.plot import plot_variogram

# estimate the variogram of the field with 40 bins
bins = np.arange(50)

sample_number = 25
bin_center, gamma = vario_estimate_unstructured(depth.T, Y_train_petro[sample_number,1,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="black")
plt.xlabel('Distance/ Lag')
plt.ylabel('Normalized semi-variance')
plt.title('Training dataset (Vclay)')
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
    
bin_center, gamma = vario_estimate_unstructured(depth.T, train_output_petro[sample_number,1,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="red")
plt.gca().legend(('True','Predicted'))
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])

# %%
# Compute variograms for true and predicted data

from gstools import vario_estimate_unstructured, Spherical
from gstools.covmodel.plot import plot_variogram

# estimate the variogram of the field with 40 bins
bins = np.arange(50)

sample_number = 25
bin_center, gamma = vario_estimate_unstructured(depth.T, Y_train_petro[sample_number,2,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="black")
plt.xlabel('Distance/ Lag')
plt.ylabel('Normalized semi-variance')
plt.title('Training dataset (Sw)')
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
    
bin_center, gamma = vario_estimate_unstructured(depth.T, train_output_petro[sample_number,2,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="red")
plt.gca().legend(('True','Predicted'))
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])

# %%
# Compute variograms for true and predicted data

from gstools import vario_estimate_unstructured, Spherical
from gstools.covmodel.plot import plot_variogram

# estimate the variogram of the field with 40 bins
bins = np.arange(50)

sample_number = 12
bin_center, gamma = vario_estimate_unstructured(depth.T, Y_test_petro[sample_number,0,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="red",linewidth=3)
plt.xlabel('Distance/ Lag')
plt.ylabel('Normalized semi-variance')
plt.title('Test dataset (Porosity)')
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
    
bin_center, gamma = vario_estimate_unstructured(depth.T, test_output_petro[sample_number,0,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="black",linewidth=3)
plt.gca().legend(('True','Predicted'))
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
# Out:
# ({'var': 0.0012858600288278828,
#   'len_scale': 21.653115527199805,
#   'nugget': 4.6859511462637324e-30},
#  array([[ 1.65225022e-08, -1.42258073e-04, -1.51855140e-08],
#         [-1.42258073e-04,  7.43312262e+00,  1.91844479e-04],
#         [-1.51855140e-08,  1.91844479e-04,  1.56151202e-08]]))

# %%
# Compute variograms for true and predicted data

from gstools import vario_estimate_unstructured, Spherical
from gstools.covmodel.plot import plot_variogram

# estimate the variogram of the field with 40 bins
bins = np.arange(50)

sample_number = 12
bin_center, gamma = vario_estimate_unstructured(depth.T, Y_test_petro[sample_number,1,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="red",linewidth=3)
plt.xlabel('Distance/ Lag')
plt.ylabel('Normalized semi-variance')
plt.title('Test dataset (Vclay)')
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
    
bin_center, gamma = vario_estimate_unstructured(depth.T, test_output_petro[sample_number,1,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="black",linewidth=3)
plt.gca().legend(('True','Predicted'))
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
# Out:
# ({'var': 0.05740237589704929,
#   'len_scale': 22.067884867093987,
#   'nugget': 1.4873531634828614e-35},
#  array([[ 3.51739253e-05, -6.83927819e-03, -3.22430058e-05],
#         [-6.83927819e-03,  8.28904383e+00,  9.32959435e-03],
#         [-3.22430058e-05,  9.32959435e-03,  3.31917692e-05]]))

# %%
# Compute variograms for true and predicted data

from gstools import vario_estimate_unstructured, Spherical
from gstools.covmodel.plot import plot_variogram

# estimate the variogram of the field with 40 bins
bins = np.arange(50)

sample_number = 12
bin_center, gamma = vario_estimate_unstructured(depth.T, Y_test_petro[sample_number,1,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="black")
plt.xlabel('Distance/ Lag')
plt.ylabel('Normalized semi-variance')
plt.title('Test dataset (Sw)')
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])
    
bin_center, gamma = vario_estimate_unstructured(depth.T, test_output_petro[sample_number,1,:], bins)
plt.plot(bin_center, gamma/np.max(gamma), color="red")
plt.gca().legend(('True','Predicted'))
# fit the variogram with a stable model. (no nugget fitted)
fit_model = Spherical(dim=1)
fit_model.fit_variogram(bin_center, gamma, nugget=True)
# plot_variogram(fit_model, x_max=bins[-1])

# %%
# Spectral coherence between true and predicted 

sample_number = 25
plt.cohere(Y_train_petro[sample_number,0,:], train_output_petro[sample_number,0,:], NFFT=16, Fs=1, color="blue")
plt.cohere(Y_train_petro[sample_number,1,:], train_output_petro[sample_number,1,:], NFFT=16, Fs=1, color="red") 
# plt.cohere(Y_train_petro[sample_number,2,:], train_output_petro[sample_number,2,:], NFFT=16, Fs=1, color="black")


# plt.gca().legend(('Porosity','Vclay', 'Sw'))
plt.gca().legend(('Porosity','Vclay'))
plt.xlabel('Wavenumber')
plt.ylabel('Coherence')
plt.title('Training example')
plt.grid(b=False)

# %%
# Spectral coherence between true and predicted (training data)

sample_number = 25
Cxy_poro, wavenumber_poro = plt.cohere(Y_train_petro[sample_number,0,:], train_output_petro[sample_number,0,:], NFFT=16, Fs=1, color="blue")
Cxy_vclay, wavenumber_vclay = plt.cohere(Y_train_petro[sample_number,1,:], train_output_petro[sample_number,1,:], NFFT=16, Fs=1, color="red") 
# Cxy_sw, wavenumber_sw = plt.cohere(Y_test_petro[sample_number,2,:], test_output_petro[sample_number,2,:], NFFT=16, Fs=1, color="black")

# Adding epsilon to the first wavenumber value
wavenumber_poro[0] = wavenumber_poro[0] + 0.001
wavenumber_vclay[0] = wavenumber_vclay[0] + 0.001
# wavenumber_sw[0] = wavenumber_sw[0] + 0.001

plt.plot(1/wavenumber_poro, Cxy_poro, color="blue", linewidth=3)
plt.plot(1/wavenumber_vclay, Cxy_vclay, color="red", linewidth=3)
# plt.plot(1/wavenumber_sw, Cxy_sw, color="black")

plt.xlim(100,2)
plt.gca().invert_xaxis()
plt.xscale("log")

# plt.gca().legend(('Porosity','Vclay', 'Sw'))
plt.gca().legend(('Porosity','Vclay'))
plt.xlabel('1/Wavenumber')
plt.ylabel('Coherence')
plt.title('Training example')
plt.grid(b=False)

# %%
# Spectral coherence between true and predicted (test data)

sample_number = 12
Cxy_poro, wavenumber_poro = plt.cohere(Y_test_petro[sample_number,0,:], test_output_petro[sample_number,0,:], NFFT=16, Fs=1, color="blue")
Cxy_vclay, wavenumber_vclay = plt.cohere(Y_test_petro[sample_number,1,:], test_output_petro[sample_number,1,:], NFFT=16, Fs=1, color="red") 
# Cxy_sw, wavenumber_sw = plt.cohere(Y_test_petro[sample_number,2,:], test_output_petro[sample_number,2,:], NFFT=16, Fs=1, color="black")

# Adding epsilon to the first wavenumber value
wavenumber_poro[0] = wavenumber_poro[0] + 0.001
wavenumber_vclay[0] = wavenumber_vclay[0] + 0.001
# wavenumber_sw[0] = wavenumber_sw[0] + 0.001

plt.plot(1/wavenumber_poro, Cxy_poro, color="blue", linewidth=3)
plt.plot(1/wavenumber_vclay, Cxy_vclay, color="red", linewidth=3)
# plt.plot(1/wavenumber_sw, Cxy_sw, color="black")

plt.xlim(100,2)
plt.gca().invert_xaxis()
plt.xscale("log")

# plt.gca().legend(('Porosity','Vclay', 'Sw'))
plt.gca().legend(('Porosity','Vclay'))
plt.xlabel('1/Wavenumber')
plt.ylabel('Coherence')
plt.title('Test example')
plt.grid(b=False)

# %%
import scipy.signal as sp


# Checking training data (smoothed)

sample_number = 25
f, axarr = plt.subplots(1, 2, sharey = True, figsize=(6,8))

ker_width = 15

axarr[0].plot(sp.medfilt(train_output_petro[sample_number, 0, :],ker_width), depth, '-k', label='predicted', linewidth=3)
axarr[0].plot(sp.medfilt(Y_train_petro[sample_number, 0, :], ker_width), depth, '--r',  label='true', linewidth=3)
axarr[0].set_xlabel("Porosity [V/V]")
axarr[0].set_ylabel("Depth [meters]")
axarr[0].invert_yaxis()
axarr[0].set_xlim(0,0.4)
axarr[0].set_ylim(0,200)
axarr[0].legend(fontsize='small')

axarr[1].plot(sp.medfilt(train_output_petro[sample_number, 1, :], ker_width), depth, '-k', linewidth=3)
axarr[1].plot(sp.medfilt(Y_train_petro[sample_number, 1, :],ker_width), depth, '--r', linewidth=3)
axarr[1].set_xlabel("Vclay [V/V]")
# axarr[1].set_ylabel("Depth")
axarr[1].invert_yaxis()
axarr[1].set_xlim(0,1)
# Out:
# (0, 1)

# %%
por_corr_coeff_smooth_train = np.corrcoef(sp.medfilt(train_output_petro[sample_number, 0, :],ker_width),
                                                     sp.medfilt(Y_train_petro[sample_number, 0, :], ker_width))
                                          
vclay_corr_coeff_smooth_train = np.corrcoef(sp.medfilt(train_output_petro[sample_number, 1, :],ker_width),
                                                     sp.medfilt(Y_train_petro[sample_number, 1, :], ker_width))

print("Correlation coefficient between smoothed true and predicted porosity for training example = ", 
     '%.3f'%(por_corr_coeff_smooth_train[0,1]))
print("Correlation coefficient between smoothed true and predicted vclay for training example = ", 
     '%.3f'%(vclay_corr_coeff_smooth_train[0,1]))
# Out:
# Correlation coefficient between smoothed true and predicted porosity for training example =  0.921
# Correlation coefficient between smoothed true and predicted vclay for training example =  0.942

# %%
# Checking testing data (smoothed)

sample_number = 12
f, axarr = plt.subplots(1, 2, sharey = True, figsize=(6,8))

ker_width = 15

axarr[0].plot(sp.medfilt(test_output_petro[sample_number, 0, :],ker_width), depth, '-k', label='predicted', linewidth=3)
axarr[0].plot(sp.medfilt(Y_test_petro[sample_number, 0, :], ker_width), depth, '--r',  label='true', linewidth=3)
axarr[0].set_xlabel("Porosity [V/V]")
axarr[0].set_ylabel("Depth [meters]")
axarr[0].invert_yaxis()
axarr[0].set_xlim(0,0.4)
axarr[0].set_ylim(0,200)
axarr[0].legend(fontsize='small')

axarr[1].plot(sp.medfilt(test_output_petro[sample_number, 1, :],ker_width), depth, '-k', linewidth=3)
axarr[1].plot(sp.medfilt(Y_test_petro[sample_number, 1, :],ker_width), depth, '--r', linewidth=3)
axarr[1].set_xlabel("Vclay [V/V]")
# axarr[1].set_ylabel("Depth")
axarr[1].invert_yaxis()
axarr[1].set_xlim(0,1)
# Out:
# (0, 1)

# %%
por_corr_coeff_smooth_test = np.corrcoef(sp.medfilt(test_output_petro[sample_number, 0, :],ker_width),
                                                     sp.medfilt(Y_test_petro[sample_number, 0, :], ker_width))
                                          
vclay_corr_coeff_smooth_test = np.corrcoef(sp.medfilt(test_output_petro[sample_number, 1, :],ker_width),
                                                     sp.medfilt(Y_test_petro[sample_number, 1, :], ker_width))

print("Correlation coefficient between smoothed true and predicted porosity for test example = ", 
     '%.3f'%(por_corr_coeff_smooth_test[0,1]))
print("Correlation coefficient between smoothed true and predicted vclay for test example = ", 
     '%.3f'%(vclay_corr_coeff_smooth_test[0,1]))
# Out:
# Correlation coefficient between smoothed true and predicted porosity for test example =  0.813
# Correlation coefficient between smoothed true and predicted vclay for test example =  0.875

# %%
# Uncertainty estimation using dropout
class KerasDropoutPrediction(object):
    def __init__(self,model):
        self.f = K.function(
                [model.layers[0].input, 
                 K.learning_phase()],
                [model.layers[-1].output])
    def predict(self,x, n_iter=10):
        result = []
        for _ in range(n_iter):
            result.append(self.f([x , 1]))
#         result = np.array(result).reshape(n_iter,len(x)).T
        return result

# %%
# Uncertainty estimation for training data 

kdp = KerasDropoutPrediction(PetroModel)
nsim = 1000
Y_train_petro_uncertainty = np.array(kdp.predict(X_train_petro,nsim))
Y_train_petro_uncertainty_reshaped = np.reshape(
    Y_train_petro_uncertainty, (nsim, Y_train_petro.shape[0], Y_train_petro.shape[1], Y_train_petro.shape[2]))


Y_train_petro_uncertainty_reshaped_p50_norm = np.percentile(Y_train_petro_uncertainty_reshaped, 50, axis=0)
Y_train_petro_uncertainty_reshaped_p50 = Y_train_petro_uncertainty_reshaped_p50_norm
Y_train_petro_uncertainty_reshaped_p50[:,0,:] = Y_train_petro_uncertainty_reshaped_p50_norm[:,0,:]*(
    np.max(porosity) - np.min(porosity)) + np.min(porosity)

Y_train_petro_uncertainty_reshaped_p5_norm = np.percentile(Y_train_petro_uncertainty_reshaped, 5, axis=0)
Y_train_petro_uncertainty_reshaped_p5 = Y_train_petro_uncertainty_reshaped_p5_norm
Y_train_petro_uncertainty_reshaped_p5[:,0,:] = Y_train_petro_uncertainty_reshaped_p5_norm[:,0,:]*(
    np.max(porosity) - np.min(porosity)) + np.min(porosity)

Y_train_petro_uncertainty_reshaped_p95_norm = np.percentile(Y_train_petro_uncertainty_reshaped, 95, axis=0)
Y_train_petro_uncertainty_reshaped_p95 = Y_train_petro_uncertainty_reshaped_p95_norm
Y_train_petro_uncertainty_reshaped_p95[:,0,:] = Y_train_petro_uncertainty_reshaped_p95_norm[:,0,:]*(
    np.max(porosity) - np.min(porosity)) + np.min(porosity)

# %%
# Checking training data

sample_number = 25
f, axarr = plt.subplots(1, 2, sharey = True, figsize = (6,8))

# axarr[0].plot(train_output_petro[sample_number, 0, :], depth, '-k', label='predicted')
axarr[0].plot(Y_train_petro[sample_number, 0, :], depth, '-r', label='true', linewidth = 2)
axarr[0].plot(Y_train_petro_uncertainty_reshaped_p50[sample_number, 0, :], depth, '--k', label='p50', linewidth = 3)
axarr[0].plot(Y_train_petro_uncertainty_reshaped_p5[sample_number, 0, :], depth, '--b', label='p5', linewidth = 3)
axarr[0].plot(Y_train_petro_uncertainty_reshaped_p95[sample_number, 0, :], depth, '--b', label='p95', linewidth = 3)
axarr[0].set_xlabel("Porosity [V/V]")
axarr[0].set_ylabel("Depth [meters]")
axarr[0].invert_yaxis()
axarr[0].set_xlim(0,0.4)
axarr[0].set_ylim(0,200)
# axarr[0].legend(fontsize = 'small')

# axarr[1].plot(train_output_petro[sample_number, 1, :], depth, '-k')
axarr[1].plot(Y_train_petro[sample_number, 1, :], depth, '-r', linewidth = 2)
axarr[1].plot(Y_train_petro_uncertainty_reshaped_p50[sample_number, 1, :], depth, '--k', linewidth = 3)
axarr[1].plot(Y_train_petro_uncertainty_reshaped_p5[sample_number, 1, :], depth, '--b', linewidth = 3)
axarr[1].plot(Y_train_petro_uncertainty_reshaped_p95[sample_number, 1, :], depth, '--b', linewidth = 3)
axarr[1].set_xlabel("Vclay [V/V]")
# axarr[1].set_ylabel("Depth [meters]")
axarr[1].invert_yaxis()
axarr[1].set_xlim(0,1)
# Out:
# (0, 1)

# %%
# Posterior falsification for the training example 
sample_number = 25
ker_width = 15
true_data_poro = sp.medfilt(Y_train_petro[sample_number, 0, :], ker_width)
p95_data_poro = sp.medfilt(Y_train_petro_uncertainty_reshaped_p95[sample_number, 0, :], ker_width)
p5_data_poro = sp.medfilt(Y_train_petro_uncertainty_reshaped_p5[sample_number, 0, :], ker_width)

true_data_vclay = sp.medfilt(Y_train_petro[sample_number, 1, :], ker_width)
p95_data_vclay = sp.medfilt(Y_train_petro_uncertainty_reshaped_p95[sample_number, 1, :], ker_width)
p5_data_vclay = sp.medfilt(Y_train_petro_uncertainty_reshaped_p5[sample_number, 1, :], ker_width)

count_true_inside_confidence_poro = (true_data_poro >= p5_data_poro) & (true_data_poro <= p95_data_poro)
count_true_inside_confidence_vclay = (true_data_vclay >= p5_data_vclay) & (true_data_vclay <= p95_data_vclay)

print("Percentage data falling inside the range for porosity = ", 
     '%.3f'%(sum(count_true_inside_confidence_poro)/len(count_true_inside_confidence_poro)) )
print("Percentage data falling inside the range for vclay = ", 
     '%.3f'%(sum(count_true_inside_confidence_vclay)/len(count_true_inside_confidence_vclay)) )
# Out:
# Percentage data falling inside the range for porosity =  0.814
# Percentage data falling inside the range for vclay =  0.749

# %%
# Uncertainty estimation for test data 

kdp = KerasDropoutPrediction(PetroModel)
nsim = 1000
Y_test_petro_uncertainty = np.array(kdp.predict(X_test_petro,nsim))
Y_test_petro_uncertainty_reshaped = np.reshape(
    Y_test_petro_uncertainty, (nsim, Y_test_petro.shape[0], Y_test_petro.shape[1], Y_test_petro.shape[2]))


Y_test_petro_uncertainty_reshaped_p50_norm = np.percentile(Y_test_petro_uncertainty_reshaped, 50, axis=0)
Y_test_petro_uncertainty_reshaped_p50 = Y_test_petro_uncertainty_reshaped_p50_norm
Y_test_petro_uncertainty_reshaped_p50[:,0,:] = Y_test_petro_uncertainty_reshaped_p50_norm[:,0,:]*(
    np.max(porosity) - np.min(porosity)) + np.min(porosity)

Y_test_petro_uncertainty_reshaped_p5_norm = np.percentile(Y_test_petro_uncertainty_reshaped, 5, axis=0)
Y_test_petro_uncertainty_reshaped_p5 = Y_test_petro_uncertainty_reshaped_p5_norm
Y_test_petro_uncertainty_reshaped_p5[:,0,:] = Y_test_petro_uncertainty_reshaped_p5_norm[:,0,:]*(
    np.max(porosity) - np.min(porosity)) + np.min(porosity)

Y_test_petro_uncertainty_reshaped_p95_norm = np.percentile(Y_test_petro_uncertainty_reshaped, 95, axis=0)
Y_test_petro_uncertainty_reshaped_p95 = Y_test_petro_uncertainty_reshaped_p95_norm
Y_test_petro_uncertainty_reshaped_p95[:,0,:] = Y_test_petro_uncertainty_reshaped_p95_norm[:,0,:]*(
    np.max(porosity) - np.min(porosity)) + np.min(porosity)

# %%
# Checking testing data

sample_number = 12
f, axarr = plt.subplots(1, 2, sharey = True, figsize = (6,8))

# axarr[0].plot(test_output_petro[sample_number, 0, :], depth, '-k', label='predicted')
axarr[0].plot(Y_test_petro[sample_number, 0, :], depth, '-r', label='true', linewidth = 2)
axarr[0].plot(Y_test_petro_uncertainty_reshaped_p50[sample_number, 0, :], depth, '--k', label='p50', linewidth = 3)
axarr[0].plot(Y_test_petro_uncertainty_reshaped_p5[sample_number, 0, :], depth, '--b', label='p5', linewidth = 3)
axarr[0].plot(Y_test_petro_uncertainty_reshaped_p95[sample_number, 0, :], depth, '--b', label='p95', linewidth = 3)
axarr[0].set_xlabel("Porosity [V/V]")
axarr[0].set_ylabel("Depth [meters]")
axarr[0].invert_yaxis()
axarr[0].set_xlim(0,0.4)
axarr[0].set_ylim(0,200)
# axarr[0].legend(fontsize = 'small')

# axarr[1].plot(test_output_petro[sample_number, 1, :], depth, '-k')
axarr[1].plot(Y_test_petro[sample_number, 1, :], depth, '-r', linewidth = 2)
axarr[1].plot(Y_test_petro_uncertainty_reshaped_p50[sample_number, 1, :], depth, '--k', linewidth = 3)
axarr[1].plot(Y_test_petro_uncertainty_reshaped_p5[sample_number, 1, :], depth, '--b', linewidth = 3)
axarr[1].plot(Y_test_petro_uncertainty_reshaped_p95[sample_number, 1, :], depth, '--b', linewidth = 3)
axarr[1].set_xlabel("Vclay [V/V]")
# axarr[1].set_ylabel("Depth")
axarr[1].invert_yaxis()
axarr[1].set_xlim(0,1)
# Out:
# (0, 1)

# %%
# Posterior falsification for the test example 
sample_number = 12
ker_width = 15
true_data_poro = sp.medfilt(Y_test_petro[sample_number, 0, :], ker_width)
p95_data_poro = sp.medfilt(Y_test_petro_uncertainty_reshaped_p95[sample_number, 0, :], ker_width)
p5_data_poro = sp.medfilt(Y_test_petro_uncertainty_reshaped_p5[sample_number, 0, :], ker_width)

true_data_vclay = sp.medfilt(Y_test_petro[sample_number, 1, :], ker_width)
p95_data_vclay = sp.medfilt(Y_test_petro_uncertainty_reshaped_p95[sample_number, 1, :], ker_width)
p5_data_vclay = sp.medfilt(Y_test_petro_uncertainty_reshaped_p5[sample_number, 1, :], ker_width)

count_true_inside_confidence_poro = (true_data_poro >= p5_data_poro) & (true_data_poro <= p95_data_poro)
count_true_inside_confidence_vclay = (true_data_vclay >= p5_data_vclay) & (true_data_vclay <= p95_data_vclay)

print("Percentage data falling inside the range for porosity = ", 
     '%.3f'%(sum(count_true_inside_confidence_poro)/len(count_true_inside_confidence_poro)) )

print("Percentage data falling inside the range for vclay = ", 
     '%.3f'%(sum(count_true_inside_confidence_vclay)/len(count_true_inside_confidence_vclay)) )
# Out:
# Percentage data falling inside the range for porosity =  0.698
# Percentage data falling inside the range for vclay =  0.734
